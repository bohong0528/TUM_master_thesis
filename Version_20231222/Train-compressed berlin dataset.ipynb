# %%
import json
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsRegressor, KNeighborsClassifier
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder, MinMaxScaler, RobustScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso, RidgeCV, LassoCV, LogisticRegression, LogisticRegressionCV
from sklearn.svm import SVR, SVC
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, GradientBoostingClassifier, RandomForestClassifier
from sklearn.neural_network import MLPRegressor, MLPClassifier
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error, make_scorer, max_error, accuracy_score
from sklearn.model_selection import GridSearchCV, cross_val_score, KFold, RandomizedSearchCV, ShuffleSplit, cross_validate, train_test_split
from scipy.stats import expon, reciprocal, uniform
from sklearn.gaussian_process.kernels import RBF, WhiteKernel, DotProduct, ExpSineSquared, RationalQuadratic, ConstantKernel, Matern
from sklearn.feature_selection import RFE, SelectFromModel, RFECV, SelectKBest, chi2, f_regression
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline, Pipeline
from mango import Tuner, scheduler
import xgboost as xgb
from skopt  import BayesSearchCV 
import lightgbm as lgb
from sklearn.cluster import OPTICS, MiniBatchKMeans
from pyGRNN import GRNN
from skopt.space import Categorical, Space, Dimension, Integer
from sklearn.inspection import permutation_importance
from optuna.integration import OptunaSearchCV
import optuna
import matplotlib.pyplot as plt
from loading import load_data

# %% [markdown]
# ## Parameter setting

# %%
numerical_features = ['start_node_x', 'start_node_y', 'end_node_x', 'end_node_y', 'link_length', 'link_freespeed', 
                      'link_capacity', 'link_permlanes', 'start_count', 'end_count', 'go_to_sum', 'rush_hour', 
                      'max_dur', 'cemdapStopDuration_s', 'length_per_capacity_ratio', 'speed_capacity_ratio',
                      'length_times_lanes', 'speed_times_capacity', 'link_times', 'capacity_divided_by_lanes',
                      'income', 'score', 'income_avg', 'score_avg'
                     ]
category_feature = ['type', 'home-activity-zone']
scaler = StandardScaler()
le = LabelEncoder()
ohe = OneHotEncoder(sparse_output=False)
ct = ColumnTransformer(
     [("num_preprocess", scaler, numerical_features),
      ("text_preprocess", ohe, category_feature)], remainder='passthrough').set_output(transform="pandas")
clf = {
    'KNN': KNeighborsClassifier(),
#     'XGB': xgb.XGBClassifier(random_state=101),
    'LGBM': lgb.LGBMClassifier(random_state=101, verbose=-1),
    'RF': RandomForestClassifier(random_state=101),
#     'GB': GradientBoostingClassifier(random_state=101),
#     'ANN': MLPClassifier(random_state=101)
}

model_space = {
    'KNN': KNeighborsRegressor(),
    'XGB': xgb.XGBRegressor(random_state=101),
    'LGBM': lgb.LGBMRegressor(random_state=101, verbose=-1),
    'RF': RandomForestRegressor(random_state=101),
    'GB': GradientBoostingRegressor(random_state=101),
    'ANN': MLPRegressor(random_state=101),
    'GPR': GaussianProcessRegressor(copy_X_train=False, random_state=101),
#     'SVR': SVR()
}
model_space_feature = {
    'SVR': RandomForestRegressor(random_state=101),
    'KNN': RandomForestRegressor(random_state=101),
    'XGB': xgb.XGBRegressor(random_state=101),
    'LGBM': lgb.LGBMRegressor(random_state=101, verbose=-1),
    'RF': RandomForestRegressor(random_state=101),
    'GB': GradientBoostingRegressor(random_state=101),
    'ANN': RandomForestRegressor(random_state=101),
    # 'GRNN': RandomForestRegressor(random_state=101)
}
param_space = {
'SVR': {
    "C": optuna.distributions.FloatDistribution(1e-5, 1e5),
    'gamma': optuna.distributions.CategoricalDistribution(['scale', 'auto']), 
    'kernel': optuna.distributions.CategoricalDistribution(['linear', 'poly', 'rbf', 'sigmoid']),  
    # 'epsilon': optuna.distributions.FloatDistribution(0.01, 1),  
},
'RF':  {
    'max_features': optuna.distributions.CategoricalDistribution(['sqrt', 'log2']),
    'n_estimators': optuna.distributions.IntDistribution(50, 501, 50),
    'max_depth': optuna.distributions.IntDistribution(1, 200),
    'min_samples_leaf': optuna.distributions.IntDistribution(1, 20),
    # 'criterion': Categorical(['absolute_error', 'friedman_mse'])
},
'GB':{
    'learning_rate': optuna.distributions.FloatDistribution(0.01, 1.0),
    'n_estimators': optuna.distributions.IntDistribution(50, 501, 50),
    'max_depth': optuna.distributions.IntDistribution(1, 200),
    'min_samples_split': optuna.distributions.IntDistribution(2, 11),
    'min_samples_leaf': optuna.distributions.IntDistribution(1, 10),
    'subsample': optuna.distributions.FloatDistribution(0.1, 1.0),
},
'ANN': {
    'hidden_layer_sizes': optuna.distributions.CategoricalDistribution([(100,), (50,), (50, 50), (100, 100), (30, 30, 30)]),
    'activation': optuna.distributions.CategoricalDistribution(['tanh', 'relu', 'identity', 'logistic']),
    'solver': optuna.distributions.CategoricalDistribution(['sgd', 'adam']),
    'alpha': optuna.distributions.FloatDistribution(1e-5, 1e5, log=True),
},
'KNN':{
    'n_neighbors': optuna.distributions.IntDistribution(1, 50),
    'weights': optuna.distributions.CategoricalDistribution(['uniform', 'distance']),
    'algorithm': optuna.distributions.CategoricalDistribution(['auto', 'ball_tree', 'kd_tree', 'brute'])
},    
'LGBM': {
    'learning_rate': optuna.distributions.FloatDistribution(0.01, 1.0),
    'n_estimators': optuna.distributions.IntDistribution(50, 501, 50),
    'max_depth': optuna.distributions.IntDistribution(1, 50),
    'num_leaves': optuna.distributions.IntDistribution(2, 50),
    'min_child_samples': optuna.distributions.IntDistribution(1, 20),
    'subsample': optuna.distributions.FloatDistribution(0.1, 1.0),
    'colsample_bytree': optuna.distributions.FloatDistribution(0.1, 1.0),
},
'XGB': {
    'learning_rate': optuna.distributions.FloatDistribution(0.01, 1.0),
    'n_estimators': optuna.distributions.IntDistribution(50, 501, 50),
    'max_depth': optuna.distributions.IntDistribution(1, 20),
    'max_leaves': optuna.distributions.IntDistribution(2, 50),
    'max_bin': optuna.distributions.IntDistribution(2, 50),
    'gamma': optuna.distributions.IntDistribution(1, 20),
},
'GPR':{
    'kernel': optuna.distributions.CategoricalDistribution([0.1**2 * RBF(length_scale=0.1) + 
                                    WhiteKernel(noise_level=0.1**2, noise_level_bounds=(1e-5, 1e5)), 
                                    0.5**2 * RationalQuadratic(length_scale=1.0, alpha=1.0),
                                    50.0**2 * RBF(length_scale=50.0), DotProduct() + WhiteKernel(), 
                                    1.0 * Matern(length_scale=1.0, nu=1.5),
                                    RBF() + ConstantKernel(constant_value=2)
                                                           ]),
    'alpha':  optuna.distributions.FloatDistribution(1e-15, 1e10)
}
}

# %% [markdown]
# ## Load data

# %%
train_files = ['s-0.json', 's-1.json', 's-2.json', 's-3.json', 's-4.json','s-5.json', 's-6.json', 's-7.json', 's-8.json', 's-9.json'] 
test_files = ['s-15.json', 's-16.json', 's-17.json', 's-18.json','s-19.json']
validate_files = ['s-10.json', 's-11.json', 's-12.json', 's-13.json','s-14.json']
train_files = ['Data/cutoutWorlds/Train/po-1_pn-1.0_sn-1/' + i for i in train_files]
test_files = ['Data/cutoutWorlds/Test/po-1_pn-1.0_sn-1/' + j for j in test_files]
validate_files = ['Data/cutoutWorlds/Validate/po-1_pn-1.0_sn-1/' + k for k in validate_files]
df_activities = pd.read_pickle("Data/cutoutWorlds/Train/po-1_pn-1.0_sn-1/df_activities.pkl")
df_links_network = pd.read_pickle("Data/cutoutWorlds/Train/po-1_pn-1.0_sn-1/df_links_network.pkl")
train_data = load_data(train_files, df_activities, df_links_network)
validate_data = load_data(validate_files, df_activities, df_links_network)
test_data = load_data(test_files, df_activities, df_links_network)
train_data['dataset'] = 'train'
validate_data['dataset'] = 'validate'
test_data['dataset'] = 'test'
Big_data = pd.concat([train_data, validate_data, test_data], ignore_index=True)

# %% [markdown]
# ## Find the shortest path

# %%
# Find the indices where 'link_id' is 0
indices = Big_data.index[Big_data['link_id'] == 0].tolist()

# Add the end of the DataFrame to the indices list
indices.append(len(Big_data))

# Split the DataFrame using the indices
dfs = [Big_data.iloc[indices[n]:indices[n+1]] for n in range(len(indices)-1)]

# %%
list_od = []
list_nodes = []
all_files = train_files + validate_files + test_files
for i in all_files:
    with open(i) as f:
        d = json.load(f)
        list_od.append(d['o_d_pairs'])
        list_nodes.append(d['nodes_id'])
tuples_links = [ list(zip(dfs[i]['link_from'], dfs[i]['link_to'], dfs[i]['link_length'])) for i in range(20)]
list_od_tuples = [[(origin, destination) for origin, destination in list_od[i]]for i in range(20)]

# %%
import networkx as nx
shortest_paths_list = []
for i in range(20):
    G = nx.Graph()
    G.add_nodes_from(list_nodes[i])
    G.add_weighted_edges_from(tuples_links[i])
    shortest_paths = {}
    for origin, destination in list_od_tuples[i]:
        # This will find the shortest path by weight
        try:
            shortest_path = nx.shortest_path(G, source=origin, target=destination, weight='weight')
        except:
            shortest_path = []
        shortest_paths[(origin, destination)] = shortest_path
    shortest_paths_list.append(shortest_paths)

# %%
from collections import defaultdict
for i in range(20):
    link_usage_counts = defaultdict(int)

    # Iterate over each path and each link in the path
    for path in shortest_paths_list[i].values():
        for start_node, end_node in zip(path, path[1:]):
            # Order the nodes to avoid counting (node1, node2) and (node2, node1) separately
            ordered_link = tuple(sorted((start_node, end_node)))
            link_usage_counts[ordered_link] += 1

    # Now you have a dictionary with the count of usage for each link

    # Assume you have a DataFrame 'links_df' with columns ['node_start', 'node_end']
    # links_df = ...

    # Add a 'used_count' column to your links data
    dfs[i]['used_count'] = dfs[i].apply(
        lambda row: link_usage_counts[tuple(sorted((row['link_from'], row['link_to'])))],
        axis=1
    )

# %%
Big_data = pd.concat(dfs)
nodes_data = Big_data[['link_id', 'start_node_x', 'start_node_y', 'end_node_x', 'end_node_y']]
grouped = nodes_data.groupby(['start_node_x', 'start_node_y'])
filtered_df = grouped.filter(lambda x: len(x) == 1)
filtered_df = filtered_df.drop_duplicates()
node_mapping = filtered_df.set_index(['start_node_x', 'start_node_y']).apply(
    lambda row: (row['end_node_x'], row['end_node_y']), axis=1).to_dict()

all_nodes = set(node_mapping.keys()) | set(node_mapping.values())
end_nodes = set(node_mapping.values())

start_nodes = list(all_nodes - end_nodes)

paths = []
for start_node in start_nodes:
    path = [start_node]
    while path[-1] in node_mapping:
        next_node = node_mapping[path[-1]]
        path.append(next_node)
    paths.append(path)
    
new_paths = [x for x in paths if len(x) >2]
def map_path_to_links(df, path):
    path_links = pd.DataFrame()
    for i in range(len(path) - 1):
        start_node = path[i]
        end_node = path[i+1]
        link_row = df[(df['start_node_x'] == start_node[0]) & 
                      (df['start_node_y'] == start_node[1]) & 
                      (df['end_node_x'] == end_node[0]) & 
                      (df['end_node_y'] == end_node[1])]
        if not link_row.empty:
            path_links = pd.concat([path_links, link_row])
    return path_links

# Step 3: Create separate DataFrames for each path
path_dfs = []
for path in new_paths:
    link_df = map_path_to_links(Big_data, path)
    path_dfs.append(link_df)

Big_data_drop = Big_data.copy(deep=True)
for path_df in path_dfs:
    numeric_df = path_df.select_dtypes(include=[ 'float64', 'int64'])
    column_means = numeric_df.mean()
    mean_df = pd.DataFrame([column_means])
    zone = path_df['home-activity-zone'].mode()
    type_value = path_df['type'].mode()
    dataset = path_df['dataset'].mode()
    mean_df['home-activity-zone'] = zone
    mean_df['type'] = type_value
    mean_df['dataset'] = dataset
    Big_data_drop = pd.concat([Big_data_drop, mean_df])

    try:
        Big_data_drop.drop(path_df.index, inplace=True)
    except:
        pass

# %% [markdown]
# ## Clustering

# %%
cluster = MiniBatchKMeans(n_clusters=500, random_state=101)
Big_data_drop['x_y_coor'] = cluster.fit_predict(Big_data_drop[['start_node_x', 'start_node_y',
                                                           'end_node_x', 'end_node_y']])
cluster1 = MiniBatchKMeans(n_clusters=500, random_state=101)
Big_data_drop['similar_link'] = cluster1.fit_predict(Big_data_drop[['link_length', 'link_freespeed',
                                                           'link_capacity', 'link_permlanes']])
cluster2 = MiniBatchKMeans(n_clusters=500, random_state=101)
Big_data_drop['planxml'] = cluster2.fit_predict(Big_data_drop[['income', 'score', 'rush_hour',
                                                               'max_dur', 'cemdapStopDuration_s']])

Big_data_drop = Big_data_drop.astype({'x_y_coor':'int64','similar_link':'int64', 'planxml':'int64'})

# %%
train_data_drop = Big_data_drop[Big_data_drop['dataset']=='train']
validate_data_drop = Big_data_drop[Big_data_drop['dataset']=='validate']
test_data_drop = Big_data_drop[Big_data_drop['dataset']=='test']

# %% [markdown]
# ## Create compressed berlin dataset

# %%
# change the column name for  xy coordinate
column_name = 'similar_link'
train_data_edit = pd.DataFrame()
for i in list(set(train_data_drop[column_name].tolist())):
    new_train = train_data_drop[train_data_drop[column_name]==i]
    numeric_df = new_train.select_dtypes(include=[ 'float64', 'int64'])
    column_means = numeric_df.mean()
    mean_df = pd.DataFrame([column_means])
    zone = new_train['home-activity-zone'].mode()
    type_value = new_train['type'].mode()
    dataset = new_train['dataset'].mode()
    mean_df['home-activity-zone'] = zone
    mean_df['type'] = type_value
    mean_df['dataset'] = dataset
    train_data_edit = pd.concat([train_data_edit, mean_df], ignore_index=True)
    
validate_data_edit = pd.DataFrame()
for i in list(set(validate_data_drop[column_name].tolist())):
    new_validate = validate_data_drop[validate_data_drop[column_name]==i]
    numeric_df = new_validate.select_dtypes(include=[ 'float64', 'int64'])
    column_means = numeric_df.mean()
    mean_df = pd.DataFrame([column_means])
    zone = new_validate['home-activity-zone'].mode()
    type_value = new_validate['type'].mode()
    dataset = new_validate['dataset'].mode()
    mean_df['home-activity-zone'] = zone
    mean_df['type'] = type_value
    mean_df['dataset'] = dataset
    validate_data_edit = pd.concat([validate_data_edit, mean_df], ignore_index=True)

Big_data_edit = pd.concat([train_data_edit, validate_data_edit, test_data_drop], ignore_index=True)
Big_data_edit = Big_data_edit.astype({column_name:'int64'})

# %%
Big_data_tr = ct.fit_transform(Big_data_edit)
Big_data_tr['used_link'] = 1
Big_data_tr['used_link'][Big_data_tr['remainder__link_counts']==0] = 0
Big_data_tr = Big_data_tr.reset_index(drop=True)
train_data_tr = Big_data_tr[Big_data_tr['remainder__dataset']=='train']
validate_data_tr = Big_data_tr[Big_data_tr['remainder__dataset']=='validate']
test_data_tr = Big_data_tr[Big_data_tr['remainder__dataset']=='test']

train_index = list(train_data_tr.index)
validate_index = list(validate_data_tr.index)

temp = pd.concat([train_data_tr, validate_data_tr], ignore_index=True)

# %%
X_t_feature = temp.drop(columns=['remainder__dataset', 'remainder__link_counts', 'used_link', 'remainder__link_id',
                                 'remainder__link_from', 'remainder__link_to', 'num_preprocess__start_node_x', 'num_preprocess__start_node_y',
                                'num_preprocess__end_node_x', 'num_preprocess__end_node_y', 
                                 'num_preprocess__capacity_divided_by_lanes', 'num_preprocess__score_avg', 'num_preprocess__income_avg',
                                 'num_preprocess__length_per_capacity_ratio', 'num_preprocess__length_times_lanes', 'num_preprocess__speed_times_capacity'
                                ])
correlation_matrix = X_t_feature.corr()


# Find the most correlated feature for each feature, excluding itself
most_correlated = correlation_matrix.apply(lambda x: x.index[x.abs()[x.index != x.name].argmax()], axis=1)

# Create a DataFrame to store the most correlated features
corr_table = pd.DataFrame({'Feature': correlation_matrix.columns, 'Most Correlated': most_correlated})

# Add a column to show the correlation value
corr_table['Correlation Value'] = corr_table.apply(lambda x: correlation_matrix.loc[x['Feature'], x['Most Correlated']], axis=1)

new_corr_table = corr_table.sort_values(by='Correlation Value', ascending=False).reset_index(drop=True)
new_corr_table[(new_corr_table['Correlation Value'].abs()>=0.8) & (new_corr_table['Correlation Value'].abs() !=1)]
# Out:
#                                 Feature                Most Correlated  \
# 3                 num_preprocess__score         num_preprocess__income
# 4  num_preprocess__cemdapStopDuration_s         num_preprocess__income
# 5        num_preprocess__link_permlanes  num_preprocess__link_capacity
#
#    Correlation Value
# 3           0.989629
# 4           0.908351
# 5           0.844500

# %%
temp = temp.drop(columns=['remainder__link_id', 'remainder__link_from', 'remainder__link_to',
                                  'num_preprocess__start_node_x', 'num_preprocess__start_node_y',
                                'num_preprocess__end_node_x', 'num_preprocess__end_node_y', 
                                 'num_preprocess__capacity_divided_by_lanes', 'num_preprocess__score_avg', 'num_preprocess__income_avg',
                                 'num_preprocess__length_per_capacity_ratio', 'num_preprocess__length_times_lanes', 'num_preprocess__speed_times_capacity'])
test_data_tr = test_data_tr.drop(columns=['remainder__link_id', 'remainder__link_from', 'remainder__link_to',
                                  'num_preprocess__start_node_x', 'num_preprocess__start_node_y',
                                'num_preprocess__end_node_x', 'num_preprocess__end_node_y', 
                                 'num_preprocess__capacity_divided_by_lanes', 'num_preprocess__score_avg', 'num_preprocess__income_avg',
                                 'num_preprocess__length_per_capacity_ratio', 'num_preprocess__length_times_lanes', 'num_preprocess__speed_times_capacity'])

# %% [markdown]
# # Classification and regression

# %%
X_t_clf = temp.drop(columns=['remainder__dataset', 'remainder__link_counts', 'used_link'])
y_t_clf = temp['used_link']

X_te_clf = test_data_tr.drop(columns=['remainder__dataset', 'remainder__link_counts', 'used_link'])
y_te_clf = test_data_tr['used_link']

# %%
best_model_clf = {}
for model_name in clf.keys():   
    model = clf[model_name]
    pipeline  = Pipeline([('selector', SelectKBest(f_regression)),
                  ('model', model)])
    param_grid = {}
    param_grid['selector__k']=optuna.distributions.IntDistribution(2, len(X_t_clf.columns))
    for key in param_space[model_name].keys():
        param_grid[f'model__{key}']=param_space[model_name][key]
    
    # BayesSearchCV
    opt = OptunaSearchCV(
        pipeline,
        param_grid,
        n_trials=50,
        cv=[(train_index, validate_index), (train_index, validate_index)]
    )
    opt.fit(X_t_clf, y_t_clf)
    y_pred_clf = opt.predict(X_te_clf)
    best_model_clf[model_name] = [opt, opt.best_score_, y_pred_clf]
    print(model_name, opt.best_score_, accuracy_score(y_te_clf, y_pred_clf))
# Out:
# [I 2024-06-14 16:53:42,899] A new study created in memory with name: no-name-0ffb1b2a-c633-440c-97e8-1758eb5ec7f8
# [I 2024-06-14 16:53:43,003] Trial 0 finished with value: 0.9936974789915967 and parameters: {'selector__k': 29, 'model__n_neighbors': 1, 'model__weights': 'distance', 'model__algorithm': 'auto'}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:43,053] Trial 1 finished with value: 0.9936974789915967 and parameters: {'selector__k': 25, 'model__n_neighbors': 37, 'model__weights': 'distance', 'model__algorithm': 'kd_tree'}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:43,116] Trial 2 finished with value: 0.9936974789915967 and parameters: {'selector__k': 23, 'model__n_neighbors': 39, 'model__weights': 'uniform', 'model__algorithm': 'ball_tree'}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:43
 'model__weights': 'distance', 'model__algorithm': 'auto'}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:45,018] Trial 37 finished with value: 0.9936974789915967 and parameters: {'selector__k': 26, 'model__n_neighbors': 3, 'model__weights': 'distance', 'model__algorithm': 'kd_tree'}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:45,076] Trial 38 finished with value: 0.9936974789915967 and parameters: {'selector__k': 31, 'model__n_neighbors': 9, 'model__weights': 'distance', 'model__algorithm': 'ball_tree'}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:45,150] Trial 39 finished with value: 0.9936974789915967 and parameters: {'selector__k': 29, 'model__n_neighbors': 44, 'model__weights': 'uniform', 'model__algorithm': 'brute'}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:45,202] Trial 40 finished with value: 0.9936974789915967 and parameters: {'selector__k': 26, 'model__n_neighbors': 21, 'model__weights': 'distance', 'model__algorithm': 'auto'}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:45,248] Trial 41 finished with value: 0.9936974789915967 and parameters: {'selector__k': 14, 'model__n_neighbors': 42, 'model__weights': 'distance', 'model__algorithm': 'kd_tree'}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:45,294] Trial 42 finished with value: 0.9936974789915967 and parameters: {'selector__k': 9, 'model__n_neighbors': 38, 'model__weights': 'distance', 'model__algorithm': 'kd_tree'}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:45,349] Trial 43 finished with value: 0.9936974789915967 and parameters: {'selector__k': 18, 'model__n_neighbors': 46, 'model__weights': 'distance', 'model__algorithm': 'kd_tree'}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:45,404] Trial 44 finished with value: 0.9936974789915967 and parameters: {'selector__k': 9, 'model__n_neighbors': 35, 'model__weights': 'distance', 'model__algorithm': 'kd_tree'}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:45,465] Trial 45 finished with value: 0.9936974789915967 and parameters: {'selector__k': 22, 'model__n_neighbors': 33, 'model__weights': 'distance', 'model__algorithm': 'kd_tree'}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:45,520] Trial 46 finished with value: 0.9936974789915967 and parameters: {'selector__k': 24, 'model__n_neighbors': 48, 'model__weights': 'distance', 'model__algorithm': 'auto'}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:45,593] Trial 47 finished with value: 0.9936974789915967 and parameters: {'selector__k': 20, 'model__n_neighbors': 30, 'model__weights': 'uniform', 'model__algorithm': 'brute'}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:45,636] Trial 48 finished with value: 0.9936974789915967 and parameters: {'selector__k': 22, 'model__n_neighbors': 7, 'model__weights': 'distance', 'model__algorithm': 'kd_tree'}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:45,683] Trial 49 finished with value: 0.9936974789915967 and parameters: {'selector__k': 15, 'model__n_neighbors': 40, 'model__weights': 'distance', 'model__algorithm': 'ball_tree'}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:45,723] A new study created in memory with name: no-name-b0f6a714-4fd6-45c7-802d-89bf2e3cdfc6
# [I 2024-06-14 16:53:45,760] Trial 0 finished with value: 0.9936974789915967 and parameters: {'selector__k': 20, 'model__learning_rate': 0.34196622395858506, 'model__n_estimators': 179, 'model__max_depth': 41, 'model__num_leaves': 31, 'model__min_child_samples': 11, 'model__subsample': 0.7488772456456018, 'model__colsample_bytree': 0.9446819946194527}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:45,795] Trial 1 finished with value: 0.9936974789915967 and parameters: {'selector__k': 16, 'model__learning_rate': 0.16206511637286034, 'model__n_estimators': 90, 'model__max_depth': 41, 'model__num_leaves': 19, 'model__min_child_samples': 13, 'model__subsample': 0.20720798492248188, 'model__colsample_bytree': 0.4760024967050902}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:45,830] Trial 2 finished with value: 0.9936974789915967 and parameters: {'selector__k': 8, 'model__learning_rate': 0.7767240104065148, 'model__n_estimators': 62, 'model__max_depth': 34, 'model__num_leaves': 2, 'model__min_child_samples': 1, 'model__subsample': 0.22138555976132723, 'model__colsample_bytree': 0.9908749379071398}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:45,865] Trial 3 finished with value: 0.9936974789915967 and parameters: {'selector__k': 12, 'model__learning_rate': 0.05104749050232192, 'model__n_estimators': 191, 'model__max_depth': 37, 'model__num_leaves': 36, 'model__min_child_samples': 16, 'model__subsample': 0.13141246921145674, 'model__colsample_bytree': 0.20305402029440803}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:45,901] Trial 4 finished with value: 0.9936974789915967 and parameters: {'selector__k': 34, 'model__learning_rate': 0.7799791313917217, 'model__n_estimators': 102, 'model__max_depth': 19, 'model__num_leaves': 4, 'model__min_child_samples': 14, 'model__subsample': 0.5550369273056743, 'model__colsample_bytree': 0.23332813140913605}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:45,937] Trial 5 finished with value: 0.9936974789915967 and parameters: {'selector__k': 12, 'model__learning_rate': 0.13302390469891123, 'model__n_estimators': 313, 'model__max_depth': 29, 'model__num_leaves': 22, 'model__min_child_samples': 17, 'model__subsample': 0.3928552552819129, 'model__colsample_bytree': 0.9943857589699076}. Best is trial 0 with value: 0.9936974789915967.
# KNN 0.9936974789915967 0.8437458897803498
# [I 2024-06-14 16:53:45,975] Trial 6 finished with value: 0.9936974789915967 and parameters: {'selector__k': 16, 'model__learning_rate': 0.7718625538244588, 'model__n_estimators': 204, 'model__max_depth': 41, 'model__num_leaves': 47, 'model__min_child_samples': 18, 'model__subsample': 0.19851419236944068, 'model__colsample_bytree': 0.5318322254620497}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:46,012] Trial 7 finished with value: 0.9936974789915967 and parameters: {'selector__k': 10, 'model__learning_rate': 0.12558381311756836, 'model__n_estimators': 413, 'model__max_depth': 47, 'model__num_leaves': 6, 'model__min_child_samples': 10, 'model__subsample': 0.19961489256185874, 'model__colsample_bytree': 0.4590095777727201}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:46,053] Trial 8 finished with value: 0.9936974789915967 and parameters: {'selector__k': 24, 'model__learning_rate': 0.3616164229378845, 'model__n_estimators': 315, 'model__max_depth': 30, 'model__num_leaves': 23, 'model__min_child_samples': 14, 'model__subsample': 0.8736873117372211, 'model__colsample_bytree': 0.602427008526293}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:46,086] Trial 9 finished with value: 0.9936974789915967 and parameters: {'selector__k': 26, 'model__learning_rate': 0.2182747402030168, 'model__n_estimators': 210, 'model__max_depth': 10, 'model__num_leaves': 50, 'model__min_child_samples': 13, 'model__subsample': 0.41676249201971083, 'model__colsample_bytree': 0.5840193767809921}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:46,146] Trial 10 finished with value: 0.9936974789915967 and parameters: {'selector__k': 3, 'model__learning_rate': 0.5727753296677285, 'model__n_estimators': 120, 'model__max_depth': 19, 'model__num_leaves': 34, 'model__min_child_samples': 7, 'model__subsample': 0.8874085560196453, 'model__colsample_bytree': 0.7953925629988674}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:46,208] Trial 11 finished with value: 0.9936974789915967 and parameters: {'selector__k': 21, 'model__learning_rate': 0.3581907802905674, 'model__n_estimators': 72, 'model__max_depth': 49, 'model__num_leaves': 16, 'model__min_child_samples': 8, 'model__subsample': 0.6800932089508624, 'model__colsample_bytree': 0.3966844994629801}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:46,272] Trial 12 finished with value: 0.9936974789915967 and parameters: {'selector__k': 18, 'model__learning_rate': 0.48127153204751727, 'model__n_estimators': 125, 'model__max_depth': 41, 'model__num_leaves': 34, 'model__min_child_samples': 6, 'model__subsample': 0.7386612430285517, 'model__colsample_bytree': 0.7422588914239077}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:46,339] Trial 13 finished with value: 0.9936974789915967 and parameters: {'selector__k': 29, 'model__learning_rate': 0.2891600504614767, 'model__n_estimators': 81, 'model__max_depth': 22, 'model__num_leaves': 17, 'model__min_child_samples': 20, 'model__subsample': 0.6245922076182262, 'model__colsample_bytree': 0.3466113446740604}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:46,405] Trial 14 finished with value: 0.9936974789915967 and parameters: {'selector__k': 16, 'model__learning_rate': 0.9933000984104614, 'model__n_estimators': 50, 'model__max_depth': 43, 'model__num_leaves': 29, 'model__min_child_samples': 11, 'model__subsample': 0.37482273354951984, 'model__colsample_bytree': 0.7595670172508728}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:46,472] Trial 15 finished with value: 0.9936974789915967 and parameters: {'selector__k': 22, 'model__learning_rate': 0.4644891304474568, 'model__n_estimators': 156, 'model__max_depth': 2, 'model__num_leaves': 12, 'model__min_child_samples': 11, 'model__subsample': 0.998682917824746, 'model__colsample_bytree': 0.11136948823608245}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:46,542] Trial 16 finished with value: 0.9936974789915967 and parameters: {'selector__k': 29, 'model__learning_rate': 0.01790346184293856, 'model__n_estimators': 104, 'model__max_depth': 36, 'model__num_leaves': 42, 'model__min_child_samples': 4, 'model__subsample': 0.7749780246520273, 'model__colsample_bytree': 0.8300749248252954}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:46,620] Trial 17 finished with value: 0.9936974789915967 and parameters: {'selector__k': 5, 'model__learning_rate': 0.5862479192048141, 'model__n_estimators': 159, 'model__max_depth': 49, 'model__num_leaves': 28, 'model__min_child_samples': 9, 'model__subsample': 0.5086233345070778, 'model__colsample_bytree': 0.9044644705409703}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:46,701] Trial 18 finished with value: 0.9936974789915967 and parameters: {'selector__k': 15, 'model__learning_rate': 0.2320546772868879, 'model__n_estimators': 281, 'model__max_depth': 31, 'model__num_leaves': 11, 'model__min_child_samples': 12, 'model__subsample': 0.3175212374563065, 'model__colsample_bytree': 0.6764204335114554}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:46,775] Trial 19 finished with value: 0.9936974789915967 and parameters: {'selector__k': 20, 'model__learning_rate': 0.4188049622501545, 'model__n_estimators': 496, 'model__max_depth': 42, 'model__num_leaves': 40, 'model__min_child_samples': 15, 'model__subsample': 0.5048563133064052, 'model__colsample_bytree': 0.4799668182143866}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:46,844] Trial 20 finished with value: 0.9936974789915967 and parameters: {'selector__k': 28, 'model__learning_rate': 0.15870400539876184, 'model__n_estimators': 92, 'model__max_depth': 25, 'model__num_leaves': 21, 'model__min_child_samples': 4, 'model__subsample': 0.610271949754436, 'model__colsample_bytree': 0.6652443361912654}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:46,922] Trial 21 finished with value: 0.9936974789915967 and parameters: {'selector__k': 8, 'model__learning_rate': 0.7069935493227565, 'model__n_estimators': 58, 'model__max_depth': 35, 'model__num_leaves': 9, 'model__min_child_samples': 2, 'model__subsample': 0.24763395702501909, 'model__colsample_bytree': 0.9985728701365689}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:47,000] Trial 22 finished with value: 0.9936974789915967 and parameters: {'selector__k': 7, 'model__learning_rate': 0.6497832543352106, 'model__n_estimators': 68, 'model__max_depth': 34, 'model__num_leaves': 3, 'model__min_child_samples': 2, 'model__subsample': 0.10565106565138631, 'model__colsample_bytree': 0.9179040590133445}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:47,077] Trial 23 finished with value: 0.9936974789915967 and parameters: {'selector__k': 11, 'model__learning_rate': 0.8978687033275554, 'model__n_estimators': 60, 'model__max_depth': 45, 'model__num_leaves': 17, 'model__min_child_samples': 5, 'model__subsample': 0.27706203183844963, 'model__colsample_bytree': 0.9048106082667033}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:47,147] Trial 24 finished with value: 0.9936974789915967 and parameters: {'selector__k': 2, 'model__learning_rate': 0.34063311871972995, 'model__n_estimators': 83, 'model__max_depth': 39, 'model__num_leaves': 29, 'model__min_child_samples': 9, 'model__subsample': 0.45730256774785316, 'model__colsample_bytree': 0.3336824978709323}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:47,214] Trial 25 finished with value: 0.9936974789915967 and parameters: {'selector__k': 14, 'model__learning_rate': 0.2402944382521696, 'model__n_estimators': 140, 'model__max_depth': 33, 'model__num_leaves': 26, 'model__min_child_samples': 13, 'model__subsample': 0.3406150763795967, 'model__colsample_bytree': 0.8513981028888904}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:47,283] Trial 26 finished with value: 0.9936974789915967 and parameters: {'selector__k': 18, 'model__learning_rate': 0.8762470178535708, 'model__n_estimators': 248, 'model__max_depth': 27, 'model__num_leaves': 7, 'model__min_child_samples': 12, 'model__subsample': 0.18336847673465678, 'model__colsample_bytree': 0.6906386354014753}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:47,349] Trial 27 finished with value: 0.9936974789915967 and parameters: {'selector__k': 8, 'model__learning_rate': 0.5727471122224013, 'model__n_estimators': 50, 'model__max_depth': 38, 'model__num_leaves': 14, 'model__min_child_samples': 1, 'model__subsample': 0.8420520561773565, 'model__colsample_bytree': 0.9328727011526876}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:47,418] Trial 28 finished with value: 0.9936974789915967 and parameters: {'selector__k': 24, 'model__learning_rate': 0.41196794059894054, 'model__n_estimators': 70, 'model__max_depth': 45, 'model__num_leaves': 20, 'model__min_child_samples': 19, 'model__subsample': 0.6944886557104659, 'model__colsample_bytree': 0.44754793096367523}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:47,487] Trial 29 finished with value: 0.9936974789915967 and parameters: {'selector__k': 14, 'model__learning_rate': 0.08262649465091931, 'model__n_estimators': 118, 'model__max_depth': 38, 'model__num_leaves': 38, 'model__min_child_samples': 16, 'model__subsample': 0.12208696971305184, 'model__colsample_bytree': 0.2843969691781985}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:47,560] Trial 30 finished with value: 0.9936974789915967 and parameters: {'selector__k': 19, 'model__learning_rate': 0.2970166890285955, 'model__n_estimators': 166, 'model__max_depth': 14, 'model__num_leaves': 34, 'model__min_child_samples': 8, 'model__subsample': 0.2671555314582486, 'model__colsample_bytree': 0.5333984887604689}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:47,629] Trial 31 finished with value: 0.9936974789915967 and parameters: {'selector__k': 34, 'model__learning_rate': 0.048760425791755393, 'model__n_estimators': 197, 'model__max_depth': 37, 'model__num_leaves': 32, 'model__min_child_samples': 15, 'model__subsample': 0.15011320463958908, 'model__colsample_bytree': 0.18435446155260332}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:47,699] Trial 32 finished with value: 0.9936974789915967 and parameters: {'selector__k': 12, 'model__learning_rate': 0.18964318424993468, 'model__n_estimators': 180, 'model__max_depth': 32, 'model__num_leaves': 37, 'model__min_child_samples': 17, 'model__subsample': 0.22244880715397336, 'model__colsample_bytree': 0.219251038000508}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:47,768] Trial 33 finished with value: 0.9936974789915967 and parameters: {'selector__k': 12, 'model__learning_rate': 0.1110678785937208, 'model__n_estimators': 244, 'model__max_depth': 26, 'model__num_leaves': 44, 'model__min_child_samples': 14, 'model__subsample': 0.30662473118775646, 'model__colsample_bytree': 0.1337099087881899}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:47,837] Trial 34 finished with value: 0.9936974789915967 and parameters: {'selector__k': 10, 'model__learning_rate': 0.011887080075757742, 'model__n_estimators': 107, 'model__max_depth': 40, 'model__num_leaves': 25, 'model__min_child_samples': 17, 'model__subsample': 0.18220200832784486, 'model__colsample_bytree': 0.9851030234969766}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:47,901] Trial 35 finished with value: 0.9936974789915967 and parameters: {'selector__k': 6, 'model__learning_rate': 0.08130328853842052, 'model__n_estimators': 145, 'model__max_depth': 44, 'model__num_leaves': 31, 'model__min_child_samples': 10, 'model__subsample': 0.10464366029577692, 'model__colsample_bytree': 0.2854969832020743}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:47,971] Trial 36 finished with value: 0.9936974789915967 and parameters: {'selector__k': 9, 'model__learning_rate': 0.1770358954093878, 'model__n_estimators': 222, 'model__max_depth': 28, 'model__num_leaves': 24, 'model__min_child_samples': 15, 'model__subsample': 0.15798145739466313, 'model__colsample_bytree': 0.6061845907780746}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:48,042] Trial 37 finished with value: 0.9936974789915967 and parameters: {'selector__k': 17, 'model__learning_rate': 0.7715263160282101, 'model__n_estimators': 185, 'model__max_depth': 47, 'model__num_leaves': 46, 'model__min_child_samples': 13, 'model__subsample': 0.3616961331280081, 'model__colsample_bytree': 0.41547269404903897}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:48,114] Trial 38 finished with value: 0.9936974789915967 and parameters: {'selector__k': 13, 'model__learning_rate': 0.31243513435867315, 'model__n_estimators': 339, 'model__max_depth': 30, 'model__num_leaves': 38, 'model__min_child_samples': 16, 'model__subsample': 0.4277396379815852, 'model__colsample_bytree': 0.8490837411805192}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:48,181] Trial 39 finished with value: 0.9936974789915967 and parameters: {'selector__k': 4, 'model__learning_rate': 0.26009078802749175, 'model__n_estimators': 86, 'model__max_depth': 41, 'model__num_leaves': 19, 'model__min_child_samples': 18, 'model__subsample': 0.22825500069954657, 'model__colsample_bytree': 0.4902457775266402}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:48,250] Trial 40 finished with value: 0.9936974789915967 and parameters: {'selector__k': 22, 'model__learning_rate': 0.12876781288927025, 'model__n_estimators': 130, 'model__max_depth': 50, 'model__num_leaves': 2, 'model__min_child_samples': 12, 'model__subsample': 0.9513597194073444, 'model__colsample_bytree': 0.967535436606994}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:48,378] Trial 41 finished with value: 0.9936974789915967 and parameters: {'selector__k': 34, 'model__learning_rate': 0.8275475597842111, 'model__n_estimators': 93, 'model__max_depth': 23, 'model__num_leaves': 5, 'model__min_child_samples': 14, 'model__subsample': 0.5603696873605974, 'model__colsample_bytree': 0.20479718118418228}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:48,450] Trial 42 finished with value: 0.9936974789915967 and parameters: {'selector__k': 26, 'model__learning_rate': 0.7272383199659052, 'model__n_estimators': 106, 'model__max_depth': 16, 'model__num_leaves': 6, 'model__min_child_samples': 10, 'model__subsample': 0.8391771579529381, 'model__colsample_bytree': 0.16294309787496933}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:48,522] Trial 43 finished with value: 0.9936974789915967 and parameters: {'selector__k': 32, 'model__learning_rate': 0.9464008367907932, 'model__n_estimators': 223, 'model__max_depth': 20, 'model__num_leaves': 9, 'model__min_child_samples': 13, 'model__subsample': 0.6337993713504776, 'model__colsample_bytree': 0.2454864689978104}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:48,593] Trial 44 finished with value: 0.9936974789915967 and parameters: {'selector__k': 16, 'model__learning_rate': 0.5353865472575229, 'model__n_estimators': 76, 'model__max_depth': 11, 'model__num_leaves': 4, 'model__min_child_samples': 14, 'model__subsample': 0.7378424438475659, 'model__colsample_bytree': 0.3641685527101292}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:48,667] Trial 45 finished with value: 0.9936974789915967 and parameters: {'selector__k': 32, 'model__learning_rate': 0.814928770709224, 'model__n_estimators': 62, 'model__max_depth': 6, 'model__num_leaves': 14, 'model__min_child_samples': 11, 'model__subsample': 0.5835733037365834, 'model__colsample_bytree': 0.27868274230288775}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:48,739] Trial 46 finished with value: 0.9936974789915967 and parameters: {'selector__k': 10, 'model__learning_rate': 0.6528486590640383, 'model__n_estimators': 115, 'model__max_depth': 35, 'model__num_leaves': 32, 'model__min_child_samples': 7, 'model__subsample': 0.522305798449293, 'model__colsample_bytree': 0.5806493814161164}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:48,811] Trial 47 finished with value: 0.9936974789915967 and parameters: {'selector__k': 15, 'model__learning_rate': 0.4377971965484753, 'model__n_estimators': 94, 'model__max_depth': 47, 'model__num_leaves': 36, 'model__min_child_samples': 16, 'model__subsample': 0.7998131380998443, 'model__colsample_bytree': 0.10030948971313888}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:48,885] Trial 48 finished with value: 0.9936974789915967 and parameters: {'selector__k': 24, 'model__learning_rate': 0.6457576207122747, 'model__n_estimators': 134, 'model__max_depth': 17, 'model__num_leaves': 8, 'model__min_child_samples': 12, 'model__subsample': 0.4148347604935614, 'model__colsample_bytree': 0.7878440932689597}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:48,955] Trial 49 finished with value: 0.9936974789915967 and parameters: {'selector__k': 6, 'model__learning_rate': 0.7241319980467535, 'model__n_estimators': 154, 'model__max_depth': 42, 'model__num_leaves': 27, 'model__min_child_samples': 20, 'model__subsample': 0.46722040105498297, 'model__colsample_bytree': 0.3759110958795433}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:49,012] A new study created in memory with name: no-name-6e05e5d4-38fd-499d-993c-5c872cb53dd2
# LGBM 0.9936974789915967 0.8428252005787189
# [I 2024-06-14 16:53:49,335] Trial 0 finished with value: 0.9936974789915967 and parameters: {'selector__k': 29, 'model__max_features': 'log2', 'model__n_estimators': 152, 'model__max_depth': 177, 'model__min_samples_leaf': 12}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:50,033] Trial 1 finished with value: 0.9936974789915967 and parameters: {'selector__k': 10, 'model__max_features': 'sqrt', 'model__n_estimators': 325, 'model__max_depth': 186, 'model__min_samples_leaf': 5}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:50,238] Trial 2 finished with value: 0.9936974789915967 and parameters: {'selector__k': 13, 'model__max_features': 'log2', 'model__n_estimators': 94, 'model__max_depth': 157, 'model__min_samples_leaf': 11}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:50,622] Trial 3 finished with value: 0.9936974789915967 and parameters: {'selector__k': 3, 'model__max_features': 'sqrt', 'model__n_estimators': 177, 'model__max_depth': 135, 'model__min_samples_leaf': 15}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:50,940] Trial 4 finished with value: 0.9936974789915967 and parameters: {'selector__k': 10, 'model__max_features': 'sqrt', 'model__n_estimators': 149, 'model__max_depth': 181, 'model__min_samples_leaf': 11}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:51,207] Trial 5 finished with value: 0.9936974789915967 and parameters: {'selector__k': 15, 'model__max_features': 'sqrt', 'model__n_estimators': 126, 'model__max_depth': 191, 'model__min_samples_leaf': 17}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:51,611] Trial 6 finished with value: 0.9936974789915967 and parameters: {'selector__k': 22, 'model__max_features': 'sqrt', 'model__n_estimators': 196, 'model__max_depth': 63, 'model__min_samples_leaf': 1}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:52,275] Trial 7 finished with value: 0.9936974789915967 and parameters: {'selector__k': 35, 'model__max_features': 'log2', 'model__n_estimators': 311, 'model__max_depth': 156, 'model__min_samples_leaf': 1}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:52,528] Trial 8 finished with value: 0.9936974789915967 and parameters: {'selector__k': 18, 'model__max_features': 'sqrt', 'model__n_estimators': 118, 'model__max_depth': 187, 'model__min_samples_leaf': 18}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:53,403] Trial 9 finished with value: 0.9936974789915967 and parameters: {'selector__k': 16, 'model__max_features': 'sqrt', 'model__n_estimators': 438, 'model__max_depth': 142, 'model__min_samples_leaf': 15}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:53,552] Trial 10 finished with value: 0.9936974789915967 and parameters: {'selector__k': 29, 'model__max_features': 'log2', 'model__n_estimators': 56, 'model__max_depth': 16, 'model__min_samples_leaf': 6}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:54,159] Trial 11 finished with value: 0.9936974789915967 and parameters: {'selector__k': 24, 'model__max_features': 'log2', 'model__n_estimators': 272, 'model__max_depth': 91, 'model__min_samples_leaf': 7}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:55,032] Trial 12 finished with value: 0.9936974789915967 and parameters: {'selector__k': 6, 'model__max_features': 'log2', 'model__n_estimators': 420, 'model__max_depth': 114, 'model__min_samples_leaf': 7}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:55,590] Trial 13 finished with value: 0.9936974789915967 and parameters: {'selector__k': 31, 'model__max_features': 'log2', 'model__n_estimators': 240, 'model__max_depth': 196, 'model__min_samples_leaf': 4}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:55,799] Trial 14 finished with value: 0.9936974789915967 and parameters: {'selector__k': 24, 'model__max_features': 'sqrt', 'model__n_estimators': 77, 'model__max_depth': 84, 'model__min_samples_leaf': 10}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:56,492] Trial 15 finished with value: 0.9936974789915967 and parameters: {'selector__k': 9, 'model__max_features': 'log2', 'model__n_estimators': 319, 'model__max_depth': 166, 'model__min_samples_leaf': 13}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:56,922] Trial 16 finished with value: 0.9936974789915967 and parameters: {'selector__k': 28, 'model__max_features': 'log2', 'model__n_estimators': 194, 'model__max_depth': 120, 'model__min_samples_leaf': 20}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:57,964] Trial 17 finished with value: 0.9936974789915967 and parameters: {'selector__k': 21, 'model__max_features': 'sqrt', 'model__n_estimators': 486, 'model__max_depth': 49, 'model__min_samples_leaf': 9}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:58,486] Trial 18 finished with value: 0.9936974789915967 and parameters: {'selector__k': 2, 'model__max_features': 'log2', 'model__n_estimators': 227, 'model__max_depth': 166, 'model__min_samples_leaf': 4}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:59,248] Trial 19 finished with value: 0.9936974789915967 and parameters: {'selector__k': 35, 'model__max_features': 'sqrt', 'model__n_estimators': 348, 'model__max_depth': 133, 'model__min_samples_leaf': 13}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:59,591] Trial 20 finished with value: 0.9936974789915967 and parameters: {'selector__k': 11, 'model__max_features': 'log2', 'model__n_estimators': 142, 'model__max_depth': 2, 'model__min_samples_leaf': 3}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:53:59,847] Trial 21 finished with value: 0.9936974789915967 and parameters: {'selector__k': 13, 'model__max_features': 'log2', 'model__n_estimators': 95, 'model__max_depth': 157, 'model__min_samples_leaf': 11}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:54:00,129] Trial 22 finished with value: 0.9936974789915967 and parameters: {'selector__k': 7, 'model__max_features': 'log2', 'model__n_estimators': 93, 'model__max_depth': 176, 'model__min_samples_leaf': 9}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:54:00,306] Trial 23 finished with value: 0.9936974789915967 and parameters: {'selector__k': 13, 'model__max_features': 'log2', 'model__n_estimators': 64, 'model__max_depth': 200, 'model__min_samples_leaf': 13}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:54:00,573] Trial 24 finished with value: 0.9936974789915967 and parameters: {'selector__k': 19, 'model__max_features': 'log2', 'model__n_estimators': 111, 'model__max_depth': 148, 'model__min_samples_leaf': 8}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:54:00,767] Trial 25 finished with value: 0.9936974789915967 and parameters: {'selector__k': 5, 'model__max_features': 'log2', 'model__n_estimators': 77, 'model__max_depth': 168, 'model__min_samples_leaf': 12}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:54:01,052] Trial 26 finished with value: 0.9936974789915967 and parameters: {'selector__k': 14, 'model__max_features': 'sqrt', 'model__n_estimators': 101, 'model__max_depth': 116, 'model__min_samples_leaf': 5}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:54:01,421] Trial 27 finished with value: 0.9936974789915967 and parameters: {'selector__k': 9, 'model__max_features': 'log2', 'model__n_estimators': 163, 'model__max_depth': 178, 'model__min_samples_leaf': 15}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:54:01,621] Trial 28 finished with value: 0.9936974789915967 and parameters: {'selector__k': 18, 'model__max_features': 'sqrt', 'model__n_estimators': 79, 'model__max_depth': 152, 'model__min_samples_leaf': 10}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:54:01,763] Trial 29 finished with value: 0.9936974789915967 and parameters: {'selector__k': 4, 'model__max_features': 'sqrt', 'model__n_estimators': 50, 'model__max_depth': 129, 'model__min_samples_leaf': 15}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:54:02,069] Trial 30 finished with value: 0.9936974789915967 and parameters: {'selector__k': 27, 'model__max_features': 'log2', 'model__n_estimators': 135, 'model__max_depth': 137, 'model__min_samples_leaf': 14}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:54:02,430] Trial 31 finished with value: 0.9936974789915967 and parameters: {'selector__k': 2, 'model__max_features': 'sqrt', 'model__n_estimators': 163, 'model__max_depth': 175, 'model__min_samples_leaf': 17}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:54:02,856] Trial 32 finished with value: 0.9936974789915967 and parameters: {'selector__k': 10, 'model__max_features': 'sqrt', 'model__n_estimators': 196, 'model__max_depth': 184, 'model__min_samples_leaf': 12}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:54:03,228] Trial 33 finished with value: 0.9936974789915967 and parameters: {'selector__k': 7, 'model__max_features': 'sqrt', 'model__n_estimators': 168, 'model__max_depth': 160, 'model__min_samples_leaf': 16}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:54:03,781] Trial 34 finished with value: 0.9936974789915967 and parameters: {'selector__k': 12, 'model__max_features': 'sqrt', 'model__n_estimators': 255, 'model__max_depth': 104, 'model__min_samples_leaf': 12}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:54:04,241] Trial 35 finished with value: 0.9936974789915967 and parameters: {'selector__k': 16, 'model__max_features': 'sqrt', 'model__n_estimators': 209, 'model__max_depth': 186, 'model__min_samples_leaf': 19}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:54:04,855] Trial 36 finished with value: 0.9936974789915967 and parameters: {'selector__k': 8, 'model__max_features': 'sqrt', 'model__n_estimators': 290, 'model__max_depth': 146, 'model__min_samples_leaf': 11}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:54:05,152] Trial 37 finished with value: 0.9936974789915967 and parameters: {'selector__k': 32, 'model__max_features': 'sqrt', 'model__n_estimators': 129, 'model__max_depth': 191, 'model__min_samples_leaf': 17}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:54:05,999] Trial 38 finished with value: 0.9936974789915967 and parameters: {'selector__k': 16, 'model__max_features': 'sqrt', 'model__n_estimators': 386, 'model__max_depth': 126, 'model__min_samples_leaf': 2}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:54:06,276] Trial 39 finished with value: 0.9936974789915967 and parameters: {'selector__k': 4, 'model__max_features': 'log2', 'model__n_estimators': 117, 'model__max_depth': 142, 'model__min_samples_leaf': 14}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:54:06,679] Trial 40 finished with value: 0.9936974789915967 and parameters: {'selector__k': 21, 'model__max_features': 'sqrt', 'model__n_estimators': 180, 'model__max_depth': 100, 'model__min_samples_leaf': 8}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:54:07,025] Trial 41 finished with value: 0.9936974789915967 and parameters: {'selector__k': 10, 'model__max_features': 'sqrt', 'model__n_estimators': 146, 'model__max_depth': 175, 'model__min_samples_leaf': 9}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:54:07,281] Trial 42 finished with value: 0.9936974789915967 and parameters: {'selector__k': 15, 'model__max_features': 'sqrt', 'model__n_estimators': 108, 'model__max_depth': 192, 'model__min_samples_leaf': 11}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:54:07,497] Trial 43 finished with value: 0.9936974789915967 and parameters: {'selector__k': 25, 'model__max_features': 'sqrt', 'model__n_estimators': 88, 'model__max_depth': 158, 'model__min_samples_leaf': 6}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:54:07,995] Trial 44 finished with value: 0.9936974789915967 and parameters: {'selector__k': 11, 'model__max_features': 'log2', 'model__n_estimators': 226, 'model__max_depth': 184, 'model__min_samples_leaf': 14}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:54:08,169] Trial 45 finished with value: 0.9936974789915967 and parameters: {'selector__k': 6, 'model__max_features': 'sqrt', 'model__n_estimators': 65, 'model__max_depth': 200, 'model__min_samples_leaf': 10}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:54:08,518] Trial 46 finished with value: 0.9936974789915967 and parameters: {'selector__k': 18, 'model__max_features': 'log2', 'model__n_estimators': 151, 'model__max_depth': 166, 'model__min_samples_leaf': 16}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:54:08,812] Trial 47 finished with value: 0.9936974789915967 and parameters: {'selector__k': 8, 'model__max_features': 'sqrt', 'model__n_estimators': 127, 'model__max_depth': 66, 'model__min_samples_leaf': 1}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:54:09,521] Trial 48 finished with value: 0.9936974789915967 and parameters: {'selector__k': 32, 'model__max_features': 'log2', 'model__n_estimators': 331, 'model__max_depth': 168, 'model__min_samples_leaf': 7}. Best is trial 0 with value: 0.9936974789915967.
# [I 2024-06-14 16:54:10,117] Trial 49 finished with value: 0.9936974789915967 and parameters: {'selector__k': 3, 'model__max_features': 'sqrt', 'model__n_estimators': 277, 'model__max_depth': 180, 'model__min_samples_leaf': 13}. Best is trial 0 with value: 0.9936974789915967.
# RF 0.9936974789915967 0.8462449033276338

# %%
import pickle
with open('best_model_clf_compressed.pickle', 'wb') as f:
    pickle.dump(best_model_clf, f, pickle.HIGHEST_PROTOCOL)

# %%
best_model_clf = pd.read_pickle("best_model_clf_compressed.pickle")

# %%
best_md_from_clf = sorted(best_model_clf.items(), key=lambda t: t[1][1])[-1]
temp_tr = test_data_tr.copy(deep=True)
temp_tr['y_pred_clf'] = best_md_from_clf[1][2]

# %% [markdown]
# ### Group the used link from training and validation dataset and later group the predicted used link in test dataset

# %%
used_link_1 = temp[temp['used_link']==1]
used_link_1_train = used_link_1[used_link_1['remainder__dataset']=='train']
used_link_1_validate = used_link_1[used_link_1['remainder__dataset']=='validate']
temp_2 = pd.concat([used_link_1_train, used_link_1_validate], ignore_index=True)
X_t = temp_2.drop(columns=['remainder__dataset', 'remainder__link_counts', 'used_link'])
y_t = temp_2['remainder__link_counts']

train_index = list(temp_2[temp_2['remainder__dataset']=='train'].index)
validate_index = list(temp_2[temp_2['remainder__dataset']=='validate'].index)

X_te = temp_tr[temp_tr['y_pred_clf']==1].drop(columns=['remainder__dataset', 'remainder__link_counts', 'used_link', 'y_pred_clf'])
y_te = temp_tr[temp_tr['y_pred_clf']==1]['remainder__link_counts']

X_te_0 = temp_tr[temp_tr['y_pred_clf']==0].drop(columns=['remainder__dataset', 'remainder__link_counts', 'used_link', 'y_pred_clf'])
X_te_0['y_pred'] = 0
y_te_0 = temp_tr[temp_tr['y_pred_clf']==0]['remainder__link_counts']
y_te_all = pd.concat([y_te, y_te_0])

# %%
best_model_reg = {}
for model_name in model_space.keys():   
    model = model_space[model_name]
    pipeline  = Pipeline([('selector', SelectKBest(f_regression)),
                  ('model', model)])
    param_grid = {}
    param_grid['selector__k']=optuna.distributions.IntDistribution(2, 48)
    for key in param_space[model_name].keys():
        param_grid[f'model__{key}']=param_space[model_name][key]
    
    # BayesSearchCV
    opt = OptunaSearchCV(
        pipeline,
        param_grid,
        n_trials=50,
        cv=[(train_index, validate_index), (train_index, validate_index)],
        scoring='neg_mean_absolute_error'
    )
    opt.fit(X_t, y_t)
    y_pred = opt.predict(X_te)
    y_pred_all = np.concatenate([y_pred, np.array(X_te_0['y_pred'])])
    mae = mean_absolute_error(y_te_all, y_pred_all)
    mse = mean_squared_error(y_te_all, y_pred_all)
    me = max_error(y_te_all, y_pred_all)
    best_model_reg[model_name] = (opt, mae, mse, me)
    print(model_name, opt.best_score_, mae, mse, me)
# Out:
# [I 2024-06-14 16:55:44,860] A new study created in memory with name: no-name-b3943769-82a9-44b9-a2d0-1ae1d7c52383
# [I 2024-06-14 16:55:44,906] Trial 0 finished with value: -17.47556886410939 and parameters: {'selector__k': 29, 'model__n_neighbors': 23, 'model__weights': 'uniform', 'model__algorithm': 'kd_tree'}. Best is trial 0 with value: -17.47556886410939.
# [W 2024-06-14 16:55:44,924] Trial 1 failed with parameters: {'selector__k': 45, 'model__n_neighbors': 16, 'model__weights': 'distance', 'model__algorithm': 'kd_tree'} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:44,925] Trial 1 failed with value nan.
# [W 2024-06-14 16:55:44,943] Trial 2 failed with parameters: {'selector__k': 38, 'model__n_neighbors': 15, 'model__weights': 'distance', 'model__algorithm': 'brute'} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:44,944] Trial 2 failed with value nan.
# [W 2024-06-14 16:55:44,963] Trial 3 failed with parameters: {'selector__k': 46, 'model__n_neighbors': 17, 'model__weights': 'uniform', 'model__algorithm': 'auto'} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:44,964] Trial 3 failed with value nan.
# [I 2024-06-14 16:55:44,992] Trial 4 finished with value: -14.037371080213187 and parameters: {'selector__k': 2, 'model__n_neighbors': 9, 'model__weights': 'uniform', 'model__algorithm': 'ball_tree'}. Best is trial 4 with value: -14.037371080213187.
# [I 2024-06-14 16:55:45,027] Trial 5 finished with value: -13.631305002094223 and parameters: {'selector__k': 20, 'model__n_neighbors': 16, 'model__weights': 'distance', 'model__algorithm': 'ball_tree'}. Best is trial 5 with value: -13.631305002094223.
# [I 2024-06-14 16:55:45,069] Trial 6 finished with value: -20.473784118097083 and parameters: {'selector__k': 35, 'model__n_neighbors': 25, 'model__weights': 'uniform', 'model__algorithm': 'ball_tree'}. Best is trial 5 with value: -13.631305002094223.
# [I 2024-06-14 16:55:45,109] Trial 7 finished with value: -15.44487770278063 and parameters: {'selector__k': 24, 'model__n_neighbors': 41, 'model__weights': 'uniform', 'model__algorithm': 'auto'}. Best is trial 5 with value: -13.631305002094223.
# [I 2024-06-14 16:55:45,153] Trial 8 finished with value: -14.7731905492598 and parameters: {'selector__k': 28, 'model__n_neighbors': 50, 'model__weights': 'distance', 'model__algorithm': 'brute'}. Best is trial 5 with value: -13.631305002094223.
# [I 2024-06-14 16:55:45,191] Trial 9 finished with value: -20.667512270735887 and parameters: {'selector__k': 30, 'model__n_neighbors': 27, 'model__weights': 'uniform', 'model__algorithm': 'brute'}. Best is trial
 'model__n_neighbors': 7, 'model__weights': 'distance', 'model__algorithm': 'kd_tree'} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:45,951] Trial 31 failed with value nan.
# [W 2024-06-14 16:55:45,980] Trial 32 failed with parameters: {'selector__k': 48, 'model__n_neighbors': 14, 'model__weights': 'distance', 'model__algorithm': 'kd_tree'} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:45,983] Trial 32 failed with value nan.
# [W 2024-06-14 16:55:46,015] Trial 33 failed with parameters: {'selector__k': 38, 'model__n_neighbors': 7, 'model__weights': 'distance', 'model__algorithm': 'auto'} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:46,016] Trial 33 failed with value nan.
# [W 2024-06-14 16:55:46,046] Trial 34 failed with parameters: {'selector__k': 47, 'model__n_neighbors': 7, 'model__weights': 'distance', 'model__algorithm': 'auto'} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:46,047] Trial 34 failed with value nan.
# [W 2024-06-14 16:55:46,077] Trial 35 failed with parameters: {'selector__k': 44, 'model__n_neighbors': 7, 'model__weights': 'distance', 'model__algorithm': 'kd_tree'} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:46,078] Trial 35 failed with value nan.
# [W 2024-06-14 16:55:46,111] Trial 36 failed with parameters: {'selector__k': 44, 'model__n_neighbors': 7, 'model__weights': 'distance', 'model__algorithm': 'kd_tree'} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:46,113] Trial 36 failed with value nan.
# [I 2024-06-14 16:55:46,169] Trial 37 finished with value: -12.986584802805513 and parameters: {'selector__k': 14, 'model__n_neighbors': 7, 'model__weights': 'distance', 'model__algorithm': 'kd_tree'}. Best is trial 24 with value: -8.919248656377167.
# [W 2024-06-14 16:55:46,232] Trial 38 failed with parameters: {'selector__k': 44, 'model__n_neighbors': 14, 'model__weights': 'distance', 'model__algorithm': 'auto'} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:46,233] Trial 38 failed with value nan.
# [I 2024-06-14 16:55:46,284] Trial 39 finished with value: -13.813587941565398 and parameters: {'selector__k': 2, 'model__n_neighbors': 15, 'model__weights': 'distance', 'model__algorithm': 'auto'}. Best is trial 24 with value: -8.919248656377167.
# [W 2024-06-14 16:55:46,314] Trial 40 failed with parameters: {'selector__k': 36, 'model__n_neighbors': 32, 'model__weights': 'distance', 'model__algorithm': 'ball_tree'} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:46,316] Trial 40 failed with value nan.
# [W 2024-06-14 16:55:46,344] Trial 41 failed with parameters: {'selector__k': 47, 'model__n_neighbors': 32, 'model__weights': 'distance', 'model__algorithm': 'ball_tree'} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:46,345] Trial 41 failed with value nan.
# [W 2024-06-14 16:55:46,378] Trial 42 failed with parameters: {'selector__k': 48, 'model__n_neighbors': 20, 'model__weights': 'distance', 'model__algorithm': 'ball_tree'} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:46,379] Trial 42 failed with value nan.
# [W 2024-06-14 16:55:46,408] Trial 43 failed with parameters: {'selector__k': 41, 'model__n_neighbors': 5, 'model__weights': 'distance', 'model__algorithm': 'ball_tree'} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:46,409] Trial 43 failed with value nan.
# [W 2024-06-14 16:55:46,440] Trial 44 failed with parameters: {'selector__k': 44, 'model__n_neighbors': 33, 'model__weights': 'distance', 'model__algorithm': 'ball_tree'} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:46,440] Trial 44 failed with value nan.
# [W 2024-06-14 16:55:46,470] Trial 45 failed with parameters: {'selector__k': 37, 'model__n_neighbors': 31, 'model__weights': 'distance', 'model__algorithm': 'ball_tree'} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:46,470] Trial 45 failed with value nan.
# [W 2024-06-14 16:55:46,493] Trial 46 failed with parameters: {'selector__k': 46, 'model__n_neighbors': 33, 'model__weights': 'distance', 'model__algorithm': 'ball_tree'} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:46,494] Trial 46 failed with value nan.
# [W 2024-06-14 16:55:46,517] Trial 47 failed with parameters: {'selector__k': 46, 'model__n_neighbors': 31, 'model__weights': 'distance', 'model__algorithm': 'ball_tree'} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:46,518] Trial 47 failed with value nan.
# [W 2024-06-14 16:55:46,542] Trial 48 failed with parameters: {'selector__k': 44, 'model__n_neighbors': 6, 'model__weights': 'distance', 'model__algorithm': 'ball_tree'} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:46,542] Trial 48 failed with value nan.
# [W 2024-06-14 16:55:46,567] Trial 49 failed with parameters: {'selector__k': 41, 'model__n_neighbors': 31, 'model__weights': 'distance', 'model__algorithm': 'ball_tree'} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:46,569] Trial 49 failed with value nan.
# [I 2024-06-14 16:55:46,626] A new study created in memory with name: no-name-a630f190-2468-4373-844a-f1402e1c06a8
# [W 2024-06-14 16:55:46,644] Trial 0 failed with parameters: {'selector__k': 44, 'model__learning_rate': 0.9432347534658282, 'model__n_estimators': 131, 'model__max_depth': 12, 'model__max_leaves': 14, 'model__max_bin': 6, 'model__gamma': 2} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:46,645] Trial 0 failed with value nan.
# [W 2024-06-14 16:55:46,663] Trial 1 failed with parameters: {'selector__k': 40, 'model__learning_rate': 0.21152432814906655, 'model__n_estimators': 350, 'model__max_depth': 3, 'model__max_leaves': 40, 'model__max_bin': 42, 'model__gamma': 1} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:46,664] Trial 1 failed with value nan.
# KNN -8.919248656377167 9.871155507378237 353.3200908159889 174.2916344516359
# [I 2024-06-14 16:55:46,909] Trial 2 finished with value: -9.255366513429887 and parameters: {'selector__k': 18, 'model__learning_rate': 0.4335256285388143, 'model__n_estimators': 220, 'model__max_depth': 4, 'model__max_leaves': 43, 'model__max_bin': 17, 'model__gamma': 9}. Best is trial 2 with value: -9.255366513429887.
# [I 2024-06-14 16:55:47,000] Trial 3 finished with value: -9.918359879705624 and parameters: {'selector__k': 11, 'model__learning_rate': 0.7002698228756383, 'model__n_estimators': 76, 'model__max_depth': 19, 'model__max_leaves': 42, 'model__max_bin': 14, 'model__gamma': 15}. Best is trial 2 with value: -9.255366513429887.
# [I 2024-06-14 16:55:47,200] Trial 4 finished with value: -9.54586691254863 and parameters: {'selector__k': 20, 'model__learning_rate': 0.6735951710970887, 'model__n_estimators': 392, 'model__max_depth': 17, 'model__max_leaves': 33, 'model__max_bin': 42, 'model__gamma': 14}. Best is trial 2 with value: -9.255366513429887.
# [I 2024-06-14 16:55:47,277] Trial 5 finished with value: -11.92442684003655 and parameters: {'selector__k': 35, 'model__learning_rate': 0.8454378500588295, 'model__n_estimators': 50, 'model__max_depth': 12, 'model__max_leaves': 5, 'model__max_bin': 5, 'model__gamma': 9}. Best is trial 2 with value: -9.255366513429887.
# [I 2024-06-14 16:55:47,354] Trial 6 finished with value: -9.921879312397913 and parameters: {'selector__k': 5, 'model__learning_rate': 0.5654988723581812, 'model__n_estimators': 111, 'model__max_depth': 1, 'model__max_leaves': 20, 'model__max_bin': 16, 'model__gamma': 19}. Best is trial 2 with value: -9.255366513429887.
# [I 2024-06-14 16:55:47,411] Trial 7 finished with value: -9.16506280811135 and parameters: {'selector__k': 25, 'model__learning_rate': 0.19119615779582302, 'model__n_estimators': 58, 'model__max_depth': 1, 'model__max_leaves': 21, 'model__max_bin': 38, 'model__gamma': 19}. Best is trial 7 with value: -9.16506280811135.
# [I 2024-06-14 16:55:47,588] Trial 8 finished with value: -12.4172512877373 and parameters: {'selector__k': 30, 'model__learning_rate': 0.6796278014272963, 'model__n_estimators': 348, 'model__max_depth': 14, 'model__max_leaves': 32, 'model__max_bin': 2, 'model__gamma': 18}. Best is trial 7 with value: -9.16506280811135.
# [I 2024-06-14 16:55:47,726] Trial 9 finished with value: -9.492220454509582 and parameters: {'selector__k': 12, 'model__learning_rate': 0.1450320131561381, 'model__n_estimators': 101, 'model__max_depth': 18, 'model__max_leaves': 22, 'model__max_bin': 49, 'model__gamma': 5}. Best is trial 7 with value: -9.16506280811135.
# [W 2024-06-14 16:55:47,742] Trial 10 failed with parameters: {'selector__k': 39, 'model__learning_rate': 0.36271605750966324, 'model__n_estimators': 154, 'model__max_depth': 3, 'model__max_leaves': 48, 'model__max_bin': 46, 'model__gamma': 4} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:47,743] Trial 10 failed with value nan.
# [I 2024-06-14 16:55:47,861] Trial 11 finished with value: -9.41779782037198 and parameters: {'selector__k': 19, 'model__learning_rate': 0.34751829198498946, 'model__n_estimators': 204, 'model__max_depth': 5, 'model__max_leaves': 36, 'model__max_bin': 18, 'model__gamma': 9}. Best is trial 7 with value: -9.16506280811135.
# [W 2024-06-14 16:55:47,878] Trial 12 failed with parameters: {'selector__k': 45, 'model__learning_rate': 0.064292870829538, 'model__n_estimators': 117, 'model__max_depth': 1, 'model__max_leaves': 43, 'model__max_bin': 29, 'model__gamma': 19} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:47,879] Trial 12 failed with value nan.
# [I 2024-06-14 16:55:47,952] Trial 13 finished with value: -9.980488884078865 and parameters: {'selector__k': 16, 'model__learning_rate': 0.5486543692765262, 'model__n_estimators': 60, 'model__max_depth': 12, 'model__max_leaves': 21, 'model__max_bin': 18, 'model__gamma': 12}. Best is trial 7 with value: -9.16506280811135.
# [W 2024-06-14 16:55:48,001] Trial 14 failed with parameters: {'selector__k': 44, 'model__learning_rate': 0.016516852575670427, 'model__n_estimators': 130, 'model__max_depth': 8, 'model__max_leaves': 9, 'model__max_bin': 33, 'model__gamma': 2} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:48,002] Trial 14 failed with value nan.
# [W 2024-06-14 16:55:48,054] Trial 15 failed with parameters: {'selector__k': 48, 'model__learning_rate': 0.024694982145159583, 'model__n_estimators': 141, 'model__max_depth': 7, 'model__max_leaves': 2, 'model__max_bin': 34, 'model__gamma': 1} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:48,055] Trial 15 failed with value nan.
# [W 2024-06-14 16:55:48,103] Trial 16 failed with parameters: {'selector__k': 47, 'model__learning_rate': 0.0312218894107317, 'model__n_estimators': 130, 'model__max_depth': 8, 'model__max_leaves': 11, 'model__max_bin': 34, 'model__gamma': 1} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:48,104] Trial 16 failed with value nan.
# [W 2024-06-14 16:55:48,147] Trial 17 failed with parameters: {'selector__k': 41, 'model__learning_rate': 0.19652976451150583, 'model__n_estimators': 138, 'model__max_depth': 7, 'model__max_leaves': 7, 'model__max_bin': 33, 'model__gamma': 2} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:48,147] Trial 17 failed with value nan.
# [W 2024-06-14 16:55:48,188] Trial 18 failed with parameters: {'selector__k': 48, 'model__learning_rate': 0.023426300659689397, 'model__n_estimators': 126, 'model__max_depth': 8, 'model__max_leaves': 9, 'model__max_bin': 34, 'model__gamma': 3} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:48,189] Trial 18 failed with value nan.
# [W 2024-06-14 16:55:48,231] Trial 19 failed with parameters: {'selector__k': 45, 'model__learning_rate': 0.10894906500627223, 'model__n_estimators': 144, 'model__max_depth': 8, 'model__max_leaves': 9, 'model__max_bin': 33, 'model__gamma': 1} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:48,232] Trial 19 failed with value nan.
# [W 2024-06-14 16:55:48,273] Trial 20 failed with parameters: {'selector__k': 44, 'model__learning_rate': 0.04226745946345045, 'model__n_estimators': 138, 'model__max_depth': 7, 'model__max_leaves': 7, 'model__max_bin': 33, 'model__gamma': 1} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:48,274] Trial 20 failed with value nan.
# [W 2024-06-14 16:55:48,322] Trial 21 failed with parameters: {'selector__k': 47, 'model__learning_rate': 0.039495508341916286, 'model__n_estimators': 142, 'model__max_depth': 7, 'model__max_leaves': 9, 'model__max_bin': 35, 'model__gamma': 1} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:48,322] Trial 21 failed with value nan.
# [W 2024-06-14 16:55:48,364] Trial 22 failed with parameters: {'selector__k': 48, 'model__learning_rate': 0.019678781399989687, 'model__n_estimators': 135, 'model__max_depth': 7, 'model__max_leaves': 7, 'model__max_bin': 34, 'model__gamma': 2} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:48,365] Trial 22 failed with value nan.
# [W 2024-06-14 16:55:48,406] Trial 23 failed with parameters: {'selector__k': 41, 'model__learning_rate': 0.07368698214784114, 'model__n_estimators': 138, 'model__max_depth': 8, 'model__max_leaves': 7, 'model__max_bin': 33, 'model__gamma': 4} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:48,408] Trial 23 failed with value nan.
# [W 2024-06-14 16:55:48,448] Trial 24 failed with parameters: {'selector__k': 47, 'model__learning_rate': 0.022665071321003094, 'model__n_estimators': 136, 'model__max_depth': 7, 'model__max_leaves': 7, 'model__max_bin': 33, 'model__gamma': 1} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:48,450] Trial 24 failed with value nan.
# [W 2024-06-14 16:55:48,491] Trial 25 failed with parameters: {'selector__k': 45, 'model__learning_rate': 0.01398194344757997, 'model__n_estimators': 133, 'model__max_depth': 7, 'model__max_leaves': 2, 'model__max_bin': 34, 'model__gamma': 2} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:48,492] Trial 25 failed with value nan.
# [W 2024-06-14 16:55:48,534] Trial 26 failed with parameters: {'selector__k': 41, 'model__learning_rate': 0.025113708935522283, 'model__n_estimators': 130, 'model__max_depth': 8, 'model__max_leaves': 10, 'model__max_bin': 33, 'model__gamma': 1} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:48,535] Trial 26 failed with value nan.
# [W 2024-06-14 16:55:48,576] Trial 27 failed with parameters: {'selector__k': 48, 'model__learning_rate': 0.014141419176413816, 'model__n_estimators': 132, 'model__max_depth': 7, 'model__max_leaves': 7, 'model__max_bin': 33, 'model__gamma': 2} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:48,577] Trial 27 failed with value nan.
# [W 2024-06-14 16:55:48,620] Trial 28 failed with parameters: {'selector__k': 47, 'model__learning_rate': 0.029620995189661103, 'model__n_estimators': 123, 'model__max_depth': 7, 'model__max_leaves': 8, 'model__max_bin': 31, 'model__gamma': 1} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:48,621] Trial 28 failed with value nan.
# [W 2024-06-14 16:55:48,669] Trial 29 failed with parameters: {'selector__k': 47, 'model__learning_rate': 0.07439698503755171, 'model__n_estimators': 131, 'model__max_depth': 7, 'model__max_leaves': 10, 'model__max_bin': 34, 'model__gamma': 3} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:48,669] Trial 29 failed with value nan.
# [W 2024-06-14 16:55:48,722] Trial 30 failed with parameters: {'selector__k': 38, 'model__learning_rate': 0.0650430848219205, 'model__n_estimators': 141, 'model__max_depth': 7, 'model__max_leaves': 9, 'model__max_bin': 33, 'model__gamma': 3} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:48,724] Trial 30 failed with value nan.
# [W 2024-06-14 16:55:48,776] Trial 31 failed with parameters: {'selector__k': 46, 'model__learning_rate': 0.06149325555928015, 'model__n_estimators': 126, 'model__max_depth': 8, 'model__max_leaves': 8, 'model__max_bin': 34, 'model__gamma': 1} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:48,777] Trial 31 failed with value nan.
# [W 2024-06-14 16:55:48,824] Trial 32 failed with parameters: {'selector__k': 46, 'model__learning_rate': 0.03601008477808948, 'model__n_estimators': 136, 'model__max_depth': 8, 'model__max_leaves': 9, 'model__max_bin': 33, 'model__gamma': 1} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:48,825] Trial 32 failed with value nan.
# [W 2024-06-14 16:55:48,869] Trial 33 failed with parameters: {'selector__k': 45, 'model__learning_rate': 0.04564959993280915, 'model__n_estimators': 146, 'model__max_depth': 7, 'model__max_leaves': 7, 'model__max_bin': 35, 'model__gamma': 3} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:48,871] Trial 33 failed with value nan.
# [W 2024-06-14 16:55:48,912] Trial 34 failed with parameters: {'selector__k': 47, 'model__learning_rate': 0.06730092125028164, 'model__n_estimators': 132, 'model__max_depth': 7, 'model__max_leaves': 9, 'model__max_bin': 33, 'model__gamma': 20} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:48,913] Trial 34 failed with value nan.
# [W 2024-06-14 16:55:48,954] Trial 35 failed with parameters: {'selector__k': 48, 'model__learning_rate': 0.09567677731808327, 'model__n_estimators': 132, 'model__max_depth': 7, 'model__max_leaves': 8, 'model__max_bin': 33, 'model__gamma': 2} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:48,956] Trial 35 failed with value nan.
# [W 2024-06-14 16:55:49,002] Trial 36 failed with parameters: {'selector__k': 47, 'model__learning_rate': 0.02816163530549537, 'model__n_estimators': 143, 'model__max_depth': 7, 'model__max_leaves': 7, 'model__max_bin': 35, 'model__gamma': 2} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:49,003] Trial 36 failed with value nan.
# [W 2024-06-14 16:55:49,044] Trial 37 failed with parameters: {'selector__k': 46, 'model__learning_rate': 0.08253932762073711, 'model__n_estimators': 123, 'model__max_depth': 6, 'model__max_leaves': 7, 'model__max_bin': 34, 'model__gamma': 2} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:49,045] Trial 37 failed with value nan.
# [W 2024-06-14 16:55:49,086] Trial 38 failed with parameters: {'selector__k': 44, 'model__learning_rate': 0.04735052775704096, 'model__n_estimators': 137, 'model__max_depth': 7, 'model__max_leaves': 8, 'model__max_bin': 34, 'model__gamma': 3} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:49,087] Trial 38 failed with value nan.
# [W 2024-06-14 16:55:49,129] Trial 39 failed with parameters: {'selector__k': 47, 'model__learning_rate': 0.07272746228178686, 'model__n_estimators': 137, 'model__max_depth': 7, 'model__max_leaves': 10, 'model__max_bin': 34, 'model__gamma': 1} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:49,130] Trial 39 failed with value nan.
# [W 2024-06-14 16:55:49,170] Trial 40 failed with parameters: {'selector__k': 47, 'model__learning_rate': 0.07962870474375694, 'model__n_estimators': 134, 'model__max_depth': 7, 'model__max_leaves': 10, 'model__max_bin': 32, 'model__gamma': 1} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:49,171] Trial 40 failed with value nan.
# [W 2024-06-14 16:55:49,215] Trial 41 failed with parameters: {'selector__k': 46, 'model__learning_rate': 0.08467599921936264, 'model__n_estimators': 131, 'model__max_depth': 7, 'model__max_leaves': 9, 'model__max_bin': 37, 'model__gamma': 2} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:49,215] Trial 41 failed with value nan.
# [W 2024-06-14 16:55:49,258] Trial 42 failed with parameters: {'selector__k': 42, 'model__learning_rate': 0.09121154641236506, 'model__n_estimators': 131, 'model__max_depth': 7, 'model__max_leaves': 9, 'model__max_bin': 33, 'model__gamma': 2} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:49,259] Trial 42 failed with value nan.
# [W 2024-06-14 16:55:49,303] Trial 43 failed with parameters: {'selector__k': 44, 'model__learning_rate': 0.03263187403909906, 'model__n_estimators': 139, 'model__max_depth': 7, 'model__max_leaves': 8, 'model__max_bin': 34, 'model__gamma': 1} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:49,304] Trial 43 failed with value nan.
# [W 2024-06-14 16:55:49,353] Trial 44 failed with parameters: {'selector__k': 46, 'model__learning_rate': 0.13700378440965524, 'model__n_estimators': 136, 'model__max_depth': 7, 'model__max_leaves': 7, 'model__max_bin': 34, 'model__gamma': 2} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:49,353] Trial 44 failed with value nan.
# [W 2024-06-14 16:55:49,402] Trial 45 failed with parameters: {'selector__k': 48, 'model__learning_rate': 0.028712599603407746, 'model__n_estimators': 128, 'model__max_depth': 7, 'model__max_leaves': 9, 'model__max_bin': 33, 'model__gamma': 1} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:49,403] Trial 45 failed with value nan.
# [W 2024-06-14 16:55:49,451] Trial 46 failed with parameters: {'selector__k': 45, 'model__learning_rate': 0.01317552230615715, 'model__n_estimators': 129, 'model__max_depth': 7, 'model__max_leaves': 9, 'model__max_bin': 34, 'model__gamma': 1} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:49,452] Trial 46 failed with value nan.
# [W 2024-06-14 16:55:49,502] Trial 47 failed with parameters: {'selector__k': 47, 'model__learning_rate': 0.030433523265812612, 'model__n_estimators': 144, 'model__max_depth': 7, 'model__max_leaves': 9, 'model__max_bin': 35, 'model__gamma': 3} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:49,502] Trial 47 failed with value nan.
# [W 2024-06-14 16:55:49,545] Trial 48 failed with parameters: {'selector__k': 43, 'model__learning_rate': 0.025386829257059984, 'model__n_estimators': 156, 'model__max_depth': 8, 'model__max_leaves': 8, 'model__max_bin': 33, 'model__gamma': 2} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:49,546] Trial 48 failed with value nan.
# [W 2024-06-14 16:55:49,587] Trial 49 failed with parameters: {'selector__k': 48, 'model__learning_rate': 0.04394877589484175, 'model__n_estimators': 118, 'model__max_depth': 7, 'model__max_leaves': 9, 'model__max_bin': 34, 'model__gamma': 1} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:49,588] Trial 49 failed with value nan.
# [I 2024-06-14 16:55:49,625] A new study created in memory with name: no-name-0697a822-d550-4c97-a08c-05bd099341c5
# XGB -9.16506280811135 11.08223330575923 334.8926792245897 168.25401306152344
# [I 2024-06-14 16:55:50,851] Trial 0 finished with value: -8.040665971661948 and parameters: {'selector__k': 18, 'model__learning_rate': 0.5729694885290083, 'model__n_estimators': 375, 'model__max_depth': 14, 'model__num_leaves': 40, 'model__min_child_samples': 1, 'model__subsample': 0.8299960182102328, 'model__colsample_bytree': 0.5620655946648829}. Best is trial 0 with value: -8.040665971661948.
# [W 2024-06-14 16:55:50,867] Trial 1 failed with parameters: {'selector__k': 36, 'model__learning_rate': 0.13022067107121327, 'model__n_estimators': 82, 'model__max_depth': 21, 'model__num_leaves': 13, 'model__min_child_samples': 9, 'model__subsample': 0.5641217153550651, 'model__colsample_bytree': 0.971070613531251} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:50,867] Trial 1 failed with value nan.
# [I 2024-06-14 16:55:51,412] Trial 2 finished with value: -16.31298594215975 and parameters: {'selector__k': 33, 'model__learning_rate': 0.9520764374815296, 'model__n_estimators': 177, 'model__max_depth': 41, 'model__num_leaves': 36, 'model__min_child_samples': 12, 'model__subsample': 0.9801607065907549, 'model__colsample_bytree': 0.33995857151985165}. Best is trial 0 with value: -8.040665971661948.
# [I 2024-06-14 16:55:51,688] Trial 3 finished with value: -10.13776783391308 and parameters: {'selector__k': 30, 'model__learning_rate': 0.09482977855964028, 'model__n_estimators': 124, 'model__max_depth': 47, 'model__num_leaves': 16, 'model__min_child_samples': 13, 'model__subsample': 0.8311340124013255, 'model__colsample_bytree': 0.9835048886639842}. Best is trial 0 with value: -8.040665971661948.
# [I 2024-06-14 16:55:51,868] Trial 4 finished with value: -11.609932557950685 and parameters: {'selector__k': 32, 'model__learning_rate': 0.7455401058312026, 'model__n_estimators': 130, 'model__max_depth': 4, 'model__num_leaves': 12, 'model__min_child_samples': 4, 'model__subsample': 0.9579155880338404, 'model__colsample_bytree': 0.5829463401433056}. Best is trial 0 with value: -8.040665971661948.
# [W 2024-06-14 16:55:51,884] Trial 5 failed with parameters: {'selector__k': 43, 'model__learning_rate': 0.8234175167937513, 'model__n_estimators': 101, 'model__max_depth': 5, 'model__num_leaves': 47, 'model__min_child_samples': 3, 'model__subsample': 0.8379219795432826, 'model__colsample_bytree': 0.3704291388582551} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:51,885] Trial 5 failed with value nan.
# [W 2024-06-14 16:55:51,912] Trial 6 failed with parameters: {'selector__k': 46, 'model__learning_rate': 0.044313210628564394, 'model__n_estimators': 442, 'model__max_depth': 25, 'model__num_leaves': 8, 'model__min_child_samples': 7, 'model__subsample': 0.8706979373159006, 'model__colsample_bytree': 0.6985991483484312} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:51,913] Trial 6 failed with value nan.
# [I 2024-06-14 16:55:52,128] Trial 7 finished with value: -15.960051829317964 and parameters: {'selector__k': 26, 'model__learning_rate': 0.773757003311579, 'model__n_estimators': 143, 'model__max_depth': 7, 'model__num_leaves': 28, 'model__min_child_samples': 19, 'model__subsample': 0.8095846730970973, 'model__colsample_bytree': 0.6524224921030382}. Best is trial 0 with value: -8.040665971661948.
# [I 2024-06-14 16:55:52,880] Trial 8 finished with value: -16.787216547981657 and parameters: {'selector__k': 29, 'model__learning_rate': 0.6494935289683852, 'model__n_estimators': 260, 'model__max_depth': 50, 'model__num_leaves': 27, 'model__min_child_samples': 13, 'model__subsample': 0.7007784505054004, 'model__colsample_bytree': 0.4375049994726099}. Best is trial 0 with value: -8.040665971661948.
# [I 2024-06-14 16:55:53,718] Trial 9 finished with value: -8.772319671381284 and parameters: {'selector__k': 22, 'model__learning_rate': 0.10887530460486643, 'model__n_estimators': 377, 'model__max_depth': 9, 'model__num_leaves': 35, 'model__min_child_samples': 5, 'model__subsample': 0.5498147697842382, 'model__colsample_bytree': 0.5341379486005671}. Best is trial 0 with value: -8.040665971661948.
# [I 2024-06-14 16:55:53,851] Trial 10 finished with value: -9.55875071351101 and parameters: {'selector__k': 31, 'model__learning_rate': 0.024069133267116016, 'model__n_estimators': 102, 'model__max_depth': 14, 'model__num_leaves': 8, 'model__min_child_samples': 6, 'model__subsample': 0.11367698766645999, 'model__colsample_bytree': 0.9917130652733679}. Best is trial 0 with value: -8.040665971661948.
# [I 2024-06-14 16:55:53,982] Trial 11 finished with value: -15.234291732704577 and parameters: {'selector__k': 7, 'model__learning_rate': 0.6298796200231076, 'model__n_estimators': 278, 'model__max_depth': 44, 'model__num_leaves': 4, 'model__min_child_samples': 18, 'model__subsample': 0.903901319508947, 'model__colsample_bytree': 0.22665799398839173}. Best is trial 0 with value: -8.040665971661948.
# [I 2024-06-14 16:55:55,138] Trial 12 finished with value: -13.666934865095758 and parameters: {'selector__k': 33, 'model__learning_rate': 0.7537952298929401, 'model__n_estimators': 490, 'model__max_depth': 29, 'model__num_leaves': 32, 'model__min_child_samples': 18, 'model__subsample': 0.9439088087803621, 'model__colsample_bytree': 0.9135074616268108}. Best is trial 0 with value: -8.040665971661948.
# [W 2024-06-14 16:55:55,179] Trial 13 failed with parameters: {'selector__k': 48, 'model__learning_rate': 0.3480013351128236, 'model__n_estimators': 58, 'model__max_depth': 22, 'model__num_leaves': 50, 'model__min_child_samples': 1, 'model__subsample': 0.5057951557001924, 'model__colsample_bytree': 0.7562048611330815} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:55,180] Trial 13 failed with value nan.
# [W 2024-06-14 16:55:55,223] Trial 14 failed with parameters: {'selector__k': 48, 'model__learning_rate': 0.34307419436086695, 'model__n_estimators': 54, 'model__max_depth': 21, 'model__num_leaves': 50, 'model__min_child_samples': 1, 'model__subsample': 0.477555839604941, 'model__colsample_bytree': 0.7604306918954742} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:55,224] Trial 14 failed with value nan.
# [W 2024-06-14 16:55:55,269] Trial 15 failed with parameters: {'selector__k': 48, 'model__learning_rate': 0.35795024842836487, 'model__n_estimators': 53, 'model__max_depth': 22, 'model__num_leaves': 50, 'model__min_child_samples': 1, 'model__subsample': 0.4667190091647564, 'model__colsample_bytree': 0.7585455678237336} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:55,270] Trial 15 failed with value nan.
# [W 2024-06-14 16:55:55,314] Trial 16 failed with parameters: {'selector__k': 48, 'model__learning_rate': 0.3191214021899016, 'model__n_estimators': 51, 'model__max_depth': 21, 'model__num_leaves': 49, 'model__min_child_samples': 1, 'model__subsample': 0.476775400818788, 'model__colsample_bytree': 0.7563174364551788} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:55,315] Trial 16 failed with value nan.
# [W 2024-06-14 16:55:55,361] Trial 17 failed with parameters: {'selector__k': 45, 'model__learning_rate': 0.33254988983415246, 'model__n_estimators': 62, 'model__max_depth': 22, 'model__num_leaves': 49, 'model__min_child_samples': 1, 'model__subsample': 0.5030243116285642, 'model__colsample_bytree': 0.7669330442180604} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:55,362] Trial 17 failed with value nan.
# [W 2024-06-14 16:55:55,404] Trial 18 failed with parameters: {'selector__k': 48, 'model__learning_rate': 0.3833971818581958, 'model__n_estimators': 76, 'model__max_depth': 21, 'model__num_leaves': 44, 'model__min_child_samples': 2, 'model__subsample': 0.47497385118486896, 'model__colsample_bytree': 0.738675328334965} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:55,405] Trial 18 failed with value nan.
# [W 2024-06-14 16:55:55,457] Trial 19 failed with parameters: {'selector__k': 46, 'model__learning_rate': 0.3669576331284858, 'model__n_estimators': 57, 'model__max_depth': 22, 'model__num_leaves': 45, 'model__min_child_samples': 2, 'model__subsample': 0.484513247384521, 'model__colsample_bytree': 0.7685206668246773} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:55,458] Trial 19 failed with value nan.
# [W 2024-06-14 16:55:55,508] Trial 20 failed with parameters: {'selector__k': 46, 'model__learning_rate': 0.34793535070425896, 'model__n_estimators': 50, 'model__max_depth': 21, 'model__num_leaves': 48, 'model__min_child_samples': 1, 'model__subsample': 0.4559997755924093, 'model__colsample_bytree': 0.7300680558228362} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:55,508] Trial 20 failed with value nan.
# [W 2024-06-14 16:55:55,551] Trial 21 failed with parameters: {'selector__k': 46, 'model__learning_rate': 0.3500128339024679, 'model__n_estimators': 54, 'model__max_depth': 20, 'model__num_leaves': 49, 'model__min_child_samples': 1, 'model__subsample': 0.48462848824377036, 'model__colsample_bytree': 0.7757910698081684} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:55,552] Trial 21 failed with value nan.
# [I 2024-06-14 16:55:55,922] Trial 22 finished with value: -8.59481422256157 and parameters: {'selector__k': 13, 'model__learning_rate': 0.35279765846228434, 'model__n_estimators': 62, 'model__max_depth': 22, 'model__num_leaves': 49, 'model__min_child_samples': 1, 'model__subsample': 0.48623663522898286, 'model__colsample_bytree': 0.7403995210711514}. Best is trial 0 with value: -8.040665971661948.
# [I 2024-06-14 16:55:56,240] Trial 23 finished with value: -8.686177610336836 and parameters: {'selector__k': 13, 'model__learning_rate': 0.3338000696420342, 'model__n_estimators': 52, 'model__max_depth': 22, 'model__num_leaves': 50, 'model__min_child_samples': 1, 'model__subsample': 0.4947333350753037, 'model__colsample_bytree': 0.7682869274932281}. Best is trial 0 with value: -8.040665971661948.
# [W 2024-06-14 16:55:56,287] Trial 24 failed with parameters: {'selector__k': 43, 'model__learning_rate': 0.369426482421507, 'model__n_estimators': 51, 'model__max_depth': 21, 'model__num_leaves': 48, 'model__min_child_samples': 1, 'model__subsample': 0.3629344382350753, 'model__colsample_bytree': 0.7577685203183031} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:56,288] Trial 24 failed with value nan.
# [I 2024-06-14 16:55:56,590] Trial 25 finished with value: -8.79421184914477 and parameters: {'selector__k': 17, 'model__learning_rate': 0.3883952819719753, 'model__n_estimators': 51, 'model__max_depth': 22, 'model__num_leaves': 50, 'model__min_child_samples': 1, 'model__subsample': 0.39508648176032435, 'model__colsample_bytree': 0.7474535977247265}. Best is trial 0 with value: -8.040665971661948.
# [W 2024-06-14 16:55:56,641] Trial 26 failed with parameters: {'selector__k': 44, 'model__learning_rate': 0.40159318326278826, 'model__n_estimators': 73, 'model__max_depth': 31, 'model__num_leaves': 42, 'model__min_child_samples': 8, 'model__subsample': 0.2874965624549176, 'model__colsample_bytree': 0.7890117720555473} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:56,642] Trial 26 failed with value nan.
# [W 2024-06-14 16:55:56,693] Trial 27 failed with parameters: {'selector__k': 44, 'model__learning_rate': 0.3722055464193742, 'model__n_estimators': 77, 'model__max_depth': 31, 'model__num_leaves': 42, 'model__min_child_samples': 8, 'model__subsample': 0.25975458967565823, 'model__colsample_bytree': 0.7971929006828234} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:56,693] Trial 27 failed with value nan.
# [W 2024-06-14 16:55:56,754] Trial 28 failed with parameters: {'selector__k': 45, 'model__learning_rate': 0.4180734891301248, 'model__n_estimators': 76, 'model__max_depth': 32, 'model__num_leaves': 42, 'model__min_child_samples': 8, 'model__subsample': 0.2470846632028445, 'model__colsample_bytree': 0.801938441961808} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:56,756] Trial 28 failed with value nan.
# [W 2024-06-14 16:55:56,813] Trial 29 failed with parameters: {'selector__k': 45, 'model__learning_rate': 0.4045115000778494, 'model__n_estimators': 73, 'model__max_depth': 32, 'model__num_leaves': 42, 'model__min_child_samples': 8, 'model__subsample': 0.33503263884844914, 'model__colsample_bytree': 0.8034640685369201} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:56,814] Trial 29 failed with value nan.
# [W 2024-06-14 16:55:56,874] Trial 30 failed with parameters: {'selector__k': 42, 'model__learning_rate': 0.3979908407389649, 'model__n_estimators': 82, 'model__max_depth': 35, 'model__num_leaves': 43, 'model__min_child_samples': 8, 'model__subsample': 0.34555992164643234, 'model__colsample_bytree': 0.7976828138696724} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:56,875] Trial 30 failed with value nan.
# [W 2024-06-14 16:55:56,929] Trial 31 failed with parameters: {'selector__k': 45, 'model__learning_rate': 0.40887873695628635, 'model__n_estimators': 243, 'model__max_depth': 30, 'model__num_leaves': 43, 'model__min_child_samples': 9, 'model__subsample': 0.31842626031459664, 'model__colsample_bytree': 0.7567489852469584} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:56,930] Trial 31 failed with value nan.
# [I 2024-06-14 16:55:57,118] Trial 32 finished with value: -13.727371490708022 and parameters: {'selector__k': 4, 'model__learning_rate': 0.3683060611745156, 'model__n_estimators': 79, 'model__max_depth': 15, 'model__num_leaves': 41, 'model__min_child_samples': 8, 'model__subsample': 0.31512722050708697, 'model__colsample_bytree': 0.106270223449204}. Best is trial 0 with value: -8.040665971661948.
# [W 2024-06-14 16:55:57,189] Trial 33 failed with parameters: {'selector__k': 45, 'model__learning_rate': 0.5112081482699853, 'model__n_estimators': 225, 'model__max_depth': 31, 'model__num_leaves': 43, 'model__min_child_samples': 3, 'model__subsample': 0.6858430947917289, 'model__colsample_bytree': 0.8093122951234062} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:57,190] Trial 33 failed with value nan.
# [W 2024-06-14 16:55:57,258] Trial 34 failed with parameters: {'selector__k': 44, 'model__learning_rate': 0.4984278912958342, 'model__n_estimators': 205, 'model__max_depth': 36, 'model__num_leaves': 42, 'model__min_child_samples': 3, 'model__subsample': 0.672445898597075, 'model__colsample_bytree': 0.7931290801602118} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:57,259] Trial 34 failed with value nan.
# [W 2024-06-14 16:55:57,315] Trial 35 failed with parameters: {'selector__k': 45, 'model__learning_rate': 0.49907717363392423, 'model__n_estimators': 203, 'model__max_depth': 29, 'model__num_leaves': 43, 'model__min_child_samples': 3, 'model__subsample': 0.6951171612515883, 'model__colsample_bytree': 0.7997152402535372} because of the following error: The value nan is not acceptable.
# [W 2024-06-14 16:55:57,316] Trial 35 failed with value nan.
# [W 2024-06-14 16:55:57,369] Trial 36 failed with parameters: {'selector__k': 42, 'model__learning_rate': 0.5018836542368708, 'model__n_estimators': 206, 'model__max_depth': 31, 'model__num_leaves': 43, 'model__min_child_samples': 3, 'model__subsample': 0.6745433974603221, 'model__colsample_bytree': 0.789700542634267} because of the following error: The value nan is not acceptable.
# ...
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_gb.py:610, in BaseGradientBoosting._fit_stages(self, X, y, raw_predictions, sample_weight, random_state, X_val, y_val, sample_weight_val, begin_at_stage, monitor)
#     603         initial_loss = loss_(
#     604             y[~sample_mask],
#     605             raw_predictions[~sample_mask],
#     606             sample_weight[~sample_mask],
#     607         )
#     609 # fit next stage of trees
# --> 610 raw_predictions = self._fit_stage(
#     611     i,
#     612     X,
#     613     y,
#     614     raw_predictions,
#     615     sample_weight,
#     616     sample_mask,
#     617     random_state,
#     618     X_csc,
#     619     X_csr,
#     620 )
#     622 # track loss
#     623 if do_oob:
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_gb.py:245, in BaseGradientBoosting._fit_stage(self, i, X, y, raw_predictions, sample_weight, sample_mask, random_state, X_csc, X_csr)
#     242     sample_weight = sample_weight * sample_mask.astype(np.float64)
#     244 X = X_csr if X_csr is not None else X
# --> 245 tree.fit(X, residual, sample_weight=sample_weight, check_input=False)
#     247 # update tree leaves
#     248 loss.update_terminal_regions(
#     249     tree.tree_,
#     250     X,
#    (...)
#     257     k=k,
#     258 )
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\tree\_classes.py:1320, in DecisionTreeRegressor.fit(self, X, y, sample_weight, check_input)
#    1290 @_fit_context(prefer_skip_nested_validation=True)
#    1291 def fit(self, X, y, sample_weight=None, check_input=True):
#    1292     """Build a decision tree regressor from the training set (X, y).
#    1293
#    1294     Parameters
#    (...)
#    1317         Fitted estimator.
#    1318     """
# -> 1320     super()._fit(
#    1321         X,
#    1322         y,
#    1323         sample_weight=sample_weight,
#    1324         check_input=check_input,
#    1325     )
#    1326     return self
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\tree\_classes.py:443, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     432 else:
#     433     builder = BestFirstTreeBuilder(
#     434         splitter,
#     435         min_samples_split,
#    (...)
#     440         self.min_impurity_decrease,
#     441     )
# --> 443 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     445 if self.n_outputs_ == 1 and is_classifier(self):
#     446     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:
# [I 2024-03-05 22:46:37,445] Trial 1 finished with value: -24.040013343273138 and parameters: {'selector__k': 22, 'model__kernel': DotProduct(sigma_0=1) + WhiteKernel(noise_level=1), 'model__alpha': 424793770.1229809}. Best is trial 1 with value: -24.040013343273138.
# [I 2024-03-05 22:46:39,339] Trial 2 finished with value: -29.13557360985365 and parameters: {'selector__k': 40, 'model__kernel': 1**2 * Matern(length_scale=1, nu=1.5), 'model__alpha': 9765930507.399818}. Best is trial 1 with value: -24.040013343273138.
# [I 2024-03-05 22:46:39,579] Trial 3 finished with value: -29.135573608006247 and parameters: {'selector__k': 18, 'model__kernel': 0.5**2 * RationalQuadratic(alpha=1, length_scale=1), 'model__alpha': 4155669346.4848695}. Best is trial 1 with value: -24.040013343273138.
# [I 2024-03-05 22:46:39,839] Trial 4 finished with value: -29.134933841605687 and parameters: {'selector__k': 21, 'model__kernel': 50**2 * RBF(length_scale=50), 'model__alpha': 4403261578.166934}. Best is trial 1 with value: -24.040013343273138.
# [I 2024-03-05 22:46:40,085] Trial 5 finished with value: -29.13191107406027 and parameters: {'selector__k': 17, 'model__kernel': 50**2 * RBF(length_scale=50), 'model__alpha': 4514785246.914673}. Best is trial 1 with value: -24.040013343273138.
# [I 2024-03-05 22:46:40,340] Trial 6 finished with value: -29.13557360982676 and parameters: {'selector__k': 40, 'model__kernel': 0.5**2 * RationalQuadratic(alpha=1, length_scale=1), 'model__alpha': 4536809944.648671}. Best is trial 1 with value: -24.040013343273138.
# [I 2024-03-05 22:46:40,586] Trial 7 finished with value: -29.135568603905522 and parameters: {'selector__k': 29, 'model__kernel': RBF(length_scale=1) + 1.41**2, 'model__alpha': 5486074603.386683}. Best is trial 1 with value: -24.040013343273138.
# [I 2024-03-05 22:46:40,725] Trial 8 finished with value: -26.49790129603825 and parameters: {'selector__k': 30, 'model__kernel': DotProduct(sigma_0=1) + WhiteKernel(noise_level=1), 'model__alpha': 2636955097.729907}. Best is trial 1 with value: -24.040013343273138.
# [I 2024-03-05 22:46:40,990] Trial 9 finished with value: -29.13557360983344 and parameters: {'selector__k': 40, 'model__kernel': 0.5**2 * RationalQuadratic(alpha=1, length_scale=1), 'model__alpha': 6034801019.249974}. Best is trial 1 with value: -24.040013343273138.
# [I 2024-03-05 22:46:41,488] Trial 10 finished with value: -29.13557360971299 and parameters: {'selector__k': 7, 'model__kernel': 0.1**2 * RBF(length_scale=0.1) + WhiteKernel(noise_level=0.01), 'model__alpha': 108150504.69992638}. Best is trial 1 with value: -24.040013343273138.
# [I 2024-03-05 22:46:41,655] Trial 11 finished with value: -29.066318504994307 and parameters: {'selector__k': 9, 'model__kernel': DotProduct(sigma_0=1) + WhiteKernel(noise_level=1), 'model__alpha': 215845164.58415318}. Best is trial 1 with value: -24.040013343273138.
# [I 2024-03-05 22:46
. Best is trial 3 with value: -7.717460021548955.
# [I 2024-03-05 22:47:02,887] Trial 4 finished with value: -11.562354431525605 and parameters: {'selector__k': 6, 'model__learning_rate': 0.5094167903582406, 'model__n_estimators': 456, 'model__max_depth': 1, 'model__max_leaves': 17, 'model__max_bin': 28, 'model__gamma': 12}. Best is trial 3 with value: -7.717460021548955.
# [I 2024-03-05 22:47:03,079] Trial 5 finished with value: -11.508161739973922 and parameters: {'selector__k': 40, 'model__learning_rate': 0.6220805232033215, 'model__n_estimators': 143, 'model__max_depth': 15, 'model__max_leaves': 47, 'model__max_bin': 39, 'model__gamma': 1}. Best is trial 3 with value: -7.717460021548955.
# [I 2024-03-05 22:47:03,631] Trial 6 finished with value: -10.067108087105712 and parameters: {'selector__k': 47, 'model__learning_rate': 0.03623920358164273, 'model__n_estimators': 403, 'model__max_depth': 8, 'model__max_leaves': 50, 'model__max_bin': 25, 'model__gamma': 16}. Best is trial 3 with value: -7.717460021548955.
# [I 2024-03-05 22:47:03,950] Trial 7 finished with value: -9.076323967684903 and parameters: {'selector__k': 27, 'model__learning_rate': 0.9708378892559705, 'model__n_estimators': 428, 'model__max_depth': 7, 'model__max_leaves': 29, 'model__max_bin': 11, 'model__gamma': 10}. Best is trial 3 with value: -7.717460021548955.
# [I 2024-03-05 22:47:04,269] Trial 8 finished with value: -8.350099642325757 and parameters: {'selector__k': 20, 'model__learning_rate': 0.15960085634940566, 'model__n_estimators': 428, 'model__max_depth': 11, 'model__max_leaves': 20, 'model__max_bin': 23, 'model__gamma': 6}. Best is trial 3 with value: -7.717460021548955.
# [I 2024-03-05 22:47:04,467] Trial 9 finished with value: -9.682903653518274 and parameters: {'selector__k': 34, 'model__learning_rate': 0.20139750827323782, 'model__n_estimators': 185, 'model__max_depth': 10, 'model__max_leaves': 14, 'model__max_bin': 29, 'model__gamma': 11}. Best is trial 3 with value: -7.717460021548955.
# [I 2024-03-05 22:47:04,626] Trial 10 finished with value: -12.208842289900598 and parameters: {'selector__k': 2, 'model__learning_rate': 0.759122015213449, 'model__n_estimators': 56, 'model__max_depth': 1, 'model__max_leaves': 4, 'model__max_bin': 49, 'model__gamma': 7}. Best is trial 3 with value: -7.717460021548955.
# [I 2024-03-05 22:47:04,818] Trial 11 finished with value: -12.292324419335909 and parameters: {'selector__k': 15, 'model__learning_rate': 0.33661895594825597, 'model__n_estimators': 75, 'model__max_depth': 14, 'model__max_leaves': 36, 'model__max_bin': 2, 'model__gamma': 6}. Best is trial 3 with value: -7.717460021548955.
# [I 2024-03-05 22:47:05,043] Trial 12 finished with value: -7.992902595022533 and parameters: {'selector__k': 12, 'model__learning_rate': 0.07575280461724843, 'model__n_estimators': 100, 'model__max_depth': 12, 'model__max_leaves': 7, 'model__max_bin': 18, 'model__gamma': 6}. Best is trial 3 with value: -7.717460021548955.
# [I 2024-03-05 22:47:05,262] Trial 13 finished with value: -13.671473279522983 and parameters: {'selector__k': 10, 'model__learning_rate': 0.010051211178734754, 'model__n_estimators': 99, 'model__max_depth': 5, 'model__max_leaves': 8, 'model__max_bin': 16, 'model__gamma': 8}. Best is trial 3 with value: -7.717460021548955.
# [I 2024-03-05 22:47:05,446] Trial 14 finished with value: -9.269266055548735 and parameters: {'selector__k': 13, 'model__learning_rate': 0.382495100457026, 'model__n_estimators': 51, 'model__max_depth': 13, 'model__max_leaves': 36, 'model__max_bin': 6, 'model__gamma': 4}. Best is trial 3 with value: -7.717460021548955.
# [I 2024-03-05 22:47:05,630] Trial 15 finished with value: -8.567733587660719 and parameters: {'selector__k': 27, 'model__learning_rate': 0.24417908248792983, 'model__n_estimators': 85, 'model__max_depth': 4, 'model__max_leaves': 2, 'model__max_bin': 19, 'model__gamma': 14}. Best is trial 3 with value: -7.717460021548955.
# [I 2024-03-05 22:47:05,918] Trial 16 finished with value: -9.00921271869475 and parameters: {'selector__k': 21, 'model__learning_rate': 0.11147589320028822, 'model__n_estimators': 145, 'model__max_depth': 10, 'model__max_leaves': 29, 'model__max_bin': 38, 'model__gamma': 9}. Best is trial 3 with value: -7.717460021548955.
# [I 2024-03-05 22:47:06,114] Trial 17 finished with value: -9.198689178574528 and parameters: {'selector__k': 9, 'model__learning_rate': 0.4039275145943276, 'model__n_estimators': 66, 'model__max_depth': 17, 'model__max_leaves': 11, 'model__max_bin': 10, 'model__gamma': 4}. Best is trial 3 with value: -7.717460021548955.
# [I 2024-03-05 22:47:06,309] Trial 18 finished with value: -10.899290076356792 and parameters: {'selector__k': 2, 'model__learning_rate': 0.7170097876298137, 'model__n_estimators': 118, 'model__max_depth': 8, 'model__max_leaves': 42, 'model__max_bin': 21, 'model__gamma': 13}. Best is trial 3 with value: -7.717460021548955.
# [I 2024-03-05 22:47:06,639] Trial 19 finished with value: -8.236971013409372 and parameters: {'selector__k': 15, 'model__learning_rate': 0.09206192528530588, 'model__n_estimators': 230, 'model__max_depth': 12, 'model__max_leaves': 24, 'model__max_bin': 17, 'model__gamma': 16}. Best is trial 3 with value: -7.717460021548955.
# [I 2024-03-05 22:47:06,863] Trial 20 finished with value: -7.547178927206244 and parameters: {'selector__k': 30, 'model__learning_rate': 0.2724748010055935, 'model__n_estimators': 87, 'model__max_depth': 16, 'model__max_leaves': 35, 'model__max_bin': 36, 'model__gamma': 4}. Best is trial 20 with value: -7.547178927206244.
# [I 2024-03-05 22:47:07,097] Trial 21 finished with value: -9.492432680867886 and parameters: {'selector__k': 32, 'model__learning_rate': 0.25935976691991397, 'model__n_estimators': 80, 'model__max_depth': 16, 'model__max_leaves': 37, 'model__max_bin': 37, 'model__gamma': 4}. Best is trial 20 with value: -7.547178927206244.
# [I 2024-03-05 22:47:07,339] Trial 22 finished with value: -11.379100840050455 and parameters: {'selector__k': 32, 'model__learning_rate': 0.41088289053437577, 'model__n_estimators': 124, 'model__max_depth': 20, 'model__max_leaves': 45, 'model__max_bin': 43, 'model__gamma': 5}. Best is trial 20 with value: -7.547178927206244.
# [I 2024-03-05 22:47:07,562] Trial 23 finished with value: -8.208017998254823 and parameters: {'selector__k': 24, 'model__learning_rate': 0.2261683757784717, 'model__n_estimators': 93, 'model__max_depth': 14, 'model__max_leaves': 33, 'model__max_bin': 33, 'model__gamma': 8}. Best is trial 20 with value: -7.547178927206244.
# [I 2024-03-05 22:47:07,831] Trial 24 finished with value: -8.309627183543363 and parameters: {'selector__k': 17, 'model__learning_rate': 0.08518913508206813, 'model__n_estimators': 66, 'model__max_depth': 16, 'model__max_leaves': 41, 'model__max_bin': 24, 'model__gamma': 3}. Best is trial 20 with value: -7.547178927206244.
# [I 2024-03-05 22:47:08,033] Trial 25 finished with value: -9.215395726975594 and parameters: {'selector__k': 10, 'model__learning_rate': 0.30368664902209563, 'model__n_estimators': 68, 'model__max_depth': 3, 'model__max_leaves': 32, 'model__max_bin': 12, 'model__gamma': 10}. Best is trial 20 with value: -7.547178927206244.
# [I 2024-03-05 22:47:08,296] Trial 26 finished with value: -8.743282381891177 and parameters: {'selector__k': 26, 'model__learning_rate': 0.1811627126789333, 'model__n_estimators': 119, 'model__max_depth': 12, 'model__max_leaves': 49, 'model__max_bin': 43, 'model__gamma': 7}. Best is trial 20 with value: -7.547178927206244.
# [I 2024-03-05 22:47:08,526] Trial 27 finished with value: -10.747379464003187 and parameters: {'selector__k': 6, 'model__learning_rate': 0.4557405798121832, 'model__n_estimators': 161, 'model__max_depth': 7, 'model__max_leaves': 44, 'model__max_bin': 21, 'model__gamma': 6}. Best is trial 20 with value: -7.547178927206244.
# [I 2024-03-05 22:47:08,746] Trial 28 finished with value: -8.669656603375836 and parameters: {'selector__k': 23, 'model__learning_rate': 0.3403669741510426, 'model__n_estimators': 95, 'model__max_depth': 9, 'model__max_leaves': 39, 'model__max_bin': 35, 'model__gamma': 8}. Best is trial 20 with value: -7.547178927206244.
# [I 2024-03-05 22:47:09,016] Trial 29 finished with value: -10.143445306899903 and parameters: {'selector__k': 36, 'model__learning_rate': 0.2944103230746779, 'model__n_estimators': 195, 'model__max_depth': 13, 'model__max_leaves': 25, 'model__max_bin': 7, 'model__gamma': 3}. Best is trial 20 with value: -7.547178927206244.
# [I 2024-03-05 22:47:09,249] Trial 30 finished with value: -8.529102643823967 and parameters: {'selector__k': 30, 'model__learning_rate': 0.05273040603076139, 'model__n_estimators': 59, 'model__max_depth': 6, 'model__max_leaves': 32, 'model__max_bin': 14, 'model__gamma': 2}. Best is trial 20 with value: -7.547178927206244.
# [I 2024-03-05 22:47:09,490] Trial 31 finished with value: -9.431373649760443 and parameters: {'selector__k': 38, 'model__learning_rate': 0.20910415256117076, 'model__n_estimators': 89, 'model__max_depth': 14, 'model__max_leaves': 33, 'model__max_bin': 32, 'model__gamma': 9}. Best is trial 20 with value: -7.547178927206244.
# [I 2024-03-05 22:47:09,761] Trial 32 finished with value: -8.72192617577164 and parameters: {'selector__k': 24, 'model__learning_rate': 0.12289079386138158, 'model__n_estimators': 103, 'model__max_depth': 15, 'model__max_leaves': 21, 'model__max_bin': 27, 'model__gamma': 8}. Best is trial 20 with value: -7.547178927206244.
# [I 2024-03-05 22:47:10,000] Trial 33 finished with value: -9.522551866772815 and parameters: {'selector__k': 43, 'model__learning_rate': 0.24223936657722706, 'model__n_estimators': 74, 'model__max_depth': 18, 'model__max_leaves': 28, 'model__max_bin': 42, 'model__gamma': 11}. Best is trial 20 with value: -7.547178927206244.
# [I 2024-03-05 22:47:10,216] Trial 34 finished with value: -7.967093625635201 and parameters: {'selector__k': 13, 'model__learning_rate': 0.48246508790654774, 'model__n_estimators': 109, 'model__max_depth': 11, 'model__max_leaves': 34, 'model__max_bin': 33, 'model__gamma': 5}. Best is trial 20 with value: -7.547178927206244.
# [I 2024-03-05 22:47:10,435] Trial 35 finished with value: -8.187880519212467 and parameters: {'selector__k': 13, 'model__learning_rate': 0.55865580989651, 'model__n_estimators': 111, 'model__max_depth': 11, 'model__max_leaves': 38, 'model__max_bin': 30, 'model__gamma': 1}. Best is trial 20 with value: -7.547178927206244.
# [I 2024-03-05 22:47:10,674] Trial 36 finished with value: -8.583091347607652 and parameters: {'selector__k': 7, 'model__learning_rate': 0.5840647058567852, 'model__n_estimators': 134, 'model__max_depth': 9, 'model__max_leaves': 46, 'model__max_bin': 49, 'model__gamma': 19}. Best is trial 20 with value: -7.547178927206244.
# [I 2024-03-05 22:47:10,962] Trial 37 finished with value: -8.419344907256129 and parameters: {'selector__k': 19, 'model__learning_rate': 0.4804320025544154, 'model__n_estimators': 240, 'model__max_depth': 12, 'model__max_leaves': 23, 'model__max_bin': 26, 'model__gamma': 5}. Best is trial 20 with value: -7.547178927206244.
# [I 2024-03-05 22:47:11,215] Trial 38 finished with value: -8.884961440231978 and parameters: {'selector__k': 17, 'model__learning_rate': 0.6406914933386411, 'model__n_estimators': 154, 'model__max_depth': 19, 'model__max_leaves': 17, 'model__max_bin': 40, 'model__gamma': 2}. Best is trial 20 with value: -7.547178927206244.
# [I 2024-03-05 22:47:11,456] Trial 39 finished with value: -8.583996078126239 and parameters: {'selector__k': 13, 'model__learning_rate': 0.938724299022853, 'model__n_estimators': 170, 'model__max_depth': 2, 'model__max_leaves': 43, 'model__max_bin': 34, 'model__gamma': 5}. Best is trial 20 with value: -7.547178927206244.
# [I 2024-03-05 22:47:11,699] Trial 40 finished with value: -9.34716607818937 and parameters: {'selector__k': 22, 'model__learning_rate': 0.43549595074984704, 'model__n_estimators': 131, 'model__max_depth': 9, 'model__max_leaves': 48, 'model__max_bin': 20, 'model__gamma': 3}. Best is trial 20 with value: -7.547178927206244.
# [I 2024-03-05 22:47:11,928] Trial 41 finished with value: -8.346252656478104 and parameters: {'selector__k': 12, 'model__learning_rate': 0.5120726042427818, 'model__n_estimators': 108, 'model__max_depth': 11, 'model__max_leaves': 39, 'model__max_bin': 30, 'model__gamma': 1}. Best is trial 20 with value: -7.547178927206244.
# [I 2024-03-05 22:47:12,164] Trial 42 finished with value: -10.405584328048702 and parameters: {'selector__k': 6, 'model__learning_rate': 0.5475984036170589, 'model__n_estimators': 112, 'model__max_depth': 11, 'model__max_leaves': 39, 'model__max_bin': 28, 'model__gamma': 1}. Best is trial 20 with value: -7.547178927206244.
# [I 2024-03-05 22:47:12,365] Trial 43 finished with value: -8.24043552610027 and parameters: {'selector__k': 16, 'model__learning_rate': 0.6820160246187631, 'model__n_estimators': 84, 'model__max_depth': 13, 'model__max_leaves': 36, 'model__max_bin': 36, 'model__gamma': 2}. Best is trial 20 with value: -7.547178927206244.
# [I 2024-03-05 22:47:12,588] Trial 44 finished with value: -8.275560578481409 and parameters: {'selector__k': 19, 'model__learning_rate': 0.3543036430064287, 'model__n_estimators': 101, 'model__max_depth': 10, 'model__max_leaves': 27, 'model__max_bin': 23, 'model__gamma': 3}. Best is trial 20 with value: -7.547178927206244.
# [I 2024-03-05 22:47:12,780] Trial 45 finished with value: -9.980354693449753 and parameters: {'selector__k': 4, 'model__learning_rate': 0.7944297577877973, 'model__n_estimators': 76, 'model__max_depth': 8, 'model__max_leaves': 31, 'model__max_bin': 31, 'model__gamma': 6}. Best is trial 20 with value: -7.547178927206244.
# [I 2024-03-05 22:47:12,994] Trial 46 finished with value: -8.342737761954053 and parameters: {'selector__k': 12, 'model__learning_rate': 0.5580024021338547, 'model__n_estimators': 91, 'model__max_depth': 6, 'model__max_leaves': 35, 'model__max_bin': 18, 'model__gamma': 4}. Best is trial 20 with value: -7.547178927206244.
# [I 2024-03-05 22:47:13,306] Trial 47 finished with value: -8.092232225585592 and parameters: {'selector__k': 9, 'model__learning_rate': 0.5931240015252371, 'model__n_estimators': 301, 'model__max_depth': 15, 'model__max_leaves': 9, 'model__max_bin': 46, 'model__gamma': 7}. Best is trial 20 with value: -7.547178927206244.
# [I 2024-03-05 22:47:13,630] Trial 48 finished with value: -7.872962065090153 and parameters: {'selector__k': 8, 'model__learning_rate': 0.15616486887708603, 'model__n_estimators': 276, 'model__max_depth': 16, 'model__max_leaves': 7, 'model__max_bin': 46, 'model__gamma': 12}. Best is trial 20 with value: -7.547178927206244.
# [I 2024-03-05 22:47:14,014] Trial 49 finished with value: -8.496100159659747 and parameters: {'selector__k': 29, 'model__learning_rate': 0.15495969323953773, 'model__n_estimators': 347, 'model__max_depth': 18, 'model__max_leaves': 5, 'model__max_bin': 40, 'model__gamma': 13}. Best is trial 20 with value: -7.547178927206244.
# [I 2024-03-05 22:47:14,118] A new study created in memory with name: no-name-5a263748-2f4f-48ac-949b-de8bd7506e44
# XGB -7.547178927206244 10.329288991723658 306.23490355093264 195.2083522251674
# [I 2024-03-05 22:47:15,064] Trial 0 finished with value: -8.858247267168705 and parameters: {'selector__k': 24, 'model__learning_rate': 0.4653584482628788, 'model__n_estimators': 413, 'model__max_depth': 33, 'model__num_leaves': 32, 'model__min_child_samples': 1, 'model__subsample': 0.21247981918362702, 'model__colsample_bytree': 0.2825551216142438}. Best is trial 0 with value: -8.858247267168705.
# [I 2024-03-05 22:47:15,205] Trial 1 finished with value: -11.662470801059547 and parameters: {'selector__k': 22, 'model__learning_rate': 0.6117486036840505, 'model__n_estimators': 61, 'model__max_depth': 41, 'model__num_leaves': 43, 'model__min_child_samples': 16, 'model__subsample': 0.3005432701846761, 'model__colsample_bytree': 0.28162322390926914}. Best is trial 0 with value: -8.858247267168705.
# [I 2024-03-05 22:47:15,448] Trial 2 finished with value: -13.243402470893761 and parameters: {'selector__k': 7, 'model__learning_rate': 0.6595528615159119, 'model__n_estimators': 187, 'model__max_depth': 43, 'model__num_leaves': 39, 'model__min_child_samples': 5, 'model__subsample': 0.9235256577830969, 'model__colsample_bytree': 0.12220270724523015}. Best is trial 0 with value: -8.858247267168705.
# [I 2024-03-05 22:47:16,035] Trial 3 finished with value: -8.410338144115793 and parameters: {'selector__k': 29, 'model__learning_rate': 0.037821232641937125, 'model__n_estimators': 176, 'model__max_depth': 32, 'model__num_leaves': 29, 'model__min_child_samples': 1, 'model__subsample': 0.3153526274155086, 'model__colsample_bytree': 0.8446361466541223}. Best is trial 3 with value: -8.410338144115793.
# [I 2024-03-05 22:47:16,408] Trial 4 finished with value: -9.428031785015214 and parameters: {'selector__k': 14, 'model__learning_rate': 0.15188188943046102, 'model__n_estimators': 379, 'model__max_depth': 11, 'model__num_leaves': 15, 'model__min_child_samples': 6, 'model__subsample': 0.6120662493444744, 'model__colsample_bytree': 0.11374371963730816}. Best is trial 3 with value: -8.410338144115793.
# [I 2024-03-05 22:47:16,504] Trial 5 finished with value: -10.729372806036475 and parameters: {'selector__k': 15, 'model__learning_rate': 0.03388614426902751, 'model__n_estimators': 56, 'model__max_depth': 4, 'model__num_leaves': 46, 'model__min_child_samples': 17, 'model__subsample': 0.2892852380838394, 'model__colsample_bytree': 0.9568089060166726}. Best is trial 3 with value: -8.410338144115793.
# [I 2024-03-05 22:47:16,730] Trial 6 finished with value: -11.302146445283968 and parameters: {'selector__k': 6, 'model__learning_rate': 0.47899061658869396, 'model__n_estimators': 78, 'model__max_depth': 11, 'model__num_leaves': 37, 'model__min_child_samples': 2, 'model__subsample': 0.8263653962175119, 'model__colsample_bytree': 0.7186185281060459}. Best is trial 3 with value: -8.410338144115793.
# [I 2024-03-05 22:47:16,907] Trial 7 finished with value: -8.77807172201609 and parameters: {'selector__k': 17, 'model__learning_rate': 0.5399209857182303, 'model__n_estimators': 188, 'model__max_depth': 35, 'model__num_leaves': 7, 'model__min_child_samples': 3, 'model__subsample': 0.49555637985656353, 'model__colsample_bytree': 0.9763719376831634}. Best is trial 3 with value: -8.410338144115793.
# [I 2024-03-05 22:47:17,220] Trial 8 finished with value: -12.658388026494238 and parameters: {'selector__k': 45, 'model__learning_rate': 0.48787459186010346, 'model__n_estimators': 139, 'model__max_depth': 18, 'model__num_leaves': 22, 'model__min_child_samples': 18, 'model__subsample': 0.32596340204595375, 'model__colsample_bytree': 0.9173851672872328}. Best is trial 3 with value: -8.410338144115793.
# [I 2024-03-05 22:47:17,498] Trial 9 finished with value: -17.21021560506964 and parameters: {'selector__k': 20, 'model__learning_rate': 0.9270949550503526, 'model__n_estimators': 109, 'model__max_depth': 33, 'model__num_leaves': 37, 'model__min_child_samples': 5, 'model__subsample': 0.7127442463278393, 'model__colsample_bytree': 0.27190136179398094}. Best is trial 3 with value: -8.410338144115793.
# [I 2024-03-05 22:47:18,156] Trial 10 finished with value: -11.2016625998996 and parameters: {'selector__k': 39, 'model__learning_rate': 0.2532370138984086, 'model__n_estimators': 262, 'model__max_depth': 50, 'model__num_leaves': 24, 'model__min_child_samples': 11, 'model__subsample': 0.4713101857707396, 'model__colsample_bytree': 0.6025724137815486}. Best is trial 3 with value: -8.410338144115793.
# [I 2024-03-05 22:47:18,384] Trial 11 finished with value: -11.5662353707061 and parameters: {'selector__k': 32, 'model__learning_rate': 0.8120581469193879, 'model__n_estimators': 209, 'model__max_depth': 28, 'model__num_leaves': 3, 'model__min_child_samples': 9, 'model__subsample': 0.4836394885536781, 'model__colsample_bytree': 0.7786483076612721}. Best is trial 3 with value: -8.410338144115793.
# [I 2024-03-05 22:47:18,639] Trial 12 finished with value: -10.22724206770284 and parameters: {'selector__k': 32, 'model__learning_rate': 0.31165466824083876, 'model__n_estimators': 120, 'model__max_depth': 22, 'model__num_leaves': 9, 'model__min_child_samples': 1, 'model__subsample': 0.10661487200354419, 'model__colsample_bytree': 0.9955757077774444}. Best is trial 3 with value: -8.410338144115793.
# [I 2024-03-05 22:47:19,166] Trial 13 finished with value: -11.96208300739976 and parameters: {'selector__k': 32, 'model__learning_rate': 0.3364520681925226, 'model__n_estimators': 272, 'model__max_depth': 38, 'model__num_leaves': 17, 'model__min_child_samples': 12, 'model__subsample': 0.39581492126010476, 'model__colsample_bytree': 0.8097402496172992}. Best is trial 3 with value: -8.410338144115793.
# [I 2024-03-05 22:47:19,586] Trial 14 finished with value: -8.568200900246552 and parameters: {'selector__k': 15, 'model__learning_rate': 0.6811585802062993, 'model__n_estimators': 170, 'model__max_depth': 28, 'model__num_leaves': 28, 'model__min_child_samples': 4, 'model__subsample': 0.6084496625995935, 'model__colsample_bytree': 0.6279455658402384}. Best is trial 3 with value: -8.410338144115793.
# [I 2024-03-05 22:47:19,926] Trial 15 finished with value: -9.884516302794351 and parameters: {'selector__k': 28, 'model__learning_rate': 0.739850358619932, 'model__n_estimators': 92, 'model__max_depth': 27, 'model__num_leaves': 31, 'model__min_child_samples': 7, 'model__subsample': 0.6410679987340335, 'model__colsample_bytree': 0.5592873383244062}. Best is trial 3 with value: -8.410338144115793.
# [I 2024-03-05 22:47:20,502] Trial 16 finished with value: -8.00055307630308 and parameters: {'selector__k': 11, 'model__learning_rate': 0.018398864041107018, 'model__n_estimators': 278, 'model__max_depth': 19, 'model__num_leaves': 30, 'model__min_child_samples': 8, 'model__subsample': 0.7549343637609642, 'model__colsample_bytree': 0.4405556565788411}. Best is trial 16 with value: -8.00055307630308.
# [I 2024-03-05 22:47:20,993] Trial 17 finished with value: -12.307110958286163 and parameters: {'selector__k': 2, 'model__learning_rate': 0.012015447241772385, 'model__n_estimators': 498, 'model__max_depth': 14, 'model__num_leaves': 22, 'model__min_child_samples': 14, 'model__subsample': 0.7821686970263948, 'model__colsample_bytree': 0.42064366239550344}. Best is trial 16 with value: -8.00055307630308.
# [I 2024-03-05 22:47:21,684] Trial 18 finished with value: -11.220825572012492 and parameters: {'selector__k': 37, 'model__learning_rate': 0.14583907445270905, 'model__n_estimators': 264, 'model__max_depth': 21, 'model__num_leaves': 32, 'model__min_child_samples': 9, 'model__subsample': 0.9911490355067771, 'model__colsample_bytree': 0.4256279461488667}. Best is trial 16 with value: -8.00055307630308.
# [I 2024-03-05 22:47:21,930] Trial 19 finished with value: -8.848316659883382 and parameters: {'selector__k': 10, 'model__learning_rate': 0.1561029965360451, 'model__n_estimators': 333, 'model__max_depth': 1, 'model__num_leaves': 17, 'model__min_child_samples': 8, 'model__subsample': 0.17194783023743465, 'model__colsample_bytree': 0.4420959787201395}. Best is trial 16 with value: -8.00055307630308.
# [I 2024-03-05 22:47:22,257] Trial 20 finished with value: -9.557218092318053 and parameters: {'selector__k': 26, 'model__learning_rate': 0.08796842029428224, 'model__n_estimators': 147, 'model__max_depth': 17, 'model__num_leaves': 50, 'model__min_child_samples': 20, 'model__subsample': 0.8508484766109098, 'model__colsample_bytree': 0.49005772087587357}. Best is trial 16 with value: -8.00055307630308.
# [I 2024-03-05 22:47:22,768] Trial 21 finished with value: -8.905087267295642 and parameters: {'selector__k': 11, 'model__learning_rate': 0.8436250912802201, 'model__n_estimators': 214, 'model__max_depth': 29, 'model__num_leaves': 28, 'model__min_child_samples': 4, 'model__subsample': 0.6087980372129388, 'model__colsample_bytree': 0.6627015627654691}. Best is trial 16 with value: -8.00055307630308.
# [I 2024-03-05 22:47:23,209] Trial 22 finished with value: -8.835125224762205 and parameters: {'selector__k': 19, 'model__learning_rate': 0.23563972303773661, 'model__n_estimators': 165, 'model__max_depth': 25, 'model__num_leaves': 26, 'model__min_child_samples': 3, 'model__subsample': 0.7290063490340349, 'model__colsample_bytree': 0.8693785010326622}. Best is trial 16 with value: -8.00055307630308.
# [I 2024-03-05 22:47:23,885] Trial 23 finished with value: -8.993226893054311 and parameters: {'selector__k': 13, 'model__learning_rate': 0.39300143217305716, 'model__n_estimators': 288, 'model__max_depth': 24, 'model__num_leaves': 30, 'model__min_child_samples': 6, 'model__subsample': 0.682575882099791, 'model__colsample_bytree': 0.6945341506883227}. Best is trial 16 with value: -8.00055307630308.
# [I 2024-03-05 22:47:24,436] Trial 24 finished with value: -10.999957863772305 and parameters: {'selector__k': 7, 'model__learning_rate': 0.9832586363535072, 'model__n_estimators': 229, 'model__max_depth': 30, 'model__num_leaves': 34, 'model__min_child_samples': 3, 'model__subsample': 0.544529965867429, 'model__colsample_bytree': 0.6017212300018298}. Best is trial 16 with value: -8.00055307630308.
# [I 2024-03-05 22:47:24,885] Trial 25 finished with value: -9.202111675265028 and parameters: {'selector__k': 18, 'model__learning_rate': 0.6670216270635029, 'model__n_estimators': 166, 'model__max_depth': 20, 'model__num_leaves': 20, 'model__min_child_samples': 1, 'model__subsample': 0.40764326830559694, 'model__colsample_bytree': 0.815923329629095}. Best is trial 16 with value: -8.00055307630308.
# [I 2024-03-05 22:47:25,179] Trial 26 finished with value: -12.12888496361752 and parameters: {'selector__k': 2, 'model__learning_rate': 0.08393419402743765, 'model__n_estimators': 124, 'model__max_depth': 45, 'model__num_leaves': 26, 'model__min_child_samples': 8, 'model__subsample': 0.565533571158188, 'model__colsample_bytree': 0.5125276084371957}. Best is trial 16 with value: -8.00055307630308.
# [I 2024-03-05 22:47:26,411] Trial 27 finished with value: -8.638690860111396 and parameters: {'selector__k': 29, 'model__learning_rate': 0.2455314111326862, 'model__n_estimators': 334, 'model__max_depth': 36, 'model__num_leaves': 39, 'model__min_child_samples': 4, 'model__subsample': 0.7610389232078231, 'model__colsample_bytree': 0.6159494991671512}. Best is trial 16 with value: -8.00055307630308.
# [I 2024-03-05 22:47:26,650] Trial 28 finished with value: -10.928853181645154 and parameters: {'selector__k': 23, 'model__learning_rate': 0.573340290442127, 'model__n_estimators': 101, 'model__max_depth': 7, 'model__num_leaves': 35, 'model__min_child_samples': 12, 'model__subsample': 0.8810221148124089, 'model__colsample_bytree': 0.38711988211609016}. Best is trial 16 with value: -8.00055307630308.
# [I 2024-03-05 22:47:27,314] Trial 29 finished with value: -13.895741638812373 and parameters: {'selector__k': 47, 'model__learning_rate': 0.73194479058613, 'model__n_estimators': 401, 'model__max_depth': 32, 'model__num_leaves': 29, 'model__min_child_samples': 1, 'model__subsample': 0.40507556858081295, 'model__colsample_bytree': 0.21047758726572802}. Best is trial 16 with value: -8.00055307630308.
# [I 2024-03-05 22:47:27,920] Trial 30 finished with value: -14.782633792814213 and parameters: {'selector__k': 38, 'model__learning_rate': 0.4097985405649335, 'model__n_estimators': 182, 'model__max_depth': 24, 'model__num_leaves': 42, 'model__min_child_samples': 6, 'model__subsample': 0.6645026751961248, 'model__colsample_bytree': 0.34666623736727314}. Best is trial 16 with value: -8.00055307630308.
# [I 2024-03-05 22:47:28,918] Trial 31 finished with value: -8.151429842472764 and parameters: {'selector__k': 30, 'model__learning_rate': 0.20276219661765182, 'model__n_estimators': 333, 'model__max_depth': 36, 'model__num_leaves': 34, 'model__min_child_samples': 4, 'model__subsample': 0.7635232870427198, 'model__colsample_bytree': 0.7306145404861484}. Best is trial 16 with value: -8.00055307630308.
# [I 2024-03-05 22:47:30,250] Trial 32 finished with value: -8.174148593585361 and parameters: {'selector__k': 26, 'model__learning_rate': 0.0724225008082392, 'model__n_estimators': 465, 'model__max_depth': 39, 'model__num_leaves': 34, 'model__min_child_samples': 4, 'model__subsample': 0.7785656790389723, 'model__colsample_bytree': 0.7444560137851894}. Best is trial 16 with value: -8.00055307630308.
# [I 2024-03-05 22:47:31,604] Trial 33 finished with value: -8.641908242131823 and parameters: {'selector__k': 24, 'model__learning_rate': 0.07479194185838096, 'model__n_estimators': 465, 'model__max_depth': 40, 'model__num_leaves': 34, 'model__min_child_samples': 2, 'model__subsample': 0.8100258319095875, 'model__colsample_bytree': 0.8350023120520831}. Best is trial 16 with value: -8.00055307630308.
# [I 2024-03-05 22:47:32,921] Trial 34 finished with value: -9.233041313567734 and parameters: {'selector__k': 35, 'model__learning_rate': 0.174673306824307, 'model__n_estimators': 354, 'model__max_depth': 47, 'model__num_leaves': 42, 'model__min_child_samples': 5, 'model__subsample': 0.898811395901587, 'model__colsample_bytree': 0.7435763616412533}. Best is trial 16 with value: -8.00055307630308.
# [I 2024-03-05 22:47:34,201] Trial 35 finished with value: -7.604467130365416 and parameters: {'selector__k': 27, 'model__learning_rate': 0.010984693069110832, 'model__n_estimators': 429, 'model__max_depth': 39, 'model__num_leaves': 39, 'model__min_child_samples': 7, 'model__subsample': 0.9268399953284792, 'model__colsample_bytree': 0.8807629790142398}. Best is trial 35 with value: -7.604467130365416.
# [I 2024-03-05 22:47:35,486] Trial 36 finished with value: -8.51784485527573 and parameters: {'selector__k': 27, 'model__learning_rate': 0.10459532597819433, 'model__n_estimators': 407, 'model__max_depth': 40, 'model__num_leaves': 46, 'model__min_child_samples': 10, 'model__subsample': 0.9616580068998195, 'model__colsample_bytree': 0.894529841211826}. Best is trial 35 with value: -7.604467130365416.
# [I 2024-03-05 22:47:36,849] Trial 37 finished with value: -8.104063858344496 and parameters: {'selector__k': 23, 'model__learning_rate': 0.20893626373865065, 'model__n_estimators': 448, 'model__max_depth': 43, 'model__num_leaves': 40, 'model__min_child_samples': 7, 'model__subsample': 0.9052019222446821, 'model__colsample_bytree': 0.7687036493757347}. Best is trial 35 with value: -7.604467130365416.
# [I 2024-03-05 22:47:37,797] Trial 38 finished with value: -8.335956333603837 and parameters: {'selector__k': 23, 'model__learning_rate': 0.2067688462709702, 'model__n_estimators': 311, 'model__max_depth': 44, 'model__num_leaves': 38, 'model__min_child_samples': 7, 'model__subsample': 0.9223671434465486, 'model__colsample_bytree': 0.6702646903121056}. Best is trial 35 with value: -7.604467130365416.
# [I 2024-03-05 22:47:39,084] Trial 39 finished with value: -8.225460924643897 and parameters: {'selector__k': 20, 'model__learning_rate': 0.31570563476214475, 'model__n_estimators': 371, 'model__max_depth': 50, 'model__num_leaves': 44, 'model__min_child_samples': 7, 'model__subsample': 0.9560508758358726, 'model__colsample_bytree': 0.9279352152014086}. Best is trial 35 with value: -7.604467130365416.
# [I 2024-03-05 22:47:40,471] Trial 40 finished with value: -8.796477218439424 and parameters: {'selector__k': 34, 'model__learning_rate': 0.012246630889270194, 'model__n_estimators': 433, 'model__max_depth': 43, 'model__num_leaves': 41, 'model__min_child_samples': 9, 'model__subsample': 0.8576481862825784, 'model__colsample_bytree': 0.7796023115141266}. Best is trial 35 with value: -7.604467130365416.
# [I 2024-03-05 22:47:42,005] Trial 41 finished with value: -9.268417418023331 and parameters: {'selector__k': 41, 'model__learning_rate': 0.1223047777520328, 'model__n_estimators': 456, 'model__max_depth': 38, 'model__num_leaves': 35, 'model__min_child_samples': 6, 'model__subsample': 0.7754445610733272, 'model__colsample_bytree': 0.77961100871715}. Best is trial 35 with value: -7.604467130365416.
# [I 2024-03-05 22:47:43,729] Trial 42 finished with value: -8.480564152947359 and parameters: {'selector__k': 30, 'model__learning_rate': 0.06198096004177568, 'model__n_estimators': 499, 'model__max_depth': 35, 'model__num_leaves': 40, 'model__min_child_samples': 5, 'model__subsample': 0.8275719705576507, 'model__colsample_bytree': 0.8721055000090076}. Best is trial 35 with value: -7.604467130365416.
# [I 2024-03-05 22:47:45,052] Trial 43 finished with value: -8.214298279638871 and parameters: {'selector__k': 25, 'model__learning_rate': 0.1760054095809835, 'model__n_estimators': 397, 'model__max_depth': 38, 'model__num_leaves': 45, 'model__min_child_samples': 8, 'model__subsample': 0.7322840843849818, 'model__colsample_bytree': 0.7327318204821518}. Best is trial 35 with value: -7.604467130365416.
# [I 2024-03-05 22:47:46,028] Trial 44 finished with value: -8.216885593439788 and parameters: {'selector__k': 22, 'model__learning_rate': 0.04978039578532354, 'model__n_estimators': 305, 'model__max_depth': 42, 'model__num_leaves': 48, 'model__min_child_samples': 10, 'model__subsample': 0.9254471069763414, 'model__colsample_bytree': 0.9357639202201238}. Best is trial 35 with value: -7.604467130365416.
# [I 2024-03-05 22:47:47,032] Trial 45 finished with value: -8.837693269707533 and parameters: {'selector__k': 21, 'model__learning_rate': 0.27920806472311677, 'model__n_estimators': 357, 'model__max_depth': 46, 'model__num_leaves': 37, 'model__min_child_samples': 5, 'model__subsample': 0.9926275812347441, 'model__colsample_bytree': 0.5344447258127923}. Best is trial 35 with value: -7.604467130365416.
# [I 2024-03-05 22:47:47,747] Trial 46 finished with value: -8.018604904425493 and parameters: {'selector__k': 30, 'model__learning_rate': 0.20463498576388928, 'model__n_estimators': 240, 'model__max_depth': 34, 'model__num_leaves': 32, 'model__min_child_samples': 7, 'model__subsample': 0.8130670089207269, 'model__colsample_bytree': 0.6952957180334446}. Best is trial 35 with value: -7.604467130365416.
# ...
# [W 2024-03-05 22:59:11,885] Trial 42 failed with value nan.
# [W 2024-03-05 22:59:13,818] Trial 43 failed with parameters: {'selector__k': 45, 'model__hidden_layer_sizes': (50, 50), 'model__activation': 'identity', 'model__solver': 'sgd', 'model__alpha': 1.0220722768975153e-05} because of the following error: The value nan is not acceptable.
# [W 2024-03-05 22:59:13,819] Trial 43 failed with value nan.
# [W 2024-03-05 22:59:15,796] Trial 44 failed with parameters: {'selector__k': 43, 'model__hidden_layer_sizes': (50, 50), 'model__activation': 'identity', 'model__solver': 'sgd', 'model__alpha': 1.760805593395123e-05} because of the following error: The value nan is not acceptable.
# [W 2024-03-05 22:59:15,797] Trial 44 failed with value nan.
# [W 2024-03-05 22:59:17,843] Trial 45 failed with parameters: {'selector__k': 46, 'model__hidden_layer_sizes': (50, 50), 'model__activation': 'identity', 'model__solver': 'sgd', 'model__alpha': 5.373028539557157e-05} because of the following error: The value nan is not acceptable.
# [W 2024-03-05 22:59:17,845] Trial 45 failed with value nan.
# [W 2024-03-05 22:59:19,925] Trial 46 failed with parameters: {'selector__k': 45, 'model__hidden_layer_sizes': (50, 50), 'model__activation': 'identity', 'model__solver': 'sgd', 'model__alpha': 0.00010390866361462707} because of the following error: The value nan is not acceptable.
# [W 2024-03-05 22:59:19,927] Trial 46 failed with value nan.
# [W 2024-03-05 22:59:21,991] Trial 47 failed with parameters: {'selector__k': 48, 'model__hidden_layer_sizes': (50, 50), 'model__activation': 'identity', 'model__solver': 'sgd', 'model__alpha': 1.5054921677483968e-05} because of the following error: The value nan is not acceptable.
# [W 2024-03-05 22:59:21,992] Trial 47 failed with value nan.
# [W 2024-03-05 22:59:24,059] Trial 48 failed with parameters: {'selector__k': 47, 'model__hidden_layer_sizes': (50, 50), 'model__activation': 'identity', 'model__solver': 'sgd', 'model__alpha': 1.5730081214923733e-05} because of the following error: The value nan is not acceptable.
# [W 2024-03-05 22:59:24,060] Trial 48 failed with value nan.
# [W 2024-03-05 22:59:26,132] Trial 49 failed with parameters: {'selector__k': 47, 'model__hidden_layer_sizes': (50, 50), 'model__activation': 'identity', 'model__solver': 'sgd', 'model__alpha': 1.8396606556676262e-05} because of the following error: The value nan is not acceptable.
# [W 2024-03-05 22:59:26,133] Trial 49 failed with value nan.
# [I 2024-03-05 22:59:27,235] A new study created in memory with name: no-name-a1181ded-a574-4fe8-b0b0-ea2eae6d6120
# ANN -8.638800891417262 12.134652152574736 502.33922316787306 364.9480938634163
# [I 2024-03-05 22:59:27,470] Trial 0 finished with value: -29.011849065928192 and parameters: {'selector__k': 22, 'model__kernel': RBF(length_scale=1) + 1.41**2, 'model__alpha':
. Best is trial 0 with value: -9.149874910310963.
# [I 2024-03-05 22:59:58,037] Trial 11 finished with value: -9.80010627153175 and parameters: {'learning_rate': 0.09048588414570577, 'n_estimators': 258, 'max_depth': 7, 'max_leaves': 14, 'max_bin': 36, 'gamma': 7}. Best is trial 0 with value: -9.149874910310963.
# [I 2024-03-05 22:59:58,308] Trial 12 finished with value: -11.694762463900004 and parameters: {'learning_rate': 0.6332767312869128, 'n_estimators': 96, 'max_depth': 14, 'max_leaves': 12, 'max_bin': 16, 'gamma': 20}. Best is trial 0 with value: -9.149874910310963.
# [I 2024-03-05 22:59:58,718] Trial 13 finished with value: -9.661279371573041 and parameters: {'learning_rate': 0.18185704218704343, 'n_estimators': 187, 'max_depth': 9, 'max_leaves': 13, 'max_bin': 36, 'gamma': 7}. Best is trial 0 with value: -9.149874910310963.
# [I 2024-03-05 22:59:59,236] Trial 14 finished with value: -9.534346458462176 and parameters: {'learning_rate': 0.5802701754947434, 'n_estimators': 332, 'max_depth': 20, 'max_leaves': 20, 'max_bin': 18, 'gamma': 4}. Best is trial 0 with value: -9.149874910310963.
# [I 2024-03-05 22:59:59,782] Trial 15 finished with value: -9.692850987250251 and parameters: {'learning_rate': 0.40632890187791837, 'n_estimators': 346, 'max_depth': 20, 'max_leaves': 20, 'max_bin': 30, 'gamma': 4}. Best is trial 0 with value: -9.149874910310963.
# [I 2024-03-05 23:00:00,365] Trial 16 finished with value: -10.469150974833902 and parameters: {'learning_rate': 0.21583112250577724, 'n_estimators': 351, 'max_depth': 1, 'max_leaves': 19, 'max_bin': 20, 'gamma': 5}. Best is trial 0 with value: -9.149874910310963.
# [I 2024-03-05 23:00:00,946] Trial 17 finished with value: -11.245537717662396 and parameters: {'learning_rate': 0.5936408277872435, 'n_estimators': 309, 'max_depth': 15, 'max_leaves': 6, 'max_bin': 42, 'gamma': 9}. Best is trial 0 with value: -9.149874910310963.
# [I 2024-03-05 23:00:01,355] Trial 18 finished with value: -9.14097490228708 and parameters: {'learning_rate': 0.48154563729328603, 'n_estimators': 179, 'max_depth': 20, 'max_leaves': 35, 'max_bin': 28, 'gamma': 1}. Best is trial 18 with value: -9.14097490228708.
# [I 2024-03-05 23:00:01,843] Trial 19 finished with value: -9.790055602784225 and parameters: {'learning_rate': 0.21208602070901406, 'n_estimators': 183, 'max_depth': 12, 'max_leaves': 36, 'max_bin': 30, 'gamma': 1}. Best is trial 18 with value: -9.14097490228708.
# [I 2024-03-05 23:00:02,105] Trial 20 finished with value: -8.977624907463005 and parameters: {'learning_rate': 0.09338219969458406, 'n_estimators': 86, 'max_depth': 1, 'max_leaves': 50, 'max_bin': 43, 'gamma': 6}. Best is trial 20 with value: -8.977624907463005.
# [I 2024-03-05 23:00:02,360] Trial 21 finished with value: -8.545447452500282 and parameters: {'learning_rate': 0.08094904981695245, 'n_estimators': 75, 'max_depth': 2, 'max_leaves': 50, 'max_bin': 43, 'gamma': 6}. Best is trial 21 with value: -8.545447452500282.
# [I 2024-03-05 23:00:02,610] Trial 22 finished with value: -14.540746257848705 and parameters: {'learning_rate': 0.028280848964065464, 'n_estimators': 78, 'max_depth': 1, 'max_leaves': 49, 'max_bin': 45, 'gamma': 9}. Best is trial 21 with value: -8.545447452500282.
# [I 2024-03-05 23:00:02,899] Trial 23 finished with value: -9.474505251538023 and parameters: {'learning_rate': 0.2815279600886227, 'n_estimators': 50, 'max_depth': 4, 'max_leaves': 42, 'max_bin': 42, 'gamma': 2}. Best is trial 21 with value: -8.545447452500282.
# [I 2024-03-05 23:00:03,197] Trial 24 finished with value: -8.71217855778047 and parameters: {'learning_rate': 0.1503469252414059, 'n_estimators': 85, 'max_depth': 3, 'max_leaves': 50, 'max_bin': 45, 'gamma': 5}. Best is trial 21 with value: -8.545447452500282.
# [I 2024-03-05 23:00:03,485] Trial 25 finished with value: -8.596305186661326 and parameters: {'learning_rate': 0.12299994512731748, 'n_estimators': 81, 'max_depth': 3, 'max_leaves': 49, 'max_bin': 44, 'gamma': 5}. Best is trial 21 with value: -8.545447452500282.
# [I 2024-03-05 23:00:03,768] Trial 26 finished with value: -8.93346057135941 and parameters: {'learning_rate': 0.13125978921867218, 'n_estimators': 67, 'max_depth': 4, 'max_leaves': 45, 'max_bin': 47, 'gamma': 4}. Best is trial 21 with value: -8.545447452500282.
# [I 2024-03-05 23:00:04,061] Trial 27 finished with value: -9.303651279165377 and parameters: {'learning_rate': 0.2902014537920352, 'n_estimators': 107, 'max_depth': 3, 'max_leaves': 40, 'max_bin': 39, 'gamma': 10}. Best is trial 21 with value: -8.545447452500282.
# [I 2024-03-05 23:00:04,352] Trial 28 finished with value: -9.372875746266676 and parameters: {'learning_rate': 0.16735819502851496, 'n_estimators': 54, 'max_depth': 6, 'max_leaves': 50, 'max_bin': 46, 'gamma': 5}. Best is trial 21 with value: -8.545447452500282.
# [I 2024-03-05 23:00:04,631] Trial 29 finished with value: -8.602725015795658 and parameters: {'learning_rate': 0.05686371683117973, 'n_estimators': 82, 'max_depth': 3, 'max_leaves': 46, 'max_bin': 33, 'gamma': 6}. Best is trial 21 with value: -8.545447452500282.
# [I 2024-03-05 23:00:04,998] Trial 30 finished with value: -9.251221625532688 and parameters: {'learning_rate': 0.050194530184677455, 'n_estimators': 66, 'max_depth': 8, 'max_leaves': 38, 'max_bin': 33, 'gamma': 6}. Best is trial 21 with value: -8.545447452500282.
# [I 2024-03-05 23:00:05,294] Trial 31 finished with value: -9.463946320295738 and parameters: {'learning_rate': 0.10302631338385564, 'n_estimators': 87, 'max_depth': 3, 'max_leaves': 45, 'max_bin': 39, 'gamma': 7}. Best is trial 21 with value: -8.545447452500282.
# [I 2024-03-05 23:00:05,567] Trial 32 finished with value: -9.131527100269329 and parameters: {'learning_rate': 0.2351648234603783, 'n_estimators': 78, 'max_depth': 3, 'max_leaves': 46, 'max_bin': 47, 'gamma': 8}. Best is trial 21 with value: -8.545447452500282.
# [I 2024-03-05 23:00:05,917] Trial 33 finished with value: -8.578411271599572 and parameters: {'learning_rate': 0.1406196779984645, 'n_estimators': 109, 'max_depth': 5, 'max_leaves': 48, 'max_bin': 34, 'gamma': 3}. Best is trial 21 with value: -8.545447452500282.
# [I 2024-03-05 23:00:06,225] Trial 34 finished with value: -9.015726425097972 and parameters: {'learning_rate': 0.3743811755676604, 'n_estimators': 105, 'max_depth': 5, 'max_leaves': 42, 'max_bin': 34, 'gamma': 3}. Best is trial 21 with value: -8.545447452500282.
# [I 2024-03-05 23:00:06,571] Trial 35 finished with value: -8.129276107202934 and parameters: {'learning_rate': 0.06740534512960786, 'n_estimators': 123, 'max_depth': 2, 'max_leaves': 47, 'max_bin': 33, 'gamma': 3}. Best is trial 35 with value: -8.129276107202934.
# [I 2024-03-05 23:00:07,007] Trial 36 finished with value: -11.08603078777553 and parameters: {'learning_rate': 0.14098224439654516, 'n_estimators': 125, 'max_depth': 2, 'max_leaves': 42, 'max_bin': 41, 'gamma': 3}. Best is trial 35 with value: -8.129276107202934.
# [I 2024-03-05 23:00:07,486] Trial 37 finished with value: -9.7803276783241 and parameters: {'learning_rate': 0.27561946137958615, 'n_estimators': 149, 'max_depth': 5, 'max_leaves': 48, 'max_bin': 23, 'gamma': 2}. Best is trial 35 with value: -8.129276107202934.
# [I 2024-03-05 23:00:07,832] Trial 38 finished with value: -11.328485437726261 and parameters: {'learning_rate': 0.4246173748988885, 'n_estimators': 118, 'max_depth': 2, 'max_leaves': 31, 'max_bin': 28, 'gamma': 2}. Best is trial 35 with value: -8.129276107202934.
# [I 2024-03-05 23:00:08,112] Trial 39 finished with value: -9.838638108232182 and parameters: {'learning_rate': 0.34498898662698724, 'n_estimators': 58, 'max_depth': 9, 'max_leaves': 39, 'max_bin': 50, 'gamma': 3}. Best is trial 35 with value: -8.129276107202934.
# [I 2024-03-05 23:00:08,572] Trial 40 finished with value: -8.58564196941978 and parameters: {'learning_rate': 0.05897525042267354, 'n_estimators': 135, 'max_depth': 5, 'max_leaves': 48, 'max_bin': 31, 'gamma': 11}. Best is trial 35 with value: -8.129276107202934.
# [I 2024-03-05 23:00:08,979] Trial 41 finished with value: -8.612764551393875 and parameters: {'learning_rate': 0.07379651877731515, 'n_estimators': 136, 'max_depth': 5, 'max_leaves': 47, 'max_bin': 32, 'gamma': 11}. Best is trial 35 with value: -8.129276107202934.
# [I 2024-03-05 23:00:09,263] Trial 42 finished with value: -10.2797678814361 and parameters: {'learning_rate': 0.11718059119232724, 'n_estimators': 92, 'max_depth': 2, 'max_leaves': 44, 'max_bin': 10, 'gamma': 9}. Best is trial 35 with value: -8.129276107202934.
# [I 2024-03-05 23:00:09,629] Trial 43 finished with value: -12.407862969070015 and parameters: {'learning_rate': 0.016123887797318215, 'n_estimators': 72, 'max_depth': 7, 'max_leaves': 47, 'max_bin': 23, 'gamma': 12}. Best is trial 35 with value: -8.129276107202934.
# [I 2024-03-05 23:00:09,950] Trial 44 finished with value: -9.352407952962666 and parameters: {'learning_rate': 0.18651934837489081, 'n_estimators': 100, 'max_depth': 4, 'max_leaves': 43, 'max_bin': 37, 'gamma': 4}. Best is trial 35 with value: -8.129276107202934.
# [I 2024-03-05 23:00:10,303] Trial 45 finished with value: -12.530623894945943 and parameters: {'learning_rate': 0.23279397340380273, 'n_estimators': 138, 'max_depth': 2, 'max_leaves': 48, 'max_bin': 40, 'gamma': 15}. Best is trial 35 with value: -8.129276107202934.
# [I 2024-03-05 23:00:10,754] Trial 46 finished with value: -9.06333060229349 and parameters: {'learning_rate': 0.07193674493447758, 'n_estimators': 165, 'max_depth': 6, 'max_leaves': 25, 'max_bin': 31, 'gamma': 12}. Best is trial 35 with value: -8.129276107202934.
# [I 2024-03-05 23:00:11,057] Trial 47 finished with value: -10.224885944989602 and parameters: {'learning_rate': 0.9385663749122105, 'n_estimators': 115, 'max_depth': 7, 'max_leaves': 38, 'max_bin': 35, 'gamma': 8}. Best is trial 35 with value: -8.129276107202934.
# [I 2024-03-05 23:00:11,605] Trial 48 finished with value: -8.695263904776665 and parameters: {'learning_rate': 0.017383272803936603, 'n_estimators': 214, 'max_depth': 4, 'max_leaves': 41, 'max_bin': 28, 'gamma': 10}. Best is trial 35 with value: -8.129276107202934.
# [I 2024-03-05 23:00:11,942] Trial 49 finished with value: -9.57757491551365 and parameters: {'learning_rate': 0.18249163567202997, 'n_estimators': 97, 'max_depth': 9, 'max_leaves': 44, 'max_bin': 26, 'gamma': 5}. Best is trial 35 with value: -8.129276107202934.
# [I 2024-03-05 23:00:12,078] A new study created in memory with name: no-name-5fab49dc-b79a-4e54-9852-992c7a6406b5
# [I 2024-03-05 23:00:12,267] Trial 0 finished with value: -15.892713148380068 and parameters: {'learning_rate': 0.907892720695498, 'n_estimators': 239, 'max_depth': 3, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 0.5409430737314819, 'colsample_bytree': 0.34014450168515553}. Best is trial 0 with value: -15.892713148380068.
# XGB -8.129276107202934 10.655416532121972 309.0461921707954 157.2042476109096
# [I 2024-03-05 23:00:12,414] Trial 1 finished with value: -9.007271369368588 and parameters: {'learning_rate': 0.021865067121023492, 'n_estimators': 155, 'max_depth': 9, 'num_leaves': 6, 'min_child_samples': 5, 'subsample': 0.9185931992055312, 'colsample_bytree': 0.4343921407762077}. Best is trial 1 with value: -9.007271369368588.
# [I 2024-03-05 23:00:12,557] Trial 2 finished with value: -9.35837353834492 and parameters: {'learning_rate': 0.15416263806994593, 'n_estimators': 94, 'max_depth': 40, 'num_leaves': 9, 'min_child_samples': 5, 'subsample': 0.616246314184996, 'colsample_bytree': 0.9860193735807611}. Best is trial 1 with value: -9.007271369368588.
# [I 2024-03-05 23:00:12,763] Trial 3 finished with value: -13.64590152382586 and parameters: {'learning_rate': 0.42331903358307293, 'n_estimators': 248, 'max_depth': 35, 'num_leaves': 6, 'min_child_samples': 14, 'subsample': 0.4445243533199511, 'colsample_bytree': 0.5316928920805017}. Best is trial 1 with value: -9.007271369368588.
# [I 2024-03-05 23:00:13,307] Trial 4 finished with value: -14.75771956883364 and parameters: {'learning_rate': 0.2624905760830746, 'n_estimators': 399, 'max_depth': 47, 'num_leaves': 16, 'min_child_samples': 19, 'subsample': 0.6577168106695694, 'colsample_bytree': 0.4610797586289148}. Best is trial 1 with value: -9.007271369368588.
# [I 2024-03-05 23:00:13,478] Trial 5 finished with value: -18.29503211619748 and parameters: {'learning_rate': 0.6651397710852203, 'n_estimators': 286, 'max_depth': 2, 'num_leaves': 27, 'min_child_samples': 20, 'subsample': 0.23345453562787116, 'colsample_bytree': 0.5527234600125852}. Best is trial 1 with value: -9.007271369368588.
# [I 2024-03-05 23:00:13,751] Trial 6 finished with value: -9.816377669667798 and parameters: {'learning_rate': 0.23660225507463786, 'n_estimators': 108, 'max_depth': 13, 'num_leaves': 21, 'min_child_samples': 1, 'subsample': 0.9151865842367701, 'colsample_bytree': 0.626752272701297}. Best is trial 1 with value: -9.007271369368588.
# [I 2024-03-05 23:00:13,836] Trial 7 finished with value: -12.53161421947748 and parameters: {'learning_rate': 0.3334206179202869, 'n_estimators': 78, 'max_depth': 19, 'num_leaves': 4, 'min_child_samples': 6, 'subsample': 0.13841649954114382, 'colsample_bytree': 0.4203254045785968}. Best is trial 1 with value: -9.007271369368588.
# [I 2024-03-05 23:00:13,929] Trial 8 finished with value: -17.62878661768003 and parameters: {'learning_rate': 0.8986743626846241, 'n_estimators': 85, 'max_depth': 4, 'num_leaves': 5, 'min_child_samples': 17, 'subsample': 0.4582790184822978, 'colsample_bytree': 0.4887134728746363}. Best is trial 1 with value: -9.007271369368588.
# [I 2024-03-05 23:00:14,038] Trial 9 finished with value: -15.190585655588626 and parameters: {'learning_rate': 0.8475292943987986, 'n_estimators': 62, 'max_depth': 46, 'num_leaves': 10, 'min_child_samples': 6, 'subsample': 0.24954336516236503, 'colsample_bytree': 0.6777557742121078}. Best is trial 1 with value: -9.007271369368588.
# [I 2024-03-05 23:00:14,414] Trial 10 finished with value: -11.619094823822248 and parameters: {'learning_rate': 0.025417651743236607, 'n_estimators': 161, 'max_depth': 26, 'num_leaves': 46, 'min_child_samples': 11, 'subsample': 0.9986487764273617, 'colsample_bytree': 0.11038665693040034}. Best is trial 1 with value: -9.007271369368588.
# [I 2024-03-05 23:00:14,712] Trial 11 finished with value: -8.92707114423481 and parameters: {'learning_rate': 0.026036160461034064, 'n_estimators': 141, 'max_depth': 34, 'num_leaves': 12, 'min_child_samples': 2, 'subsample': 0.7540531526416476, 'colsample_bytree': 0.9876560020487418}. Best is trial 11 with value: -8.92707114423481.
# [I 2024-03-05 23:00:15,070] Trial 12 finished with value: -8.734837504496886 and parameters: {'learning_rate': 0.0356646331704398, 'n_estimators': 145, 'max_depth': 30, 'num_leaves': 15, 'min_child_samples': 1, 'subsample': 0.7842458038633082, 'colsample_bytree': 0.9308052969387376}. Best is trial 12 with value: -8.734837504496886.
# [I 2024-03-05 23:00:15,458] Trial 13 finished with value: -9.847518053283311 and parameters: {'learning_rate': 0.6035267497762064, 'n_estimators': 147, 'max_depth': 30, 'num_leaves': 17, 'min_child_samples': 1, 'subsample': 0.7575046329542858, 'colsample_bytree': 0.9862910167392152}. Best is trial 12 with value: -8.734837504496886.
# [I 2024-03-05 23:00:15,982] Trial 14 finished with value: -9.537993797451781 and parameters: {'learning_rate': 0.13161534127740643, 'n_estimators': 132, 'max_depth': 35, 'num_leaves': 33, 'min_child_samples': 2, 'subsample': 0.8008622856758809, 'colsample_bytree': 0.8357774833096225}. Best is trial 12 with value: -8.734837504496886.
# [I 2024-03-05 23:00:16,358] Trial 15 finished with value: -10.354034697405291 and parameters: {'learning_rate': 0.43214972038948285, 'n_estimators': 188, 'max_depth': 21, 'num_leaves': 15, 'min_child_samples': 9, 'subsample': 0.7741843422513862, 'colsample_bytree': 0.8356776706222969}. Best is trial 12 with value: -8.734837504496886.
# [I 2024-03-05 23:00:18,024] Trial 16 finished with value: -9.318123391738045 and parameters: {'learning_rate': 0.13498884062736205, 'n_estimators': 450, 'max_depth': 39, 'num_leaves': 38, 'min_child_samples': 3, 'subsample': 0.6459851984853712, 'colsample_bytree': 0.8555100892664094}. Best is trial 12 with value: -8.734837504496886.
# [I 2024-03-05 23:00:18,255] Trial 17 finished with value: -12.467525252468917 and parameters: {'learning_rate': 0.019573765944815268, 'n_estimators': 57, 'max_depth': 27, 'num_leaves': 23, 'min_child_samples': 8, 'subsample': 0.8121873535207329, 'colsample_bytree': 0.7658267398707783}. Best is trial 12 with value: -8.734837504496886.
# [I 2024-03-05 23:00:18,522] Trial 18 finished with value: -9.665508366437118 and parameters: {'learning_rate': 0.7009965971333434, 'n_estimators': 112, 'max_depth': 32, 'num_leaves': 13, 'min_child_samples': 3, 'subsample': 0.6989755159666212, 'colsample_bytree': 0.9292626511211141}. Best is trial 12 with value: -8.734837504496886.
# [I 2024-03-05 23:00:18,985] Trial 19 finished with value: -13.155694612300623 and parameters: {'learning_rate': 0.3461118499429495, 'n_estimators': 189, 'max_depth': 18, 'num_leaves': 22, 'min_child_samples': 13, 'subsample': 0.8862263176096986, 'colsample_bytree': 0.730613006343453}. Best is trial 12 with value: -8.734837504496886.
# [I 2024-03-05 23:00:19,208] Trial 20 finished with value: -10.722885541670733 and parameters: {'learning_rate': 0.5282221555590932, 'n_estimators': 365, 'max_depth': 42, 'num_leaves': 2, 'min_child_samples': 4, 'subsample': 0.4885747299309822, 'colsample_bytree': 0.9103323682376144}. Best is trial 12 with value: -8.734837504496886.
# [I 2024-03-05 23:00:19,503] Trial 21 finished with value: -10.816835903415432 and parameters: {'learning_rate': 0.01648065356598876, 'n_estimators': 191, 'max_depth': 12, 'num_leaves': 10, 'min_child_samples': 7, 'subsample': 0.9861250439892635, 'colsample_bytree': 0.2571386365251427}. Best is trial 12 with value: -8.734837504496886.
# [I 2024-03-05 23:00:19,793] Trial 22 finished with value: -9.215541561268985 and parameters: {'learning_rate': 0.13780261543570288, 'n_estimators': 122, 'max_depth': 9, 'num_leaves': 19, 'min_child_samples': 4, 'subsample': 0.8860479252407827, 'colsample_bytree': 0.34369786498515476}. Best is trial 12 with value: -8.734837504496886.
# [I 2024-03-05 23:00:20,095] Trial 23 finished with value: -9.184705613664923 and parameters: {'learning_rate': 0.21724385595743534, 'n_estimators': 150, 'max_depth': 22, 'num_leaves': 12, 'min_child_samples': 1, 'subsample': 0.8533859791294439, 'colsample_bytree': 0.6278236764758754}. Best is trial 12 with value: -8.734837504496886.
# [I 2024-03-05 23:00:20,396] Trial 24 finished with value: -9.829396224650232 and parameters: {'learning_rate': 0.08750738462022614, 'n_estimators': 241, 'max_depth': 29, 'num_leaves': 7, 'min_child_samples': 3, 'subsample': 0.7184846209058326, 'colsample_bytree': 0.7674209910146227}. Best is trial 12 with value: -8.734837504496886.
# [I 2024-03-05 23:00:20,691] Trial 25 finished with value: -13.102690153749936 and parameters: {'learning_rate': 0.08250801468148362, 'n_estimators': 171, 'max_depth': 33, 'num_leaves': 14, 'min_child_samples': 5, 'subsample': 0.9400061641759103, 'colsample_bytree': 0.1417547752997358}. Best is trial 12 with value: -8.734837504496886.
# [I 2024-03-05 23:00:20,843] Trial 26 finished with value: -9.295438413104927 and parameters: {'learning_rate': 0.20497364193114287, 'n_estimators': 104, 'max_depth': 24, 'num_leaves': 2, 'min_child_samples': 2, 'subsample': 0.5906286238454056, 'colsample_bytree': 0.9198587028081391}. Best is trial 12 with value: -8.734837504496886.
# [I 2024-03-05 23:00:21,184] Trial 27 finished with value: -13.761304112400108 and parameters: {'learning_rate': 0.3090709962420246, 'n_estimators': 142, 'max_depth': 15, 'num_leaves': 25, 'min_child_samples': 7, 'subsample': 0.7184036006244846, 'colsample_bytree': 0.22525490418353544}. Best is trial 12 with value: -8.734837504496886.
# [I 2024-03-05 23:00:21,550] Trial 28 finished with value: -8.868710594581549 and parameters: {'learning_rate': 0.07123269540296198, 'n_estimators': 71, 'max_depth': 41, 'num_leaves': 49, 'min_child_samples': 4, 'subsample': 0.8251170180869597, 'colsample_bytree': 0.38307023541703467}. Best is trial 12 with value: -8.734837504496886.
# [I 2024-03-05 23:00:21,822] Trial 29 finished with value: -17.650100733846585 and parameters: {'learning_rate': 0.9993795561026299, 'n_estimators': 70, 'max_depth': 43, 'num_leaves': 49, 'min_child_samples': 11, 'subsample': 0.5309393723178026, 'colsample_bytree': 0.35107156891739255}. Best is trial 12 with value: -8.734837504496886.
# [I 2024-03-05 23:00:22,847] Trial 30 finished with value: -8.859523631364759 and parameters: {'learning_rate': 0.08670141921177241, 'n_estimators': 283, 'max_depth': 37, 'num_leaves': 41, 'min_child_samples': 2, 'subsample': 0.39463599339670924, 'colsample_bytree': 0.2890203217630497}. Best is trial 12 with value: -8.734837504496886.
# [I 2024-03-05 23:00:24,003] Trial 31 finished with value: -10.150269650876666 and parameters: {'learning_rate': 0.08323736271281845, 'n_estimators': 349, 'max_depth': 38, 'num_leaves': 42, 'min_child_samples': 2, 'subsample': 0.38189148874024803, 'colsample_bytree': 0.24081564566898367}. Best is trial 12 with value: -8.734837504496886.
# [I 2024-03-05 23:00:25,160] Trial 32 finished with value: -9.24737668972971 and parameters: {'learning_rate': 0.1703636485088808, 'n_estimators': 288, 'max_depth': 36, 'num_leaves': 50, 'min_child_samples': 4, 'subsample': 0.3668365296821395, 'colsample_bytree': 0.38458305537162707}. Best is trial 12 with value: -8.734837504496886.
# [I 2024-03-05 23:00:25,830] Trial 33 finished with value: -9.167045122287874 and parameters: {'learning_rate': 0.07474211084582258, 'n_estimators': 218, 'max_depth': 50, 'num_leaves': 34, 'min_child_samples': 2, 'subsample': 0.8367853410944156, 'colsample_bytree': 0.28265239365231043}. Best is trial 12 with value: -8.734837504496886.
# [I 2024-03-05 23:00:26,205] Trial 34 finished with value: -14.024595783102322 and parameters: {'learning_rate': 0.06967146119882786, 'n_estimators': 86, 'max_depth': 43, 'num_leaves': 44, 'min_child_samples': 1, 'subsample': 0.5766057603506418, 'colsample_bytree': 0.1691850552103118}. Best is trial 12 with value: -8.734837504496886.
# [I 2024-03-05 23:00:27,106] Trial 35 finished with value: -12.997633863368785 and parameters: {'learning_rate': 0.28233559744857883, 'n_estimators': 279, 'max_depth': 32, 'num_leaves': 39, 'min_child_samples': 5, 'subsample': 0.3665860576298967, 'colsample_bytree': 0.3070072946967039}. Best is trial 12 with value: -8.734837504496886.
# [I 2024-03-05 23:00:28,239] Trial 36 finished with value: -15.152338369519594 and parameters: {'learning_rate': 0.39826592131404526, 'n_estimators': 492, 'max_depth': 36, 'num_leaves': 31, 'min_child_samples': 3, 'subsample': 0.6789451193897792, 'colsample_bytree': 0.1864336965133615}. Best is trial 12 with value: -8.734837504496886.
# [I 2024-03-05 23:00:28,497] Trial 37 finished with value: -8.910305175574626 and parameters: {'learning_rate': 0.18608996825727198, 'n_estimators': 53, 'max_depth': 40, 'num_leaves': 28, 'min_child_samples': 4, 'subsample': 0.2762129224012861, 'colsample_bytree': 0.9994683277859413}. Best is trial 12 with value: -8.734837504496886.
# [I 2024-03-05 23:00:28,756] Trial 38 finished with value: -10.121849027956353 and parameters: {'learning_rate': 0.17423420730516637, 'n_estimators': 50, 'max_depth': 47, 'num_leaves': 37, 'min_child_samples': 6, 'subsample': 0.31222473457394606, 'colsample_bytree': 0.4911320425596626}. Best is trial 12 with value: -8.734837504496886.
# [I 2024-03-05 23:00:29,027] Trial 39 finished with value: -10.741190993820128 and parameters: {'learning_rate': 0.20928678756650881, 'n_estimators': 68, 'max_depth': 40, 'num_leaves': 28, 'min_child_samples': 9, 'subsample': 0.139194537537598, 'colsample_bytree': 0.5678842045127339}. Best is trial 12 with value: -8.734837504496886.
# [I 2024-03-05 23:00:29,244] Trial 40 finished with value: -11.481141748019267 and parameters: {'learning_rate': 0.2413826745134409, 'n_estimators': 50, 'max_depth': 38, 'num_leaves': 46, 'min_child_samples': 15, 'subsample': 0.2515037885009472, 'colsample_bytree': 0.4161759924721566}. Best is trial 12 with value: -8.734837504496886.
# [I 2024-03-05 23:00:29,577] Trial 41 finished with value: -15.374697002290318 and parameters: {'learning_rate': 0.011850270247829229, 'n_estimators': 58, 'max_depth': 29, 'num_leaves': 41, 'min_child_samples': 4, 'subsample': 0.31144038926894746, 'colsample_bytree': 0.9709493691991178}. Best is trial 12 with value: -8.734837504496886.
# [I 2024-03-05 23:00:29,900] Trial 42 finished with value: -9.097092873159275 and parameters: {'learning_rate': 0.10751965971098358, 'n_estimators': 97, 'max_depth': 42, 'num_leaves': 19, 'min_child_samples': 1, 'subsample': 0.1807999853375996, 'colsample_bytree': 0.9933444651220115}. Best is trial 12 with value: -8.734837504496886.
# [I 2024-03-05 23:00:30,340] Trial 43 finished with value: -9.358603072111936 and parameters: {'learning_rate': 0.048387081461424564, 'n_estimators': 75, 'max_depth': 34, 'num_leaves': 48, 'min_child_samples': 3, 'subsample': 0.4177624949375601, 'colsample_bytree': 0.9092963074445851}. Best is trial 12 with value: -8.734837504496886.
# [I 2024-03-05 23:00:30,690] Trial 44 finished with value: -9.177993095157138 and parameters: {'learning_rate': 0.18359961316081264, 'n_estimators': 86, 'max_depth': 46, 'num_leaves': 29, 'min_child_samples': 5, 'subsample': 0.5176425193439048, 'colsample_bytree': 0.9677174426689213}. Best is trial 12 with value: -8.734837504496886.
# [I 2024-03-05 23:00:31,548] Trial 45 finished with value: -9.033417402505972 and parameters: {'learning_rate': 0.1205115179796712, 'n_estimators': 216, 'max_depth': 37, 'num_leaves': 35, 'min_child_samples': 2, 'subsample': 0.751784953788939, 'colsample_bytree': 0.8648510525781583}. Best is trial 12 with value: -8.734837504496886.
# [I 2024-03-05 23:00:31,783] Trial 46 finished with value: -9.312013880804791 and parameters: {'learning_rate': 0.05520667686545892, 'n_estimators': 126, 'max_depth': 41, 'num_leaves': 8, 'min_child_samples': 6, 'subsample': 0.3165004430224383, 'colsample_bytree': 0.7877788893375812}. Best is trial 12 with value: -8.734837504496886.
# [I 2024-03-05 23:00:32,076] Trial 47 finished with value: -9.798522117899424 and parameters: {'learning_rate': 0.2647933138219951, 'n_estimators': 63, 'max_depth': 30, 'num_leaves': 25, 'min_child_samples': 1, 'subsample': 0.220908226227992, 'colsample_bytree': 0.9439749938682}. Best is trial 12 with value: -8.734837504496886.
# [I 2024-03-05 23:00:32,507] Trial 48 finished with value: -8.752893064093541 and parameters: {'learning_rate': 0.7545146289396374, 'n_estimators': 171, 'max_depth': 45, 'num_leaves': 18, 'min_child_samples': 4, 'subsample': 0.6501838631362953, 'colsample_bytree': 0.8836878001699531}. Best is trial 12 with value: -8.734837504496886.
# [I 2024-03-05 23:00
# [I 2024-03-05 23:01:09,494] Trial 13 finished with value: -9.99953921708282 and parameters: {'max_features': 'sqrt', 'n_estimators': 345, 'max_depth': 123, 'min_samples_leaf': 1}. Best is trial 13 with value: -9.99953921708282.
# [I 2024-03-05 23:01:14,047] Trial 14 finished with value: -10.006259768330795 and parameters: {'max_features': 'sqrt', 'n_estimators': 334, 'max_depth': 120, 'min_samples_leaf': 1}. Best is trial 13 with value: -9.99953921708282.
# [I 2024-03-05 23:01:16,942] Trial 15 finished with value: -12.156616524906024 and parameters: {'max_features': 'sqrt', 'n_estimators': 345, 'max_depth': 124, 'min_samples_leaf': 13}. Best is trial 13 with value: -9.99953921708282.
# [I 2024-03-05 23:01:19,995] Trial 16 finished with value: -10.24486929911069 and parameters: {'max_features': 'sqrt', 'n_estimators': 306, 'max_depth': 133, 'min_samples_leaf': 4}. Best is trial 13 with value: -9.99953921708282.
# [I 2024-03-05 23:01:22,680] Trial 17 finished with value: -9.751861749652976 and parameters: {'max_features': 'sqrt', 'n_estimators': 196, 'max_depth': 151, 'min_samples_leaf': 1}. Best is trial 17 with value: -9.751861749652976.
# [I 2024-03-05 23:01:24,489] Trial 18 finished with value: -10.763652879660688 and parameters: {'max_features': 'sqrt', 'n_estimators': 191, 'max_depth': 99, 'min_samples_leaf': 7}. Best is trial 17 with value: -9.751861749652976.
# [I 2024-03-05 23:01:26,095] Trial 19 finished with value: -12.219897949180538 and parameters: {'max_features': 'sqrt', 'n_estimators': 189, 'max_depth': 156, 'min_samples_leaf': 12}. Best is trial 17 with value: -9.751861749652976.
# [I 2024-03-05 23:01:27,412] Trial 20 finished with value: -9.897466604451346 and parameters: {'max_features': 'sqrt', 'n_estimators': 118, 'max_depth': 156, 'min_samples_leaf': 3}. Best is trial 17 with value: -9.751861749652976.
# [I 2024-03-05 23:01:28,575] Trial 21 finished with value: -9.89014551518 and parameters: {'max_features': 'sqrt', 'n_estimators': 102, 'max_depth': 158, 'min_samples_leaf': 3}. Best is trial 17 with value: -9.751861749652976.
# [I 2024-03-05 23:01:29,555] Trial 22 finished with value: -9.882531513569488 and parameters: {'max_features': 'sqrt', 'n_estimators': 86, 'max_depth': 160, 'min_samples_leaf': 3}. Best is trial 17 with value: -9.751861749652976.
# [I 2024-03-05 23:01:30,513] Trial 23 finished with value: -10.958920548909846 and parameters: {'max_features': 'sqrt', 'n_estimators': 95, 'max_depth': 165, 'min_samples_leaf': 6}. Best is trial 17 with value: -9.751861749652976.
# [I 2024-03-05 23:01:31,095] Trial 24 finished with value: -11.228702160096956 and parameters: {'max_features': 'sqrt', 'n_estimators': 53, 'max_depth': 140, 'min_samples_leaf': 5}. Best is trial 17 with value: -9.751861749652976.
# [I 2024-03-05 23:01:31,873] Trial 25 finished with value: -11.238915723031282 and parameters: {'max_features': 'sqrt', 'n_estimators': 79, 'max_depth': 168, 'min_samples_leaf': 8}. Best is trial 17 with value: -9.751861749652976.
# [I 2024-03-05 23:01:32,992] Trial 26 finished with value: -9.842121953271391 and parameters: {'max_features': 'sqrt', 'n_estimators': 99, 'max_depth': 100, 'min_samples_leaf': 3}. Best is trial 17 with value: -9.751861749652976.
# [I 2024-03-05 23:01:33,684] Trial 27 finished with value: -11.689326701813377 and parameters: {'max_features': 'sqrt', 'n_estimators': 73, 'max_depth': 100, 'min_samples_leaf': 10}. Best is trial 17 with value: -9.751861749652976.
# [I 2024-03-05 23:01:35,069] Trial 28 finished with value: -9.74144077088241 and parameters: {'max_features': 'sqrt', 'n_estimators': 115, 'max_depth': 89, 'min_samples_leaf': 2}. Best is trial 28 with value: -9.74144077088241.
# ...
# [W 2024-03-05 23:10:59,486] Trial 35 failed with value nan.
# [W 2024-03-05 23:11:00,813] Trial 36 failed with parameters: {'hidden_layer_sizes': (50,), 'activation': 'identity', 'solver': 'sgd', 'alpha':
. Best is trial 21 with value: -23.34320473375313.
# [I 2024-03-05 23:11:35,105] Trial 38 finished with value: -29.01185567520459 and parameters: {'kernel': 1**2 * Matern(length_scale=1, nu=1.5), 'alpha': 2283398396.0498924}. Best is trial 21 with value: -23.34320473375313.
# [I 2024-03-05 23:11:35,404] Trial 39 finished with value: -29.011852791621692 and parameters: {'kernel': RBF(length_scale=1) + 1.41**2, 'alpha': 9443035416.225826}. Best is trial 21 with value: -23.34320473375313.
# [I 2024-03-05 23:11:35,706] Trial 40 finished with value: -29.011840832998146 and parameters: {'kernel': 50**2 * RBF(length_scale=50), 'alpha': 7134041289.212366}. Best is trial 21 with value: -23.34320473375313.
# [I 2024-03-05 23:11:35,871] Trial 41 finished with value: -23.66238836600998 and parameters: {'kernel': DotProduct(sigma_0=1) + WhiteKernel(noise_level=1), 'alpha': 682329469.8838278}. Best is trial 21 with value: -23.34320473375313.
# [I 2024-03-05 23:11:36,029] Trial 42 finished with value: -23.320734789384375 and parameters: {'kernel': DotProduct(sigma_0=1) + WhiteKernel(noise_level=1), 'alpha': 331830517.5669733}. Best is trial 42 with value: -23.320734789384375.
# [I 2024-03-05 23:11:36,183] Trial 43 finished with value: -23.363213195426436 and parameters: {'kernel': DotProduct(sigma_0=1) + WhiteKernel(noise_level=1), 'alpha': 396062535.4606356}. Best is trial 42 with value: -23.320734789384375.
# [I 2024-03-05 23:11:36,354] Trial 44 finished with value: -25.343797683460195 and parameters: {'kernel': DotProduct(sigma_0=1) + WhiteKernel(noise_level=1), 'alpha': 2191698014.6278915}. Best is trial 42 with value: -23.320734789384375.
# [I 2024-03-05 23:11:36,645] Trial 45 finished with value: -29.011835852291295 and parameters: {'kernel': RBF(length_scale=1) + 1.41**2, 'alpha': 1373650711.8921318}. Best is trial 42 with value: -23.320734789384375.
# [I 2024-03-05 23:11:36,799] Trial 46 finished with value: -26.807099211362996 and parameters: {'kernel': DotProduct(sigma_0=1) + WhiteKernel(noise_level=1), 'alpha': 5047887962.4412985}. Best is trial 42 with value: -23.320734789384375.
# [I 2024-03-05 23:11:37,095] Trial 47 finished with value: -29.01185567510244 and parameters: {'kernel': 0.5**2 * RationalQuadratic(alpha=1, length_scale=1), 'alpha': 830236516.3518423}. Best is trial 42 with value: -23.320734789384375.
# [I 2024-03-05 23:11:37,258] Trial 48 finished with value: -25.96794713981433 and parameters: {'kernel': DotProduct(sigma_0=1) + WhiteKernel(noise_level=1), 'alpha': 3132929028.0178866}. Best is trial 42 with value: -23.320734789384375.
# [I 2024-03-05 23:11:37,414] Trial 49 finished with value: -26.60440527908339 and parameters: {'kernel': DotProduct(sigma_0=1) + WhiteKernel(noise_level=1), 'alpha': 4478664857.262427}. Best is trial 42 with value: -23.320734789384375.
# GPR -23.320734789384375 21.914804028579766 962.1333617828723 262.681917815002

# %%
with open('best_model_onlyreg.pickle', 'wb') as f:
    pickle.dump(best_model_onlyreg, f, pickle.HIGHEST_PROTOCOL)

# %%
# X_t = X_t_old[selected_features] 
# X_t['cluster'] = train_data_tr['remainder__clusters']
# X_t['remainder__link_counts'] = train_data_tr['remainder__link_counts']
# X_v = validate_data_tr[selected_features]
# X_v['cluster'] = validate_data_tr['remainder__clusters']
# X_v['remainder__link_counts'] = validate_data_tr['remainder__link_counts']
# X_te = test_data_tr[selected_features]
# X_te['cluster'] = test_data_tr['remainder__clusters']
# X_te['remainder__link_counts'] = test_data_tr['remainder__link_counts']

# %% [markdown]
# ## old/temp record(not used anymore)

# %%
model = xgb.XGBRegressor(random_state=101)
opt = BayesSearchCV(
    model,
    param_space['XGB'],
    n_iter=50,  # Adjust the number of iterations based on your computational resources
    cv=ShuffleSplit(test_size=0.20, n_splits=3),  # Adjust the number of cross-validation folds
    scoring='neg_mean_absolute_error',  # Use a suitable regression metric
    n_jobs=-1,
)

opt.fit(X_t, y_t)
best_params = opt.best_params_ 

model = xgb.XGBRegressor(**best_params, random_state=101)
model.fit(X_t, y_t)
te_predictions = model.predict(X_te)
te_mae = mean_absolute_error(y_te, te_predictions)
print(te_mae)

onehot = OneHotEncoder()
X_t_leaves = onehot.fit_transform(model.apply(X_t))
rf_lr = LogisticRegressionCV(cv=ShuffleSplit(test_size=0.20, n_splits=3))
rf_lr.fit(X_t_leaves, y_t)
X_te_leaves = onehot.transform(model.apply(X_te))
y_te_pred_rf_lr = rf_lr.predict(X_te_leaves)
te_rflr_mae = mean_absolute_error(y_te, y_te_pred_rf_lr)
print(te_rflr_mae)

# %%
v_mae_list = []
te_mae_list = []
v_rf_mae_list = []
te_rf_mae_list = []
# X_te['cluster'] = 1
for cluster_label in list(set(X_t['cluster'])):
    X_v_cluster, X_te_cluster = None, None
    v_mae, te_mae, v_rflr_mae, te_rflr_mae = None, None, None, None
    # Subset the training data for the current cluster
    X_t_cluster = X_t[X_t['cluster'] == cluster_label]
    y_t_cluster = X_t_cluster['remainder__link_counts']
    X_t_cluster = X_t_cluster.drop(columns=['remainder__link_counts','cluster'])  
    
    if cluster_label in list(set(X_v['cluster'])):
        X_v_cluster = X_v[X_v['cluster'] == cluster_label]
        y_v_cluster = X_v_cluster['remainder__link_counts']
        X_v_cluster = X_v_cluster.drop(columns=['remainder__link_counts','cluster'])  
    if cluster_label in list(set(X_te['cluster'])):
        X_te_cluster = X_te[X_te['cluster'] == cluster_label]
        y_te_cluster = X_te_cluster['remainder__link_counts']
        X_te_cluster = X_te_cluster.drop(columns=['remainder__link_counts','cluster'])  
    

    # Train a regression model for the current cluster
    # model = RidgeCV(scoring='neg_mean_absolute_error')
    # model = RandomForestRegressor(criterion='friedman_mse', n_estimators=300,
    #                   random_state=101)

    if not ((X_v_cluster is None) and (X_te_cluster is None)):

        model = xgb.XGBRegressor(random_state=101)
        opt = BayesSearchCV(
            model,
            param_space['XGB'],
            n_iter=60,  # Adjust the number of iterations based on your computational resources
            cv=ShuffleSplit(test_size=0.20, n_splits=1),  # Adjust the number of cross-validation folds
            scoring='neg_mean_absolute_error',  # Use a suitable regression metric
            n_jobs=-1,
        )
        
        opt.fit(X_t_cluster, y_t_cluster)
        best_params = opt.best_params_ 
        onehot = OneHotEncoder()
        model = xgb.XGBRegressor(**best_params, random_state=101)
        model.fit(X_t_cluster, y_t_cluster)

        X_t_leaves = onehot.fit_transform(model.apply(X_t_cluster))
        rf_lr = LogisticRegression()
        rf_lr.fit(X_t_leaves, y_t_cluster)
        if (X_v_cluster is not None):
            v_predictions = model.predict(X_v_cluster)
            v_mae = mean_absolute_error(y_v_cluster, v_predictions)
            row_count = len(y_v_cluster)
            v_mae_list.append(v_mae*row_count)

            X_v_leaves = onehot.transform(model.apply(X_v_cluster))
            y_v_pred_rf_lr = rf_lr.predict(X_v_leaves)
            row_count = len(y_v_pred_rf_lr)
            v_rflr_mae = mean_absolute_error(y_v_cluster, y_v_pred_rf_lr)
            v_rf_mae_list.append(v_rflr_mae*row_count)
        if (X_te_cluster is not None):
            te_predictions = model.predict(X_te_cluster)
            te_mae = mean_absolute_error(y_te_cluster, te_predictions)
            row_count = len(y_te_cluster)
            te_mae_list.append(te_mae*row_count)
      
            X_te_leaves = onehot.transform(model.apply(X_te_cluster))
            y_te_pred_rf_lr = rf_lr.predict(X_te_leaves)
            row_count = len(y_te_pred_rf_lr)
            te_rflr_mae = mean_absolute_error(y_te_cluster, y_te_pred_rf_lr)
            te_rf_mae_list.append(te_rflr_mae*row_count)
    print(cluster_label, v_mae, te_mae, v_rflr_mae, te_rflr_mae)
v_mae_list = list(filter(lambda item: item is not None, v_mae_list))    
te_mae_list = list(filter(lambda item: item is not None, te_mae_list))    
v_mean_mae = sum(v_mae_list)/len(X_v)
te_mean_mae = sum(te_mae_list)/len(X_te)
print(v_mean_mae)
print(te_mean_mae)

# %%
best_params = None
best_mae = 0.0

# Generate all combinations of hyperparameters
param_combinations = product(*param_grid.values())
# Loop through hyperparameter combinations
for params in param_combinations:
    # Create and train the model with the current hyperparameters
    model = lgb.LGBMRegressor(**dict(zip(param_grid.keys(), params)), random_state=101)
    model.fit(X_t[X_v.columns], y_t)

    # Evaluate the model on the validation dataset
    y_val_pred = model.predict(X_v)
    mae = mean_absolute_error(y_v, y_val_pred)

    # Check if current hyperparameters are the best
    if mae > best_mae:
        best_mae = mae
        best_params = dict(zip(param_grid.keys(), params))
print(best_mae)
print(best_params)
# Train the final model using the entire training dataset with the best hyperparameters
final_model = lgb.LGBMRegressor(**best_params, random_state=101)
final_model.fit(X_t, y_t)

# Evaluate the final model on the test dataset
y_test_pred = final_model.predict(X_te)
test_mae = mean_absolute_error(y_te, y_test_pred)
print(test_mae)

# %%
# Define the LGBMRegressor model
lgbm_model = lgb.LGBMRegressor(random_state=101, force_col_wise=True)

# Create a Bayesian optimization object
opt = BayesSearchCV(
    lgbm_model,
    param_space,
    n_iter=100,  # Adjust the number of iterations based on your computational resources
    cv=3,  # Adjust the number of cross-validation folds
    scoring='neg_mean_absolute_error',  # Use a suitable regression metric
    n_jobs=-1,
)

# Perform Bayesian optimization
opt.fit(X_t[X_v.columns], y_t, eval_set = [(X_v, y_v)])

# Get the best hyperparameters
best_params = opt.best_params_
print(opt.best_estimator_)

# Train the final model with the best hyperparameters
final_model = lgb.LGBMRegressor(**best_params, random_state=101, force_col_wise=True)
final_model.fit(X_t, y_t, eval_set = [(X_te, y_te)])

print("With LGB Pred")
y_t_pred = final_model.predict(X_t)
print(mean_absolute_error(y_t, y_t_pred))

y_te_pred = final_model.predict(X_te)
print(mean_absolute_error(y_te, y_te_pred))

# %%
print("---------------")

onehot = OneHotEncoder()
X_t_leaves = onehot.fit_transform(final_model.predict(X_t, pred_leaf=True))
xgb_lr = LogisticRegression()
xgb_lr.fit(X_t_leaves, y_t)

print("With LGB + LR Pred")
X_t_leaves = onehot.transform(final_model.predict(X_t, pred_leaf=True))
y_t_pred_xgb_lr = xgb_lr.predict(X_t_leaves)
print(mean_absolute_error(y_t, y_t_pred_xgb_lr))

X_te_leaves = onehot.transform(final_model.predict(X_te, pred_leaf=True))
y_te_pred_xgb_lr = xgb_lr.predict(X_te_leaves)
print(mean_absolute_error(y_te, y_te_pred_xgb_lr))

# %%
param_space = {
    'learning_rate': np.arange(0.01, 1.0, 0.01),
    'n_estimators': np.arange(50, 2001, 50),
    'max_depth': np.arange(1, 20),
    'max_leaves': np.arange(2, 50),
    'max_bin': np.arange(2, 50),
    'gamma': np.arange(1, 20),
    # 'min_child_weight': np.arange(0, 20),
    # 'subsample': np.arange(0.1, 1.0, 0.1),
    # 'colsample_bytree': np.arange(0.1, 1.0, 0.1),
    # 'reg_alpha': np.arange(0, 100),
    # 'reg_lambda': np.arange(0, 10, 0.01),
}

# Define the LGBMRegressor model
xgb_model = xgb.XGBRegressor(random_state=101)

# Create a Bayesian optimization object
opt = BayesSearchCV(
    xgb_model,
    param_space,
    n_iter=100,  # Adjust the number of iterations based on your computational resources
    cv=3,  # Adjust the number of cross-validation folds
    scoring='neg_mean_absolute_error',  # Use a suitable regression metric
    n_jobs=-1,
)

# Perform Bayesian optimization
opt.fit(X_t[X_v.columns], y_t, eval_set = [(X_v, y_v)])
# 
# Get the best hyperparameters
best_params = opt.best_params_
print(opt.best_estimator_)

# Train the final model using the entire training dataset with the best hyperparameters
final_model = xgb.XGBRegressor(**best_params, random_state=101)
final_model.fit(X_t, y_t, eval_set = [(X_te, y_te)])

# Evaluate the final model on the test dataset
y_test_pred = final_model.predict(X_te)
test_mae = mean_absolute_error(y_te, y_test_pred)
print(test_mae)

# %%
# Train the final model with the best hyperparameters
final_model = xgb.XGBRegressor(**best_params, random_state=101)
final_model.fit(X_t, y_t)

print("With XGB Pred")
y_t_pred = final_model.predict(X_t)
print(mean_absolute_error(y_t, y_t_pred))

y_te_pred = final_model.predict(X_te)
print(mean_absolute_error(y_te, y_te_pred))

print("---------------")

onehot = OneHotEncoder()
X_t_leaves = onehot.fit_transform(final_model.apply(X_t))
xgb_lr = LogisticRegression()
xgb_lr.fit(X_t_leaves, y_t)

print("With XGB + LR Pred")
X_t_leaves = onehot.transform(final_model.apply(X_t))
y_t_pred_xgb_lr = xgb_lr.predict(X_t_leaves)
print(mean_absolute_error(y_t, y_t_pred_xgb_lr))

X_te_leaves = onehot.transform(final_model.apply(X_te))
y_te_pred_xgb_lr = xgb_lr.predict(X_te_leaves)
print(mean_absolute_error(y_te, y_te_pred_xgb_lr))


# # Make predictions on the validation set
# y_pred = final_model.predict(X_te)

# # Evaluate the model on the validation set
# mae = mean_absolute_error(y_te, y_pred)
# print(f'Mean Absolute Error on Validation Set: {mae}')

# %%
param_space =  {
    'max_features': Categorical(['sqrt', 'log2']),
    'n_estimators': np.arange(50, 2001, 50),
    'bootstrap': Categorical([True, False]),
    'max_depth': np.arange(1, 20),
    'min_samples_leaf': np.arange(1, 20),
    'criterion': Categorical(['squared_error', 'absolute_error', 'friedman_mse', 'poisson'])
}
# Define the LGBMRegressor model
rf_model = RandomForestRegressor(random_state=101)

# Create a Bayesian optimization object
opt = BayesSearchCV(
    rf_model,
    param_space,
    n_iter=100,  # Adjust the number of iterations based on your computational resources
    cv=3,  # Adjust the number of cross-validation folds
    scoring='neg_mean_absolute_error',  # Use a suitable regression metric
    n_jobs=-1,
)

# Perform Bayesian optimization
opt.fit(X_t, y_t)

# Get the best hyperparameters
best_params = opt.best_params_
print(opt.best_estimator_)

# %%
# Train the final model with the best hyperparameters
final_model = RandomForestRegressor(**best_params, random_state=101)
final_model.fit(X_t, y_t)

print("With RF Pred")
y_t_pred = final_model.predict(X_t)
print(mean_absolute_error(y_t, y_t_pred))

y_te_pred = final_model.predict(X_te)
print(mean_absolute_error(y_te, y_te_pred))

print("---------------")

onehot = OneHotEncoder()
X_t_leaves = onehot.fit_transform(final_model.apply(X_t))
xgb_lr = LogisticRegression()
xgb_lr.fit(X_t_leaves, y_t)

print("With XGB + LR Pred")
X_t_leaves = onehot.transform(final_model.apply(X_t))
y_t_pred_xgb_lr = xgb_lr.predict(X_t_leaves)
print(mean_absolute_error(y_t, y_t_pred_xgb_lr))

X_te_leaves = onehot.transform(final_model.apply(X_te))
y_te_pred_xgb_lr = xgb_lr.predict(X_te_leaves)
print(mean_absolute_error(y_te, y_te_pred_xgb_lr))

# %%
param_space = {
    'learning_rate': np.arange(0.01, 1.0, 0.01),
    'n_estimators': np.arange(50, 2001, 50),
    'max_depth': np.arange(1, 200),
    'min_samples_split': np.arange(2, 11, 1),
    'min_samples_leaf': np.arange(1, 10),
    'subsample': np.arange(0.1, 1.0, 0.1),
}
# Define the LGBMRegressor model
gb_model = GradientBoostingRegressor(random_state=101)

# Create a Bayesian optimization object
opt = BayesSearchCV(
    gb_model,
    param_space,
    n_iter=100,  # Adjust the number of iterations based on your computational resources
    cv=3,  # Adjust the number of cross-validation folds
    scoring='neg_mean_absolute_error',  # Use a suitable regression metric
    n_jobs=-1,
)

# Perform Bayesian optimization
opt.fit(X_t, y_t)

# Get the best hyperparameters
best_params = opt.best_params_
print(opt.best_estimator_)

# %%
final_model = GradientBoostingRegressor(**best_params, random_state=101)
final_model.fit(X_t, y_t)

print("With GB Pred")
y_t_pred = final_model.predict(X_t)
print(mean_absolute_error(y_t, y_t_pred))

y_te_pred = final_model.predict(X_te)
print(mean_absolute_error(y_te, y_te_pred))

print("---------------")

onehot = OneHotEncoder()
X_t_leaves = onehot.fit_transform(final_model.apply(X_t))
xgb_lr = LogisticRegression()
xgb_lr.fit(X_t_leaves, y_t)

print("With XGB + LR Pred")
X_t_leaves = onehot.transform(final_model.apply(X_t))
y_t_pred_xgb_lr = xgb_lr.predict(X_t_leaves)
print(mean_absolute_error(y_t, y_t_pred_xgb_lr))

X_te_leaves = onehot.transform(final_model.apply(X_te))
y_te_pred_xgb_lr = xgb_lr.predict(X_te_leaves)
print(mean_absolute_error(y_te, y_te_pred_xgb_lr))

# %%
def set_randomstate(model):
    current_params = model.get_params()

    # Update the random_state if it exists, otherwise add it to the parameters
    current_params['random_state'] = 101

    # Set the modified parameters back to the model
    model.set_params(**current_params)
    return model

kf = KFold(n_splits=5, shuffle=True, random_state=101)
models = {
    # 'Linear Regression': LinearRegression(),
    # 'Lasso': LassoCV(cv=kf, random_state=42, max_iter=200000),
    # 'Logistic': LogisticRegression(),
    # 'KNN': pd.read_pickle("result_KNN.pkl")['estimator'],
    'XGB': set_randomstate(pd.read_pickle("result_XGB.pkl")['estimator']),
    'LGBM': set_randomstate(pd.read_pickle("result_LGBM.pkl")['estimator']),
    # 'Ridge': RidgeCV(cv=kf),
    # 'SVR': pd.read_pickle("result_SVR.pkl")['estimator'],
    # 'Random Forest': RandomForestRegressor(bootstrap=False, max_depth=15, max_features=0.7,
    #                   min_samples_leaf=9, n_estimators=200, random_state=101),
    # 'Gradient Boosting': GradientBoostingRegressor(learning_rate=0.01, max_depth=14, min_samples_leaf=3,
    #                       min_samples_split=4, n_estimators=950, random_state=101, subsample=0.8),
    # 'Artificial Neural Network': MLPRegressor(activation='logistic', alpha=0.01, hidden_layer_sizes=(50, 50),
    #          max_iter=4000, random_state=101),
    # 'Gaussian Process Regression': GaussianProcessRegressor(0.1 ** 2 * RBF(length_scale=0.1) + WhiteKernel(noise_level=0.1 ** 2, noise_level_bounds=(1e-5, 1e5)))
}

# %%
# Function to train and evaluate models
def evaluate_models(models, X_train, y_train):
    results = {}
    for name, model in models.items():
        scoring=['neg_mean_absolute_error','neg_mean_squared_error']
        # Define the cross-validation strategy (e.g., 5-fold cross-validation)
        kf = KFold(n_splits=5, shuffle=True, random_state=101)

        # Perform k-fold cross-validation and calculate MSE and MAE
        scores = cross_validate(model, X_train, y_train, cv=kf, scoring=scoring, n_jobs=-1)

        mean_mae = -scores['test_neg_mean_absolute_error'].mean()
        mean_mse = -scores['test_neg_mean_squared_error'].mean()
        std_mse = scores['test_neg_mean_squared_error'].std()

        print(name + " done")
        print(mean_mae, mean_mse, std_mse)
        results[name] = {'MAE': mean_mae, 'MSE': mean_mse, 'MSE_std': std_mse}
    
    return results

# Train and evaluate
results = evaluate_models(models, X_t, y_t)

# %%
def model_lr_evaluation(models, X_train, y_train, X_test, y_test):
    results = {}
    scoring=['neg_mean_absolute_error','neg_mean_squared_error']

    for name, model in models.items():
        final_model = model
        
        scores = cross_validate(model, X_train, y_train, cv=3, scoring=scoring, n_jobs=-1)
        mean_mae = -scores['test_neg_mean_absolute_error'].mean()
        mean_mse = -scores['test_neg_mean_squared_error'].mean()
        std_mse = scores['test_neg_mean_squared_error'].std()
        print(name + " done")
        print(mean_mae, mean_mse, std_mse)
        
        final_model.fit(X_train, y_train)
        y_te_pred = final_model.predict(X_test)
        print(mean_absolute_error(y_test, y_te_pred), mean_squared_error(y_test, y_te_pred))
        
        print("---------------")
        
        onehot = OneHotEncoder()
        if name == 'LGBM':
            X_t_leaves = onehot.fit_transform(final_model.predict(X_train, pred_leaf=True))
        elif name == 'XGB':
            X_t_leaves = onehot.fit_transform(final_model.apply(X_train))
        xgb_lr = LogisticRegression()
        xgb_lr.fit(X_t_leaves, y_train)

        if name == 'LGBM':
            X_t_leaves = onehot.transform(final_model.predict(X_train, pred_leaf=True))
            X_te_leaves = onehot.transform(final_model.predict(X_test, pred_leaf=True))
        elif name == 'XGB':
            X_t_leaves = onehot.transform(final_model.apply(X_train))
            X_te_leaves = onehot.transform(final_model.apply(X_test))

        scores = cross_validate(model, X_t_leaves, y_train, cv=kf, scoring=scoring, n_jobs=-1)
        mean_mae = -scores['test_neg_mean_absolute_error'].mean()
        mean_mse = -scores['test_neg_mean_squared_error'].mean()
        std_mse = scores['test_neg_mean_squared_error'].std()
        print(mean_mae, mean_mse, std_mse) 
        
        y_te_pred_xgb_lr = xgb_lr.predict(X_te_leaves)
        print(mean_absolute_error(y_test, y_te_pred_xgb_lr), mean_squared_error(y_test, y_te_pred_xgb_lr))

model_lr_evaluation(models, X_t, y_t, X_te, y_te)

# %%
def evaluate_models_with_test(model, X_train, y_train, X_test, y_test):
    results = {}
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)      
    results = {'MAE': mae, 'MSE': mse}
    
    return results

# %%
import pickle

result_final_with_test = {}
for name, model in models.items():
    result_final_with_test[name] = evaluate_models_with_test(model, X_t, y_t, X_te, y_te)

result_final_with_test

# %%
train_data_0 = train_data[train_data['clusters']==0]
train_data_1 = train_data[train_data['clusters']==1]
validate_data_0 = validate_data[validate_data['clusters']==0]
validate_data_1 = validate_data[validate_data['clusters']==1]
test_data_0 = test_data[test_data['clusters']==0]
test_data_1 = test_data[test_data['clusters']==1]
test_data_2 = test_data[test_data['clusters']==2]
test_data_1 = pd.concat([test_data_1, test_data_2], ignore_index=True)

import matplotlib.pyplot as plt

# Assuming you have three DataFrames: df1, df2, and df3

# Plotting DataFrame 1 in red
plt.plot(train_data_0['start_node_x'], train_data_0['start_node_y'], 'ro-', label='DF1 Start')
plt.plot(train_data_0['end_node_x'], train_data_0['end_node_y'], 'ro-', label='DF1 End')

# Plotting DataFrame 2 in green
plt.plot(train_data_1['start_node_x'], train_data_1['start_node_y'], 'go-', label='DF2 Start')
plt.plot(train_data_1['end_node_x'], train_data_1['end_node_y'], 'go-', label='DF2 End')

# Plotting DataFrame 3 in blue
plt.plot(validate_data_0['start_node_x'], validate_data_0['start_node_y'], 'bo-', label='DF3 Start')
plt.plot(validate_data_0['end_node_x'], validate_data_0['end_node_y'], 'bo-', label='DF3 End')
plt.plot(validate_data_1['start_node_x'], validate_data_1['start_node_y'], 'yo-', label='DF4 Start')
plt.plot(validate_data_1['end_node_x'], validate_data_1['end_node_y'], 'yo-', label='DF4 End')

plt.plot(test_data_0['start_node_x'], test_data_0['start_node_y'], 'co-', label='DF5 Start')
plt.plot(test_data_0['end_node_x'], test_data_0['end_node_y'], 'co-', label='DF5 End')
plt.plot(test_data_1['start_node_x'], test_data_1['start_node_y'], 'mo-', label='DF6 Start')
plt.plot(test_data_1['end_node_x'], test_data_1['end_node_y'], 'mo-', label='DF6 End')
# plt.plot(test_data_2['start_node_x'], test_data_2['start_node_y'], 'ko-', label='DF7 Start')
# plt.plot(test_data_2['end_node_x'], test_data_2['end_node_y'], 'ko-', label='DF7 End')
# Add labels and legend
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()

# Show the plot
plt.show()
