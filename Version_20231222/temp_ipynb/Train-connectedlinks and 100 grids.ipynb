# %%
import json
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsRegressor, KNeighborsClassifier
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder, MinMaxScaler, RobustScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso, RidgeCV, LassoCV, LogisticRegression, LogisticRegressionCV
from sklearn.svm import SVR, SVC
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, GradientBoostingClassifier, RandomForestClassifier
from sklearn.neural_network import MLPRegressor, MLPClassifier
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error, make_scorer, max_error, accuracy_score
from sklearn.model_selection import GridSearchCV, cross_val_score, KFold, RandomizedSearchCV, ShuffleSplit, cross_validate, train_test_split
from scipy.stats import expon, reciprocal, uniform
from sklearn.gaussian_process.kernels import RBF, WhiteKernel, DotProduct, ExpSineSquared, RationalQuadratic, ConstantKernel, Matern
from sklearn.feature_selection import RFE, SelectFromModel, RFECV, SelectKBest, chi2, f_regression
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline, Pipeline
from mango import Tuner, scheduler
import xgboost as xgb
from skopt  import BayesSearchCV 
import lightgbm as lgb
from sklearn.cluster import OPTICS, MiniBatchKMeans
from pyGRNN import GRNN
from skopt.space import Categorical, Space, Dimension, Integer
from sklearn.inspection import permutation_importance
from optuna.integration import OptunaSearchCV
import optuna
import matplotlib.pyplot as plt
from loading import load_data
# Out:
# C:\Users\LinBoH\AppData\Local\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
numerical_features = ['start_node_x', 'start_node_y', 'end_node_x', 'end_node_y', 'link_length', 'link_freespeed', 
                      'link_capacity', 'link_permlanes', 'start_count', 'end_count', 'go_to_sum', 'rush_hour', 
                      'max_dur', 'cemdapStopDuration_s', 'length_per_capacity_ratio', 'speed_capacity_ratio',
                      'length_times_lanes', 'speed_times_capacity', 'length_times', 'capacity_divided_by_lanes',
                      'income', 'score', 'income_avg', 'score_avg'
                     ]
category_feature = ['type', 'home-activity-zone']
scaler = StandardScaler()
le = LabelEncoder()
ohe = OneHotEncoder(sparse_output=False)
ct = ColumnTransformer(
     [("num_preprocess", scaler, numerical_features),
      ("text_preprocess", ohe, category_feature)], remainder='passthrough').set_output(transform="pandas")
clf = {
    'KNN': KNeighborsClassifier(),
#     'XGB': xgb.XGBClassifier(random_state=101),
    'LGBM': lgb.LGBMClassifier(random_state=101, verbose=-1),
    'RF': RandomForestClassifier(random_state=101),
#     'GB': GradientBoostingClassifier(random_state=101),
#     'ANN': MLPClassifier(random_state=101)
}

model_space = {
    'KNN': KNeighborsRegressor(),
    'XGB': xgb.XGBRegressor(random_state=101),
    'LGBM': lgb.LGBMRegressor(random_state=101, verbose=-1),
    'RF': RandomForestRegressor(random_state=101),
    'GB': GradientBoostingRegressor(random_state=101),
    'ANN': MLPRegressor(random_state=101),
    'GPR': GaussianProcessRegressor(copy_X_train=False, random_state=101),
#     'SVR': SVR()
}
model_space_feature = {
    'SVR': RandomForestRegressor(random_state=101),
    'KNN': RandomForestRegressor(random_state=101),
    'XGB': xgb.XGBRegressor(random_state=101),
    'LGBM': lgb.LGBMRegressor(random_state=101, verbose=-1),
    'RF': RandomForestRegressor(random_state=101),
    'GB': GradientBoostingRegressor(random_state=101),
    'ANN': RandomForestRegressor(random_state=101),
    # 'GRNN': RandomForestRegressor(random_state=101)
}
param_space = {
'SVR': {
    "C": optuna.distributions.FloatDistribution(1e-5, 1e5),
    'gamma': optuna.distributions.CategoricalDistribution(['scale', 'auto']), 
    'kernel': optuna.distributions.CategoricalDistribution(['linear', 'poly', 'rbf', 'sigmoid']),  
    # 'epsilon': optuna.distributions.FloatDistribution(0.01, 1),  
},
'RF':  {
    'max_features': optuna.distributions.CategoricalDistribution(['sqrt', 'log2']),
    'n_estimators': optuna.distributions.IntDistribution(50, 501, 50),
    'max_depth': optuna.distributions.IntDistribution(1, 200),
    'min_samples_leaf': optuna.distributions.IntDistribution(1, 20),
    # 'criterion': Categorical(['absolute_error', 'friedman_mse'])
},
'GB':{
    'learning_rate': optuna.distributions.FloatDistribution(0.01, 1.0),
    'n_estimators': optuna.distributions.IntDistribution(50, 501, 50),
    'max_depth': optuna.distributions.IntDistribution(1, 200),
    'min_samples_split': optuna.distributions.IntDistribution(2, 11),
    'min_samples_leaf': optuna.distributions.IntDistribution(1, 10),
    'subsample': optuna.distributions.FloatDistribution(0.1, 1.0),
},
'ANN': {
    'hidden_layer_sizes': optuna.distributions.CategoricalDistribution([(100,), (50,), (50, 50), (100, 100), (30, 30, 30)]),
    'activation': optuna.distributions.CategoricalDistribution(['tanh', 'relu', 'identity', 'logistic']),
    'solver': optuna.distributions.CategoricalDistribution(['sgd', 'adam']),
    'alpha': optuna.distributions.FloatDistribution(1e-5, 1e5, log=True),
},
'KNN':{
    'n_neighbors': optuna.distributions.IntDistribution(1, 50),
    'weights': optuna.distributions.CategoricalDistribution(['uniform', 'distance']),
    'algorithm': optuna.distributions.CategoricalDistribution(['auto', 'ball_tree', 'kd_tree', 'brute'])
},    
'LGBM': {
    'learning_rate': optuna.distributions.FloatDistribution(0.01, 1.0),
    'n_estimators': optuna.distributions.IntDistribution(50, 501, 50),
    'max_depth': optuna.distributions.IntDistribution(1, 50),
    'num_leaves': optuna.distributions.IntDistribution(2, 50),
    'min_child_samples': optuna.distributions.IntDistribution(1, 20),
    'subsample': optuna.distributions.FloatDistribution(0.1, 1.0),
    'colsample_bytree': optuna.distributions.FloatDistribution(0.1, 1.0),
},
'XGB': {
    'learning_rate': optuna.distributions.FloatDistribution(0.01, 1.0),
    'n_estimators': optuna.distributions.IntDistribution(50, 501, 50),
    'max_depth': optuna.distributions.IntDistribution(1, 20),
    'max_leaves': optuna.distributions.IntDistribution(2, 50),
    'max_bin': optuna.distributions.IntDistribution(2, 50),
    'gamma': optuna.distributions.IntDistribution(1, 20),
},
'GPR':{
    'kernel': optuna.distributions.CategoricalDistribution([0.1**2 * RBF(length_scale=0.1) + 
                                    WhiteKernel(noise_level=0.1**2, noise_level_bounds=(1e-5, 1e5)), 
                                    0.5**2 * RationalQuadratic(length_scale=1.0, alpha=1.0),
                                    50.0**2 * RBF(length_scale=50.0), DotProduct() + WhiteKernel(), 
                                    1.0 * Matern(length_scale=1.0, nu=1.5),
                                    RBF() + ConstantKernel(constant_value=2)
                                                           ]),
    'alpha':  optuna.distributions.FloatDistribution(1e-15, 1e10)
}
}

# %%
train_files = ['s-0.json', 's-1.json', 's-2.json', 's-3.json', 's-4.json','s-5.json', 's-6.json', 's-7.json', 's-8.json', 's-9.json'] 
test_files = ['s-15.json', 's-16.json', 's-17.json', 's-18.json','s-19.json']
validate_files = ['s-10.json', 's-11.json', 's-12.json', 's-13.json','s-14.json']
train_files = ['Data/cutoutWorlds/Train/po-1_pn-1.0_sn-1/' + i for i in train_files]
test_files = ['Data/cutoutWorlds/Test/po-1_pn-1.0_sn-1/' + j for j in test_files]
validate_files = ['Data/cutoutWorlds/Validate/po-1_pn-1.0_sn-1/' + k for k in validate_files]
df_activities = pd.read_pickle("Data/cutoutWorlds/Train/po-1_pn-1.0_sn-1/df_activities.pkl")
df_links_network = pd.read_pickle("Data/cutoutWorlds/Train/po-1_pn-1.0_sn-1/df_links_network.pkl")
train_data = load_data(train_files, df_activities, df_links_network)
validate_data = load_data(validate_files, df_activities, df_links_network)
test_data = load_data(test_files, df_activities, df_links_network)
train_data['dataset'] = 'train'
validate_data['dataset'] = 'validate'
test_data['dataset'] = 'test'
Big_data = pd.concat([train_data, validate_data, test_data], ignore_index=True)

# %%
nodes_data = Big_data[['link_id', 'start_node_x', 'start_node_y', 'end_node_x', 'end_node_y']]
grouped = nodes_data.groupby(['start_node_x', 'start_node_y'])
filtered_df = grouped.filter(lambda x: len(x) == 1)
filtered_df = filtered_df.drop_duplicates()
node_mapping = filtered_df.set_index(['start_node_x', 'start_node_y']).apply(
    lambda row: (row['end_node_x'], row['end_node_y']), axis=1).to_dict()

all_nodes = set(node_mapping.keys()) | set(node_mapping.values())
end_nodes = set(node_mapping.values())

start_nodes = list(all_nodes - end_nodes)

paths = []
for start_node in start_nodes:
    path = [start_node]
    while path[-1] in node_mapping:
        next_node = node_mapping[path[-1]]
        path.append(next_node)
    paths.append(path)
    
new_paths = [x for x in paths if len(x) >2]
def map_path_to_links(df, path):
    path_links = pd.DataFrame()
    for i in range(len(path) - 1):
        start_node = path[i]
        end_node = path[i+1]
        link_row = df[(df['start_node_x'] == start_node[0]) & 
                      (df['start_node_y'] == start_node[1]) & 
                      (df['end_node_x'] == end_node[0]) & 
                      (df['end_node_y'] == end_node[1])]
        if not link_row.empty:
            path_links = pd.concat([path_links, link_row])
    return path_links

# Step 3: Create separate DataFrames for each path
path_dfs = []
for path in new_paths:
    link_df = map_path_to_links(Big_data, path)
    path_dfs.append(link_df)

Big_data_drop = Big_data.copy(deep=True)
for path_df in path_dfs:
    numeric_df = path_df.select_dtypes(include=[ 'float64', 'int64'])
    column_means = numeric_df.mean()
    mean_df = pd.DataFrame([column_means])
    zone = path_df['home-activity-zone'].mode()
    type_value = path_df['type'].mode()
    dataset = path_df['dataset'].mode()
    mean_df['home-activity-zone'] = zone
    mean_df['type'] = type_value
    mean_df['dataset'] = dataset
    Big_data_drop = pd.concat([Big_data_drop, mean_df])

    try:
        Big_data_drop.drop(path_df.index, inplace=True)
    except:
        pass

# %%
cluster = MiniBatchKMeans(n_clusters=500, random_state=101)
Big_data_drop['x_y_coor'] = cluster.fit_predict(Big_data_drop[['start_node_x', 'start_node_y',
                                                           'end_node_x', 'end_node_y']])
cluster1 = MiniBatchKMeans(n_clusters=500, random_state=101)
Big_data_drop['similar_link'] = cluster1.fit_predict(Big_data_drop[['link_length', 'link_freespeed',
                                                           'link_capacity', 'link_permlanes']])
cluster2 = MiniBatchKMeans(n_clusters=500, random_state=101)
Big_data_drop['planxml'] = cluster2.fit_predict(Big_data_drop[['income', 'score', 'rush_hour',
                                                               'max_dur', 'cemdapStopDuration_s']])

Big_data_drop = Big_data_drop.astype({'x_y_coor':'int64','similar_link':'int64', 'planxml':'int64'})

# %%
train_data_drop = Big_data_drop[Big_data_drop['dataset']=='train']
validate_data_drop = Big_data_drop[Big_data_drop['dataset']=='validate']
test_data_drop = Big_data_drop[Big_data_drop['dataset']=='test']

# %%
column_name = 'planxml'
train_data_edit = pd.DataFrame()
for i in list(set(train_data_drop[column_name].tolist())):
    new_train = train_data_drop[train_data_drop[column_name]==i]
    numeric_df = new_train.select_dtypes(include=[ 'float64', 'int64'])
    column_means = numeric_df.mean()
    mean_df = pd.DataFrame([column_means])
    zone = new_train['home-activity-zone'].mode()
    type_value = new_train['type'].mode()
    dataset = new_train['dataset'].mode()
    mean_df['home-activity-zone'] = zone
    mean_df['type'] = type_value
    mean_df['dataset'] = dataset
    train_data_edit = pd.concat([train_data_edit, mean_df], ignore_index=True)
    
validate_data_edit = pd.DataFrame()
for i in list(set(validate_data_drop[column_name].tolist())):
    new_validate = validate_data_drop[validate_data_drop[column_name]==i]
    numeric_df = new_validate.select_dtypes(include=[ 'float64', 'int64'])
    column_means = numeric_df.mean()
    mean_df = pd.DataFrame([column_means])
    zone = new_validate['home-activity-zone'].mode()
    type_value = new_validate['type'].mode()
    dataset = new_validate['dataset'].mode()
    mean_df['home-activity-zone'] = zone
    mean_df['type'] = type_value
    mean_df['dataset'] = dataset
    validate_data_edit = pd.concat([validate_data_edit, mean_df], ignore_index=True)

Big_data_edit = pd.concat([train_data_edit, validate_data_edit, test_data_drop], ignore_index=True)
Big_data_edit = Big_data_edit.astype({column_name:'int64'})

# %%
Big_data_tr = ct.fit_transform(Big_data_edit)
Big_data_tr['used_link'] = 1
Big_data_tr['used_link'][Big_data_tr['remainder__link_counts']==0] = 0
Big_data_tr = Big_data_tr.reset_index(drop=True)
train_data_tr = Big_data_tr[Big_data_tr['remainder__dataset']=='train']
validate_data_tr = Big_data_tr[Big_data_tr['remainder__dataset']=='validate']
test_data_tr = Big_data_tr[Big_data_tr['remainder__dataset']=='test']

train_index = list(train_data_tr.index)
validate_index = list(validate_data_tr.index)

temp = pd.concat([train_data_tr, validate_data_tr], ignore_index=True)

# %%
X_t_clf = temp.drop(columns=['remainder__dataset', 'remainder__link_counts', 'used_link'])
y_t_clf = temp['used_link']

X_te_clf = test_data_tr.drop(columns=['remainder__dataset', 'remainder__link_counts', 'used_link'])
y_te_clf = test_data_tr['used_link']

# %%
best_model_clf = {}
for model_name in clf.keys():   
    model = clf[model_name]
    pipeline  = Pipeline([('selector', SelectKBest(f_regression)),
                  ('model', model)])
    param_grid = {}
    param_grid['selector__k']=optuna.distributions.IntDistribution(10, 47)
    for key in param_space[model_name].keys():
        param_grid[f'model__{key}']=param_space[model_name][key]
    
    # BayesSearchCV
    opt = OptunaSearchCV(
        pipeline,
        param_grid,
        n_trials=50,
        cv=[(train_index, validate_index), (train_index, validate_index)]
    )
    opt.fit(X_t_clf, y_t_clf)
    y_pred_clf = opt.predict(X_te_clf)
    best_model_clf[model_name] = [opt, opt.best_score_, y_pred_clf]
    print(model_name, opt.best_score_, accuracy_score(y_te_clf, y_pred_clf))
# Out:
# [I 2024-02-19 23:01:44,014] A new study created in memory with name: no-name-66e13394-9dca-4501-b671-20af835b554e
# [I 2024-02-19 23:01:44,070] Trial 0 finished with value: 1.0 and parameters: {'selector__k': 42, 'model__n_neighbors': 33, 'model__weights': 'distance', 'model__algorithm': 'kd_tree'}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:44,118] Trial 1 finished with value: 1.0 and parameters: {'selector__k': 24, 'model__n_neighbors': 38, 'model__weights': 'distance', 'model__algorithm': 'kd_tree'}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:44,161] Trial 2 finished with value: 1.0 and parameters: {'selector__k': 15, 'model__n_neighbors': 27, 'model__weights': 'distance', 'model__algorithm': 'auto'}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:44,377] Trial 3 finished with value: 1.0 and parameters: {'selector__k': 38, 'model__n_neighbors': 5, 'model__weights': 'distance', 'model__algorithm': 'auto'}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:44,447] Trial 4 finished with value: 1.0 and parameters: {'selector__k': 26, 'model__n_neighbors': 9, 'model__weights': 'uniform', 'model__algorithm': 'ball_tree'}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:44,514] Trial 5 finished with value: 1.0 and parameters: {'selector__k': 23, 'model__n_neighbors': 4, 'model__weights': 'uniform', 'model__algorithm': 'ball_tree'}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:44,580] Trial 6 finished with value: 1.0 and parameters: {'selector__k': 14, 'model__n_neighbors': 25, 'model__weights': 'uniform', 'model__algorithm': 'auto'}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:44,810] Trial 7 finished with value: 1.0 and parameters: {'selector__k': 46, 'model__n_neighbors': 42, 'model__weights': 'uniform', 'model__algorithm': 'auto'}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:45,025] Trial 8 finished with value: 1.0 and parameters: {'selector__k': 10, 'model__n_neighbors': 28, 'model__weights': 'uniform', 'model__algorithm': 'brute'}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:45,078] Trial 9 finished with value: 1.0 and parameters: {'selector__k': 20, 'model__n_neighbors': 5, 'model__weights': 'uniform', 'model__algorithm': 'kd_tree'}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:45,160] Trial 10 finished with value: 1.0 and parameters: {'selector__k': 35, 'model__n_neighbors': 50, 'model__weights': 'distance', 'model__algorithm': 'kd_tree'}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:45,239] Trial 11 finished with value: 1.0 and parameters: {'selector__k': 33, 'model__n_neighbors': 37, 'model__weights': 'distance', 'model__algorithm': 'kd_tree'}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:45
 'model__n_neighbors': 38, 'model__weights': 'distance', 'model__algorithm': 'ball_tree'}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:50,111] Trial 46 finished with value: 1.0 and parameters: {'selector__k': 20, 'model__n_neighbors': 6, 'model__weights': 'uniform', 'model__algorithm': 'kd_tree'}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:50,194] Trial 47 finished with value: 1.0 and parameters: {'selector__k': 33, 'model__n_neighbors': 50, 'model__weights': 'distance', 'model__algorithm': 'kd_tree'}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:50,434] Trial 48 finished with value: 1.0 and parameters: {'selector__k': 42, 'model__n_neighbors': 3, 'model__weights': 'distance', 'model__algorithm': 'brute'}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:50,514] Trial 49 finished with value: 1.0 and parameters: {'selector__k': 12, 'model__n_neighbors': 26, 'model__weights': 'distance', 'model__algorithm': 'auto'}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:50,867] A new study created in memory with name: no-name-c07cfde7-670e-40be-897d-662b8677f590
# [I 2024-02-19 23:01:50,939] Trial 0 finished with value: 1.0 and parameters: {'selector__k': 15, 'model__learning_rate': 0.6924671765287518, 'model__n_estimators': 339, 'model__max_depth': 10, 'model__num_leaves': 35, 'model__min_child_samples': 4, 'model__subsample': 0.7612266540805754, 'model__colsample_bytree': 0.3776303611584074}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:51,003] Trial 1 finished with value: 1.0 and parameters: {'selector__k': 33, 'model__learning_rate': 0.5900637004578784, 'model__n_estimators': 252, 'model__max_depth': 19, 'model__num_leaves': 21, 'model__min_child_samples': 17, 'model__subsample': 0.8533428008018661, 'model__colsample_bytree': 0.34648007644740425}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:51,071] Trial 2 finished with value: 1.0 and parameters: {'selector__k': 47, 'model__learning_rate': 0.7134087956774499, 'model__n_estimators': 205, 'model__max_depth': 5, 'model__num_leaves': 14, 'model__min_child_samples': 19, 'model__subsample': 0.3366517409300658, 'model__colsample_bytree': 0.4021596436489714}. Best is trial 0 with value: 1.0.
# KNN 1.0 0.8462449033276338
# [I 2024-02-19 23:01:51,128] Trial 3 finished with value: 1.0 and parameters: {'selector__k': 17, 'model__learning_rate': 0.22247857064303891, 'model__n_estimators': 56, 'model__max_depth': 46, 'model__num_leaves': 12, 'model__min_child_samples': 9, 'model__subsample': 0.9068781014202166, 'model__colsample_bytree': 0.9050297147918321}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:51,188] Trial 4 finished with value: 1.0 and parameters: {'selector__k': 31, 'model__learning_rate': 0.3259013646458304, 'model__n_estimators': 97, 'model__max_depth': 17, 'model__num_leaves': 38, 'model__min_child_samples': 6, 'model__subsample': 0.6667962867728544, 'model__colsample_bytree': 0.3193145753471868}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:51,246] Trial 5 finished with value: 1.0 and parameters: {'selector__k': 11, 'model__learning_rate': 0.16447415783142252, 'model__n_estimators': 90, 'model__max_depth': 34, 'model__num_leaves': 38, 'model__min_child_samples': 15, 'model__subsample': 0.9229497666484674, 'model__colsample_bytree': 0.3450949294913551}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:51,313] Trial 6 finished with value: 1.0 and parameters: {'selector__k': 20, 'model__learning_rate': 0.04398689046489186, 'model__n_estimators': 324, 'model__max_depth': 45, 'model__num_leaves': 2, 'model__min_child_samples': 5, 'model__subsample': 0.9525739447578468, 'model__colsample_bytree': 0.41803060485863053}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:51,374] Trial 7 finished with value: 1.0 and parameters: {'selector__k': 13, 'model__learning_rate': 0.7334971903984775, 'model__n_estimators': 253, 'model__max_depth': 50, 'model__num_leaves': 13, 'model__min_child_samples': 9, 'model__subsample': 0.7839685283160579, 'model__colsample_bytree': 0.6547626021673306}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:51,437] Trial 8 finished with value: 1.0 and parameters: {'selector__k': 30, 'model__learning_rate': 0.4204315695928492, 'model__n_estimators': 247, 'model__max_depth': 18, 'model__num_leaves': 29, 'model__min_child_samples': 16, 'model__subsample': 0.27387058773776024, 'model__colsample_bytree': 0.37532854568496365}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:51,501] Trial 9 finished with value: 1.0 and parameters: {'selector__k': 31, 'model__learning_rate': 0.2284942588771562, 'model__n_estimators': 163, 'model__max_depth': 8, 'model__num_leaves': 14, 'model__min_child_samples': 3, 'model__subsample': 0.14590036693870198, 'model__colsample_bytree': 0.2885102135841996}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:51,652] Trial 10 finished with value: 1.0 and parameters: {'selector__k': 22, 'model__learning_rate': 0.9926722113066787, 'model__n_estimators': 495, 'model__max_depth': 29, 'model__num_leaves': 50, 'model__min_child_samples': 2, 'model__subsample': 0.5155381416843351, 'model__colsample_bytree': 0.10463661039996203}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:51,806] Trial 11 finished with value: 1.0 and parameters: {'selector__k': 41, 'model__learning_rate': 0.6222502480246934, 'model__n_estimators': 420, 'model__max_depth': 15, 'model__num_leaves': 27, 'model__min_child_samples': 13, 'model__subsample': 0.7070998432813446, 'model__colsample_bytree': 0.6054558465810231}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:51,957] Trial 12 finished with value: 1.0 and parameters: {'selector__k': 35, 'model__learning_rate': 0.9109403051337788, 'model__n_estimators': 343, 'model__max_depth': 2, 'model__num_leaves': 36, 'model__min_child_samples': 19, 'model__subsample': 0.5313939784178381, 'model__colsample_bytree': 0.12179632981279304}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:52,104] Trial 13 finished with value: 1.0 and parameters: {'selector__k': 26, 'model__learning_rate': 0.5428550187762462, 'model__n_estimators': 133, 'model__max_depth': 24, 'model__num_leaves': 21, 'model__min_child_samples': 11, 'model__subsample': 0.8056905780271405, 'model__colsample_bytree': 0.7492819798659678}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:52,251] Trial 14 finished with value: 1.0 and parameters: {'selector__k': 37, 'model__learning_rate': 0.8054302290722243, 'model__n_estimators': 328, 'model__max_depth': 10, 'model__num_leaves': 48, 'model__min_child_samples': 7, 'model__subsample': 0.6450587090310338, 'model__colsample_bytree': 0.5061026682417463}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:52,398] Trial 15 finished with value: 1.0 and parameters: {'selector__k': 26, 'model__learning_rate': 0.5086854626651436, 'model__n_estimators': 216, 'model__max_depth': 23, 'model__num_leaves': 22, 'model__min_child_samples': 15, 'model__subsample': 0.806620629763506, 'model__colsample_bytree': 0.21933854231127184}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:52,552] Trial 16 finished with value: 1.0 and parameters: {'selector__k': 17, 'model__learning_rate': 0.6425002997724918, 'model__n_estimators': 160, 'model__max_depth': 35, 'model__num_leaves': 33, 'model__min_child_samples': 1, 'model__subsample': 0.46793655469605966, 'model__colsample_bytree': 0.5144258582089878}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:52,708] Trial 17 finished with value: 1.0 and parameters: {'selector__k': 41, 'model__learning_rate': 0.4045230137434059, 'model__n_estimators': 372, 'model__max_depth': 12, 'model__num_leaves': 42, 'model__min_child_samples': 20, 'model__subsample': 0.9773733520602028, 'model__colsample_bytree': 0.25557633524620726}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:52,861] Trial 18 finished with value: 1.0 and parameters: {'selector__k': 22, 'model__learning_rate': 0.8407571833172853, 'model__n_estimators': 291, 'model__max_depth': 20, 'model__num_leaves': 23, 'model__min_child_samples': 12, 'model__subsample': 0.8440152746517231, 'model__colsample_bytree': 0.7086512665060964}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:53,020] Trial 19 finished with value: 1.0 and parameters: {'selector__k': 35, 'model__learning_rate': 0.5714958508524935, 'model__n_estimators': 500, 'model__max_depth': 32, 'model__num_leaves': 31, 'model__min_child_samples': 4, 'model__subsample': 0.7160560891685586, 'model__colsample_bytree': 0.46990861069815054}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:53,162] Trial 20 finished with value: 1.0 and parameters: {'selector__k': 27, 'model__learning_rate': 0.4341906166547897, 'model__n_estimators': 122, 'model__max_depth': 2, 'model__num_leaves': 44, 'model__min_child_samples': 17, 'model__subsample': 0.5969074574126292, 'model__colsample_bytree': 0.19657407714298863}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:53,314] Trial 21 finished with value: 1.0 and parameters: {'selector__k': 47, 'model__learning_rate': 0.7081426405322836, 'model__n_estimators': 202, 'model__max_depth': 6, 'model__num_leaves': 18, 'model__min_child_samples': 19, 'model__subsample': 0.3936859683598062, 'model__colsample_bytree': 0.4149891003155218}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:53,465] Trial 22 finished with value: 1.0 and parameters: {'selector__k': 47, 'model__learning_rate': 0.7280008114669971, 'model__n_estimators': 197, 'model__max_depth': 13, 'model__num_leaves': 6, 'model__min_child_samples': 18, 'model__subsample': 0.31574697104729244, 'model__colsample_bytree': 0.5942698685487755}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:53,628] Trial 23 finished with value: 1.0 and parameters: {'selector__k': 42, 'model__learning_rate': 0.62990726731796, 'model__n_estimators': 258, 'model__max_depth': 6, 'model__num_leaves': 9, 'model__min_child_samples': 14, 'model__subsample': 0.10040053961069184, 'model__colsample_bytree': 0.4465610694729102}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:53,788] Trial 24 finished with value: 1.0 and parameters: {'selector__k': 44, 'model__learning_rate': 0.8107603739093944, 'model__n_estimators': 186, 'model__max_depth': 1, 'model__num_leaves': 19, 'model__min_child_samples': 8, 'model__subsample': 0.29435169654148097, 'model__colsample_bytree': 0.3158932611448207}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:53,953] Trial 25 finished with value: 1.0 and parameters: {'selector__k': 38, 'model__learning_rate': 0.678837605523091, 'model__n_estimators': 412, 'model__max_depth': 9, 'model__num_leaves': 26, 'model__min_child_samples': 17, 'model__subsample': 0.4255204226077568, 'model__colsample_bytree': 0.18593946487158602}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:54,112] Trial 26 finished with value: 1.0 and parameters: {'selector__k': 10, 'model__learning_rate': 0.9111902945634572, 'model__n_estimators': 290, 'model__max_depth': 21, 'model__num_leaves': 16, 'model__min_child_samples': 20, 'model__subsample': 0.8688108476100062, 'model__colsample_bytree': 0.40031914553684295}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:54,265] Trial 27 finished with value: 1.0 and parameters: {'selector__k': 34, 'model__learning_rate': 0.597481204925121, 'model__n_estimators': 131, 'model__max_depth': 28, 'model__num_leaves': 24, 'model__min_child_samples': 11, 'model__subsample': 0.5900430379878561, 'model__colsample_bytree': 0.54586589200813}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:54,422] Trial 28 finished with value: 1.0 and parameters: {'selector__k': 16, 'model__learning_rate': 0.7788109481962026, 'model__n_estimators': 229, 'model__max_depth': 5, 'model__num_leaves': 9, 'model__min_child_samples': 13, 'model__subsample': 0.7332868137110915, 'model__colsample_bytree': 0.9734198816347829}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:54,578] Trial 29 finished with value: 1.0 and parameters: {'selector__k': 15, 'model__learning_rate': 0.4875495902303487, 'model__n_estimators': 63, 'model__max_depth': 14, 'model__num_leaves': 34, 'model__min_child_samples': 9, 'model__subsample': 0.17112186869635684, 'model__colsample_bytree': 0.8003581204634175}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:54,735] Trial 30 finished with value: 1.0 and parameters: {'selector__k': 19, 'model__learning_rate': 0.888056756376606, 'model__n_estimators': 175, 'model__max_depth': 40, 'model__num_leaves': 10, 'model__min_child_samples': 17, 'model__subsample': 0.8806169776315063, 'model__colsample_bytree': 0.2639282374614187}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:54,888] Trial 31 finished with value: 1.0 and parameters: {'selector__k': 13, 'model__learning_rate': 0.3235612702757412, 'model__n_estimators': 75, 'model__max_depth': 18, 'model__num_leaves': 14, 'model__min_child_samples': 6, 'model__subsample': 0.8978673528943878, 'model__colsample_bytree': 0.9074456757829767}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:55,035] Trial 32 finished with value: 1.0 and parameters: {'selector__k': 22, 'model__learning_rate': 0.013303475538203435, 'model__n_estimators': 56, 'model__max_depth': 38, 'model__num_leaves': 4, 'model__min_child_samples': 10, 'model__subsample': 0.763757357981367, 'model__colsample_bytree': 0.33766813465341794}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:55,194] Trial 33 finished with value: 1.0 and parameters: {'selector__k': 24, 'model__learning_rate': 0.1267104429574814, 'model__n_estimators': 83, 'model__max_depth': 50, 'model__num_leaves': 17, 'model__min_child_samples': 6, 'model__subsample': 0.9402863790554199, 'model__colsample_bytree': 0.8383429721679128}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:55,348] Trial 34 finished with value: 1.0 and parameters: {'selector__k': 19, 'model__learning_rate': 0.2624134951387591, 'model__n_estimators': 109, 'model__max_depth': 11, 'model__num_leaves': 12, 'model__min_child_samples': 5, 'model__subsample': 0.9963828320341472, 'model__colsample_bytree': 0.3676835381984235}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:55,503] Trial 35 finished with value: 1.0 and parameters: {'selector__k': 13, 'model__learning_rate': 0.6873472485472831, 'model__n_estimators': 283, 'model__max_depth': 42, 'model__num_leaves': 38, 'model__min_child_samples': 15, 'model__subsample': 0.6769600924311111, 'model__colsample_bytree': 0.4407535729715531}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:55,662] Trial 36 finished with value: 1.0 and parameters: {'selector__k': 29, 'model__learning_rate': 0.07435017332993735, 'model__n_estimators': 144, 'model__max_depth': 46, 'model__num_leaves': 6, 'model__min_child_samples': 8, 'model__subsample': 0.9301459096459457, 'model__colsample_bytree': 0.6049836638202312}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:55,819] Trial 37 finished with value: 1.0 and parameters: {'selector__k': 32, 'model__learning_rate': 0.4877938607262105, 'model__n_estimators': 106, 'model__max_depth': 15, 'model__num_leaves': 27, 'model__min_child_samples': 18, 'model__subsample': 0.8299240253664306, 'model__colsample_bytree': 0.32780093149432765}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:55,980] Trial 38 finished with value: 1.0 and parameters: {'selector__k': 17, 'model__learning_rate': 0.38055640349278413, 'model__n_estimators': 241, 'model__max_depth': 26, 'model__num_leaves': 20, 'model__min_child_samples': 3, 'model__subsample': 0.3723787591671487, 'model__colsample_bytree': 0.4791483382351148}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:56,143] Trial 39 finished with value: 1.0 and parameters: {'selector__k': 39, 'model__learning_rate': 0.757570762813776, 'model__n_estimators': 401, 'model__max_depth': 17, 'model__num_leaves': 15, 'model__min_child_samples': 16, 'model__subsample': 0.7523138006036092, 'model__colsample_bytree': 0.6982740795381503}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:56,293] Trial 40 finished with value: 1.0 and parameters: {'selector__k': 12, 'model__learning_rate': 0.20943361802625882, 'model__n_estimators': 70, 'model__max_depth': 7, 'model__num_leaves': 30, 'model__min_child_samples': 1, 'model__subsample': 0.9103152803359668, 'model__colsample_bytree': 0.38286698072977665}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:56,443] Trial 41 finished with value: 1.0 and parameters: {'selector__k': 32, 'model__learning_rate': 0.3009706457067063, 'model__n_estimators': 98, 'model__max_depth': 17, 'model__num_leaves': 42, 'model__min_child_samples': 4, 'model__subsample': 0.640102835077331, 'model__colsample_bytree': 0.3040989526230268}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:56,595] Trial 42 finished with value: 1.0 and parameters: {'selector__k': 31, 'model__learning_rate': 0.16681414283089135, 'model__n_estimators': 52, 'model__max_depth': 4, 'model__num_leaves': 38, 'model__min_child_samples': 7, 'model__subsample': 0.7837197515804633, 'model__colsample_bytree': 0.14221676715000287}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:56,746] Trial 43 finished with value: 1.0 and parameters: {'selector__k': 28, 'model__learning_rate': 0.5510870997396787, 'model__n_estimators': 84, 'model__max_depth': 21, 'model__num_leaves': 12, 'model__min_child_samples': 9, 'model__subsample': 0.22350588071839605, 'model__colsample_bytree': 0.2560104614308097}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:56,896] Trial 44 finished with value: 1.0 and parameters: {'selector__k': 25, 'model__learning_rate': 0.3092015321165656, 'model__n_estimators': 59, 'model__max_depth': 9, 'model__num_leaves': 39, 'model__min_child_samples': 5, 'model__subsample': 0.6737256500710692, 'model__colsample_bytree': 0.36735882450532575}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:57,060] Trial 45 finished with value: 1.0 and parameters: {'selector__k': 34, 'model__learning_rate': 0.3624092614814977, 'model__n_estimators': 343, 'model__max_depth': 24, 'model__num_leaves': 35, 'model__min_child_samples': 3, 'model__subsample': 0.502774179262199, 'model__colsample_bytree': 0.5413767421967741}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:57,216] Trial 46 finished with value: 1.0 and parameters: {'selector__k': 44, 'model__learning_rate': 0.44045096155142865, 'model__n_estimators': 155, 'model__max_depth': 31, 'model__num_leaves': 45, 'model__min_child_samples': 6, 'model__subsample': 0.8423140270231492, 'model__colsample_bytree': 0.9977624963906857}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:57,372] Trial 47 finished with value: 1.0 and parameters: {'selector__k': 20, 'model__learning_rate': 0.6481504690986748, 'model__n_estimators': 267, 'model__max_depth': 47, 'model__num_leaves': 24, 'model__min_child_samples': 10, 'model__subsample': 0.5629788346312257, 'model__colsample_bytree': 0.27231903818853176}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:57,525] Trial 48 finished with value: 1.0 and parameters: {'selector__k': 24, 'model__learning_rate': 0.2289975023038341, 'model__n_estimators': 216, 'model__max_depth': 16, 'model__num_leaves': 32, 'model__min_child_samples': 7, 'model__subsample': 0.7964719128995988, 'model__colsample_bytree': 0.2183420178631411}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:57,691] Trial 49 finished with value: 1.0 and parameters: {'selector__k': 15, 'model__learning_rate': 0.10800625570307083, 'model__n_estimators': 452, 'model__max_depth': 12, 'model__num_leaves': 28, 'model__min_child_samples': 19, 'model__subsample': 0.7016737877162615, 'model__colsample_bytree': 0.43631059362193375}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:01:57,734] A new study created in memory with name: no-name-d69cdd26-8b80-455f-8f28-54c9f6cc2f3e
# LGBM 1.0 0.8462449033276338
# [I 2024-02-19 23:01:58,462] Trial 0 finished with value: 1.0 and parameters: {'selector__k': 39, 'model__max_features': 'sqrt', 'model__n_estimators': 117, 'model__max_depth': 27, 'model__min_samples_leaf': 20}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:00,821] Trial 1 finished with value: 1.0 and parameters: {'selector__k': 15, 'model__max_features': 'log2', 'model__n_estimators': 405, 'model__max_depth': 82, 'model__min_samples_leaf': 14}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:01,805] Trial 2 finished with value: 1.0 and parameters: {'selector__k': 18, 'model__max_features': 'sqrt', 'model__n_estimators': 160, 'model__max_depth': 59, 'model__min_samples_leaf': 15}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:02,284] Trial 3 finished with value: 1.0 and parameters: {'selector__k': 37, 'model__max_features': 'sqrt', 'model__n_estimators': 72, 'model__max_depth': 105, 'model__min_samples_leaf': 11}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:04,177] Trial 4 finished with value: 1.0 and parameters: {'selector__k': 20, 'model__max_features': 'log2', 'model__n_estimators': 306, 'model__max_depth': 74, 'model__min_samples_leaf': 15}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:05,238] Trial 5 finished with value: 1.0 and parameters: {'selector__k': 16, 'model__max_features': 'sqrt', 'model__n_estimators': 170, 'model__max_depth': 97, 'model__min_samples_leaf': 1}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:05,630] Trial 6 finished with value: 1.0 and parameters: {'selector__k': 44, 'model__max_features': 'log2', 'model__n_estimators': 59, 'model__max_depth': 29, 'model__min_samples_leaf': 4}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:06,314] Trial 7 finished with value: 1.0 and parameters: {'selector__k': 37, 'model__max_features': 'log2', 'model__n_estimators': 108, 'model__max_depth': 11, 'model__min_samples_leaf': 13}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:07,089] Trial 8 finished with value: 1.0 and parameters: {'selector__k': 41, 'model__max_features': 'sqrt', 'model__n_estimators': 124, 'model__max_depth': 136, 'model__min_samples_leaf': 10}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:09,164] Trial 9 finished with value: 1.0 and parameters: {'selector__k': 16, 'model__max_features': 'log2', 'model__n_estimators': 353, 'model__max_depth': 60, 'model__min_samples_leaf': 11}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:10,507] Trial 10 finished with value: 1.0 and parameters: {'selector__k': 30, 'model__max_features': 'sqrt', 'model__n_estimators': 220, 'model__max_depth': 164, 'model__min_samples_leaf': 19}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:13,379] Trial 11 finished with value: 1.0 and parameters: {'selector__k': 28, 'model__max_features': 'log2', 'model__n_estimators': 462, 'model__max_depth': 39, 'model__min_samples_leaf': 20}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:14,023] Trial 12 finished with value: 1.0 and parameters: {'selector__k': 10, 'model__max_features': 'sqrt', 'model__n_estimators': 94, 'model__max_depth': 1, 'model__min_samples_leaf': 17}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:15,398] Trial 13 finished with value: 1.0 and parameters: {'selector__k': 28, 'model__max_features': 'log2', 'model__n_estimators': 223, 'model__max_depth': 101, 'model__min_samples_leaf': 7}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:18,316] Trial 14 finished with value: 1.0 and parameters: {'selector__k': 47, 'model__max_features': 'log2', 'model__n_estimators': 487, 'model__max_depth': 182, 'model__min_samples_leaf': 16}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:19,744] Trial 15 finished with value: 1.0 and parameters: {'selector__k': 36, 'model__max_features': 'sqrt', 'model__n_estimators': 226, 'model__max_depth': 37, 'model__min_samples_leaf': 20}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:20,582] Trial 16 finished with value: 1.0 and parameters: {'selector__k': 25, 'model__max_features': 'sqrt', 'model__n_estimators': 124, 'model__max_depth': 132, 'model__min_samples_leaf': 18}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:21,149] Trial 17 finished with value: 1.0 and parameters: {'selector__k': 10, 'model__max_features': 'log2', 'model__n_estimators': 78, 'model__max_depth': 79, 'model__min_samples_leaf': 7}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:23,071] Trial 18 finished with value: 1.0 and parameters: {'selector__k': 32, 'model__max_features': 'log2', 'model__n_estimators': 312, 'model__max_depth': 129, 'model__min_samples_leaf': 13}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:23,469] Trial 19 finished with value: 1.0 and parameters: {'selector__k': 23, 'model__max_features': 'sqrt', 'model__n_estimators': 53, 'model__max_depth': 24, 'model__min_samples_leaf': 13}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:24,632] Trial 20 finished with value: 1.0 and parameters: {'selector__k': 33, 'model__max_features': 'log2', 'model__n_estimators': 184, 'model__max_depth': 54, 'model__min_samples_leaf': 8}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:25,511] Trial 21 finished with value: 1.0 and parameters: {'selector__k': 18, 'model__max_features': 'sqrt', 'model__n_estimators': 139, 'model__max_depth': 59, 'model__min_samples_leaf': 15}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:26,139] Trial 22 finished with value: 1.0 and parameters: {'selector__k': 13, 'model__max_features': 'sqrt', 'model__n_estimators': 92, 'model__max_depth': 68, 'model__min_samples_leaf': 17}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:28,427] Trial 23 finished with value: 1.0 and parameters: {'selector__k': 22, 'model__max_features': 'sqrt', 'model__n_estimators': 379, 'model__max_depth': 89, 'model__min_samples_leaf': 14}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:29,366] Trial 24 finished with value: 1.0 and parameters: {'selector__k': 14, 'model__max_features': 'sqrt', 'model__n_estimators': 150, 'model__max_depth': 44, 'model__min_samples_leaf': 18}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:31,056] Trial 25 finished with value: 1.0 and parameters: {'selector__k': 25, 'model__max_features': 'sqrt', 'model__n_estimators': 276, 'model__max_depth': 17, 'model__min_samples_leaf': 10}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:32,243] Trial 26 finished with value: 1.0 and parameters: {'selector__k': 19, 'model__max_features': 'sqrt', 'model__n_estimators': 193, 'model__max_depth': 115, 'model__min_samples_leaf': 15}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:32,727] Trial 27 finished with value: 1.0 and parameters: {'selector__k': 41, 'model__max_features': 'sqrt', 'model__n_estimators': 69, 'model__max_depth': 76, 'model__min_samples_leaf': 12}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:33,410] Trial 28 finished with value: 1.0 and parameters: {'selector__k': 13, 'model__max_features': 'log2', 'model__n_estimators': 102, 'model__max_depth': 51, 'model__min_samples_leaf': 17}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:33,965] Trial 29 finished with value: 1.0 and parameters: {'selector__k': 40, 'model__max_features': 'sqrt', 'model__n_estimators': 79, 'model__max_depth': 111, 'model__min_samples_leaf': 19}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:35,598] Trial 30 finished with value: 1.0 and parameters: {'selector__k': 35, 'model__max_features': 'sqrt', 'model__n_estimators': 265, 'model__max_depth': 92, 'model__min_samples_leaf': 9}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:36,074] Trial 31 finished with value: 1.0 and parameters: {'selector__k': 38, 'model__max_features': 'sqrt', 'model__n_estimators': 65, 'model__max_depth': 77, 'model__min_samples_leaf': 11}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:36,872] Trial 32 finished with value: 1.0 and parameters: {'selector__k': 45, 'model__max_features': 'sqrt', 'model__n_estimators': 119, 'model__max_depth': 113, 'model__min_samples_leaf': 14}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:37,949] Trial 33 finished with value: 1.0 and parameters: {'selector__k': 17, 'model__max_features': 'sqrt', 'model__n_estimators': 168, 'model__max_depth': 66, 'model__min_samples_leaf': 4}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:38,541] Trial 34 finished with value: 1.0 and parameters: {'selector__k': 21, 'model__max_features': 'log2', 'model__n_estimators': 85, 'model__max_depth': 29, 'model__min_samples_leaf': 12}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:38,989] Trial 35 finished with value: 1.0 and parameters: {'selector__k': 39, 'model__max_features': 'sqrt', 'model__n_estimators': 59, 'model__max_depth': 152, 'model__min_samples_leaf': 16}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:39,956] Trial 36 finished with value: 1.0 and parameters: {'selector__k': 43, 'model__max_features': 'log2', 'model__n_estimators': 142, 'model__max_depth': 84, 'model__min_samples_leaf': 5}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:40,702] Trial 37 finished with value: 1.0 and parameters: {'selector__k': 33, 'model__max_features': 'sqrt', 'model__n_estimators': 111, 'model__max_depth': 103, 'model__min_samples_leaf': 2}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:41,084] Trial 38 finished with value: 1.0 and parameters: {'selector__k': 15, 'model__max_features': 'sqrt', 'model__n_estimators': 51, 'model__max_depth': 12, 'model__min_samples_leaf': 15}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:43,706] Trial 39 finished with value: 1.0 and parameters: {'selector__k': 42, 'model__max_features': 'log2', 'model__n_estimators': 432, 'model__max_depth': 44, 'model__min_samples_leaf': 12}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:45,937] Trial 40 finished with value: 1.0 and parameters: {'selector__k': 30, 'model__max_features': 'sqrt', 'model__n_estimators': 373, 'model__max_depth': 2, 'model__min_samples_leaf': 9}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:47,893] Trial 41 finished with value: 1.0 and parameters: {'selector__k': 19, 'model__max_features': 'log2', 'model__n_estimators': 323, 'model__max_depth': 66, 'model__min_samples_leaf': 14}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:49,611] Trial 42 finished with value: 1.0 and parameters: {'selector__k': 26, 'model__max_features': 'log2', 'model__n_estimators': 271, 'model__max_depth': 102, 'model__min_samples_leaf': 16}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:52,170] Trial 43 finished with value: 1.0 and parameters: {'selector__k': 12, 'model__max_features': 'log2', 'model__n_estimators': 421, 'model__max_depth': 72, 'model__min_samples_leaf': 13}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:53,718] Trial 44 finished with value: 1.0 and parameters: {'selector__k': 20, 'model__max_features': 'log2', 'model__n_estimators': 237, 'model__max_depth': 32, 'model__min_samples_leaf': 19}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:54,935] Trial 45 finished with value: 1.0 and parameters: {'selector__k': 35, 'model__max_features': 'log2', 'model__n_estimators': 196, 'model__max_depth': 124, 'model__min_samples_leaf': 11}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:56,912] Trial 46 finished with value: 1.0 and parameters: {'selector__k': 16, 'model__max_features': 'log2', 'model__n_estimators': 319, 'model__max_depth': 87, 'model__min_samples_leaf': 18}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:02:59,326] Trial 47 finished with value: 1.0 and parameters: {'selector__k': 23, 'model__max_features': 'log2', 'model__n_estimators': 407, 'model__max_depth': 97, 'model__min_samples_leaf': 16}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:03:02,236] Trial 48 finished with value: 1.0 and parameters: {'selector__k': 45, 'model__max_features': 'sqrt', 'model__n_estimators': 479, 'model__max_depth': 143, 'model__min_samples_leaf': 14}. Best is trial 0 with value: 1.0.
# [I 2024-02-19 23:03:03,116] Trial 49 finished with value: 1.0 and parameters: {'selector__k': 11, 'model__max_features': 'log2', 'model__n_estimators': 130, 'model__max_depth': 50, 'model__min_samples_leaf': 20}. Best is trial 0 with value: 1.0.
# RF 1.0 0.8462449033276338

# %%
import pickle
with open('best_model_clf.pickle', 'wb') as f:
    pickle.dump(best_model_clf, f, pickle.HIGHEST_PROTOCOL)

# %%
best_model_clf = pd.read_pickle("best_model_clf.pickle")

# %%
best_md_from_clf = sorted(best_model_clf.items(), key=lambda t: t[1][1])[-1]
temp_tr = test_data_tr.copy(deep=True)
temp_tr['y_pred_clf'] = best_md_from_clf[1][2]

# %%
used_link_1 = temp[temp['used_link']==1]
used_link_1_train = used_link_1[used_link_1['remainder__dataset']=='train']
used_link_1_validate = used_link_1[used_link_1['remainder__dataset']=='validate']
temp_2 = pd.concat([used_link_1_train, used_link_1_validate], ignore_index=True)
X_t = temp_2.drop(columns=['remainder__dataset', 'remainder__link_counts', 'used_link'])
y_t = temp_2['remainder__link_counts']

train_index = list(temp_2[temp_2['remainder__dataset']=='train'].index)
validate_index = list(temp_2[temp_2['remainder__dataset']=='validate'].index)

X_te = temp_tr[temp_tr['y_pred_clf']==1].drop(columns=['remainder__dataset', 'remainder__link_counts', 'used_link', 'y_pred_clf'])
y_te = temp_tr[temp_tr['y_pred_clf']==1]['remainder__link_counts']

X_te_0 = temp_tr[temp_tr['y_pred_clf']==0].drop(columns=['remainder__dataset', 'remainder__link_counts', 'used_link', 'y_pred_clf'])
X_te_0['y_pred'] = 0
y_te_0 = temp_tr[temp_tr['y_pred_clf']==0]['remainder__link_counts']
y_te_all = pd.concat([y_te, y_te_0])

# %%
best_model_reg = {}
for model_name in model_space.keys():   
    model = model_space[model_name]
    pipeline  = Pipeline([('selector', SelectKBest(f_regression)),
                  ('model', model)])
    param_grid = {}
    param_grid['selector__k']=optuna.distributions.IntDistribution(2, 38)
    for key in param_space[model_name].keys():
        param_grid[f'model__{key}']=param_space[model_name][key]
    
    # BayesSearchCV
    opt = OptunaSearchCV(
        pipeline,
        param_grid,
        n_trials=50,
        cv=[(train_index, validate_index), (train_index, validate_index)],
        scoring='neg_mean_absolute_error'
    )
    opt.fit(X_t, y_t)
    y_pred = opt.predict(X_te)
    y_pred_all = np.concatenate([y_pred, np.array(X_te_0['y_pred'])])
    mae = mean_absolute_error(y_te_all, y_pred_all)
    mse = mean_squared_error(y_te_all, y_pred_all)
    me = max_error(y_te_all, y_pred_all)
    best_model_reg[model_name] = (opt, mae, mse, me)
    print(model_name, opt.best_score_, mae, mse, me)
# Out:
# [I 2024-02-19 23:03:03,635] A new study created in memory with name: no-name-0716b4b6-1321-4768-96c3-e1e95a82232f
# [I 2024-02-19 23:03:03,692] Trial 0 finished with value: -11.540283289603234 and parameters: {'selector__k': 26, 'model__n_neighbors': 1, 'model__weights': 'distance', 'model__algorithm': 'ball_tree'}. Best is trial 0 with value: -11.540283289603234.
# [I 2024-02-19 23:03:03,904] Trial 1 finished with value: -8.379073831345579 and parameters: {'selector__k': 17, 'model__n_neighbors': 15, 'model__weights': 'uniform', 'model__algorithm': 'brute'}. Best is trial 1 with value: -8.379073831345579.
# [I 2024-02-19 23:03:03,953] Trial 2 finished with value: -10.146931974763099 and parameters: {'selector__k': 30, 'model__n_neighbors': 43, 'model__weights': 'uniform', 'model__algorithm': 'kd_tree'}. Best is trial 1 with value: -8.379073831345579.
# [I 2024-02-19 23:03:04,158] Trial 3 finished with value: -7.441718068263958 and parameters: {'selector__k': 10, 'model__n_neighbors': 4, 'model__weights': 'uniform', 'model__algorithm': 'brute'}. Best is trial 3 with value: -7.441718068263958.
# [I 2024-02-19 23:03:04,378] Trial 4 finished with value: -10.180428682904381 and parameters: {'selector__k': 33, 'model__n_neighbors': 37, 'model__weights': 'distance', 'model__algorithm': 'brute'}. Best is trial 3 with value: -7.441718068263958.
# [I 2024-02-19 23:03:04,424] Trial 5 finished with value: -10.264225100630759 and parameters: {'selector__k': 36, 'model__n_neighbors': 24, 'model__weights': 'distance', 'model__algorithm': 'ball_tree'}. Best is trial 3 with value: -7.441718068263958.
# [I 2024-02-19 23:03:04,474] Trial 6 finished with value: -10.197043360774037 and parameters: {'selector__k': 32, 'model__n_neighbors': 34, 'model__weights': 'distance', 'model__algorithm': 'kd_tree'}. Best is trial 3 with value: -7.441718068263958.
# [I 2024-02-19 23:03:04,522] Trial 7 finished with value: -10.349598322769257 and parameters: {'selector__k': 37, 'model__n_neighbors': 23, 'model__weights': 'distance', 'model__algorithm': 'kd_tree'}. Best is trial 3 with value: -7.441718068263958.
# [I 2024-02-19 23:03:04,564] Trial 8 finished with value: -7.625258821705454 and parameters: {'selector__k': 10, 'model__n_neighbors': 17, 'model__weights': 'distance', 'model__algorithm': 'auto'}. Best is trial 3 with value: -7.441718068263958.
# [I 2024-02-19 23:03:04,607] Trial 9 finished with value: -8.321497826621288 and parameters: {'selector__k': 14, 'model__n_neighbors': 20, 'model__weights': 'distance', 'model__algorithm': 'kd_tree'}. Best is trial 3 with value: -7.441718068263958.
# [I 2024-02-19 23:03:04,834] Trial 10 finished with value: -8.570104968831883 and parameters: {'selector__k': 4, 'model__n_neighbors': 1, 'model__weights': 'uniform', 'model__algorithm': 'brute'}. Best is trial 3 with value: -7.441718068263958.
# [I 2024-02-19 23:03:04,904] Trial 11 finished with value: -7.471089518421018 and parameters: {'selector__k': 7, 'model__n_neighbors': 11, 'model__weights': 'uniform', 'model__algorithm': 'auto'}. Best is trial 3 with value: -7.441718068263958.
# [I 2024-02-19 23:03:04,970] Trial 12 finished with value: -7.683904320017804 and parameters: {'selector__k': 2, 'model__n_neighbors': 10, 'model__weights': 'uniform', 'model__algorithm': 'auto'}. Best is trial 3 with value: -7.441718068263958.
# [I 2024-02-19 23:03:05,037] Trial 13 finished with value: -7.331835963782396 and parameters: {'selector__k': 9, 'model__n_neighbors': 9, 'model__weights': 'uniform', 'model__algorithm': 'auto'}. Best is trial 13 with value: -7.331835963782396.
# [I 2024-02-19 23:03:05,267] Trial 14 finished with value: -7.989527137548725 and parameters: {'selector__k': 22, 'model__n_neighbors': 8, 'model__weights': 'uniform', 'model__algorithm': 'auto'}. Best is trial 13 with value: -7.331835963782396.
# [I 2024-02-19 23:03:05,498] Trial 15 finished with value: -7.754706562892021 and parameters: {'selector__k': 12, 'model__n_neighbors': 5, 'model__weights': 'uniform', 'model__algorithm': 'brute'}. Best is trial 13 with value: -7.331835963782396.
# [I 2024-02-19 23:03:05,724] Trial 16 finished with value: -8.96600052645083 and parameters: {'selector__k': 17, 'model__n_neighbors': 29, 'model__weights': 'uniform', 'model__algorithm': 'brute'}. Best is trial 13 with value: -7.331835963782396.
# [I 2024-02-19 23:03
 'model__weights': 'distance', 'model__algorithm': 'auto'}. Best is trial 22 with value: -7.297829107207343.
# [I 2024-02-19 23:03:08,963] Trial 48 finished with value: -7.641813661295916 and parameters: {'selector__k': 11, 'model__n_neighbors': 3, 'model__weights': 'distance', 'model__algorithm': 'kd_tree'}. Best is trial 22 with value: -7.297829107207343.
# [I 2024-02-19 23:03:09,211] Trial 49 finished with value: -7.2562509954734455 and parameters: {'selector__k': 9, 'model__n_neighbors': 9, 'model__weights': 'distance', 'model__algorithm': 'brute'}. Best is trial 49 with value: -7.2562509954734455.
# [I 2024-02-19 23:03:09,326] A new study created in memory with name: no-name-06ac49a7-8813-4966-aeda-4a4288e84f28
# [I 2024-02-19 23:03:09,438] Trial 0 finished with value: -9.04475139878975 and parameters: {'selector__k': 16, 'model__learning_rate': 0.4685829741360392, 'model__n_estimators': 63, 'model__max_depth': 6, 'model__max_leaves': 2, 'model__max_bin': 16, 'model__gamma': 12}. Best is trial 0 with value: -9.04475139878975.
# KNN -7.2562509954734455 17.120761588561134 573.3167900073335 227.91836200581207
# [I 2024-02-19 23:03:09,650] Trial 1 finished with value: -10.637534930826096 and parameters: {'selector__k': 21, 'model__learning_rate': 0.8908268923397015, 'model__n_estimators': 212, 'model__max_depth': 13, 'model__max_leaves': 11, 'model__max_bin': 43, 'model__gamma': 16}. Best is trial 0 with value: -9.04475139878975.
# [I 2024-02-19 23:03:09,836] Trial 2 finished with value: -7.590508737338739 and parameters: {'selector__k': 2, 'model__learning_rate': 0.15006023700376844, 'model__n_estimators': 157, 'model__max_depth': 3, 'model__max_leaves': 37, 'model__max_bin': 48, 'model__gamma': 13}. Best is trial 2 with value: -7.590508737338739.
# [I 2024-02-19 23:03:10,002] Trial 3 finished with value: -8.381770564939991 and parameters: {'selector__k': 29, 'model__learning_rate': 0.08353629887476025, 'model__n_estimators': 50, 'model__max_depth': 5, 'model__max_leaves': 39, 'model__max_bin': 19, 'model__gamma': 13}. Best is trial 2 with value: -7.590508737338739.
# [I 2024-02-19 23:03:10,302] Trial 4 finished with value: -8.005763917085162 and parameters: {'selector__k': 2, 'model__learning_rate': 0.6168016466855645, 'model__n_estimators': 360, 'model__max_depth': 2, 'model__max_leaves': 18, 'model__max_bin': 16, 'model__gamma': 18}. Best is trial 2 with value: -7.590508737338739.
# [I 2024-02-19 23:03:10,470] Trial 5 finished with value: -16.279464588110148 and parameters: {'selector__k': 16, 'model__learning_rate': 0.7501025173548018, 'model__n_estimators': 139, 'model__max_depth': 12, 'model__max_leaves': 4, 'model__max_bin': 4, 'model__gamma': 2}. Best is trial 2 with value: -7.590508737338739.
# [I 2024-02-19 23:03:10,841] Trial 6 finished with value: -8.80202729060766 and parameters: {'selector__k': 27, 'model__learning_rate': 0.43323435921763237, 'model__n_estimators': 417, 'model__max_depth': 6, 'model__max_leaves': 39, 'model__max_bin': 31, 'model__gamma': 5}. Best is trial 2 with value: -7.590508737338739.
# [I 2024-02-19 23:03:11,125] Trial 7 finished with value: -8.171284109784331 and parameters: {'selector__k': 31, 'model__learning_rate': 0.5786173303460261, 'model__n_estimators': 289, 'model__max_depth': 19, 'model__max_leaves': 44, 'model__max_bin': 12, 'model__gamma': 14}. Best is trial 2 with value: -7.590508737338739.
# [I 2024-02-19 23:03:11,411] Trial 8 finished with value: -7.7062373451425925 and parameters: {'selector__k': 38, 'model__learning_rate': 0.12328679506091873, 'model__n_estimators': 179, 'model__max_depth': 7, 'model__max_leaves': 26, 'model__max_bin': 50, 'model__gamma': 10}. Best is trial 2 with value: -7.590508737338739.
# [I 2024-02-19 23:03:11,550] Trial 9 finished with value: -8.790166474589899 and parameters: {'selector__k': 12, 'model__learning_rate': 0.8811504927107098, 'model__n_estimators': 105, 'model__max_depth': 20, 'model__max_leaves': 17, 'model__max_bin': 34, 'model__gamma': 19}. Best is trial 2 with value: -7.590508737338739.
# [I 2024-02-19 23:03:11,753] Trial 10 finished with value: -7.356895951650529 and parameters: {'selector__k': 2, 'model__learning_rate': 0.2696202464236497, 'model__n_estimators': 96, 'model__max_depth': 1, 'model__max_leaves': 50, 'model__max_bin': 40, 'model__gamma': 9}. Best is trial 10 with value: -7.356895951650529.
# [I 2024-02-19 23:03:11,964] Trial 11 finished with value: -7.229560682539986 and parameters: {'selector__k': 2, 'model__learning_rate': 0.25725383108439814, 'model__n_estimators': 103, 'model__max_depth': 1, 'model__max_leaves': 50, 'model__max_bin': 41, 'model__gamma': 8}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:12,160] Trial 12 finished with value: -8.27914019112015 and parameters: {'selector__k': 8, 'model__learning_rate': 0.2956879297951279, 'model__n_estimators': 84, 'model__max_depth': 1, 'model__max_leaves': 50, 'model__max_bin': 39, 'model__gamma': 7}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:12,388] Trial 13 finished with value: -8.698585277482065 and parameters: {'selector__k': 7, 'model__learning_rate': 0.30096626297488477, 'model__n_estimators': 99, 'model__max_depth': 9, 'model__max_leaves': 50, 'model__max_bin': 27, 'model__gamma': 8}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:12,621] Trial 14 finished with value: -8.868507279012913 and parameters: {'selector__k': 7, 'model__learning_rate': 0.2598971439643682, 'model__n_estimators': 77, 'model__max_depth': 15, 'model__max_leaves': 34, 'model__max_bin': 40, 'model__gamma': 4}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:12,847] Trial 15 finished with value: -8.120404323245507 and parameters: {'selector__k': 2, 'model__learning_rate': 0.025127777028062848, 'model__n_estimators': 123, 'model__max_depth': 1, 'model__max_leaves': 29, 'model__max_bin': 33, 'model__gamma': 9}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:13,043] Trial 16 finished with value: -8.261171909091363 and parameters: {'selector__k': 11, 'model__learning_rate': 0.39486694201431893, 'model__n_estimators': 68, 'model__max_depth': 4, 'model__max_leaves': 44, 'model__max_bin': 44, 'model__gamma': 6}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:13,411] Trial 17 finished with value: -8.016898711724904 and parameters: {'selector__k': 21, 'model__learning_rate': 0.22095279366591178, 'model__n_estimators': 225, 'model__max_depth': 9, 'model__max_leaves': 45, 'model__max_bin': 37, 'model__gamma': 2}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:13,637] Trial 18 finished with value: -8.881793669580729 and parameters: {'selector__k': 6, 'model__learning_rate': 0.4016499424047007, 'model__n_estimators': 101, 'model__max_depth': 16, 'model__max_leaves': 29, 'model__max_bin': 26, 'model__gamma': 10}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:13,825] Trial 19 finished with value: -8.646882101580884 and parameters: {'selector__k': 16, 'model__learning_rate': 0.5440222535661889, 'model__n_estimators': 54, 'model__max_depth': 8, 'model__max_leaves': 46, 'model__max_bin': 45, 'model__gamma': 4}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:14,046] Trial 20 finished with value: -8.362888585727985 and parameters: {'selector__k': 12, 'model__learning_rate': 0.673488846364427, 'model__n_estimators': 126, 'model__max_depth': 3, 'model__max_leaves': 34, 'model__max_bin': 24, 'model__gamma': 11}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:14,309] Trial 21 finished with value: -7.621947757301194 and parameters: {'selector__k': 2, 'model__learning_rate': 0.1681613848259424, 'model__n_estimators': 164, 'model__max_depth': 3, 'model__max_leaves': 40, 'model__max_bin': 50, 'model__gamma': 15}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:14,513] Trial 22 finished with value: -7.995624378853141 and parameters: {'selector__k': 5, 'model__learning_rate': 0.3433569933948438, 'model__n_estimators': 88, 'model__max_depth': 1, 'model__max_leaves': 50, 'model__max_bin': 46, 'model__gamma': 8}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:14,779] Trial 23 finished with value: -7.70806119381747 and parameters: {'selector__k': 4, 'model__learning_rate': 0.1886548815864202, 'model__n_estimators': 145, 'model__max_depth': 4, 'model__max_leaves': 36, 'model__max_bin': 40, 'model__gamma': 12}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:15,272] Trial 24 finished with value: -8.021188361948797 and parameters: {'selector__k': 9, 'model__learning_rate': 0.01598390890672227, 'model__n_estimators': 201, 'model__max_depth': 3, 'model__max_leaves': 42, 'model__max_bin': 48, 'model__gamma': 16}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:15,691] Trial 25 finished with value: -7.284195454156466 and parameters: {'selector__k': 4, 'model__learning_rate': 0.11970549320115395, 'model__n_estimators': 265, 'model__max_depth': 1, 'model__max_leaves': 47, 'model__max_bin': 35, 'model__gamma': 9}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:16,108] Trial 26 finished with value: -8.601049978609515 and parameters: {'selector__k': 10, 'model__learning_rate': 0.09077671024957543, 'model__n_estimators': 307, 'model__max_depth': 1, 'model__max_leaves': 47, 'model__max_bin': 36, 'model__gamma': 7}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:16,501] Trial 27 finished with value: -9.930424080391022 and parameters: {'selector__k': 14, 'model__learning_rate': 0.3414895477058889, 'model__n_estimators': 285, 'model__max_depth': 5, 'model__max_leaves': 47, 'model__max_bin': 30, 'model__gamma': 9}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:16,867] Trial 28 finished with value: -8.803710188544269 and parameters: {'selector__k': 5, 'model__learning_rate': 0.2473360823126863, 'model__n_estimators': 240, 'model__max_depth': 11, 'model__max_leaves': 43, 'model__max_bin': 42, 'model__gamma': 6}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:17,084] Trial 29 finished with value: -8.963699096459615 and parameters: {'selector__k': 18, 'model__learning_rate': 0.47786900143985517, 'model__n_estimators': 64, 'model__max_depth': 6, 'model__max_leaves': 48, 'model__max_bin': 36, 'model__gamma': 11}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:17,339] Trial 30 finished with value: -7.976786218401594 and parameters: {'selector__k': 4, 'model__learning_rate': 0.07586450364914957, 'model__n_estimators': 117, 'model__max_depth': 2, 'model__max_leaves': 22, 'model__max_bin': 22, 'model__gamma': 9}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:17,615] Trial 31 finished with value: -7.29601208800533 and parameters: {'selector__k': 2, 'model__learning_rate': 0.15287030882061986, 'model__n_estimators': 157, 'model__max_depth': 2, 'model__max_leaves': 38, 'model__max_bin': 47, 'model__gamma': 12}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:17,912] Trial 32 finished with value: -7.377478658305857 and parameters: {'selector__k': 4, 'model__learning_rate': 0.21177782012821972, 'model__n_estimators': 185, 'model__max_depth': 2, 'model__max_leaves': 50, 'model__max_bin': 42, 'model__gamma': 12}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:18,422] Trial 33 finished with value: -7.458759349867882 and parameters: {'selector__k': 24, 'model__learning_rate': 0.14776506638311285, 'model__n_estimators': 485, 'model__max_depth': 4, 'model__max_leaves': 41, 'model__max_bin': 38, 'model__gamma': 11}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:18,643] Trial 34 finished with value: -7.612317398680297 and parameters: {'selector__k': 2, 'model__learning_rate': 0.3498189578380384, 'model__n_estimators': 75, 'model__max_depth': 5, 'model__max_leaves': 36, 'model__max_bin': 46, 'model__gamma': 14}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:18,988] Trial 35 finished with value: -8.415773443622557 and parameters: {'selector__k': 8, 'model__learning_rate': 0.08939237941328876, 'model__n_estimators': 249, 'model__max_depth': 2, 'model__max_leaves': 32, 'model__max_bin': 43, 'model__gamma': 8}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:19,236] Trial 36 finished with value: -7.373167053558229 and parameters: {'selector__k': 4, 'model__learning_rate': 0.2783120825942237, 'model__n_estimators': 145, 'model__max_depth': 1, 'model__max_leaves': 47, 'model__max_bin': 30, 'model__gamma': 10}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:19,496] Trial 37 finished with value: -8.28225443296565 and parameters: {'selector__k': 6, 'model__learning_rate': 0.1694524341858233, 'model__n_estimators': 115, 'model__max_depth': 3, 'model__max_leaves': 39, 'model__max_bin': 33, 'model__gamma': 12}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:19,867] Trial 38 finished with value: -7.525734920182403 and parameters: {'selector__k': 2, 'model__learning_rate': 0.9651370793093603, 'model__n_estimators': 327, 'model__max_depth': 5, 'model__max_leaves': 5, 'model__max_bin': 47, 'model__gamma': 13}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:20,285] Trial 39 finished with value: -9.595389871626262 and parameters: {'selector__k': 14, 'model__learning_rate': 0.0395460657704851, 'model__n_estimators': 90, 'model__max_depth': 7, 'model__max_leaves': 42, 'model__max_bin': 6, 'model__gamma': 5}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:20,599] Trial 40 finished with value: -8.490151814382529 and parameters: {'selector__k': 9, 'model__learning_rate': 0.12925726148813857, 'model__n_estimators': 169, 'model__max_depth': 2, 'model__max_leaves': 45, 'model__max_bin': 41, 'model__gamma': 16}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:20,863] Trial 41 finished with value: -7.398073379459204 and parameters: {'selector__k': 4, 'model__learning_rate': 0.2828209688005571, 'model__n_estimators': 131, 'model__max_depth': 1, 'model__max_leaves': 48, 'model__max_bin': 29, 'model__gamma': 10}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:21,147] Trial 42 finished with value: -7.523930111793238 and parameters: {'selector__k': 4, 'model__learning_rate': 0.20294503244249887, 'model__n_estimators': 144, 'model__max_depth': 2, 'model__max_leaves': 47, 'model__max_bin': 34, 'model__gamma': 9}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:21,371] Trial 43 finished with value: -8.460619283551674 and parameters: {'selector__k': 6, 'model__learning_rate': 0.25795801609726554, 'model__n_estimators': 107, 'model__max_depth': 1, 'model__max_leaves': 44, 'model__max_bin': 38, 'model__gamma': 7}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:21,639] Trial 44 finished with value: -7.824022399717561 and parameters: {'selector__k': 3, 'model__learning_rate': 0.4245485745950889, 'model__n_estimators': 153, 'model__max_depth': 4, 'model__max_leaves': 38, 'model__max_bin': 31, 'model__gamma': 13}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:21,912] Trial 45 finished with value: -8.738969805424647 and parameters: {'selector__k': 7, 'model__learning_rate': 0.3216676275878868, 'model__n_estimators': 136, 'model__max_depth': 13, 'model__max_leaves': 48, 'model__max_bin': 35, 'model__gamma': 10}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:22,242] Trial 46 finished with value: -7.9646824603163004 and parameters: {'selector__k': 36, 'model__learning_rate': 0.12127176238899663, 'model__n_estimators': 197, 'model__max_depth': 2, 'model__max_leaves': 41, 'model__max_bin': 28, 'model__gamma': 8}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:22,482] Trial 47 finished with value: -7.413720086276882 and parameters: {'selector__k': 25, 'model__learning_rate': 0.24169978500761763, 'model__n_estimators': 98, 'model__max_depth': 3, 'model__max_leaves': 13, 'model__max_bin': 49, 'model__gamma': 9}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:22,900] Trial 48 finished with value: -8.621589732346024 and parameters: {'selector__k': 32, 'model__learning_rate': 0.4759883277342961, 'model__n_estimators': 384, 'model__max_depth': 1, 'model__max_leaves': 50, 'model__max_bin': 19, 'model__gamma': 20}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:23,136] Trial 49 finished with value: -8.69237058030461 and parameters: {'selector__k': 8, 'model__learning_rate': 0.37667929958982455, 'model__n_estimators': 77, 'model__max_depth': 18, 'model__max_leaves': 44, 'model__max_bin': 44, 'model__gamma': 11}. Best is trial 11 with value: -7.229560682539986.
# [I 2024-02-19 23:03:23,216] A new study created in memory with name: no-name-b83804ce-3e53-4a01-a8bb-50abec8e2c2b
# [I 2024-02-19 23:03:23,366] Trial 0 finished with value: -8.297612109701147 and parameters: {'selector__k': 15, 'model__learning_rate': 0.3566936588038869, 'model__n_estimators': 108, 'model__max_depth': 26, 'model__num_leaves': 6, 'model__min_child_samples': 6, 'model__subsample': 0.45167601533813817, 'model__colsample_bytree': 0.48415718033997357}. Best is trial 0 with value: -8.297612109701147.
# XGB -7.229560682539986 17.43485561002967 766.1441804343416 279.58859159265245
# [I 2024-02-19 23:03:23,599] Trial 1 finished with value: -7.330847996293005 and parameters: {'selector__k': 6, 'model__learning_rate': 0.07600383481012479, 'model__n_estimators': 410, 'model__max_depth': 2, 'model__num_leaves': 43, 'model__min_child_samples': 4, 'model__subsample': 0.9016447430868054, 'model__colsample_bytree': 0.340402895373252}. Best is trial 1 with value: -7.330847996293005.
# [I 2024-02-19 23:03:24,017] Trial 2 finished with value: -8.37397426172955 and parameters: {'selector__k': 22, 'model__learning_rate': 0.30140246504937074, 'model__n_estimators': 183, 'model__max_depth': 39, 'model__num_leaves': 20, 'model__min_child_samples': 5, 'model__subsample': 0.6392287681610004, 'model__colsample_bytree': 0.4719761782619516}. Best is trial 1 with value: -7.330847996293005.
# [I 2024-02-19 23:03:24,264] Trial 3 finished with value: -7.481642395260459 and parameters: {'selector__k': 18, 'model__learning_rate': 0.015066494642948725, 'model__n_estimators': 77, 'model__max_depth': 28, 'model__num_leaves': 47, 'model__min_child_samples': 3, 'model__subsample': 0.5059381354538725, 'model__colsample_bytree': 0.4303797732206315}. Best is trial 1 with value: -7.330847996293005.
# [I 2024-02-19 23:03:24,396] Trial 4 finished with value: -7.423513191740069 and parameters: {'selector__k': 23, 'model__learning_rate': 0.23055683076284447, 'model__n_estimators': 106, 'model__max_depth': 18, 'model__num_leaves': 19, 'model__min_child_samples': 19, 'model__subsample': 0.7595338645188034, 'model__colsample_bytree': 0.6894045646513685}. Best is trial 1 with value: -7.330847996293005.
# [I 2024-02-19 23:03:24,486] Trial 5 finished with value: -8.527143143192266 and parameters: {'selector__k': 14, 'model__learning_rate': 0.928703484690042, 'model__n_estimators': 60, 'model__max_depth': 3, 'model__num_leaves': 42, 'model__min_child_samples': 15, 'model__subsample': 0.6637205325823399, 'model__colsample_bytree': 0.3606224247857155}. Best is trial 1 with value: -7.330847996293005.
# [I 2024-02-19 23:03:24,672] Trial 6 finished with value: -6.368718595529192 and parameters: {'selector__k': 26, 'model__learning_rate': 0.06327395802624389, 'model__n_estimators': 123, 'model__max_depth': 23, 'model__num_leaves': 41, 'model__min_child_samples': 12, 'model__subsample': 0.5144059875986742, 'model__colsample_bytree': 0.5811333670997608}. Best is trial 6 with value: -6.368718595529192.
# [I 2024-02-19 23:03:24,842] Trial 7 finished with value: -7.064345520495041 and parameters: {'selector__k': 28, 'model__learning_rate': 0.461389954487162, 'model__n_estimators': 109, 'model__max_depth': 31, 'model__num_leaves': 44, 'model__min_child_samples': 12, 'model__subsample': 0.193254418124053, 'model__colsample_bytree': 0.2021763317300984}. Best is trial 6 with value: -6.368718595529192.
# [I 2024-02-19 23:03:25,145] Trial 8 finished with value: -7.46194977907007 and parameters: {'selector__k': 28, 'model__learning_rate': 0.07476508485240985, 'model__n_estimators': 199, 'model__max_depth': 29, 'model__num_leaves': 11, 'model__min_child_samples': 2, 'model__subsample': 0.306076025389065, 'model__colsample_bytree': 0.6687557739608271}. Best is trial 6 with value: -6.368718595529192.
# [I 2024-02-19 23:03:25,238] Trial 9 finished with value: -7.153980443065686 and parameters: {'selector__k': 15, 'model__learning_rate': 0.10314453920423942, 'model__n_estimators': 113, 'model__max_depth': 1, 'model__num_leaves': 34, 'model__min_child_samples': 19, 'model__subsample': 0.8800223951658028, 'model__colsample_bytree': 0.7319538323482125}. Best is trial 6 with value: -6.368718595529192.
# [I 2024-02-19 23:03:25,696] Trial 10 finished with value: -8.645641194730771 and parameters: {'selector__k': 36, 'model__learning_rate': 0.7209623179722231, 'model__n_estimators': 318, 'model__max_depth': 15, 'model__num_leaves': 32, 'model__min_child_samples': 9, 'model__subsample': 0.35062580604230653, 'model__colsample_bytree': 0.8994895491894925}. Best is trial 6 with value: -6.368718595529192.
# [I 2024-02-19 23:03:25,916] Trial 11 finished with value: -7.831970613444024 and parameters: {'selector__k': 31, 'model__learning_rate': 0.550346295221257, 'model__n_estimators': 146, 'model__max_depth': 48, 'model__num_leaves': 50, 'model__min_child_samples': 13, 'model__subsample': 0.11294703909425081, 'model__colsample_bytree': 0.10337038539355846}. Best is trial 6 with value: -6.368718595529192.
# [I 2024-02-19 23:03:26,124] Trial 12 finished with value: -7.8352252310463495 and parameters: {'selector__k': 28, 'model__learning_rate': 0.5428001028300617, 'model__n_estimators': 70, 'model__max_depth': 38, 'model__num_leaves': 35, 'model__min_child_samples': 10, 'model__subsample': 0.12593047559147252, 'model__colsample_bytree': 0.15831175120744648}. Best is trial 6 with value: -6.368718595529192.
# [I 2024-02-19 23:03:26,445] Trial 13 finished with value: -8.75506599633398 and parameters: {'selector__k': 37, 'model__learning_rate': 0.7420355415017248, 'model__n_estimators': 238, 'model__max_depth': 18, 'model__num_leaves': 39, 'model__min_child_samples': 14, 'model__subsample': 0.2704344173956718, 'model__colsample_bytree': 0.265567237098699}. Best is trial 6 with value: -6.368718595529192.
# [I 2024-02-19 23:03:26,609] Trial 14 finished with value: -6.875198275598417 and parameters: {'selector__k': 31, 'model__learning_rate': 0.42062961600013515, 'model__n_estimators': 50, 'model__max_depth': 38, 'model__num_leaves': 27, 'model__min_child_samples': 12, 'model__subsample': 0.4229107383207036, 'model__colsample_bytree': 0.6221934650466052}. Best is trial 6 with value: -6.368718595529192.
# [I 2024-02-19 23:03:26,790] Trial 15 finished with value: -6.966479260880219 and parameters: {'selector__k': 33, 'model__learning_rate': 0.22818411116779092, 'model__n_estimators': 52, 'model__max_depth': 38, 'model__num_leaves': 27, 'model__min_child_samples': 16, 'model__subsample': 0.4275764854133372, 'model__colsample_bytree': 0.5868883282654035}. Best is trial 6 with value: -6.368718595529192.
# [I 2024-02-19 23:03:27,009] Trial 16 finished with value: -7.679878791082125 and parameters: {'selector__k': 2, 'model__learning_rate': 0.4113579390407823, 'model__n_estimators': 83, 'model__max_depth': 47, 'model__num_leaves': 23, 'model__min_child_samples': 8, 'model__subsample': 0.5865976296673968, 'model__colsample_bytree': 0.8441665995801655}. Best is trial 6 with value: -6.368718595529192.
# [I 2024-02-19 23:03:27,389] Trial 17 finished with value: -8.21720135358974 and parameters: {'selector__k': 24, 'model__learning_rate': 0.6633858223595752, 'model__n_estimators': 279, 'model__max_depth': 34, 'model__num_leaves': 14, 'model__min_child_samples': 12, 'model__subsample': 0.7725600020828854, 'model__colsample_bytree': 0.5987630501883903}. Best is trial 6 with value: -6.368718595529192.
# [I 2024-02-19 23:03:27,717] Trial 18 finished with value: -10.485417248411709 and parameters: {'selector__k': 32, 'model__learning_rate': 0.990720694916331, 'model__n_estimators': 147, 'model__max_depth': 23, 'model__num_leaves': 28, 'model__min_child_samples': 7, 'model__subsample': 0.39349087641769587, 'model__colsample_bytree': 0.7618806892653955}. Best is trial 6 with value: -6.368718595529192.
# [I 2024-02-19 23:03:28,096] Trial 19 finished with value: -8.77705705043236 and parameters: {'selector__k': 8, 'model__learning_rate': 0.19406195073004107, 'model__n_estimators': 419, 'model__max_depth': 9, 'model__num_leaves': 38, 'model__min_child_samples': 16, 'model__subsample': 0.5147039775115083, 'model__colsample_bytree': 0.9984042713037199}. Best is trial 6 with value: -6.368718595529192.
# [I 2024-02-19 23:03:28,279] Trial 20 finished with value: -6.804306303657915 and parameters: {'selector__k': 26, 'model__learning_rate': 0.6042164422273042, 'model__n_estimators': 50, 'model__max_depth': 43, 'model__num_leaves': 31, 'model__min_child_samples': 11, 'model__subsample': 0.7433436701179301, 'model__colsample_bytree': 0.5384763009279603}. Best is trial 6 with value: -6.368718595529192.
# [I 2024-02-19 23:03:28,464] Trial 21 finished with value: -6.564117534675115 and parameters: {'selector__k': 26, 'model__learning_rate': 0.6259702579701814, 'model__n_estimators': 54, 'model__max_depth': 43, 'model__num_leaves': 30, 'model__min_child_samples': 11, 'model__subsample': 0.7419771099796548, 'model__colsample_bytree': 0.544956513341299}. Best is trial 6 with value: -6.368718595529192.
# [I 2024-02-19 23:03:28,693] Trial 22 finished with value: -7.5540863635428614 and parameters: {'selector__k': 26, 'model__learning_rate': 0.6271300152344481, 'model__n_estimators': 64, 'model__max_depth': 43, 'model__num_leaves': 31, 'model__min_child_samples': 10, 'model__subsample': 0.7548675303312326, 'model__colsample_bytree': 0.5425839445885806}. Best is trial 6 with value: -6.368718595529192.
# [I 2024-02-19 23:03:28,932] Trial 23 finished with value: -8.773889149488594 and parameters: {'selector__k': 19, 'model__learning_rate': 0.8047731882725201, 'model__n_estimators': 87, 'model__max_depth': 50, 'model__num_leaves': 38, 'model__min_child_samples': 11, 'model__subsample': 0.9924985715232607, 'model__colsample_bytree': 0.5173716431799011}. Best is trial 6 with value: -6.368718595529192.
# [I 2024-02-19 23:03:29,112] Trial 24 finished with value: -7.445909534514642 and parameters: {'selector__k': 21, 'model__learning_rate': 0.8337774303373056, 'model__n_estimators': 60, 'model__max_depth': 45, 'model__num_leaves': 23, 'model__min_child_samples': 8, 'model__subsample': 0.6832623221781539, 'model__colsample_bytree': 0.37305423393088255}. Best is trial 6 with value: -6.368718595529192.
# [I 2024-02-19 23:03:29,311] Trial 25 finished with value: -7.696327969269225 and parameters: {'selector__k': 26, 'model__learning_rate': 0.6111156712609722, 'model__n_estimators': 91, 'model__max_depth': 22, 'model__num_leaves': 31, 'model__min_child_samples': 14, 'model__subsample': 0.8163585648513374, 'model__colsample_bytree': 0.4280473918256204}. Best is trial 6 with value: -6.368718595529192.
# [I 2024-02-19 23:03:29,483] Trial 26 finished with value: -7.292856682158129 and parameters: {'selector__k': 25, 'model__learning_rate': 0.697524232894685, 'model__n_estimators': 51, 'model__max_depth': 33, 'model__num_leaves': 36, 'model__min_child_samples': 10, 'model__subsample': 0.5447008845988812, 'model__colsample_bytree': 0.821278616690163}. Best is trial 6 with value: -6.368718595529192.
# [I 2024-02-19 23:03:29,662] Trial 27 finished with value: -7.556563628504929 and parameters: {'selector__k': 34, 'model__learning_rate': 0.48626238421890877, 'model__n_estimators': 68, 'model__max_depth': 42, 'model__num_leaves': 41, 'model__min_child_samples': 17, 'model__subsample': 0.6163144685705175, 'model__colsample_bytree': 0.6542094474538224}. Best is trial 6 with value: -6.368718595529192.
# [I 2024-02-19 23:03:29,843] Trial 28 finished with value: -8.037365877948043 and parameters: {'selector__k': 18, 'model__learning_rate': 0.5747743188081552, 'model__n_estimators': 59, 'model__max_depth': 13, 'model__num_leaves': 46, 'model__min_child_samples': 13, 'model__subsample': 0.7228721017735836, 'model__colsample_bytree': 0.5573752078907203}. Best is trial 6 with value: -6.368718595529192.
# [I 2024-02-19 23:03:30,029] Trial 29 finished with value: -8.461328683529977 and parameters: {'selector__k': 15, 'model__learning_rate': 0.36772468826204685, 'model__n_estimators': 130, 'model__max_depth': 24, 'model__num_leaves': 2, 'model__min_child_samples': 6, 'model__subsample': 0.843957076868737, 'model__colsample_bytree': 0.4667135685978041}. Best is trial 6 with value: -6.368718595529192.
# [I 2024-02-19 23:03:30,251] Trial 30 finished with value: -8.991405206520662 and parameters: {'selector__k': 29, 'model__learning_rate': 0.7881386695069207, 'model__n_estimators': 95, 'model__max_depth': 34, 'model__num_leaves': 23, 'model__min_child_samples': 9, 'model__subsample': 0.9230729272017926, 'model__colsample_bytree': 0.5139976996157689}. Best is trial 6 with value: -6.368718595529192.
# [I 2024-02-19 23:03:30,422] Trial 31 finished with value: -6.901549296984821 and parameters: {'selector__k': 31, 'model__learning_rate': 0.4613472071019574, 'model__n_estimators': 51, 'model__max_depth': 40, 'model__num_leaves': 29, 'model__min_child_samples': 12, 'model__subsample': 0.471358558065659, 'model__colsample_bytree': 0.6128027570735108}. Best is trial 6 with value: -6.368718595529192.
# [I 2024-02-19 23:03:30,594] Trial 32 finished with value: -6.262458851244446 and parameters: {'selector__k': 35, 'model__learning_rate': 0.33269135204491, 'model__n_estimators': 51, 'model__max_depth': 44, 'model__num_leaves': 25, 'model__min_child_samples': 11, 'model__subsample': 0.6009045478237118, 'model__colsample_bytree': 0.620781184538356}. Best is trial 32 with value: -6.262458851244446.
# [I 2024-02-19 23:03:30,800] Trial 33 finished with value: -6.617840338224056 and parameters: {'selector__k': 35, 'model__learning_rate': 0.29802012680117335, 'model__n_estimators': 79, 'model__max_depth': 50, 'model__num_leaves': 17, 'model__min_child_samples': 11, 'model__subsample': 0.5841795620252515, 'model__colsample_bytree': 0.7123838447076073}. Best is trial 32 with value: -6.262458851244446.
# [I 2024-02-19 23:03:30,988] Trial 34 finished with value: -6.95042337537539 and parameters: {'selector__k': 36, 'model__learning_rate': 0.3084456822893618, 'model__n_estimators': 70, 'model__max_depth': 50, 'model__num_leaves': 16, 'model__min_child_samples': 14, 'model__subsample': 0.5798629668527466, 'model__colsample_bytree': 0.767857272518894}. Best is trial 32 with value: -6.262458851244446.
# [I 2024-02-19 23:03:31,176] Trial 35 finished with value: -7.396013659041161 and parameters: {'selector__k': 38, 'model__learning_rate': 0.2976949683661591, 'model__n_estimators': 75, 'model__max_depth': 47, 'model__num_leaves': 9, 'model__min_child_samples': 8, 'model__subsample': 0.6769284844103988, 'model__colsample_bytree': 0.7232699206011446}. Best is trial 32 with value: -6.262458851244446.
# [I 2024-02-19 23:03:31,414] Trial 36 finished with value: -7.094535525169005 and parameters: {'selector__k': 34, 'model__learning_rate': 0.1489758337498595, 'model__n_estimators': 125, 'model__max_depth': 45, 'model__num_leaves': 19, 'model__min_child_samples': 9, 'model__subsample': 0.6149392641767667, 'model__colsample_bytree': 0.6842212715915078}. Best is trial 32 with value: -6.262458851244446.
# [I 2024-02-19 23:03:31,637] Trial 37 finished with value: -6.647757318367492 and parameters: {'selector__k': 35, 'model__learning_rate': 0.03138271437806217, 'model__n_estimators': 99, 'model__max_depth': 19, 'model__num_leaves': 17, 'model__min_child_samples': 11, 'model__subsample': 0.47951653343624273, 'model__colsample_bytree': 0.4118812574770432}. Best is trial 32 with value: -6.262458851244446.
# [I 2024-02-19 23:03:31,990] Trial 38 finished with value: -7.907953006770068 and parameters: {'selector__k': 21, 'model__learning_rate': 0.33458902193809303, 'model__n_estimators': 181, 'model__max_depth': 27, 'model__num_leaves': 21, 'model__min_child_samples': 5, 'model__subsample': 0.5426997432681023, 'model__colsample_bytree': 0.47363505475942214}. Best is trial 32 with value: -6.262458851244446.
# [I 2024-02-19 23:03:32,169] Trial 39 finished with value: -7.872750402915858 and parameters: {'selector__k': 11, 'model__learning_rate': 0.17688772316639445, 'model__n_estimators': 79, 'model__max_depth': 41, 'model__num_leaves': 13, 'model__min_child_samples': 15, 'model__subsample': 0.6567153001584438, 'model__colsample_bytree': 0.2892294463840023}. Best is trial 32 with value: -6.262458851244446.
# [I 2024-02-19 23:03:32,345] Trial 40 finished with value: -6.573238957954863 and parameters: {'selector__k': 29, 'model__learning_rate': 0.11548028627095583, 'model__n_estimators': 58, 'model__max_depth': 30, 'model__num_leaves': 25, 'model__min_child_samples': 13, 'model__subsample': 0.7010557172805254, 'model__colsample_bytree': 0.6475600154078288}. Best is trial 32 with value: -6.262458851244446.
# [I 2024-02-19 23:03:32,522] Trial 41 finished with value: -6.550932166855871 and parameters: {'selector__k': 29, 'model__learning_rate': 0.10567713070992715, 'model__n_estimators': 58, 'model__max_depth': 21, 'model__num_leaves': 25, 'model__min_child_samples': 13, 'model__subsample': 0.701029931755507, 'model__colsample_bytree': 0.6393359116615264}. Best is trial 32 with value: -6.262458851244446.
# [I 2024-02-19 23:03:32,702] Trial 42 finished with value: -6.533479084457506 and parameters: {'selector__k': 29, 'model__learning_rate': 0.10996397156917248, 'model__n_estimators': 58, 'model__max_depth': 21, 'model__num_leaves': 26, 'model__min_child_samples': 13, 'model__subsample': 0.7209914594399456, 'model__colsample_bytree': 0.6476940970744556}. Best is trial 32 with value: -6.262458851244446.
# [I 2024-02-19 23:03:32,876] Trial 43 finished with value: -7.899387275024749 and parameters: {'selector__k': 30, 'model__learning_rate': 0.013517928420791192, 'model__n_estimators': 56, 'model__max_depth': 20, 'model__num_leaves': 26, 'model__min_child_samples': 18, 'model__subsample': 0.8048602942751655, 'model__colsample_bytree': 0.576236659538371}. Best is trial 32 with value: -6.262458851244446.
# [I 2024-02-19 23:03:33,059] Trial 44 finished with value: -6.490167780651247 and parameters: {'selector__k': 23, 'model__learning_rate': 0.07535361951011471, 'model__n_estimators': 64, 'model__max_depth': 15, 'model__num_leaves': 33, 'model__min_child_samples': 15, 'model__subsample': 0.6365515049649069, 'model__colsample_bytree': 0.6365211560056363}. Best is trial 32 with value: -6.262458851244446.
# [I 2024-02-19 23:03
 'model__kernel': DotProduct(sigma_0=1) + WhiteKernel(noise_level=1), 'model__alpha': 969902097.2962165}. Best is trial 39 with value: -10.381851024539543.
# [I 2024-02-19 23:05:51,195] Trial 41 finished with value: -16.61754523327422 and parameters: {'selector__k': 36, 'model__kernel': DotProduct(sigma_0=1) + WhiteKernel(noise_level=1), 'model__alpha': 252323758.7585927}. Best is trial 39 with value: -10.381851024539543.
# [I 2024-02-19 23:05:51,311] Trial 42 finished with value: -10.378278605415332 and parameters: {'selector__k': 34, 'model__kernel': DotProduct(sigma_0=1) + WhiteKernel(noise_level=1), 'model__alpha': 490214.1645124331}. Best is trial 42 with value: -10.378278605415332.
# [I 2024-02-19 23:05:51,423] Trial 43 finished with value: -20.34180871583628 and parameters: {'selector__k': 34, 'model__kernel': DotProduct(sigma_0=1) + WhiteKernel(noise_level=1), 'model__alpha': 708856386.4289067}. Best is trial 42 with value: -10.378278605415332.
# [I 2024-02-19 23:05:51,547] Trial 44 finished with value: -23.77385267742385 and parameters: {'selector__k': 32, 'model__kernel': 0.1**2 * RBF(length_scale=0.1) + WhiteKernel(noise_level=0.01), 'model__alpha': 1055845691.5217259}. Best is trial 42 with value: -10.378278605415332.
# [I 2024-02-19 23:05:51,658] Trial 45 finished with value: -23.773849850847892 and parameters: {'selector__k': 36, 'model__kernel': RBF(length_scale=1) + 1.41**2, 'model__alpha': 2254268705.9485188}. Best is trial 42 with value: -10.378278605415332.
# [I 2024-02-19 23:05:51,773] Trial 46 finished with value: -23.148001000605802 and parameters: {'selector__k': 31, 'model__kernel': DotProduct(sigma_0=1) + WhiteKernel(noise_level=1), 'model__alpha': 579349680.3302568}. Best is trial 42 with value: -10.378278605415332.
# [I 2024-02-19 23:05:51,890] Trial 47 finished with value: -21.068200118728615 and parameters: {'selector__k': 34, 'model__kernel': DotProduct(sigma_0=1) + WhiteKernel(noise_level=1), 'model__alpha': 944804515.8102262}. Best is trial 42 with value: -10.378278605415332.
# [I 2024-02-19 23:05:52,019] Trial 48 finished with value: -23.773852677405152 and parameters: {'selector__k': 37, 'model__kernel': 0.5**2 * RationalQuadratic(alpha=1, length_scale=1), 'model__alpha': 2256293462.569373}. Best is trial 42 with value: -10.378278605415332.
# [I 2024-02-19 23:05:52,146] Trial 49 finished with value: -23.773852661800305 and parameters: {'selector__k': 30, 'model__kernel': 1**2 * Matern(length_scale=1, nu=1.5), 'model__alpha': 30210586.170738455}. Best is trial 42 with value: -10.378278605415332.
# GPR -10.378278605415332 23.44617728399548 1020.2816805083735 261.5632994635494

# %%
X_t_onlyreg = temp.drop(columns=['remainder__dataset', 'remainder__link_counts', 'used_link'])
y_t_onlyreg = temp['remainder__link_counts']

X_te_onlyreg = test_data_tr.drop(columns=['remainder__dataset', 'remainder__link_counts', 'used_link'])
y_te_onlyreg = test_data_tr['remainder__link_counts']

train_index_onlyreg = list(train_data_tr.index)
validate_index_onlyreg = list(validate_data_tr.index)

# %%
best_model_onlyreg = {}
for model_name in model_space.keys():   
    model = model_space[model_name]
    pipeline  = Pipeline([('selector', SelectKBest(f_regression)),
                  ('model', model)])
    param_grid = {}
    param_grid['selector__k']=optuna.distributions.IntDistribution(10, 47)
    for key in param_space[model_name].keys():
        param_grid[f'model__{key}']=param_space[model_name][key]
    
    # BayesSearchCV
    opt = OptunaSearchCV(
        pipeline,
        param_grid,
        n_trials=50,
        cv=[(train_index_onlyreg, validate_index_onlyreg), (train_index_onlyreg, validate_index_onlyreg)],
        scoring='neg_mean_absolute_error'
    )
    opt.fit(X_t_onlyreg, y_t_onlyreg)
    y_pred = opt.predict(X_te_onlyreg)
    mae = mean_absolute_error(y_te_onlyreg, y_pred)
    mse = mean_squared_error(y_te_onlyreg, y_pred)
    me = max_error(y_te_onlyreg, y_pred)
    best_model_onlyreg[model_name] = [opt, mae, mse, me]
    print(model_name, opt.best_score_, mae, mse, me)
# Out:
# [I 2024-02-19 22:47:52,595] A new study created in memory with name: no-name-bc21603c-36d8-431d-a004-5ab808fd08d3
# [I 2024-02-19 22:47:52,650] Trial 0 finished with value: -10.196618287319273 and parameters: {'selector__k': 31, 'model__n_neighbors': 31, 'model__weights': 'uniform', 'model__algorithm': 'kd_tree'}. Best is trial 0 with value: -10.196618287319273.
# [I 2024-02-19 22:47:52,701] Trial 1 finished with value: -8.710193394272641 and parameters: {'selector__k': 16, 'model__n_neighbors': 38, 'model__weights': 'distance', 'model__algorithm': 'ball_tree'}. Best is trial 1 with value: -8.710193394272641.
# [I 2024-02-19 22:47:52,932] Trial 2 finished with value: -10.232515406011876 and parameters: {'selector__k': 31, 'model__n_neighbors': 37, 'model__weights': 'distance', 'model__algorithm': 'brute'}. Best is trial 1 with value: -8.710193394272641.
# [I 2024-02-19 22:47
 'model__weights': 'uniform', 'model__algorithm': 'kd_tree'}. Best is trial 46 with value: -7.458754842951573.
# [I 2024-02-19 22:47:57,534] Trial 49 finished with value: -7.567186361422469 and parameters: {'selector__k': 11, 'model__n_neighbors': 7, 'model__weights': 'uniform', 'model__algorithm': 'kd_tree'}. Best is trial 46 with value: -7.458754842951573.
# [I 2024-02-19 22:47:57,665] A new study created in memory with name: no-name-587b98aa-71d1-43f3-af7f-d8692bcc8247
# [I 2024-02-19 22:47:57,830] Trial 0 finished with value: -8.1035950162964 and parameters: {'selector__k': 28, 'model__learning_rate': 0.5525519560161942, 'model__n_estimators': 107, 'model__max_depth': 9, 'model__max_leaves': 7, 'model__max_bin': 36, 'model__gamma': 10}. Best is trial 0 with value: -8.1035950162964.
# KNN -7.458754842951573 16.33727220455779 561.6086024811608 232.63639885247028
# [I 2024-02-19 22:47:58,050] Trial 1 finished with value: -10.104763475477526 and parameters: {'selector__k': 39, 'model__learning_rate': 0.9151583572549509, 'model__n_estimators': 166, 'model__max_depth': 17, 'model__max_leaves': 12, 'model__max_bin': 50, 'model__gamma': 5}. Best is trial 0 with value: -8.1035950162964.
# [I 2024-02-19 22:47:58,255] Trial 2 finished with value: -9.737943849710172 and parameters: {'selector__k': 15, 'model__learning_rate': 0.6693437514482586, 'model__n_estimators': 145, 'model__max_depth': 10, 'model__max_leaves': 27, 'model__max_bin': 19, 'model__gamma': 4}. Best is trial 0 with value: -8.1035950162964.
# [I 2024-02-19 22:47:58,449] Trial 3 finished with value: -10.049789781489592 and parameters: {'selector__k': 38, 'model__learning_rate': 0.8994984595268515, 'model__n_estimators': 141, 'model__max_depth': 16, 'model__max_leaves': 48, 'model__max_bin': 27, 'model__gamma': 18}. Best is trial 0 with value: -8.1035950162964.
# [I 2024-02-19 22:47:58,775] Trial 4 finished with value: -7.964754360148212 and parameters: {'selector__k': 18, 'model__learning_rate': 0.07736559731876336, 'model__n_estimators': 191, 'model__max_depth': 9, 'model__max_leaves': 43, 'model__max_bin': 49, 'model__gamma': 15}. Best is trial 4 with value: -7.964754360148212.
# [I 2024-02-19 22:47:58,918] Trial 5 finished with value: -8.50027290925875 and parameters: {'selector__k': 17, 'model__learning_rate': 0.5309073834091886, 'model__n_estimators': 97, 'model__max_depth': 12, 'model__max_leaves': 21, 'model__max_bin': 16, 'model__gamma': 12}. Best is trial 4 with value: -7.964754360148212.
# [I 2024-02-19 22:47:59,134] Trial 6 finished with value: -8.423949693160024 and parameters: {'selector__k': 42, 'model__learning_rate': 0.39297503633485376, 'model__n_estimators': 147, 'model__max_depth': 6, 'model__max_leaves': 43, 'model__max_bin': 24, 'model__gamma': 2}. Best is trial 4 with value: -7.964754360148212.
# [I 2024-02-19 22:47:59,284] Trial 7 finished with value: -9.053504011255454 and parameters: {'selector__k': 17, 'model__learning_rate': 0.7462141158296984, 'model__n_estimators': 86, 'model__max_depth': 9, 'model__max_leaves': 29, 'model__max_bin': 16, 'model__gamma': 12}. Best is trial 4 with value: -7.964754360148212.
# [I 2024-02-19 22:47:59,815] Trial 8 finished with value: -8.657426770672831 and parameters: {'selector__k': 39, 'model__learning_rate': 0.07088211813143917, 'model__n_estimators': 340, 'model__max_depth': 7, 'model__max_leaves': 12, 'model__max_bin': 19, 'model__gamma': 5}. Best is trial 4 with value: -7.964754360148212.
# [I 2024-02-19 22:48:00,091] Trial 9 finished with value: -8.416354572385098 and parameters: {'selector__k': 16, 'model__learning_rate': 0.6490317319273232, 'model__n_estimators': 249, 'model__max_depth': 4, 'model__max_leaves': 8, 'model__max_bin': 39, 'model__gamma': 19}. Best is trial 4 with value: -7.964754360148212.
# [I 2024-02-19 22:48:00,438] Trial 10 finished with value: -7.177507264281254 and parameters: {'selector__k': 26, 'model__learning_rate': 0.05484319903700399, 'model__n_estimators': 56, 'model__max_depth': 14, 'model__max_leaves': 38, 'model__max_bin': 6, 'model__gamma': 16}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:00,739] Trial 11 finished with value: -8.241337307618252 and parameters: {'selector__k': 27, 'model__learning_rate': 0.0544234008356011, 'model__n_estimators': 51, 'model__max_depth': 14, 'model__max_leaves': 39, 'model__max_bin': 3, 'model__gamma': 16}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:00,954] Trial 12 finished with value: -8.213999623668483 and parameters: {'selector__k': 23, 'model__learning_rate': 0.2811898814315794, 'model__n_estimators': 53, 'model__max_depth': 19, 'model__max_leaves': 36, 'model__max_bin': 6, 'model__gamma': 15}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:01,303] Trial 13 finished with value: -7.590183983434131 and parameters: {'selector__k': 23, 'model__learning_rate': 0.17592318340151905, 'model__n_estimators': 234, 'model__max_depth': 1, 'model__max_leaves': 50, 'model__max_bin': 48, 'model__gamma': 9}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:01,798] Trial 14 finished with value: -8.401631215234916 and parameters: {'selector__k': 10, 'model__learning_rate': 0.2422451626122215, 'model__n_estimators': 444, 'model__max_depth': 3, 'model__max_leaves': 50, 'model__max_bin': 38, 'model__gamma': 9}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:02,169] Trial 15 finished with value: -8.157358756213563 and parameters: {'selector__k': 33, 'model__learning_rate': 0.1923260598319889, 'model__n_estimators': 252, 'model__max_depth': 1, 'model__max_leaves': 34, 'model__max_bin': 9, 'model__gamma': 8}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:02,529] Trial 16 finished with value: -8.753614303800175 and parameters: {'selector__k': 23, 'model__learning_rate': 0.3765838550963262, 'model__n_estimators': 255, 'model__max_depth': 13, 'model__max_leaves': 43, 'model__max_bin': 34, 'model__gamma': 13}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:02,772] Trial 17 finished with value: -8.502087915160956 and parameters: {'selector__k': 33, 'model__learning_rate': 0.16644596761323574, 'model__n_estimators': 73, 'model__max_depth': 20, 'model__max_leaves': 21, 'model__max_bin': 29, 'model__gamma': 7}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:03,905] Trial 18 finished with value: -7.755932331657719 and parameters: {'selector__k': 24, 'model__learning_rate': 0.013688768633230264, 'model__n_estimators': 495, 'model__max_depth': 16, 'model__max_leaves': 33, 'model__max_bin': 44, 'model__gamma': 20}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:04,099] Trial 19 finished with value: -7.665679696406508 and parameters: {'selector__k': 32, 'model__learning_rate': 0.34779306239807484, 'model__n_estimators': 67, 'model__max_depth': 1, 'model__max_leaves': 48, 'model__max_bin': 43, 'model__gamma': 17}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:04,427] Trial 20 finished with value: -7.856653660938015 and parameters: {'selector__k': 47, 'model__learning_rate': 0.15549299559025337, 'model__n_estimators': 206, 'model__max_depth': 6, 'model__max_leaves': 41, 'model__max_bin': 11, 'model__gamma': 13}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:04,622] Trial 21 finished with value: -8.227496401236927 and parameters: {'selector__k': 32, 'model__learning_rate': 0.35541456450792064, 'model__n_estimators': 65, 'model__max_depth': 2, 'model__max_leaves': 47, 'model__max_bin': 44, 'model__gamma': 17}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:04,827] Trial 22 finished with value: -7.806485345559859 and parameters: {'selector__k': 30, 'model__learning_rate': 0.2944817984487573, 'model__n_estimators': 64, 'model__max_depth': 4, 'model__max_leaves': 47, 'model__max_bin': 44, 'model__gamma': 14}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:05,066] Trial 23 finished with value: -8.337367366404683 and parameters: {'selector__k': 21, 'model__learning_rate': 0.44320898198478526, 'model__n_estimators': 119, 'model__max_depth': 2, 'model__max_leaves': 50, 'model__max_bin': 32, 'model__gamma': 11}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:05,277] Trial 24 finished with value: -7.650041009537702 and parameters: {'selector__k': 26, 'model__learning_rate': 0.12781607233851922, 'model__n_estimators': 85, 'model__max_depth': 1, 'model__max_leaves': 40, 'model__max_bin': 42, 'model__gamma': 17}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:05,544] Trial 25 finished with value: -7.54692204587776 and parameters: {'selector__k': 25, 'model__learning_rate': 0.12874437218784623, 'model__n_estimators': 82, 'model__max_depth': 12, 'model__max_leaves': 38, 'model__max_bin': 47, 'model__gamma': 19}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:05,981] Trial 26 finished with value: -7.570223814747694 and parameters: {'selector__k': 20, 'model__learning_rate': 0.2359300473127047, 'model__n_estimators': 328, 'model__max_depth': 12, 'model__max_leaves': 24, 'model__max_bin': 49, 'model__gamma': 19}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:06,449] Trial 27 finished with value: -8.73389229578872 and parameters: {'selector__k': 10, 'model__learning_rate': 0.23480947989666237, 'model__n_estimators': 348, 'model__max_depth': 12, 'model__max_leaves': 22, 'model__max_bin': 47, 'model__gamma': 20}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:06,825] Trial 28 finished with value: -8.501314571733428 and parameters: {'selector__k': 20, 'model__learning_rate': 0.011362809804022489, 'model__n_estimators': 55, 'model__max_depth': 14, 'model__max_leaves': 30, 'model__max_bin': 23, 'model__gamma': 18}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:07,065] Trial 29 finished with value: -9.25975794617219 and parameters: {'selector__k': 13, 'model__learning_rate': 0.470653492452988, 'model__n_estimators': 115, 'model__max_depth': 11, 'model__max_leaves': 24, 'model__max_bin': 39, 'model__gamma': 19}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:07,354] Trial 30 finished with value: -7.719366921159482 and parameters: {'selector__k': 28, 'model__learning_rate': 0.11048919642638326, 'model__n_estimators': 79, 'model__max_depth': 15, 'model__max_leaves': 17, 'model__max_bin': 32, 'model__gamma': 20}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:07,776] Trial 31 finished with value: -7.622685786294947 and parameters: {'selector__k': 25, 'model__learning_rate': 0.20399431737738122, 'model__n_estimators': 336, 'model__max_depth': 11, 'model__max_leaves': 32, 'model__max_bin': 47, 'model__gamma': 10}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:08,132] Trial 32 finished with value: -7.586275060458941 and parameters: {'selector__k': 21, 'model__learning_rate': 0.27653269012354703, 'model__n_estimators': 281, 'model__max_depth': 18, 'model__max_leaves': 2, 'model__max_bin': 50, 'model__gamma': 16}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:08,584] Trial 33 finished with value: -8.637327574308555 and parameters: {'selector__k': 20, 'model__learning_rate': 0.31268996985528563, 'model__n_estimators': 403, 'model__max_depth': 18, 'model__max_leaves': 3, 'model__max_bin': 50, 'model__gamma': 16}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:09,001] Trial 34 finished with value: -7.713972895605483 and parameters: {'selector__k': 30, 'model__learning_rate': 0.2589643378263132, 'model__n_estimators': 307, 'model__max_depth': 17, 'model__max_leaves': 16, 'model__max_bin': 46, 'model__gamma': 18}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:09,304] Trial 35 finished with value: -8.550319870167794 and parameters: {'selector__k': 21, 'model__learning_rate': 0.5890993786340526, 'model__n_estimators': 187, 'model__max_depth': 13, 'model__max_leaves': 37, 'model__max_bin': 50, 'model__gamma': 15}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:09,750] Trial 36 finished with value: -7.6513519454490995 and parameters: {'selector__k': 19, 'model__learning_rate': 0.11948397498168017, 'model__n_estimators': 297, 'model__max_depth': 15, 'model__max_leaves': 26, 'model__max_bin': 42, 'model__gamma': 19}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:10,087] Trial 37 finished with value: -9.10810201709373 and parameters: {'selector__k': 14, 'model__learning_rate': 0.07056155675465436, 'model__n_estimators': 166, 'model__max_depth': 10, 'model__max_leaves': 3, 'model__max_bin': 36, 'model__gamma': 16}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:10,323] Trial 38 finished with value: -8.610975123267776 and parameters: {'selector__k': 29, 'model__learning_rate': 0.9831378386021288, 'model__n_estimators': 100, 'model__max_depth': 8, 'model__max_leaves': 7, 'model__max_bin': 40, 'model__gamma': 18}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:10,687] Trial 39 finished with value: -10.04366851959469 and parameters: {'selector__k': 26, 'model__learning_rate': 0.7990054984085051, 'model__n_estimators': 290, 'model__max_depth': 17, 'model__max_leaves': 17, 'model__max_bin': 15, 'model__gamma': 14}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:11,138] Trial 40 finished with value: -8.764697780570721 and parameters: {'selector__k': 36, 'model__learning_rate': 0.42107213662651166, 'model__n_estimators': 386, 'model__max_depth': 12, 'model__max_leaves': 14, 'model__max_bin': 2, 'model__gamma': 19}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:11,554] Trial 41 finished with value: -7.7741623868561325 and parameters: {'selector__k': 22, 'model__learning_rate': 0.14707534887112297, 'model__n_estimators': 227, 'model__max_depth': 13, 'model__max_leaves': 45, 'model__max_bin': 48, 'model__gamma': 5}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:11,877] Trial 42 finished with value: -7.634161171224852 and parameters: {'selector__k': 24, 'model__learning_rate': 0.20399686483299923, 'model__n_estimators': 131, 'model__max_depth': 10, 'model__max_leaves': 29, 'model__max_bin': 47, 'model__gamma': 7}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:12,417] Trial 43 finished with value: -8.445951667191766 and parameters: {'selector__k': 19, 'model__learning_rate': 0.07692498820288005, 'model__n_estimators': 218, 'model__max_depth': 8, 'model__max_leaves': 27, 'model__max_bin': 50, 'model__gamma': 1}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:12,723] Trial 44 finished with value: -8.711100115120066 and parameters: {'selector__k': 17, 'model__learning_rate': 0.319624814006703, 'model__n_estimators': 168, 'model__max_depth': 20, 'model__max_leaves': 38, 'model__max_bin': 46, 'model__gamma': 11}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:12,972] Trial 45 finished with value: -8.943253486211445 and parameters: {'selector__k': 27, 'model__learning_rate': 0.21995660906355025, 'model__n_estimators': 59, 'model__max_depth': 15, 'model__max_leaves': 35, 'model__max_bin': 23, 'model__gamma': 9}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:13,352] Trial 46 finished with value: -8.218518318029071 and parameters: {'selector__k': 22, 'model__learning_rate': 0.17213043764287334, 'model__n_estimators': 267, 'model__max_depth': 14, 'model__max_leaves': 11, 'model__max_bin': 20, 'model__gamma': 17}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:13,730] Trial 47 finished with value: -8.058765434792612 and parameters: {'selector__k': 25, 'model__learning_rate': 0.10174706665377165, 'model__n_estimators': 187, 'model__max_depth': 16, 'model__max_leaves': 41, 'model__max_bin': 36, 'model__gamma': 12}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:14,131] Trial 48 finished with value: -7.6903558837086035 and parameters: {'selector__k': 15, 'model__learning_rate': 0.04491261690741247, 'model__n_estimators': 94, 'model__max_depth': 18, 'model__max_leaves': 44, 'model__max_bin': 45, 'model__gamma': 14}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:14,490] Trial 49 finished with value: -9.07120305634631 and parameters: {'selector__k': 18, 'model__learning_rate': 0.2676764929543919, 'model__n_estimators': 230, 'model__max_depth': 12, 'model__max_leaves': 30, 'model__max_bin': 40, 'model__gamma': 7}. Best is trial 10 with value: -7.177507264281254.
# [I 2024-02-19 22:48:14,627] A new study created in memory with name: no-name-310cefc3-fe55-4018-b88d-af3283f2e497
# XGB -7.177507264281254 17.972539647479977 698.7876389934627 232.96246065412248
# [I 2024-02-19 22:48:15,369] Trial 0 finished with value: -7.608731344191054 and parameters: {'selector__k': 39, 'model__learning_rate': 0.056726970375503026, 'model__n_estimators': 316, 'model__max_depth': 13, 'model__num_leaves': 36, 'model__min_child_samples': 3, 'model__subsample': 0.6865966751325083, 'model__colsample_bytree': 0.3429731861709645}. Best is trial 0 with value: -7.608731344191054.
# [I 2024-02-19 22:48:15,549] Trial 1 finished with value: -8.54036006580447 and parameters: {'selector__k': 39, 'model__learning_rate': 0.49721267204835173, 'model__n_estimators': 143, 'model__max_depth': 19, 'model__num_leaves': 9, 'model__min_child_samples': 6, 'model__subsample': 0.9494880276607008, 'model__colsample_bytree': 0.3462542884574966}. Best is trial 0 with value: -7.608731344191054.
# [I 2024-02-19 22:48:15,641] Trial 2 finished with value: -6.935681133917628 and parameters: {'selector__k': 47, 'model__learning_rate': 0.12796012944022955, 'model__n_estimators': 65, 'model__max_depth': 30, 'model__num_leaves': 6, 'model__min_child_samples': 18, 'model__subsample': 0.10537954668328262, 'model__colsample_bytree': 0.7249848357999492}. Best is trial 2 with value: -6.935681133917628.
# [I 2024-02-19 22:48:15,753] Trial 3 finished with value: -7.795339227783864 and parameters: {'selector__k': 43, 'model__learning_rate': 0.418491340683673, 'model__n_estimators': 83, 'model__max_depth': 26, 'model__num_leaves': 7, 'model__min_child_samples': 19, 'model__subsample': 0.3794794137206777, 'model__colsample_bytree': 0.6225328351469906}. Best is trial 2 with value: -6.935681133917628.
# [I 2024-02-19 22:48:15,860] Trial 4 finished with value: -9.188805886201608 and parameters: {'selector__k': 38, 'model__learning_rate': 0.8098461517768745, 'model__n_estimators': 111, 'model__max_depth': 42, 'model__num_leaves': 3, 'model__min_child_samples': 2, 'model__subsample': 0.31118342449952185, 'model__colsample_bytree': 0.23496963235683943}. Best is trial 2 with value: -6.935681133917628.
# [I 2024-02-19 22:48:15,975] Trial 5 finished with value: -6.5316697777132315 and parameters: {'selector__k': 38, 'model__learning_rate': 0.034581812199458425, 'model__n_estimators': 112, 'model__max_depth': 32, 'model__num_leaves': 45, 'model__min_child_samples': 18, 'model__subsample': 0.20937863079178035, 'model__colsample_bytree': 0.6551410145566391}. Best is trial 5 with value: -6.5316697777132315.
# [I 2024-02-19 22:48:16,101] Trial 6 finished with value: -8.168223369891727 and parameters: {'selector__k': 45, 'model__learning_rate': 0.775004052004957, 'model__n_estimators': 107, 'model__max_depth': 41, 'model__num_leaves': 27, 'model__min_child_samples': 14, 'model__subsample': 0.9487459295392069, 'model__colsample_bytree': 0.8140926634789623}. Best is trial 5 with value: -6.5316697777132315.
# [I 2024-02-19 22:48:16,217] Trial 7 finished with value: -7.537281770284841 and parameters: {'selector__k': 22, 'model__learning_rate': 0.4460887647191104, 'model__n_estimators': 87, 'model__max_depth': 39, 'model__num_leaves': 33, 'model__min_child_samples': 11, 'model__subsample': 0.7435946697687235, 'model__colsample_bytree': 0.42072103091601465}. Best is trial 5 with value: -6.5316697777132315.
# [I 2024-02-19 22:48:16,537] Trial 8 finished with value: -6.830715846461158 and parameters: {'selector__k': 34, 'model__learning_rate': 0.05822551808825149, 'model__n_estimators': 335, 'model__max_depth': 27, 'model__num_leaves': 31, 'model__min_child_samples': 9, 'model__subsample': 0.275733268166994, 'model__colsample_bytree': 0.5477386078690077}. Best is trial 5 with value: -6.5316697777132315.
# [I 2024-02-19 22:48:16,716] Trial 9 finished with value: -8.868358378916374 and parameters: {'selector__k': 14, 'model__learning_rate': 0.3756211412870465, 'model__n_estimators': 259, 'model__max_depth': 16, 'model__num_leaves': 14, 'model__min_child_samples': 15, 'model__subsample': 0.5591873226303392, 'model__colsample_bytree': 0.809592541856951}. Best is trial 5 with value: -6.5316697777132315.
# [I 2024-02-19 22:48:16,947] Trial 10 finished with value: -7.773346026764237 and parameters: {'selector__k': 24, 'model__learning_rate': 0.2553637744456769, 'model__n_estimators': 207, 'model__max_depth': 4, 'model__num_leaves': 50, 'model__min_child_samples': 20, 'model__subsample': 0.14233687793121735, 'model__colsample_bytree': 0.9726029643847678}. Best is trial 5 with value: -6.5316697777132315.
# [I 2024-02-19 22:48:17,508] Trial 11 finished with value: -6.497126730910424 and parameters: {'selector__k': 30, 'model__learning_rate': 0.011940235224172459, 'model__n_estimators': 477, 'model__max_depth': 29, 'model__num_leaves': 47, 'model__min_child_samples': 8, 'model__subsample': 0.321356737575551, 'model__colsample_bytree': 0.5187859295145619}. Best is trial 11 with value: -6.497126730910424.
# [I 2024-02-19 22:48:17,675] Trial 12 finished with value: -6.705004250228679 and parameters: {'selector__k': 29, 'model__learning_rate': 0.211755432234687, 'model__n_estimators': 50, 'model__max_depth': 34, 'model__num_leaves': 50, 'model__min_child_samples': 10, 'model__subsample': 0.44004118244626245, 'model__colsample_bytree': 0.5313262314627268}. Best is trial 11 with value: -6.497126730910424.
# [I 2024-02-19 22:48:18,389] Trial 13 finished with value: -7.040504108034679 and parameters: {'selector__k': 31, 'model__learning_rate': 0.015643382833935984, 'model__n_estimators': 477, 'model__max_depth': 49, 'model__num_leaves': 42, 'model__min_child_samples': 6, 'model__subsample': 0.24099603168122302, 'model__colsample_bytree': 0.13309340441359602}. Best is trial 11 with value: -6.497126730910424.
# [I 2024-02-19 22:48:18,623] Trial 14 finished with value: -8.47020852141415 and parameters: {'selector__k': 23, 'model__learning_rate': 0.6010956070919639, 'model__n_estimators': 180, 'model__max_depth': 20, 'model__num_leaves': 41, 'model__min_child_samples': 13, 'model__subsample': 0.512717092756392, 'model__colsample_bytree': 0.6412149222828314}. Best is trial 11 with value: -6.497126730910424.
# [I 2024-02-19 22:48:19,177] Trial 15 finished with value: -10.48985020830309 and parameters: {'selector__k': 34, 'model__learning_rate': 0.9589697885309142, 'model__n_estimators': 464, 'model__max_depth': 35, 'model__num_leaves': 20, 'model__min_child_samples': 7, 'model__subsample': 0.1988681942114352, 'model__colsample_bytree': 0.45644602345515245}. Best is trial 11 with value: -6.497126730910424.
# [I 2024-02-19 22:48:19,462] Trial 16 finished with value: -7.4454223748805815 and parameters: {'selector__k': 19, 'model__learning_rate': 0.19819416241969934, 'model__n_estimators': 132, 'model__max_depth': 50, 'model__num_leaves': 43, 'model__min_child_samples': 16, 'model__subsample': 0.38134596075158084, 'model__colsample_bytree': 0.6852424217541065}. Best is trial 11 with value: -6.497126730910424.
# [I 2024-02-19 22:48:19,817] Trial 17 finished with value: -9.121970372906366 and parameters: {'selector__k': 10, 'model__learning_rate': 0.3282326793876703, 'model__n_estimators': 207, 'model__max_depth': 7, 'model__num_leaves': 46, 'model__min_child_samples': 12, 'model__subsample': 0.5841171995567719, 'model__colsample_bytree': 0.9037845828017401}. Best is trial 11 with value: -6.497126730910424.
# [I 2024-02-19 22:48:20,261] Trial 18 finished with value: -7.784297977052784 and parameters: {'selector__k': 33, 'model__learning_rate': 0.6015037456920452, 'model__n_estimators': 368, 'model__max_depth': 23, 'model__num_leaves': 36, 'model__min_child_samples': 8, 'model__subsample': 0.3355479009454013, 'model__colsample_bytree': 0.7865903975605515}. Best is trial 11 with value: -6.497126730910424.
# [I 2024-02-19 22:48:20,518] Trial 19 finished with value: -8.060705215175105 and parameters: {'selector__k': 26, 'model__learning_rate': 0.25579758664119645, 'model__n_estimators': 250, 'model__max_depth': 32, 'model__num_leaves': 21, 'model__min_child_samples': 17, 'model__subsample': 0.20347105630812942, 'model__colsample_bytree': 0.4502922231565248}. Best is trial 11 with value: -6.497126730910424.
# [I 2024-02-19 22:48:21,115] Trial 20 finished with value: -7.128562238120467 and parameters: {'selector__k': 37, 'model__learning_rate': 0.12071439124384456, 'model__n_estimators': 162, 'model__max_depth': 44, 'model__num_leaves': 38, 'model__min_child_samples': 5, 'model__subsample': 0.45909394395899783, 'model__colsample_bytree': 0.5955854621516169}. Best is trial 11 with value: -6.497126730910424.
# [I 2024-02-19 22:48:21,300] Trial 21 finished with value: -6.71694127622912 and parameters: {'selector__k': 29, 'model__learning_rate': 0.16094979485603822, 'model__n_estimators': 54, 'model__max_depth': 34, 'model__num_leaves': 49, 'model__min_child_samples': 9, 'model__subsample': 0.423476174269095, 'model__colsample_bytree': 0.5495068827043251}. Best is trial 11 with value: -6.497126730910424.
# [I 2024-02-19 22:48:21,481] Trial 22 finished with value: -7.130100310690748 and parameters: {'selector__k': 27, 'model__learning_rate': 0.03311917767246709, 'model__n_estimators': 50, 'model__max_depth': 30, 'model__num_leaves': 47, 'model__min_child_samples': 10, 'model__subsample': 0.46092675717299103, 'model__colsample_bytree': 0.5473350519187918}. Best is trial 11 with value: -6.497126730910424.
# [I 2024-02-19 22:48:21,659] Trial 23 finished with value: -6.9098668621739145 and parameters: {'selector__k': 30, 'model__learning_rate': 0.2624490539835209, 'model__n_estimators': 67, 'model__max_depth': 36, 'model__num_leaves': 45, 'model__min_child_samples': 11, 'model__subsample': 0.30145466823467265, 'model__colsample_bytree': 0.4855757785931206}. Best is trial 11 with value: -6.497126730910424.
# [I 2024-02-19 22:48:21,938] Trial 24 finished with value: -7.051921663170633 and parameters: {'selector__k': 42, 'model__learning_rate': 0.10349731561280542, 'model__n_estimators': 81, 'model__max_depth': 25, 'model__num_leaves': 50, 'model__min_child_samples': 4, 'model__subsample': 0.6580699164263075, 'model__colsample_bytree': 0.35992727597795543}. Best is trial 11 with value: -6.497126730910424.
# [I 2024-02-19 22:48:22,348] Trial 25 finished with value: -8.527964387866856 and parameters: {'selector__k': 19, 'model__learning_rate': 0.17987650646355424, 'model__n_estimators': 113, 'model__max_depth': 38, 'model__num_leaves': 40, 'model__min_child_samples': 1, 'model__subsample': 0.1814405945965647, 'model__colsample_bytree': 0.7232494160492561}. Best is trial 11 with value: -6.497126730910424.
# [I 2024-02-19 22:48:22,525] Trial 26 finished with value: -7.3433716437995535 and parameters: {'selector__k': 36, 'model__learning_rate': 0.3289665970833441, 'model__n_estimators': 66, 'model__max_depth': 29, 'model__num_leaves': 44, 'model__min_child_samples': 13, 'model__subsample': 0.3629152658181665, 'model__colsample_bytree': 0.25983083744871677}. Best is trial 11 with value: -6.497126730910424.
# [I 2024-02-19 22:48:22,740] Trial 27 finished with value: -6.829304589485865 and parameters: {'selector__k': 27, 'model__learning_rate': 0.1948949036208403, 'model__n_estimators': 95, 'model__max_depth': 46, 'model__num_leaves': 31, 'model__min_child_samples': 8, 'model__subsample': 0.8080345044522671, 'model__colsample_bytree': 0.4873572149688439}. Best is trial 11 with value: -6.497126730910424.
# [I 2024-02-19 22:48:22,984] Trial 28 finished with value: -7.143631701973514 and parameters: {'selector__k': 31, 'model__learning_rate': 0.015463826172357791, 'model__n_estimators': 125, 'model__max_depth': 22, 'model__num_leaves': 46, 'model__min_child_samples': 10, 'model__subsample': 0.48462012976668967, 'model__colsample_bytree': 0.6874115316789584}. Best is trial 11 with value: -6.497126730910424.
# [I 2024-02-19 22:48:23,324] Trial 29 finished with value: -6.892169719220277 and parameters: {'selector__k': 42, 'model__learning_rate': 0.08538026961016557, 'model__n_estimators': 388, 'model__max_depth': 13, 'model__num_leaves': 36, 'model__min_child_samples': 15, 'model__subsample': 0.6144780382568489, 'model__colsample_bytree': 0.2827284870217006}. Best is trial 11 with value: -6.497126730910424.
# [I 2024-02-19 22:48:24,067] Trial 30 finished with value: -8.319608906944605 and parameters: {'selector__k': 35, 'model__learning_rate': 0.2788581009327569, 'model__n_estimators': 273, 'model__max_depth': 33, 'model__num_leaves': 39, 'model__min_child_samples': 3, 'model__subsample': 0.25322830134905094, 'model__colsample_bytree': 0.41037629668078235}. Best is trial 11 with value: -6.497126730910424.
# [I 2024-02-19 22:48:24,244] Trial 31 finished with value: -6.539399962557445 and parameters: {'selector__k': 29, 'model__learning_rate': 0.15940545320055946, 'model__n_estimators': 51, 'model__max_depth': 34, 'model__num_leaves': 50, 'model__min_child_samples': 9, 'model__subsample': 0.4365417362787355, 'model__colsample_bytree': 0.5383430766623396}. Best is trial 11 with value: -6.497126730910424.
# [I 2024-02-19 22:48:24,434] Trial 32 finished with value: -6.929673816551009 and parameters: {'selector__k': 25, 'model__learning_rate': 0.0845278805701758, 'model__n_estimators': 60, 'model__max_depth': 36, 'model__num_leaves': 48, 'model__min_child_samples': 7, 'model__subsample': 0.41349673354639094, 'model__colsample_bytree': 0.5744909795128225}. Best is trial 11 with value: -6.497126730910424.
# [I 2024-02-19 22:48:24,609] Trial 33 finished with value: -6.555465244171501 and parameters: {'selector__k': 32, 'model__learning_rate': 0.15277068200509036, 'model__n_estimators': 57, 'model__max_depth': 31, 'model__num_leaves': 50, 'model__min_child_samples': 12, 'model__subsample': 0.10511966251331754, 'model__colsample_bytree': 0.5120733668306889}. Best is trial 11 with value: -6.497126730910424.
# [I 2024-02-19 22:48:24,784] Trial 34 finished with value: -6.745843968953797 and parameters: {'selector__k': 40, 'model__learning_rate': 0.15067606813048023, 'model__n_estimators': 72, 'model__max_depth': 28, 'model__num_leaves': 44, 'model__min_child_samples': 17, 'model__subsample': 0.10309939459919039, 'model__colsample_bytree': 0.6570496271322824}. Best is trial 11 with value: -6.497126730910424.
# [I 2024-02-19 22:48:25,062] Trial 35 finished with value: -6.504778855986233 and parameters: {'selector__k': 32, 'model__learning_rate': 0.0792697276043432, 'model__n_estimators': 59, 'model__max_depth': 30, 'model__num_leaves': 47, 'model__min_child_samples': 6, 'model__subsample': 0.15423503488751322, 'model__colsample_bytree': 0.3613395590516526}. Best is trial 11 with value: -6.497126730910424.
# [I 2024-02-19 22:48:25,289] Trial 36 finished with value: -7.166875767506183 and parameters: {'selector__k': 39, 'model__learning_rate': 0.08456465027902543, 'model__n_estimators': 77, 'model__max_depth': 24, 'model__num_leaves': 47, 'model__min_child_samples': 6, 'model__subsample': 0.1762163929000781, 'model__colsample_bytree': 0.36456131768110245}. Best is trial 11 with value: -6.497126730910424.
# [I 2024-02-19 22:48:25,574] Trial 37 finished with value: -7.589113991389664 and parameters: {'selector__k': 21, 'model__learning_rate': 0.014739911975449424, 'model__n_estimators': 93, 'model__max_depth': 40, 'model__num_leaves': 37, 'model__min_child_samples': 4, 'model__subsample': 0.24818561661281408, 'model__colsample_bytree': 0.1732633322480926}. Best is trial 11 with value: -6.497126730910424.
# [I 2024-02-19 22:48:25,836] Trial 38 finished with value: -6.861422398284013 and parameters: {'selector__k': 47, 'model__learning_rate': 0.06591758838942614, 'model__n_estimators': 152, 'model__max_depth': 20, 'model__num_leaves': 33, 'model__min_child_samples': 8, 'model__subsample': 0.3251444744330617, 'model__colsample_bytree': 0.3210688828780735}. Best is trial 11 with value: -6.497126730910424.
# [I 2024-02-19 22:48:26,088] Trial 39 finished with value: -7.189783750243819 and parameters: {'selector__k': 37, 'model__learning_rate': 0.4985161460989024, 'model__n_estimators': 60, 'model__max_depth': 26, 'model__num_leaves': 25, 'model__min_child_samples': 5, 'model__subsample': 0.2887019614887867, 'model__colsample_bytree': 0.606859794822044}. Best is trial 11 with value: -6.497126730910424.
# [I 2024-02-19 22:48:26,311] Trial 40 finished with value: -8.025109386866133 and parameters: {'selector__k': 40, 'model__learning_rate': 0.6117940927483244, 'model__n_estimators': 104, 'model__max_depth': 29, 'model__num_leaves': 42, 'model__min_child_samples': 9, 'model__subsample': 0.15208057274327805, 'model__colsample_bytree': 0.39072744939819265}. Best is trial 11 with value: -6.497126730910424.
# [I 2024-02-19 22:48:26,484] Trial 41 finished with value: -6.709777899935183 and parameters: {'selector__k': 32, 'model__learning_rate': 0.13485425812589344, 'model__n_estimators': 59, 'model__max_depth': 38, 'model__num_leaves': 48, 'model__min_child_samples': 19, 'model__subsample': 0.2256184383612113, 'model__colsample_bytree': 0.7443842881018181}. Best is trial 11 with value: -6.497126730910424.
# [I 2024-02-19 22:48:26,689] Trial 42 finished with value: -6.41907169915202 and parameters: {'selector__k': 33, 'model__learning_rate': 0.13789489056458265, 'model__n_estimators': 76, 'model__max_depth': 31, 'model__num_leaves': 50, 'model__min_child_samples': 12, 'model__subsample': 0.10112523474754039, 'model__colsample_bytree': 0.5016955100528112}. Best is trial 42 with value: -6.41907169915202.
# [I 2024-02-19 22:48:26,904] Trial 43 finished with value: -6.80212432735163 and parameters: {'selector__k': 28, 'model__learning_rate': 0.06609005904563309, 'model__n_estimators': 74, 'model__max_depth': 32, 'model__num_leaves': 44, 'model__min_child_samples': 7, 'model__subsample': 0.14860603691647714, 'model__colsample_bytree': 0.44623569862015106}. Best is trial 42 with value: -6.41907169915202.
# [I 2024-02-19 22:48:27,091] Trial 44 finished with value: -7.186157292032327 and parameters: {'selector__k': 35, 'model__learning_rate': 0.22573897147510008, 'model__n_estimators': 85, 'model__max_depth': 27, 'model__num_leaves': 46, 'model__min_child_samples': 20, 'model__subsample': 0.13965031479040163, 'model__colsample_bytree': 0.5021820908933565}. Best is trial 42 with value: -6.41907169915202.
# [I 2024-02-19 22:48:27,279] Trial 45 finished with value: -7.2501431442634905 and parameters: {'selector__k': 33, 'model__learning_rate': 0.41201754489331655, 'model__n_estimators': 69, 'model__max_depth': 37, 'model__num_leaves': 41, 'model__min_child_samples': 12, 'model__subsample': 0.2740017764310054, 'model__colsample_bytree': 0.31385944867949045}. Best is trial 42 with value: -6.41907169915202.
# ...
# [W 2024-02-19 22:50:47,775] Trial 42 failed with value nan.
# [W 2024-02-19 22:50:48,327] Trial 43 failed with parameters: {'selector__k': 24, 'model__hidden_layer_sizes': (50,), 'model__activation': 'identity', 'model__solver': 'sgd', 'model__alpha': 6142.83675028595} because of the following error: The value nan is not acceptable.
# [W 2024-02-19 22:50:48,329] Trial 43 failed with value nan.
# [W 2024-02-19 22:50:48,880] Trial 44 failed with parameters: {'selector__k': 24, 'model__hidden_layer_sizes': (50,), 'model__activation': 'identity', 'model__solver': 'sgd', 'model__alpha': 6333.825080499513} because of the following error: The value nan is not acceptable.
# [W 2024-02-19 22:50:48,881] Trial 44 failed with value nan.
# [W 2024-02-19 22:50:49,415] Trial 45 failed with parameters: {'selector__k': 24, 'model__hidden_layer_sizes': (50,), 'model__activation': 'identity', 'model__solver': 'sgd', 'model__alpha': 1.5229223835245849} because of the following error: The value nan is not acceptable.
# [W 2024-02-19 22:50:49,416] Trial 45 failed with value nan.
# [W 2024-02-19 22:50:49,958] Trial 46 failed with parameters: {'selector__k': 25, 'model__hidden_layer_sizes': (50,), 'model__activation': 'identity', 'model__solver': 'sgd', 'model__alpha': 9495.568601559784} because of the following error: The value nan is not acceptable.
# [W 2024-02-19 22:50:49,959] Trial 46 failed with value nan.
# [W 2024-02-19 22:50:50,507] Trial 47 failed with parameters: {'selector__k': 25, 'model__hidden_layer_sizes': (50,), 'model__activation': 'identity', 'model__solver': 'sgd', 'model__alpha': 8776.841118728202} because of the following error: The value nan is not acceptable.
# [W 2024-02-19 22:50:50,509] Trial 47 failed with value nan.
# [W 2024-02-19 22:50:51,079] Trial 48 failed with parameters: {'selector__k': 26, 'model__hidden_layer_sizes': (50,), 'model__activation': 'identity', 'model__solver': 'sgd', 'model__alpha': 10209.468612409808} because of the following error: The value nan is not acceptable.
# [W 2024-02-19 22:50:51,081] Trial 48 failed with value nan.
# [W 2024-02-19 22:50:51,628] Trial 49 failed with parameters: {'selector__k': 25, 'model__hidden_layer_sizes': (50,), 'model__activation': 'identity', 'model__solver': 'sgd', 'model__alpha': 7512.83198633395} because of the following error: The value nan is not acceptable.
# [W 2024-02-19 22:50:51,630] Trial 49 failed with value nan.
# [I 2024-02-19 22:50:52,146] A new study created in memory with name: no-name-324e79ba-0147-48e0-b182-41ef6c8ff9e5
# [I 2024-02-19 22:50:52,241] Trial 0 finished with value: -23.773852570351607 and parameters: {'selector__k': 16, 'model__kernel': 1**2 * Matern(length_scale=1, nu=1.5), 'model__alpha': 9352409834.251043}. Best is trial 0 with value: -23.773852570351607.
# [I 2024-02-19 22:50:52,317] Trial 1 finished with value: -23.15039596417937 and parameters: {'selector__k': 45, 'model__kernel': DotProduct(sigma_0=1) + WhiteKernel(noise_level=1), 'model__alpha': 5500774807.649299}. Best is trial 1 with value: -23.15039596417937.
# ANN -7.290786452564099 15.382559311313866 532.1391035243552 171.12256608465609
# [I 2024-02-19 22:50:52,412] Trial 2 finished with value: -23.771434127648014 and parameters: {'selector__k': 29, 'model__kernel': 50**2 * RBF(length_scale=50), 'model__alpha': 1454517500.9061496}. Best is trial 1 with value: -23.15039596417937.
# [I 2024-02-19 22:50:52,503] Trial 3 finished with value: -23.773851900457185 and parameters: {'selector__k': 39, 'model__kernel': RBF(length_scale=1) + 1.41**2, 'model__alpha':
ernel': DotProduct(sigma_0=1) + WhiteKernel(noise_level=1), 'model__alpha': 1039609114.2203834}. Best is trial 45 with value: -10.306239890914275.
# [I 2024-02-19 22:50:57,448] Trial 48 finished with value: -23.77385267742385 and parameters: {'selector__k': 40, 'model__kernel': 0.1**2 * RBF(length_scale=0.1) + WhiteKernel(noise_level=0.01), 'model__alpha': 7517949149.456301}. Best is trial 45 with value: -10.306239890914275.
# [I 2024-02-19 22:50:57,575] Trial 49 finished with value: -23.773849055506936 and parameters: {'selector__k': 47, 'model__kernel': RBF(length_scale=1) + 1.41**2, 'model__alpha': 1759251152.6279452}. Best is trial 45 with value: -10.306239890914275.
# GPR -10.306239890914275 21.938868093155524 963.8576028104934 262.5516713178617

# %%
best_model_onlyreg_wofeatureselect = {}
for model_name in model_space.keys():   
    opt = OptunaSearchCV(
        model_space[model_name],
        param_space[model_name],
        n_trials=50,
        cv=[(train_index_onlyreg, validate_index_onlyreg), (train_index_onlyreg, validate_index_onlyreg)],
        scoring='neg_mean_absolute_error'
    )
    opt.fit(X_t_onlyreg, y_t_onlyreg)
    y_pred = opt.predict(X_te_onlyreg)
    mae = mean_absolute_error(y_te_onlyreg, y_pred)
    mse = mean_squared_error(y_te_onlyreg, y_pred)
    me = max_error(y_te_onlyreg, y_pred)
    best_model_onlyreg_wofeatureselect[model_name] = [opt, mae, mse, me]
    print(model_name, opt.best_score_, mae, mse, me)
# Out:
# [I 2024-02-19 22:50:57,835] A new study created in memory with name: no-name-bf62c6b5-09d1-4336-a1ba-5b89d6787daa
# [I 2024-02-19 22:50:58,053] Trial 0 finished with value: -10.108962113602463 and parameters: {'n_neighbors': 45, 'weights': 'distance', 'algorithm': 'auto'}. Best is trial 0 with value: -10.108962113602463.
# [I 2024-02-19 22:50:58,250] Trial 1 finished with value: -10.244329379613506 and parameters: {'n_neighbors': 30, 'weights': 'distance', 'algorithm': 'brute'}. Best is trial 0 with value: -10.108962113602463.
# [I 2024-02-19 22:50:58,287] Trial 2 finished with value: -10.170476477841213 and parameters: {'n_neighbors': 36, 'weights': 'distance', 'algorithm': 'ball_tree'}. Best is trial 0 with value: -10.108962113602463.
# [I 2024-02-19 22:50:58,321] Trial 3 finished with value: -10.310765712007647 and parameters: {'n_neighbors': 4, 'weights': 'distance', 'algorithm': 'ball_tree'}. Best is trial 0 with value: -10.108962113602463.
# [I 2024-02-19 22:50:58,360] Trial 4 finished with value: -10.120774393119813 and parameters: {'n_neighbors': 47, 'weights': 'distance', 'algorithm': 'ball_tree'}. Best is trial 0 with value: -10.108962113602463.
# [I 2024-02-19 22:50:58,556] Trial 5 finished with value: -10.094270723970405 and parameters: {'n_neighbors': 50, 'weights': 'uniform', 'algorithm': 'auto'}. Best is trial 5 with value: -10.094270723970405.
# [I 2024-02-19 22:50:58,754] Trial 6 finished with value: -10.112639640437743 and parameters: {'n_neighbors': 49, 'weights': 'uniform', 'algorithm': 'auto'}. Best is trial 5 with value: -10.094270723970405.
# [I 2024-02-19 22:50:58,955] Trial 7 finished with value: -10.156878589751425 and parameters: {'n_neighbors': 42, 'weights': 'distance', 'algorithm': 'brute'}. Best is trial 5 with value: -10.094270723970405.
# [I 2024-02-19 22:50:58,994] Trial 8 finished with value: -10.16415441804381 and parameters: {'n_neighbors': 38, 'weights': 'distance', 'algorithm': 'kd_tree'}. Best is trial 5 with value: -10.094270723970405.
# [I 2024-02-19 22:50:59,029] Trial 9 finished with value: -10.453342444470376 and parameters: {'n_neighbors': 12, 'weights': 'distance', 'algorithm': 'kd_tree'}. Best is trial 5 with value: -10.094270723970405.
# [I 2024-02-19 22:50:59,229] Trial 10 finished with value: -10.262879070175691 and parameters: {'n_neighbors': 21, 'weights': 'uniform', 'algorithm': 'auto'}. Best is trial 5 with value: -10.094270723970405.
# [I 2024-02-19 22:50:59,439] Trial 11 finished with value: -10.094270723970405 and parameters: {'n_neighbors': 50, 'weights': 'uniform', 'algorithm': 'auto'}. Best is trial 5 with value: -10.094270723970405.
# [I 2024-02-19 22:50:59,656] Trial 12 finished with value: -10.255673475380714 and parameters: {'n_neighbors': 27, 'weights': 'uniform', 'algorithm': 'auto'}. Best is trial 5 with value: -10.094270723970405.
# [I 2024-02-19 22:50:59,875] Trial 13 finished with value: -10.094270723970405 and parameters: {'n_neighbors': 50, 'weights': 'uniform', 'algorithm': 'auto'}. Best is trial 5 with value: -10.094270723970405.
# [I 2024-02-19 22:51:00,086] Trial 14 finished with value: -10.195272928784298 and parameters: {'n_neighbors': 35, 'weights': 'uniform', 'algorithm': 'auto'}. Best is trial 5 with value: -10.094270723970405.
# [I 2024-02-19 22:51:00,291] Trial 15 finished with value: -10.262879070175691 and parameters: {'n_neighbors': 21, 'weights': 'uniform', 'algorithm': 'auto'}. Best is trial 5 with value: -10.094270723970405.
# [I 2024-02-19 22:51:00,501] Trial 16 finished with value: -10.202604040611089 and parameters: {'n_neighbors': 41, 'weights': 'uniform', 'algorithm': 'auto'}. Best is trial 5 with value: -10.094270723970405.
# [I 2024-02-19 22:51:00,550] Trial 17 finished with value: -10.262299635452992 and parameters: {'n_neighbors': 31, 'weights': 'uniform', 'algorithm': 'kd_tree'}. Best is trial 5 with value: -10.094270723970405.
# [I 2024-02-19 22:51:00,763] Trial 18 finished with value: -10.155623825495727 and parameters: {'n_neighbors': 43, 'weights': 'uniform', 'algorithm': 'brute'}. Best is trial 5 with value: -10.094270723970405.
# [I 2024-02-19 22:51:00,972] Trial 19 finished with value: -10.318734852471895 and parameters: {'n_neighbors': 18, 'weights': 'uniform', 'algorithm': 'auto'}. Best is trial 5 with value: -10.094270723970405.
# [I 2024-02-19 22:51:01,172] Trial 20 finished with value: -10.771437057897268 and parameters: {'n_neighbors': 10, 'weights': 'uniform', 'algorithm': 'auto'}. Best is trial 5 with value: -10.094270723970405.
# [I 2024-02-19 22:51:01,381] Trial 21 finished with value: -10.126988178881433 and parameters: {'n_neighbors': 48, 'weights': 'uniform', 'algorithm': 'auto'}. Best is trial 5 with value: -10.094270723970405.
# [I 2024-02-19 22:51:01,591] Trial 22 finished with value: -10.112639640437743 and parameters: {'n_neighbors': 49, 'weights': 'uniform', 'algorithm': 'auto'}. Best is trial 5 with value: -10.094270723970405.
# [I 2024-02-19 22:51
. Best is trial 0 with value: -7.261397270568392.
# [I 2024-02-19 22:51:43,439] Trial 2 finished with value: -7.26951484963068 and parameters: {'max_features': 'sqrt', 'n_estimators': 341, 'max_depth': 142, 'min_samples_leaf': 2}. Best is trial 0 with value: -7.261397270568392.
# [I 2024-02-19 22:51:43,756] Trial 3 finished with value: -7.97930289580009 and parameters: {'max_features': 'log2', 'n_estimators': 51, 'max_depth': 107, 'min_samples_leaf': 10}. Best is trial 0 with value: -7.261397270568392.
# [I 2024-02-19 22:51:44,267] Trial 4 finished with value: -7.430377281306096 and parameters: {'max_features': 'log2', 'n_estimators': 79, 'max_depth': 156, 'min_samples_leaf': 4}. Best is trial 0 with value: -7.261397270568392.
# [I 2024-02-19 22:51:45,078] Trial 5 finished with value: -7.436290919694667 and parameters: {'max_features': 'sqrt', 'n_estimators': 130, 'max_depth': 46, 'min_samples_leaf': 5}. Best is trial 0 with value: -7.261397270568392.
# [I 2024-02-19 22:51:46,269] Trial 6 finished with value: -7.982343108410201 and parameters: {'max_features': 'sqrt', 'n_estimators': 210, 'max_depth': 180, 'min_samples_leaf': 13}. Best is trial 0 with value: -7.261397270568392.
# [I 2024-02-19 22:51:48,043] Trial 7 finished with value: -7.591402601309203 and parameters: {'max_features': 'log2', 'n_estimators': 307, 'max_depth': 150, 'min_samples_leaf': 7}. Best is trial 0 with value: -7.261397270568392.
# [I 2024-02-19 22:51:49,358] Trial 8 finished with value: -7.892612450260705 and parameters: {'max_features': 'log2', 'n_estimators': 234, 'max_depth': 70, 'min_samples_leaf': 10}. Best is trial 0 with value: -7.261397270568392.
# [I 2024-02-19 22:51:51,332] Trial 9 finished with value: -7.997109742499629 and parameters: {'max_features': 'log2', 'n_estimators': 350, 'max_depth': 13, 'min_samples_leaf': 12}. Best is trial 0 with value: -7.261397270568392.
# [I 2024-02-19 22:51:52,001] Trial 10 finished with value: -8.253440285180236 and parameters: {'max_features': 'sqrt', 'n_estimators': 113, 'max_depth': 100, 'min_samples_leaf': 19}. Best is trial 0 with value: -7.261397270568392.
# [I 2024-02-19 22:51:55,293] Trial 11 finished with value: -7.232889463181516 and parameters: {'max_features': 'sqrt', 'n_estimators': 433, 'max_depth': 194, 'min_samples_leaf': 1}. Best is trial 11 with value: -7.232889463181516.
# [I 2024-02-19 22:51:58,839] Trial 12 finished with value: -7.209693508201157 and parameters: {'max_features': 'sqrt', 'n_estimators': 472, 'max_depth': 193, 'min_samples_leaf': 1}. Best is trial 12 with value: -7.209693508201157.
# [I 2024-02-19 22:52:02,417] Trial 13 finished with value: -7.2165166952002915 and parameters: {'max_features': 'sqrt', 'n_estimators': 476, 'max_depth': 200, 'min_samples_leaf': 1}. Best is trial 12 with value: -7.209693508201157.
# [I 2024-02-19 22:52:05,978] Trial 14 finished with value: -7.217537443172707 and parameters: {'max_features': 'sqrt', 'n_estimators': 477, 'max_depth': 198, 'min_samples_leaf': 1}. Best is trial 12 with value: -7.209693508201157.
# [I 2024-02-19 22:52:08,935] Trial 15 finished with value: -7.468177844033503 and parameters: {'max_features': 'sqrt', 'n_estimators': 496, 'max_depth': 115, 'min_samples_leaf': 7}. Best is trial 12 with value: -7.209693508201157.
# [I 2024-02-19 22:52:10,565] Trial 16 finished with value: -7.513010697299556 and parameters: {'max_features': 'sqrt', 'n_estimators': 270, 'max_depth': 167, 'min_samples_leaf': 7}. Best is trial 12 with value: -7.209693508201157.
# [I 2024-02-19 22:52:13,062] Trial 17 finished with value: -7.2482811975396855 and parameters: {'max_features': 'sqrt', 'n_estimators': 385, 'max_depth': 199, 'min_samples_leaf': 3}. Best is trial 12 with value: -7.209693508201157.
# [I 2024-02-19 22:52:14,610] Trial 18 finished with value: -7.371611003504128 and parameters: {'max_features': 'sqrt', 'n_estimators': 254, 'max_depth': 125, 'min_samples_leaf': 6}. Best is trial 12 with value: -7.209693508201157.
# [I 2024-02-19 22:52:15,592] Trial 19 finished with value: -7.628307359459125 and parameters: {'max_features': 'sqrt', 'n_estimators': 164, 'max_depth': 80, 'min_samples_leaf': 9}. Best is trial 12 with value: -7.209693508201157.
# [I 2024-02-19 22:52:17,296] Trial 20 finished with value: -8.039095177447377 and parameters: {'max_features': 'sqrt', 'n_estimators': 301, 'max_depth': 165, 'min_samples_leaf': 14}. Best is trial 12 with value: -7.209693508201157.
# [I 2024-02-19 22:52:20,868] Trial 21 finished with value: -7.212001961717806 and parameters: {'max_features': 'sqrt', 'n_estimators': 479, 'max_depth': 198, 'min_samples_leaf': 1}. Best is trial 12 with value: -7.209693508201157.
# [I 2024-02-19 22:52:24,586] Trial 22 finished with value: -7.218995214212708 and parameters: {'max_features': 'sqrt', 'n_estimators': 501, 'max_depth': 183, 'min_samples_leaf': 1}. Best is trial 12 with value: -7.209693508201157.
# [I 2024-02-19 22:52:27,206] Trial 23 finished with value: -7.267916912434826 and parameters: {'max_features': 'sqrt', 'n_estimators': 398, 'max_depth': 180, 'min_samples_leaf': 3}. Best is trial 12 with value: -7.209693508201157.
# [I 2024-02-19 22:52:29,792] Trial 24 finished with value: -7.264375701266392 and parameters: {'max_features': 'sqrt', 'n_estimators': 395, 'max_depth': 199, 'min_samples_leaf': 3}. Best is trial 12 with value: -7.209693508201157.
# [I 2024-02-19 22:52:31,791] Trial 25 finished with value: -7.323807288138412 and parameters: {'max_features': 'sqrt', 'n_estimators': 323, 'max_depth': 161, 'min_samples_leaf': 5}. Best is trial 12 with value: -7.209693508201157.
# [I 2024-02-19 22:52:34,698] Trial 26 finished with value: -7.32892906581199 and parameters: {'max_features': 'log2', 'n_estimators': 412, 'max_depth': 130, 'min_samples_leaf': 1}. Best is trial 12 with value: -7.209693508201157.
# [I 2024-02-19 22:52:36,542] Trial 27 finished with value: -7.273601911257184 and parameters: {'max_features': 'sqrt', 'n_estimators': 275, 'max_depth': 175, 'min_samples_leaf': 3}. Best is trial 12 with value: -7.209693508201157.
# [I 2024-02-19 22:52:37,543] Trial 28 finished with value: -7.878277434134122 and parameters: {'max_features': 'sqrt', 'n_estimators': 171, 'max_depth': 3, 'min_samples_leaf': 8}. Best is trial 12 with value: -7.209693508201157.
# [I 2024-02-19 22:52:40,252] Trial 29 finished with value: -7.32846747645031 and parameters: {'max_features': 'sqrt', 'n_estimators': 444, 'max_depth': 187, 'min_samples_leaf': 5}. Best is trial 12 with value: -7.209693508201157.
# ...
# [W 2024-02-19 22:56:02,767] Trial 35 failed with value nan.
# [W 2024-02-19 22:56:03,728] Trial 36 failed with parameters: {'hidden_layer_sizes': (30, 30, 30), 'activation': 'identity', 'solver': 'sgd', 'alpha': 8.60359864311737} because of the following error: The value nan is not acceptable.
# [W 2024-02-19 22:56:03,729] Trial 36 failed with value nan.
# [W 2024-02-19 22:56:04,526] Trial 37 failed with parameters: {'hidden_layer_sizes': (50, 50), 'activation': 'identity', 'solver': 'sgd', 'alpha': 20.132421767132637} because of the following error: The value nan is not acceptable.
# [W 2024-02-19 22:56:04,527] Trial 37 failed with value nan.
# [W 2024-02-19 22:56:05,335] Trial 38 failed with parameters: {'hidden_layer_sizes': (50, 50), 'activation': 'identity', 'solver': 'sgd', 'alpha': 15.637427744135609} because of the following error: The value nan is not acceptable.
# [W 2024-02-19 22:56:05,336] Trial 38 failed with value nan.
# [W 2024-02-19 22:56:06,317] Trial 39 failed with parameters: {'hidden_layer_sizes': (30, 30, 30), 'activation': 'identity', 'solver': 'sgd', 'alpha': 18.79486227773401} because of the following error: The value nan is not acceptable.
# [W 2024-02-19 22:56:06,318] Trial 39 failed with value nan.
# [W 2024-02-19 22:56:07,305] Trial 40 failed with parameters: {'hidden_layer_sizes': (30, 30, 30), 'activation': 'identity', 'solver': 'sgd', 'alpha': 5.427136994329515} because of the following error: The value nan is not acceptable.
# [W 2024-02-19 22:56:07,307] Trial 40 failed with value nan.
# [W 2024-02-19 22:56:08,292] Trial 41 failed with parameters: {'hidden_layer_sizes': (30, 30, 30), 'activation': 'identity', 'solver': 'sgd', 'alpha': 38.587162159834584} because of the following error: The value nan is not acceptable.
# [W 2024-02-19 22:56:08,293] Trial 41 failed with value nan.
# [W 2024-02-19 22:56:09,105] Trial 42 failed with parameters: {'hidden_layer_sizes': (50, 50), 'activation': 'identity', 'solver': 'sgd', 'alpha': 13.397066263924543} because of the following error: The value nan is not acceptable.
# [W 2024-02-19 22:56:09,106] Trial 42 failed with value nan.
# [W 2024-02-19 22:56:09,893] Trial 43 failed with parameters: {'hidden_layer_sizes': (50, 50), 'activation': 'identity', 'solver': 'sgd', 'alpha': 26.442211211493806} because of the following error: The value nan is not acceptable.
# [W 2024-02-19 22:56:09,895] Trial 43 failed with value nan.
# [W 2024-02-19 22:56:10,885] Trial 44 failed with parameters: {'hidden_layer_sizes': (30, 30, 30), 'activation': 'identity', 'solver': 'sgd', 'alpha': 12.966595581587933} because of the following error: The value nan is not acceptable.
# [W 2024-02-19 22:56
and parameters: {'kernel': DotProduct(sigma_0=1) + WhiteKernel(noise_level=1), 'alpha': 2184737447.0106926}. Best is trial 13 with value: -10.248587467812165.
# [I 2024-02-19 22:56:20,153] Trial 49 finished with value: -17.81648068395021 and parameters: {'kernel': DotProduct(sigma_0=1) + WhiteKernel(noise_level=1), 'alpha': 406711387.25865424}. Best is trial 13 with value: -10.248587467812165.
# GPR -10.248587467812165 22.195950206537695 957.8563272393701 261.3548207891602

# %%
with open('best_model_onlyreg.pickle', 'wb') as f:
    pickle.dump(best_model_onlyreg, f, pickle.HIGHEST_PROTOCOL)

# %%
# X_t = X_t_old[selected_features] 
# X_t['cluster'] = train_data_tr['remainder__clusters']
# X_t['remainder__link_counts'] = train_data_tr['remainder__link_counts']
# X_v = validate_data_tr[selected_features]
# X_v['cluster'] = validate_data_tr['remainder__clusters']
# X_v['remainder__link_counts'] = validate_data_tr['remainder__link_counts']
# X_te = test_data_tr[selected_features]
# X_te['cluster'] = test_data_tr['remainder__clusters']
# X_te['remainder__link_counts'] = test_data_tr['remainder__link_counts']

# %%
selected_features

# %%
model = xgb.XGBRegressor(random_state=101)
opt = BayesSearchCV(
    model,
    param_space['XGB'],
    n_iter=50,  # Adjust the number of iterations based on your computational resources
    cv=ShuffleSplit(test_size=0.20, n_splits=3),  # Adjust the number of cross-validation folds
    scoring='neg_mean_absolute_error',  # Use a suitable regression metric
    n_jobs=-1,
)

opt.fit(X_t, y_t)
best_params = opt.best_params_ 

model = xgb.XGBRegressor(**best_params, random_state=101)
model.fit(X_t, y_t)
te_predictions = model.predict(X_te)
te_mae = mean_absolute_error(y_te, te_predictions)
print(te_mae)

onehot = OneHotEncoder()
X_t_leaves = onehot.fit_transform(model.apply(X_t))
rf_lr = LogisticRegressionCV(cv=ShuffleSplit(test_size=0.20, n_splits=3))
rf_lr.fit(X_t_leaves, y_t)
X_te_leaves = onehot.transform(model.apply(X_te))
y_te_pred_rf_lr = rf_lr.predict(X_te_leaves)
te_rflr_mae = mean_absolute_error(y_te, y_te_pred_rf_lr)
print(te_rflr_mae)

# %%
v_mae_list = []
te_mae_list = []
v_rf_mae_list = []
te_rf_mae_list = []
# X_te['cluster'] = 1
for cluster_label in list(set(X_t['cluster'])):
    X_v_cluster, X_te_cluster = None, None
    v_mae, te_mae, v_rflr_mae, te_rflr_mae = None, None, None, None
    # Subset the training data for the current cluster
    X_t_cluster = X_t[X_t['cluster'] == cluster_label]
    y_t_cluster = X_t_cluster['remainder__link_counts']
    X_t_cluster = X_t_cluster.drop(columns=['remainder__link_counts','cluster'])  
    
    if cluster_label in list(set(X_v['cluster'])):
        X_v_cluster = X_v[X_v['cluster'] == cluster_label]
        y_v_cluster = X_v_cluster['remainder__link_counts']
        X_v_cluster = X_v_cluster.drop(columns=['remainder__link_counts','cluster'])  
    if cluster_label in list(set(X_te['cluster'])):
        X_te_cluster = X_te[X_te['cluster'] == cluster_label]
        y_te_cluster = X_te_cluster['remainder__link_counts']
        X_te_cluster = X_te_cluster.drop(columns=['remainder__link_counts','cluster'])  
    

    # Train a regression model for the current cluster
    # model = RidgeCV(scoring='neg_mean_absolute_error')
    # model = RandomForestRegressor(criterion='friedman_mse', n_estimators=300,
    #                   random_state=101)

    if not ((X_v_cluster is None) and (X_te_cluster is None)):

        model = xgb.XGBRegressor(random_state=101)
        opt = BayesSearchCV(
            model,
            param_space['XGB'],
            n_iter=60,  # Adjust the number of iterations based on your computational resources
            cv=ShuffleSplit(test_size=0.20, n_splits=1),  # Adjust the number of cross-validation folds
            scoring='neg_mean_absolute_error',  # Use a suitable regression metric
            n_jobs=-1,
        )
        
        opt.fit(X_t_cluster, y_t_cluster)
        best_params = opt.best_params_ 
        onehot = OneHotEncoder()
        model = xgb.XGBRegressor(**best_params, random_state=101)
        model.fit(X_t_cluster, y_t_cluster)

        X_t_leaves = onehot.fit_transform(model.apply(X_t_cluster))
        rf_lr = LogisticRegression()
        rf_lr.fit(X_t_leaves, y_t_cluster)
        if (X_v_cluster is not None):
            v_predictions = model.predict(X_v_cluster)
            v_mae = mean_absolute_error(y_v_cluster, v_predictions)
            row_count = len(y_v_cluster)
            v_mae_list.append(v_mae*row_count)

            X_v_leaves = onehot.transform(model.apply(X_v_cluster))
            y_v_pred_rf_lr = rf_lr.predict(X_v_leaves)
            row_count = len(y_v_pred_rf_lr)
            v_rflr_mae = mean_absolute_error(y_v_cluster, y_v_pred_rf_lr)
            v_rf_mae_list.append(v_rflr_mae*row_count)
        if (X_te_cluster is not None):
            te_predictions = model.predict(X_te_cluster)
            te_mae = mean_absolute_error(y_te_cluster, te_predictions)
            row_count = len(y_te_cluster)
            te_mae_list.append(te_mae*row_count)
      
            X_te_leaves = onehot.transform(model.apply(X_te_cluster))
            y_te_pred_rf_lr = rf_lr.predict(X_te_leaves)
            row_count = len(y_te_pred_rf_lr)
            te_rflr_mae = mean_absolute_error(y_te_cluster, y_te_pred_rf_lr)
            te_rf_mae_list.append(te_rflr_mae*row_count)
    print(cluster_label, v_mae, te_mae, v_rflr_mae, te_rflr_mae)
v_mae_list = list(filter(lambda item: item is not None, v_mae_list))    
te_mae_list = list(filter(lambda item: item is not None, te_mae_list))    
v_mean_mae = sum(v_mae_list)/len(X_v)
te_mean_mae = sum(te_mae_list)/len(X_te)
print(v_mean_mae)
print(te_mean_mae)

# %%
best_params = None
best_mae = 0.0

# Generate all combinations of hyperparameters
param_combinations = product(*param_grid.values())
# Loop through hyperparameter combinations
for params in param_combinations:
    # Create and train the model with the current hyperparameters
    model = lgb.LGBMRegressor(**dict(zip(param_grid.keys(), params)), random_state=101)
    model.fit(X_t[X_v.columns], y_t)

    # Evaluate the model on the validation dataset
    y_val_pred = model.predict(X_v)
    mae = mean_absolute_error(y_v, y_val_pred)

    # Check if current hyperparameters are the best
    if mae > best_mae:
        best_mae = mae
        best_params = dict(zip(param_grid.keys(), params))
print(best_mae)
print(best_params)
# Train the final model using the entire training dataset with the best hyperparameters
final_model = lgb.LGBMRegressor(**best_params, random_state=101)
final_model.fit(X_t, y_t)

# Evaluate the final model on the test dataset
y_test_pred = final_model.predict(X_te)
test_mae = mean_absolute_error(y_te, y_test_pred)
print(test_mae)

# %%
# Define the LGBMRegressor model
lgbm_model = lgb.LGBMRegressor(random_state=101, force_col_wise=True)

# Create a Bayesian optimization object
opt = BayesSearchCV(
    lgbm_model,
    param_space,
    n_iter=100,  # Adjust the number of iterations based on your computational resources
    cv=3,  # Adjust the number of cross-validation folds
    scoring='neg_mean_absolute_error',  # Use a suitable regression metric
    n_jobs=-1,
)

# Perform Bayesian optimization
opt.fit(X_t[X_v.columns], y_t, eval_set = [(X_v, y_v)])

# Get the best hyperparameters
best_params = opt.best_params_
print(opt.best_estimator_)

# Train the final model with the best hyperparameters
final_model = lgb.LGBMRegressor(**best_params, random_state=101, force_col_wise=True)
final_model.fit(X_t, y_t, eval_set = [(X_te, y_te)])

print("With LGB Pred")
y_t_pred = final_model.predict(X_t)
print(mean_absolute_error(y_t, y_t_pred))

y_te_pred = final_model.predict(X_te)
print(mean_absolute_error(y_te, y_te_pred))

# %%
print("---------------")

onehot = OneHotEncoder()
X_t_leaves = onehot.fit_transform(final_model.predict(X_t, pred_leaf=True))
xgb_lr = LogisticRegression()
xgb_lr.fit(X_t_leaves, y_t)

print("With LGB + LR Pred")
X_t_leaves = onehot.transform(final_model.predict(X_t, pred_leaf=True))
y_t_pred_xgb_lr = xgb_lr.predict(X_t_leaves)
print(mean_absolute_error(y_t, y_t_pred_xgb_lr))

X_te_leaves = onehot.transform(final_model.predict(X_te, pred_leaf=True))
y_te_pred_xgb_lr = xgb_lr.predict(X_te_leaves)
print(mean_absolute_error(y_te, y_te_pred_xgb_lr))

# %%
param_space = {
    'learning_rate': np.arange(0.01, 1.0, 0.01),
    'n_estimators': np.arange(50, 2001, 50),
    'max_depth': np.arange(1, 20),
    'max_leaves': np.arange(2, 50),
    'max_bin': np.arange(2, 50),
    'gamma': np.arange(1, 20),
    # 'min_child_weight': np.arange(0, 20),
    # 'subsample': np.arange(0.1, 1.0, 0.1),
    # 'colsample_bytree': np.arange(0.1, 1.0, 0.1),
    # 'reg_alpha': np.arange(0, 100),
    # 'reg_lambda': np.arange(0, 10, 0.01),
}

# Define the LGBMRegressor model
xgb_model = xgb.XGBRegressor(random_state=101)

# Create a Bayesian optimization object
opt = BayesSearchCV(
    xgb_model,
    param_space,
    n_iter=100,  # Adjust the number of iterations based on your computational resources
    cv=3,  # Adjust the number of cross-validation folds
    scoring='neg_mean_absolute_error',  # Use a suitable regression metric
    n_jobs=-1,
)

# Perform Bayesian optimization
opt.fit(X_t[X_v.columns], y_t, eval_set = [(X_v, y_v)])
# 
# Get the best hyperparameters
best_params = opt.best_params_
print(opt.best_estimator_)

# Train the final model using the entire training dataset with the best hyperparameters
final_model = xgb.XGBRegressor(**best_params, random_state=101)
final_model.fit(X_t, y_t, eval_set = [(X_te, y_te)])

# Evaluate the final model on the test dataset
y_test_pred = final_model.predict(X_te)
test_mae = mean_absolute_error(y_te, y_test_pred)
print(test_mae)

# %%
# Train the final model with the best hyperparameters
final_model = xgb.XGBRegressor(**best_params, random_state=101)
final_model.fit(X_t, y_t)

print("With XGB Pred")
y_t_pred = final_model.predict(X_t)
print(mean_absolute_error(y_t, y_t_pred))

y_te_pred = final_model.predict(X_te)
print(mean_absolute_error(y_te, y_te_pred))

print("---------------")

onehot = OneHotEncoder()
X_t_leaves = onehot.fit_transform(final_model.apply(X_t))
xgb_lr = LogisticRegression()
xgb_lr.fit(X_t_leaves, y_t)

print("With XGB + LR Pred")
X_t_leaves = onehot.transform(final_model.apply(X_t))
y_t_pred_xgb_lr = xgb_lr.predict(X_t_leaves)
print(mean_absolute_error(y_t, y_t_pred_xgb_lr))

X_te_leaves = onehot.transform(final_model.apply(X_te))
y_te_pred_xgb_lr = xgb_lr.predict(X_te_leaves)
print(mean_absolute_error(y_te, y_te_pred_xgb_lr))


# # Make predictions on the validation set
# y_pred = final_model.predict(X_te)

# # Evaluate the model on the validation set
# mae = mean_absolute_error(y_te, y_pred)
# print(f'Mean Absolute Error on Validation Set: {mae}')

# %%
param_space =  {
    'max_features': Categorical(['sqrt', 'log2']),
    'n_estimators': np.arange(50, 2001, 50),
    'bootstrap': Categorical([True, False]),
    'max_depth': np.arange(1, 20),
    'min_samples_leaf': np.arange(1, 20),
    'criterion': Categorical(['squared_error', 'absolute_error', 'friedman_mse', 'poisson'])
}
# Define the LGBMRegressor model
rf_model = RandomForestRegressor(random_state=101)

# Create a Bayesian optimization object
opt = BayesSearchCV(
    rf_model,
    param_space,
    n_iter=100,  # Adjust the number of iterations based on your computational resources
    cv=3,  # Adjust the number of cross-validation folds
    scoring='neg_mean_absolute_error',  # Use a suitable regression metric
    n_jobs=-1,
)

# Perform Bayesian optimization
opt.fit(X_t, y_t)

# Get the best hyperparameters
best_params = opt.best_params_
print(opt.best_estimator_)

# %%
# Train the final model with the best hyperparameters
final_model = RandomForestRegressor(**best_params, random_state=101)
final_model.fit(X_t, y_t)

print("With RF Pred")
y_t_pred = final_model.predict(X_t)
print(mean_absolute_error(y_t, y_t_pred))

y_te_pred = final_model.predict(X_te)
print(mean_absolute_error(y_te, y_te_pred))

print("---------------")

onehot = OneHotEncoder()
X_t_leaves = onehot.fit_transform(final_model.apply(X_t))
xgb_lr = LogisticRegression()
xgb_lr.fit(X_t_leaves, y_t)

print("With XGB + LR Pred")
X_t_leaves = onehot.transform(final_model.apply(X_t))
y_t_pred_xgb_lr = xgb_lr.predict(X_t_leaves)
print(mean_absolute_error(y_t, y_t_pred_xgb_lr))

X_te_leaves = onehot.transform(final_model.apply(X_te))
y_te_pred_xgb_lr = xgb_lr.predict(X_te_leaves)
print(mean_absolute_error(y_te, y_te_pred_xgb_lr))

# %%
param_space = {
    'learning_rate': np.arange(0.01, 1.0, 0.01),
    'n_estimators': np.arange(50, 2001, 50),
    'max_depth': np.arange(1, 200),
    'min_samples_split': np.arange(2, 11, 1),
    'min_samples_leaf': np.arange(1, 10),
    'subsample': np.arange(0.1, 1.0, 0.1),
}
# Define the LGBMRegressor model
gb_model = GradientBoostingRegressor(random_state=101)

# Create a Bayesian optimization object
opt = BayesSearchCV(
    gb_model,
    param_space,
    n_iter=100,  # Adjust the number of iterations based on your computational resources
    cv=3,  # Adjust the number of cross-validation folds
    scoring='neg_mean_absolute_error',  # Use a suitable regression metric
    n_jobs=-1,
)

# Perform Bayesian optimization
opt.fit(X_t, y_t)

# Get the best hyperparameters
best_params = opt.best_params_
print(opt.best_estimator_)

# %%
final_model = GradientBoostingRegressor(**best_params, random_state=101)
final_model.fit(X_t, y_t)

print("With GB Pred")
y_t_pred = final_model.predict(X_t)
print(mean_absolute_error(y_t, y_t_pred))

y_te_pred = final_model.predict(X_te)
print(mean_absolute_error(y_te, y_te_pred))

print("---------------")

onehot = OneHotEncoder()
X_t_leaves = onehot.fit_transform(final_model.apply(X_t))
xgb_lr = LogisticRegression()
xgb_lr.fit(X_t_leaves, y_t)

print("With XGB + LR Pred")
X_t_leaves = onehot.transform(final_model.apply(X_t))
y_t_pred_xgb_lr = xgb_lr.predict(X_t_leaves)
print(mean_absolute_error(y_t, y_t_pred_xgb_lr))

X_te_leaves = onehot.transform(final_model.apply(X_te))
y_te_pred_xgb_lr = xgb_lr.predict(X_te_leaves)
print(mean_absolute_error(y_te, y_te_pred_xgb_lr))

# %%
def set_randomstate(model):
    current_params = model.get_params()

    # Update the random_state if it exists, otherwise add it to the parameters
    current_params['random_state'] = 101

    # Set the modified parameters back to the model
    model.set_params(**current_params)
    return model

kf = KFold(n_splits=5, shuffle=True, random_state=101)
models = {
    # 'Linear Regression': LinearRegression(),
    # 'Lasso': LassoCV(cv=kf, random_state=42, max_iter=200000),
    # 'Logistic': LogisticRegression(),
    # 'KNN': pd.read_pickle("result_KNN.pkl")['estimator'],
    'XGB': set_randomstate(pd.read_pickle("result_XGB.pkl")['estimator']),
    'LGBM': set_randomstate(pd.read_pickle("result_LGBM.pkl")['estimator']),
    # 'Ridge': RidgeCV(cv=kf),
    # 'SVR': pd.read_pickle("result_SVR.pkl")['estimator'],
    # 'Random Forest': RandomForestRegressor(bootstrap=False, max_depth=15, max_features=0.7,
    #                   min_samples_leaf=9, n_estimators=200, random_state=101),
    # 'Gradient Boosting': GradientBoostingRegressor(learning_rate=0.01, max_depth=14, min_samples_leaf=3,
    #                       min_samples_split=4, n_estimators=950, random_state=101, subsample=0.8),
    # 'Artificial Neural Network': MLPRegressor(activation='logistic', alpha=0.01, hidden_layer_sizes=(50, 50),
    #          max_iter=4000, random_state=101),
    # 'Gaussian Process Regression': GaussianProcessRegressor(0.1 ** 2 * RBF(length_scale=0.1) + WhiteKernel(noise_level=0.1 ** 2, noise_level_bounds=(1e-5, 1e5)))
}

# %%
# Function to train and evaluate models
def evaluate_models(models, X_train, y_train):
    results = {}
    for name, model in models.items():
        scoring=['neg_mean_absolute_error','neg_mean_squared_error']
        # Define the cross-validation strategy (e.g., 5-fold cross-validation)
        kf = KFold(n_splits=5, shuffle=True, random_state=101)

        # Perform k-fold cross-validation and calculate MSE and MAE
        scores = cross_validate(model, X_train, y_train, cv=kf, scoring=scoring, n_jobs=-1)

        mean_mae = -scores['test_neg_mean_absolute_error'].mean()
        mean_mse = -scores['test_neg_mean_squared_error'].mean()
        std_mse = scores['test_neg_mean_squared_error'].std()

        print(name + " done")
        print(mean_mae, mean_mse, std_mse)
        results[name] = {'MAE': mean_mae, 'MSE': mean_mse, 'MSE_std': std_mse}
    
    return results

# Train and evaluate
results = evaluate_models(models, X_t, y_t)

# %%
def model_lr_evaluation(models, X_train, y_train, X_test, y_test):
    results = {}
    scoring=['neg_mean_absolute_error','neg_mean_squared_error']

    for name, model in models.items():
        final_model = model
        
        scores = cross_validate(model, X_train, y_train, cv=3, scoring=scoring, n_jobs=-1)
        mean_mae = -scores['test_neg_mean_absolute_error'].mean()
        mean_mse = -scores['test_neg_mean_squared_error'].mean()
        std_mse = scores['test_neg_mean_squared_error'].std()
        print(name + " done")
        print(mean_mae, mean_mse, std_mse)
        
        final_model.fit(X_train, y_train)
        y_te_pred = final_model.predict(X_test)
        print(mean_absolute_error(y_test, y_te_pred), mean_squared_error(y_test, y_te_pred))
        
        print("---------------")
        
        onehot = OneHotEncoder()
        if name == 'LGBM':
            X_t_leaves = onehot.fit_transform(final_model.predict(X_train, pred_leaf=True))
        elif name == 'XGB':
            X_t_leaves = onehot.fit_transform(final_model.apply(X_train))
        xgb_lr = LogisticRegression()
        xgb_lr.fit(X_t_leaves, y_train)

        if name == 'LGBM':
            X_t_leaves = onehot.transform(final_model.predict(X_train, pred_leaf=True))
            X_te_leaves = onehot.transform(final_model.predict(X_test, pred_leaf=True))
        elif name == 'XGB':
            X_t_leaves = onehot.transform(final_model.apply(X_train))
            X_te_leaves = onehot.transform(final_model.apply(X_test))

        scores = cross_validate(model, X_t_leaves, y_train, cv=kf, scoring=scoring, n_jobs=-1)
        mean_mae = -scores['test_neg_mean_absolute_error'].mean()
        mean_mse = -scores['test_neg_mean_squared_error'].mean()
        std_mse = scores['test_neg_mean_squared_error'].std()
        print(mean_mae, mean_mse, std_mse) 
        
        y_te_pred_xgb_lr = xgb_lr.predict(X_te_leaves)
        print(mean_absolute_error(y_test, y_te_pred_xgb_lr), mean_squared_error(y_test, y_te_pred_xgb_lr))

model_lr_evaluation(models, X_t, y_t, X_te, y_te)

# %%
def evaluate_models_with_test(model, X_train, y_train, X_test, y_test):
    results = {}
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)      
    results = {'MAE': mae, 'MSE': mse}
    
    return results

# %%
import pickle

result_final_with_test = {}
for name, model in models.items():
    result_final_with_test[name] = evaluate_models_with_test(model, X_t, y_t, X_te, y_te)

result_final_with_test

# %%
train_data_0 = train_data[train_data['clusters']==0]
train_data_1 = train_data[train_data['clusters']==1]
validate_data_0 = validate_data[validate_data['clusters']==0]
validate_data_1 = validate_data[validate_data['clusters']==1]
test_data_0 = test_data[test_data['clusters']==0]
test_data_1 = test_data[test_data['clusters']==1]
test_data_2 = test_data[test_data['clusters']==2]
test_data_1 = pd.concat([test_data_1, test_data_2], ignore_index=True)

import matplotlib.pyplot as plt

# Assuming you have three DataFrames: df1, df2, and df3

# Plotting DataFrame 1 in red
plt.plot(train_data_0['start_node_x'], train_data_0['start_node_y'], 'ro-', label='DF1 Start')
plt.plot(train_data_0['end_node_x'], train_data_0['end_node_y'], 'ro-', label='DF1 End')

# Plotting DataFrame 2 in green
plt.plot(train_data_1['start_node_x'], train_data_1['start_node_y'], 'go-', label='DF2 Start')
plt.plot(train_data_1['end_node_x'], train_data_1['end_node_y'], 'go-', label='DF2 End')

# Plotting DataFrame 3 in blue
plt.plot(validate_data_0['start_node_x'], validate_data_0['start_node_y'], 'bo-', label='DF3 Start')
plt.plot(validate_data_0['end_node_x'], validate_data_0['end_node_y'], 'bo-', label='DF3 End')
plt.plot(validate_data_1['start_node_x'], validate_data_1['start_node_y'], 'yo-', label='DF4 Start')
plt.plot(validate_data_1['end_node_x'], validate_data_1['end_node_y'], 'yo-', label='DF4 End')

plt.plot(test_data_0['start_node_x'], test_data_0['start_node_y'], 'co-', label='DF5 Start')
plt.plot(test_data_0['end_node_x'], test_data_0['end_node_y'], 'co-', label='DF5 End')
plt.plot(test_data_1['start_node_x'], test_data_1['start_node_y'], 'mo-', label='DF6 Start')
plt.plot(test_data_1['end_node_x'], test_data_1['end_node_y'], 'mo-', label='DF6 End')
# plt.plot(test_data_2['start_node_x'], test_data_2['start_node_y'], 'ko-', label='DF7 Start')
# plt.plot(test_data_2['end_node_x'], test_data_2['end_node_y'], 'ko-', label='DF7 End')
# Add labels and legend
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()

# Show the plot
plt.show()
