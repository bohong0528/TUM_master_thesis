# %%
import xml.etree.ElementTree as ET
import pandas as pd
# Load and parse the XML file
tree = ET.parse(f'Scenarios/cutoutWorlds/po-1_pn-1.0_sn-1/plans.xml')
root = tree.getroot()
activities_data = []
# Iterate through each person in the XML
for person in root.findall('.//person'):
    person_id, zone, income, score = None, None, None, None
    person_id = person.get('id')   
    first_attr = person.find('attributes')
    for attr in first_attr.findall('.//attribute'):
        name = attr.get('name')
        if name == 'home-activity-zone':
            zone = attr.text
        elif name == 'income':
            income = float(attr.text)

    plan = person.find('plan')
    score = float(plan.get('score'))

    # Collect each activity's data for the person
    
    for activity in person.findall('.//activity'):
        activity_data = {}
        activity_type = activity.get('type')
        link = activity.get('link')
        try:
            end_time = pd.to_timedelta(activity.get('end_time'))
        except:
            end_time = -1
        try:
            max_dur = pd.to_timedelta(activity.get('max_dur')).total_seconds()
        except:
            max_dur = -1   
            
        if '_' in activity_type:
            activity_type_main, activity_type_value = activity_type.split('_')
        else:
            activity_type_main, activity_type_value = activity_type, 0    
        # Create a dictionary for each activity of type "other"
        activity_data['person_id'] = person_id
        activity_data['home-activity-zone'] = zone
        activity_data['income'] = income
        activity_data['score'] = score
        activity_data['activity_type_main'] = activity_type_main
        activity_data['activity_type_value'] = float(activity_type_value)
        activity_data['link'] = link
        activity_data['x'] = float(activity.get('x')) 
        activity_data['y'] = float(activity.get('y')) 
        activity_data['max_dur'] = max_dur
        activity_data['end_time'] = end_time

        for attr in activity.findall('.//attribute'):
            name = attr.get('name')
            value = attr.text
            activity_data[name] = value 
            
        # Add the activity data to the list
        activities_data.append(activity_data)
# Convert the list of data into a pandas DataFrame
df_activities = pd.DataFrame(activities_data)
df_activities.fillna(-1, inplace=True)
df_activities.to_pickle(f"Data/cutoutWorlds/Train/po-1_pn-1.0_sn-1/df_activities.pkl")
# Out:
# C:\Users\LinBoH\AppData\Local\Temp\ipykernel_11612\1462091628.py:63: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-1' has dtype incompatible with timedelta64[ns], please explicitly cast to a compatible dtype first.
#   df_activities.fillna(-1, inplace=True)

# %%
df_activities.head(50)
# Out:
#     person_id home-activity-zone  income       score activity_type_main  \
# 0   100012001        brandenburg  2070.0  129.113038               home
# 1   100012001        brandenburg  2070.0  129.113038              other
# 2   100012001        brandenburg  2070.0  129.113038               home
# 3   100012001        brandenburg  2070.0  129.113038   ride interaction
# 4   100012001        brandenburg  2070.0  129.113038   ride interaction
# 5   100012001        brandenburg  2070.0  129.113038              other
# 6   100012001        brandenburg  2070.0  129.113038   ride interaction
# 7   100012001        brandenburg  2070.0  129.113038   ride interaction
# 8   100012001        brandenburg  2070.0  129.113038               home
# 9    10001401        brandenburg  2332.0   84.912316               home
# 10   10001401        brandenburg  2332.0   84.912316    car interaction
# 11   10001401        brandenburg  2332.0   84.912316    car interaction
# 12   10001401        brandenburg  2332.0   84.912316           shopping
# 13   10001401        brandenburg  2332.0   84.912316    car interaction
# 14   10001401        brandenburg  2332.0   84.912316    car interaction
# 15   10001401        brandenburg  2332.0   84.912316            leisure
# 16   10001401        brandenburg  2332.0   84.912316    car interaction
# 17   10001401        brandenburg  2332.0   84.912316    car interaction
# 18   10001401        brandenburg  2332.0   84.912316               home
# 19   10001401        brandenburg  2332.0   84.912316    car interaction
# 20   10001401        brandenburg  2332.0   84.912316    car interaction
# 21   10001401        brandenburg  2332.0   84.912316              other
# 22   10001401        brandenburg  2332.0   84.912316    car interaction
# 23   10001401        brandenburg  2332.0   84.912316    car interaction
# 24   10001401        brandenburg  2332.0   84.912316            leisure
# 25   10001401        brandenburg  2332.0   84.912316    car interaction
# 26   10001401        brandenburg  2332.0   84.912316    car interaction
# 27   10001401        brandenburg  2332.0   84.912316            leisure
# 28   10001401        brandenburg  2332.0   84.912316    car interaction
# 29   10001401        brandenburg  2332.0   84.912316    car interaction
# 30   10001401        brandenburg  2332.0   84.912316            leisure
# 31   10001401        brandenburg  2332.0   84.912316    car interaction
# 32   10001401        brandenburg  2332.0   84.912316    car interaction
# 33   10001401        brandenburg  2332.0   84.912316               home
# 34  100041201        brandenburg  1399.0  129.908845               home
# 35  100041201        brandenburg  1399.0  129.908845              other
# 36  100041201        brandenburg  1399.0  129.908845               home
# 37  100041201        brandenburg  1399.0  129.908845           shopping
# 38  100041201        brandenburg  1399.0  129.908845               home
# 39  100048001        brandenburg  2659.0  135.323815               home
# 40  100048001        brandenburg  2659.0  135.323815   ride interaction
# 41  100048001        brandenburg  2659.0  135.323815   ride interaction
# 42  100048001        brandenburg  2659.0  135.323815              other
# 43  100048001        brandenburg  2659.0  135.323815   ride interaction
# 44  100048001        brandenburg  2659.0  135.323815   ride interaction
# 45  100048001        brandenburg  2659.0  135.323815               home
# 46  100048001        brandenburg  2659.0  135.323815              other
# 47  100048001        brandenburg  2659.0  135.323815               home
# 48  100117301        brandenburg   826.0   40.506687               home
# 49  100117301        brandenburg   826.0   40.506687    car interaction
#
#     activity_type_value    link             x             y  max_dur  \
# 0               58800.0   12466  4.628514e+06  5.831327e+06     -1.0
# 1                 600.0  106959  4.629522e+06  5.830838e+06    540.0
# 2               33000.0   12466  4.628514e+06  5.831327e+06     -1.0
# 3                   0.0   12466  4.628134e+06  5.831123e+06      0.0
# 4                   0.0   78465  4.625223e+06  5.837994e+06      0.0
# 5                1200.0   78465  4.625290e+06  5.837462e+06    960.0
# 6                   0.0   78465  4.625223e+06  5.837994e+06      0.0
# 7                   0.0   12466  4.628134e+06  5.831123e+06      0.0
# 8               58800.0   12466  4.628514e+06  5.831327e+06     -1.0
# 9               69600.0  110771  4.602137e+06  5.706357e+06     -1.0
# 10                  0.0  110771  4.602056e+06  5.706077e+06      0.0
# 8                -1  12064472                30240
# 9   0 days 10:58:00  12062410                   -1
# 10               -1        -1                   -1
# 11               -1        -1                   -1
# 12               -1  12062124                 4080
# 13               -1        -1                   -1
# 14               -1        -1                   -1
# 15               -1  12066064                 4680
# 16               -1        -1                   -1
# 17               -1        -1                   -1
# 18               -1  12062410                 2700
# 19               -1        -1                   -1
# 20               -1        -1                   -1
# 21               -1  12062219                 1620
# 22               -1        -1                   -1
# 23               -1        -1                   -1
# 24               -1  12062240                 1260
# 25               -1        -1                   -1
# 26               -1        -1                   -1
# 27               -1  12062240                 1380
# 28               -1        -1                   -1
# 29               -1        -1                   -1
# 30               -1  12062240                  360
# 31               -1        -1                   -1
# 32               -1        -1                   -1
# 33               -1  12062410                30120
# 34  0 days 08:04:00  12064472                   -1
# 35               -1  12064472                 4500
# 36  0 days 14:39:00  12064472                18780
# 37               -1  12064472                 1020
# 38               -1  12064472                41700
# 39  0 days 08:44:00  12064472                   -1
# 40               -1        -1                   -1
# 41               -1        -1                   -1
# 42               -1  12064472                  180
# 43               -1        -1                   -1
# 44               -1        -1                   -1
# 45  0 days 13:45:00  12064472                15960
# 46               -1  12064472                 1980
# 47               -1  12064472                43260
# 48  0 days 02:58:40  12064472                   -1
# 49               -1        -1                   -1

# %% [markdown]
# ## unused code

# %%
for i in range(0, 10):
    # Load and parse the XML file
    tree = ET.parse(f'Scenarios/sparseWorlds/po-1_s-{i}/network.xml')
    root = tree.getroot()

    # Prepare a list to collect the activity data
    links_data = []
    nodes_data = []
    # Iterate through each person in the XML
    for nodes in root.findall('nodes'): 
        for node in nodes.findall('.//node'):
            node_id = node.get('id')
            node_data = {
                    'node_id': node_id,
                    'x': float(node.get('x')),  # Convert to float
                    'y': float(node.get('y'))   # Convert to float
            }
            nodes_data.append(node_data)
    df_nodes = pd.DataFrame(nodes_data)

    for links in root.findall('links'): 
        for link in links.findall('.//link'):
            link_id = link.get('id')
            link_data = {
                    'link_id': link_id,
                    'from': link.get('from'),  # Convert to float
                    'to': link.get('to'),
                    'length': float(link.get('length')),
                    'freespeed': float(link.get('freespeed')),
                    'capacity': float(link.get('capacity')),
                    'permlanes': float(link.get('permlanes'))
            }
            for attr in link.findall('.//attribute'):
                name = attr.get('name')
                value = attr.text
                link_data[name] = value
            links_data.append(link_data)
    df_links = pd.DataFrame(links_data)
    df_links = df_links.merge(df_nodes, how='left', left_on='from', right_on='node_id')
    df_links = df_links.rename(columns={'x': 'start_node_x', 'y': 'start_node_y'})
    df_links.drop('node_id', axis=1, inplace=True)
    df_links = df_links.merge(df_nodes, how='left', left_on='to', right_on='node_id')
    df_links = df_links.rename(columns={'x': 'end_node_x', 'y': 'end_node_y'})
    df_links.drop('node_id', axis=1, inplace=True)
    df_links.to_pickle(f"Data/sparseWorlds/Train/po-1/df_links_network_{i}.pkl")

# %%
new = df_activities.merge(df_links, how='left', left_on='link', right_on='link_id')
new.drop(['length','freespeed','capacity','permlanes'], axis=1, inplace=True)
new

# %%
import json
file = 'Data/cutoutWorlds/Train/po-1_pn-1.0_sn-1/s-0.json'
with open(file, 'r') as f:
            data = json.load(f)
df_work = pd.DataFrame({
    'work_x': data['work_x'],
    'work_y': data['work_y'],
    'go_to_work': data['go_to_work']
})
df_home = pd.DataFrame({
    'home_x': data['home_x'],
    'home_y': data['home_y'],
    'go_to_home': data['go_to_home']
})

df_links_dataset = pd.DataFrame({
                'link_id': data['links_id'],
                'link_from': data['link_from'],
                'link_to': data['link_to'],
                'link_length': data['link_length']
            })
df_nodes_dataset = pd.DataFrame({
                'node_id': data['nodes_id'],
                'node_x': data['nodes_x'],
                'node_y': data['nodes_y']
            })
df_links_dataset = df_links_dataset.merge(df_nodes_dataset, how='left', left_on='link_from', right_on='node_id')
df_links_dataset = df_links_dataset.rename(columns={'node_x': 'start_node_x', 'node_y': 'start_node_y'})
df_links_dataset.drop('node_id', axis=1, inplace=True)
df_links_dataset = df_links_dataset.merge(df_nodes_dataset, how='left', left_on='link_to', right_on='node_id')
df_links_dataset = df_links_dataset.rename(columns={'node_x': 'end_node_x', 'node_y': 'end_node_y'})
df_links_dataset.drop('node_id', axis=1, inplace=True)

# %%
df_act_work = df_activities[df_activities['activity_type_main']=='work']
df_act_work = df_act_work.merge(df_work, how='left', left_on=['x','y'], right_on=['work_x','work_y'])
df_act_work.drop(['x','y'], axis=1, inplace=True)
df_act_work_agg = df_act_work.groupby(by="link").sum()['go_to_work'].reset_index(drop=False)
df_act_home = df_activities[df_activities['activity_type_main']=='home']
df_act_home = df_act_home.merge(df_home, how='left', left_on=['x','y'], right_on=['home_x','home_y'])
df_act_home.drop(['x','y'], axis=1, inplace=True)
df_act_home_agg = df_act_home.groupby(by="link").sum()['go_to_home'].reset_index(drop=False)
df_act_agg = df_act_home_agg.merge(df_act_work_agg, how='outer', on='link')
df_act_agg.fillna(0, inplace=True)
df_act_agg['go_to_sum'] = df_act_agg['go_to_home'] + df_act_agg['go_to_work']

# %%
mg = df_links_dataset.merge(df_links, how='left', on=['start_node_x','start_node_y','end_node_x','end_node_y'])
mg = mg[['link_id_x','link_from','link_to','link_id_y','from', 'to']]
mg = mg.rename(columns={'link_id_x': 'link_id_dataset', 'link_id_y': 'link_id_network', 'link_from': 'node_from_dataset', 'from': 'node_from_network','link_to': 'node_to_dataset', 'to': 'node_to_network'})

# %%
link_home_work = mg.merge(df_act_agg, how='left', left_on='link_id_network', right_on='link')
link_home_work['go_to_sum'].fillna(0, inplace=True)
link_go_to = link_home_work[['link_id_dataset', 'go_to_sum']]
