# %%
import json
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsRegressor, KNeighborsClassifier
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder, MinMaxScaler, RobustScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso, RidgeCV, LassoCV, LogisticRegression, LogisticRegressionCV
from sklearn.svm import SVR, SVC
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, GradientBoostingClassifier, RandomForestClassifier
from sklearn.neural_network import MLPRegressor, MLPClassifier
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error, make_scorer, max_error, accuracy_score
from sklearn.model_selection import GridSearchCV, cross_val_score, KFold, RandomizedSearchCV, ShuffleSplit, cross_validate, train_test_split
from scipy.stats import expon, reciprocal, uniform
from sklearn.gaussian_process.kernels import RBF, WhiteKernel, DotProduct, ExpSineSquared, RationalQuadratic, ConstantKernel, Matern
from sklearn.feature_selection import RFE, SelectFromModel, RFECV, SelectKBest, chi2, f_regression
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline, Pipeline
from mango import Tuner, scheduler
import xgboost as xgb
from skopt  import BayesSearchCV 
import lightgbm as lgb
from sklearn.cluster import OPTICS, MiniBatchKMeans
from pyGRNN import GRNN
from skopt.space import Categorical, Space, Dimension, Integer
from sklearn.inspection import permutation_importance
from optuna.integration import OptunaSearchCV
import optuna
import matplotlib.pyplot as plt
from loading import load_data

# %%
numerical_features = ['start_node_x', 'start_node_y', 'end_node_x', 'end_node_y', 'link_length', 'link_freespeed', 
                      'link_capacity', 'link_permlanes', 'start_count', 'end_count', 'go_to_sum', 'rush_hour', 
                      'max_dur', 'cemdapStopDuration_s', 'length_per_capacity_ratio', 'speed_capacity_ratio',
                      'length_times_lanes', 'speed_times_capacity', 'length_times', 'capacity_divided_by_lanes',
                      'income', 'score', 'income_avg', 'score_avg'
                     ]
category_feature = ['type', 'home-activity-zone']
scaler = StandardScaler()
le = LabelEncoder()
ohe = OneHotEncoder(sparse_output=False)
ct = ColumnTransformer(
     [("num_preprocess", scaler, numerical_features),
      ("text_preprocess", ohe, category_feature)], remainder='passthrough').set_output(transform="pandas")
clf = {
    'KNN': KNeighborsClassifier(),
#     'XGB': xgb.XGBClassifier(random_state=101),
    'LGBM': lgb.LGBMClassifier(random_state=101, verbose=-1),
    'RF': RandomForestClassifier(random_state=101),
#     'GB': GradientBoostingClassifier(random_state=101),
#     'ANN': MLPClassifier(random_state=101)
}

model_space = {
    'KNN': KNeighborsRegressor(),
    # 'XGB': xgb.XGBRegressor(random_state=101),
    'LGBM': lgb.LGBMRegressor(random_state=101, verbose=-1),
    'RF': RandomForestRegressor(random_state=101),
#     'GB': GradientBoostingRegressor(random_state=101),
    'ANN': MLPRegressor(random_state=101),
    # 'SVR': SVR(),
    'Linear': LinearRegression(),
    'Lasso': LassoCV(random_state=42, max_iter=100000),
    'Ridge': RidgeCV(),
}
# model_space_feature = {
#     'SVR': RandomForestRegressor(random_state=101),
#     'KNN': RandomForestRegressor(random_state=101),
#     'XGB': xgb.XGBRegressor(random_state=101),
#     'LGBM': lgb.LGBMRegressor(random_state=101, verbose=-1),
#     'RF': RandomForestRegressor(random_state=101),
#     'GB': GradientBoostingRegressor(random_state=101),
#     'ANN': RandomForestRegressor(random_state=101),
#     # 'GRNN': RandomForestRegressor(random_state=101)
# }
param_space = {
'Linear': {  
},
'Lasso': {
},
'Ridge': {  
},
# 'SVR': {
#     "C": optuna.distributions.FloatDistribution(1e-5, 1e5, log=True),
#     'gamma': optuna.distributions.CategoricalDistribution(['scale', 'auto']), 
#     'kernel': optuna.distributions.CategoricalDistribution(['linear', 'poly', 'rbf', 'sigmoid']),  
#     # 'epsilon': optuna.distributions.FloatDistribution(0.01, 1),  
# },
'RF':  {
    'max_features': optuna.distributions.CategoricalDistribution(['sqrt', 'log2']),
    'n_estimators': optuna.distributions.IntDistribution(50, 3001, 50),
    'max_depth': optuna.distributions.IntDistribution(1, 200),
    'min_samples_leaf': optuna.distributions.IntDistribution(1, 20),
    # 'criterion': Categorical(['absolute_error', 'friedman_mse'])
},
# 'GB':{
#     'learning_rate': optuna.distributions.FloatDistribution(0.01, 1.0),
#     'n_estimators': optuna.distributions.IntDistribution(50, 3001, 50),
#     'max_depth': optuna.distributions.IntDistribution(1, 200),
#     'min_samples_split': optuna.distributions.IntDistribution(2, 11),
#     'min_samples_leaf': optuna.distributions.IntDistribution(1, 10),
#     'subsample': optuna.distributions.FloatDistribution(0.1, 1.0),
# },
'ANN': {
    'hidden_layer_sizes': optuna.distributions.CategoricalDistribution([(100,), (50,), (50, 50), (100, 100), (30, 30, 30)]),
    'activation': optuna.distributions.CategoricalDistribution(['tanh', 'relu', 'logistic']),
    'solver': optuna.distributions.CategoricalDistribution(['adam', 'lbfgs']),
    'alpha': optuna.distributions.FloatDistribution(1e-5, 1e5, log=True),
},
'KNN':{
    'n_neighbors': optuna.distributions.IntDistribution(1, 50),
    'weights': optuna.distributions.CategoricalDistribution(['uniform', 'distance']),
    'algorithm': optuna.distributions.CategoricalDistribution(['auto', 'ball_tree', 'kd_tree', 'brute'])
},    
'LGBM': {
    'learning_rate': optuna.distributions.FloatDistribution(0.01, 1.0),
    'n_estimators': optuna.distributions.IntDistribution(50, 3001, 50),
    'max_depth': optuna.distributions.IntDistribution(1, 50),
    'num_leaves': optuna.distributions.IntDistribution(2, 50),
    'min_child_samples': optuna.distributions.IntDistribution(1, 20),
    'subsample': optuna.distributions.FloatDistribution(0.1, 1.0),
    'colsample_bytree': optuna.distributions.FloatDistribution(0.1, 1.0),
},
# 'XGB': {
#     'learning_rate': optuna.distributions.FloatDistribution(0.01, 1.0),
#     'n_estimators': optuna.distributions.IntDistribution(50, 3001, 50),
#     'max_depth': optuna.distributions.IntDistribution(1, 20),
#     'max_leaves': optuna.distributions.IntDistribution(2, 50),
#     'max_bin': optuna.distributions.IntDistribution(2, 50),
#     'gamma': optuna.distributions.IntDistribution(1, 20),
# },
# 'GRNN':{
#     'sigma' : np.arange(0.1, 4, 0.01)
# }
}

# %% [markdown]
# ## Load data

# %%
train_files = ['s-0.json', 's-1.json', 's-2.json', 's-3.json', 's-4.json','s-5.json', 's-6.json', 's-7.json', 's-8.json', 's-9.json'] 
test_files = ['s-15.json', 's-16.json', 's-17.json', 's-18.json','s-19.json']
validate_files = ['s-10.json', 's-11.json', 's-12.json', 's-13.json','s-14.json']
train_files = ['Data/cutoutWorlds/Train/po-1_pn-1.0_sn-1/' + i for i in train_files]
test_files = ['Data/cutoutWorlds/Test/po-1_pn-1.0_sn-1/' + j for j in test_files]
validate_files = ['Data/cutoutWorlds/Validate/po-1_pn-1.0_sn-1/' + k for k in validate_files]
df_activities = pd.read_pickle("Data/cutoutWorlds/Train/po-1_pn-1.0_sn-1/df_activities.pkl")
df_links_network = pd.read_pickle("Data/cutoutWorlds/Train/po-1_pn-1.0_sn-1/df_links_network.pkl")
train_data = load_data(train_files, df_activities, df_links_network)
validate_data = load_data(validate_files, df_activities, df_links_network)
test_data = load_data(test_files, df_activities, df_links_network)
train_data['dataset'] = 'train'
validate_data['dataset'] = 'validate'
test_data['dataset'] = 'test'
Big_data = pd.concat([train_data, validate_data, test_data], ignore_index=True)

# %% [markdown]
# ## Create feature from shortest path

# %%
# Find the indices where 'link_id' is 0
indices = Big_data.index[Big_data['link_id'] == 0].tolist()

# Add the end of the DataFrame to the indices list
indices.append(len(Big_data))

# Split the DataFrame using the indices
dfs = [Big_data.iloc[indices[n]:indices[n+1]] for n in range(len(indices)-1)]
list_od = []
list_nodes = []
all_files = train_files + validate_files + test_files
for i in all_files:
    with open(i) as f:
        d = json.load(f)
        list_od.append(d['o_d_pairs'])
        list_nodes.append(d['nodes_id'])
tuples_links = [ list(zip(dfs[i]['link_from'], dfs[i]['link_to'], dfs[i]['link_length'])) for i in range(20)]
list_od_tuples = [[(origin, destination) for origin, destination in list_od[i]]for i in range(20)]
import networkx as nx

shortest_paths_list = []
for i in range(20):
    G = nx.Graph()
    G.add_nodes_from(list_nodes[i])
    G.add_weighted_edges_from(tuples_links[i])
    shortest_paths = {}
    for origin, destination in list_od_tuples[i]:
        # This will find the shortest path by weight
        try:
            shortest_path = nx.shortest_path(G, source=origin, target=destination, weight='weight')
        except:
            shortest_path = []
        shortest_paths[(origin, destination)] = shortest_path
    shortest_paths_list.append(shortest_paths)
from collections import defaultdict
for i in range(20):
    link_usage_counts = defaultdict(int)

    # Iterate over each path and each link in the path
    for path in shortest_paths_list[i].values():
        for start_node, end_node in zip(path, path[1:]):
            # Order the nodes to avoid counting (node1, node2) and (node2, node1) separately
            ordered_link = tuple(sorted((start_node, end_node)))
            link_usage_counts[ordered_link] += 1

    # Now you have a dictionary with the count of usage for each link

    # Assume you have a DataFrame 'links_df' with columns ['node_start', 'node_end']
    # links_df = ...

    # Add a 'used_count' column to your links data
    dfs[i]['used_count'] = dfs[i].apply(
        lambda row: link_usage_counts[tuple(sorted((row['link_from'], row['link_to'])))],
        axis=1
    )
Big_data_new = pd.concat(dfs)

# %% [markdown]
# ## Create feature from clustering

# %%
cluster = MiniBatchKMeans(n_clusters=500, random_state=101)
Big_data_new['x_y_coor'] = cluster.fit_predict(Big_data_new[['start_node_x', 'start_node_y',
                                                           'end_node_x', 'end_node_y']])
cluster1 = MiniBatchKMeans(n_clusters=500, random_state=101)
Big_data_new['similar_link'] = cluster1.fit_predict(Big_data_new[['link_length', 'link_freespeed',
                                                           'link_capacity', 'link_permlanes']])
cluster2 = MiniBatchKMeans(n_clusters=500, random_state=101)
Big_data_new['planxml'] = cluster2.fit_predict(Big_data_new[['income', 'score', 'rush_hour',
                                                               'max_dur', 'cemdapStopDuration_s']])

Big_data_new = Big_data_new.astype({'x_y_coor':'int64','similar_link':'int64', 'planxml':'int64'})

# %% [markdown]
# ## Dataset numerification and standardization

# %%
Big_data_tr = ct.fit_transform(Big_data_new)
Big_data_tr['used_link'] = 1
Big_data_tr['used_link'][Big_data_tr['remainder__link_counts']==0] = 0
Big_data_tr = Big_data_tr.reset_index(drop=True)
train_data_tr = Big_data_tr[Big_data_tr['remainder__dataset']=='train']
validate_data_tr = Big_data_tr[Big_data_tr['remainder__dataset']=='validate']
test_data_tr = Big_data_tr[Big_data_tr['remainder__dataset']=='test']

train_index = list(train_data_tr.index)
validate_index = list(validate_data_tr.index)

temp = pd.concat([train_data_tr, validate_data_tr], ignore_index=True)

# %% [markdown]
# # Classification and regression

# %%
X_t_clf = temp.drop(columns=['remainder__dataset', 'remainder__link_counts', 'used_link'])
y_t_clf = temp['used_link']

X_te_clf = test_data_tr.drop(columns=['remainder__dataset', 'remainder__link_counts', 'used_link'])
y_te_clf = test_data_tr['used_link']

# %%
best_model_clf = {}
for model_name in clf.keys():   
    model = clf[model_name]
    pipeline  = Pipeline([('selector', SelectKBest(f_regression)),
                  ('model', model)])
    param_grid = {}
    param_grid['selector__k']=optuna.distributions.IntDistribution(2, len(X_t_clf.columns))
    for key in param_space[model_name].keys():
        param_grid[f'model__{key}']=param_space[model_name][key]
    
    # BayesSearchCV
    opt = OptunaSearchCV(
        pipeline,
        param_grid,
        n_trials=50,
        cv=[(train_index, validate_index), (train_index, validate_index)],
        random_state=101
    )
    opt.fit(X_t_clf, y_t_clf)
    y_pred_clf = opt.predict(X_te_clf)
    best_model_clf[model_name] = [opt, opt.best_score_, y_pred_clf, accuracy_score(y_te_clf, y_pred_clf)]
# Out:
# [I 2024-05-25 00:16:50,674] A new study created in memory with name: no-name-d6cb1e6d-8816-444d-8d21-212b45d1f5ab
# [I 2024-05-25 00:16:52,222] Trial 0 finished with value: 0.8529845246868092 and parameters: {'selector__k': 41, 'model__n_neighbors': 24, 'model__weights': 'uniform', 'model__algorithm': 'brute'}. Best is trial 0 with value: 0
 'model__weights': 'distance', 'model__algorithm': 'brute'}. Best is trial 35 with value: 0.9194301154507492.
# [I 2024-05-25 00:18:28,050] A new study created in memory with name: no-name-bc15ad2e-4e4f-496b-b426-699a38b1d2bc
# [I 2024-05-25 00:18:35,913] Trial 0 finished with value: 0.8531073446327684 and parameters: {'selector__k': 41, 'model__learning_rate': 0.47709375017765787, 'model__n_estimators': 2087, 'model__max_depth': 46, 'model__num_leaves': 24, 'model__min_child_samples': 4, 'model__subsample': 0.6970838440204888, 'model__colsample_bytree': 0.728018307398864}. Best is trial 0 with value: 0.8531073446327684.
# [I 2024-05-25 00:18:38,333] Trial 1 finished with value: 0.8177352001965119 and parameters: {'selector__k': 15, 'model__learning_rate': 0.7139779752177985, 'model__n_estimators': 748, 'model__max_depth': 36, 'model__num_leaves': 43, 'model__min_child_samples': 16, 'model__subsample': 0.6455620801605072, 'model__colsample_bytree': 0.5881762889751062}. Best is trial 0 with value: 0.8531073446327684.
# [I 2024-05-25 00:18:39,894] Trial 2 finished with value: 0.9073937607467453 and parameters: {'selector__k': 22, 'model__learning_rate': 0.09163704259521264, 'model__n_estimators': 625, 'model__max_depth': 9, 'model__num_leaves': 4, 'model__min_child_samples': 5, 'model__subsample': 0.6575390682226948, 'model__colsample_bytree': 0.2713416677416557}. Best is trial 2 with value: 0.9073937607467453.
# [I 2024-05-25 00:18:45,132] Trial 3 finished with value: 0.8410709899287644 and parameters: {'selector__k': 26, 'model__learning_rate': 0.8814838783846549, 'model__n_estimators': 2156, 'model__max_depth': 3, 'model__num_leaves': 24, 'model__min_child_samples': 8, 'model__subsample': 0.6024851063126109, 'model__colsample_bytree': 0.9875539806439302}. Best is trial 2 with value: 0.9073937607467453.
# [I 2024-05-25 00:18:47,197] Trial 4 finished with value: 0.8667403586342421 and parameters: {'selector__k': 18, 'model__learning_rate': 0.24705746508656587, 'model__n_estimators': 255, 'model__max_depth': 15, 'model__num_leaves': 37, 'model__min_child_samples': 3, 'model__subsample': 0.18150730090436135, 'model__colsample_bytree': 0.7986574492511642}. Best is trial 2 with value: 0.9073937607467453.
# [I 2024-05-25 00:18:51,017] Trial 5 finished with value: 0.5127732743797593 and parameters: {'selector__k': 36, 'model__learning_rate': 0.7348343646077565, 'model__n_estimators': 883, 'model__max_depth': 45, 'model__num_leaves': 27, 'model__min_child_samples': 2, 'model__subsample': 0.26105168401625667, 'model__colsample_bytree': 0.5812856748843152}. Best is trial 2 with value: 0.9073937607467453.
# [I 2024-05-25 00:18:55,450] Trial 6 finished with value: 0.9175878162613609 and parameters: {'selector__k': 39, 'model__learning_rate': 0.16714039138018438, 'model__n_estimators': 855, 'model__max_depth': 28, 'model__num_leaves': 15, 'model__min_child_samples': 1, 'model__subsample': 0.3801380721849661, 'model__colsample_bytree': 0.48664110585160403}. Best is trial 6 with value: 0.9175878162613609.
# [I 2024-05-25 00:18:57,940] Trial 7 finished with value: 0.8470891672807664 and parameters: {'selector__k': 18, 'model__learning_rate': 0.8814075521649741, 'model__n_estimators': 643, 'model__max_depth': 31, 'model__num_leaves': 13, 'model__min_child_samples': 8, 'model__subsample': 0.8950578430196747, 'model__colsample_bytree': 0.3843555466196359}. Best is trial 6 with value: 0.9175878162613609.
# [I 2024-05-25 00:19:00,860] Trial 8 finished with value: 0.9038319823139278 and parameters: {'selector__k': 2, 'model__learning_rate': 0.7804422164429433, 'model__n_estimators': 800, 'model__max_depth': 7, 'model__num_leaves': 25, 'model__min_child_samples': 3, 'model__subsample': 0.9976135241390007, 'model__colsample_bytree': 0.9870497120577045}. Best is trial 6 with value: 0.9175878162613609.
# [I 2024-05-25 00:19:01,942] Trial 9 finished with value: 0.9116924588553181 and parameters: {'selector__k': 26, 'model__learning_rate': 0.21916290208197312, 'model__n_estimators': 239, 'model__max_depth': 4, 'model__num_leaves': 42, 'model__min_child_samples': 2, 'model__subsample': 0.19279496704249927, 'model__colsample_bytree': 0.1848595052786653}. Best is trial 6 with value: 0.9175878162613609.
# [I 2024-05-25 00:19:02,680] Trial 10 finished with value: 0.8965856055023336 and parameters: {'selector__k': 48, 'model__learning_rate': 0.3945663497453614, 'model__n_estimators': 96, 'model__max_depth': 18, 'model__num_leaves': 11, 'model__min_child_samples': 14, 'model__subsample': 0.3995461000562339, 'model__colsample_bytree': 0.4002698777240022}. Best is trial 6 with value: 0.9175878162613609.
# [I 2024-05-25 00:19:04,462] Trial 11 finished with value: 0.8808646524195529 and parameters: {'selector__k': 30, 'model__learning_rate': 0.017887825100524946, 'model__n_estimators': 156, 'model__max_depth': 24, 'model__num_leaves': 48, 'model__min_child_samples': 1, 'model__subsample': 0.3895513776737737, 'model__colsample_bytree': 0.13280831633232315}. Best is trial 6 with value: 0.9175878162613609.
# [I 2024-05-25 00:19:06,618] Trial 12 finished with value: 0.9228690739376074 and parameters: {'selector__k': 36, 'model__learning_rate': 0.2365935914993954, 'model__n_estimators': 267, 'model__max_depth': 26, 'model__num_leaves': 33, 'model__min_child_samples': 20, 'model__subsample': 0.12579419229740718, 'model__colsample_bytree': 0.148647856243588}. Best is trial 12 with value: 0.9228690739376074.
# [I 2024-05-25 00:19:07,398] Trial 13 finished with value: 0.9126750184229919 and parameters: {'selector__k': 37, 'model__learning_rate': 0.2803122424786013, 'model__n_estimators': 55, 'model__max_depth': 32, 'model__num_leaves': 33, 'model__min_child_samples': 19, 'model__subsample': 0.3686400664450653, 'model__colsample_bytree': 0.40030700862953206}. Best is trial 12 with value: 0.9228690739376074.
# [I 2024-05-25 00:19:09,785] Trial 14 finished with value: 0.919921395234586 and parameters: {'selector__k': 48, 'model__learning_rate': 0.14384265242261413, 'model__n_estimators': 424, 'model__max_depth': 22, 'model__num_leaves': 16, 'model__min_child_samples': 12, 'model__subsample': 0.11461981210736916, 'model__colsample_bytree': 0.2516636308083411}. Best is trial 12 with value: 0.9228690739376074.
# [I 2024-05-25 00:19:12,754] Trial 15 finished with value: 0.923728813559322 and parameters: {'selector__k': 47, 'model__learning_rate': 0.38192629329948835, 'model__n_estimators': 348, 'model__max_depth': 20, 'model__num_leaves': 32, 'model__min_child_samples': 20, 'model__subsample': 0.10416718438568857, 'model__colsample_bytree': 0.2729317948390952}. Best is trial 15 with value: 0.923728813559322.
# [I 2024-05-25 00:19:14,219] Trial 16 finished with value: 0.9146401375583395 and parameters: {'selector__k': 43, 'model__learning_rate': 0.5572451514764426, 'model__n_estimators': 179, 'model__max_depth': 12, 'model__num_leaves': 33, 'model__min_child_samples': 20, 'model__subsample': 0.27997839486134446, 'model__colsample_bytree': 0.11173140477919802}. Best is trial 15 with value: 0.923728813559322.
# [I 2024-05-25 00:19:17,087] Trial 17 finished with value: 0.9216408744780152 and parameters: {'selector__k': 32, 'model__learning_rate': 0.3495125456333611, 'model__n_estimators': 372, 'model__max_depth': 40, 'model__num_leaves': 31, 'model__min_child_samples': 17, 'model__subsample': 0.502331876633455, 'model__colsample_bytree': 0.28432384731460403}. Best is trial 15 with value: 0.923728813559322.
# [I 2024-05-25 00:19:18,434] Trial 18 finished with value: 0.9157455170719725 and parameters: {'selector__k': 44, 'model__learning_rate': 0.5261273972098619, 'model__n_estimators': 108, 'model__max_depth': 20, 'model__num_leaves': 39, 'model__min_child_samples': 17, 'model__subsample': 0.15678601515020207, 'model__colsample_bytree': 0.20226090949344294}. Best is trial 15 with value: 0.923728813559322.
# [I 2024-05-25 00:19:25,698] Trial 19 finished with value: 0.9173421763694424 and parameters: {'selector__k': 35, 'model__learning_rate': 0.40805018052225683, 'model__n_estimators': 1352, 'model__max_depth': 27, 'model__num_leaves': 19, 'model__min_child_samples': 14, 'model__subsample': 0.10021738154262255, 'model__colsample_bytree': 0.3332838950372774}. Best is trial 15 with value: 0.923728813559322.
# [I 2024-05-25 00:19:30,457] Trial 20 finished with value: 0.9247113731269958 and parameters: {'selector__k': 44, 'model__learning_rate': 0.6127940727265423, 'model__n_estimators': 393, 'model__max_depth': 37, 'model__num_leaves': 50, 'model__min_child_samples': 19, 'model__subsample': 0.7635372485434165, 'model__colsample_bytree': 0.4599152136419892}. Best is trial 20 with value: 0.9247113731269958.
# [I 2024-05-25 00:19:34,834] Trial 21 finished with value: 0.91930729550479 and parameters: {'selector__k': 45, 'model__learning_rate': 0.5641625495638023, 'model__n_estimators': 376, 'model__max_depth': 37, 'model__num_leaves': 50, 'model__min_child_samples': 20, 'model__subsample': 0.7774823851938483, 'model__colsample_bytree': 0.47341474559844454}. Best is trial 20 with value: 0.9247113731269958.
# [I 2024-05-25 00:19:37,825] Trial 22 finished with value: 0.9200442151805454 and parameters: {'selector__k': 40, 'model__learning_rate': 0.6370513609099127, 'model__n_estimators': 274, 'model__max_depth': 32, 'model__num_leaves': 45, 'model__min_child_samples': 18, 'model__subsample': 0.7902416844747109, 'model__colsample_bytree': 0.1969114148011481}. Best is trial 20 with value: 0.9247113731269958.
# [I 2024-05-25 00:19:41,543] Trial 23 finished with value: 0.9269221321542619 and parameters: {'selector__k': 32, 'model__learning_rate': 0.3247292430546816, 'model__n_estimators': 461, 'model__max_depth': 41, 'model__num_leaves': 37, 'model__min_child_samples': 15, 'model__subsample': 0.5025118307109273, 'model__colsample_bytree': 0.7002305109222267}. Best is trial 23 with value: 0.9269221321542619.
# [I 2024-05-25 00:19:45,555] Trial 24 finished with value: 0.9269221321542619 and parameters: {'selector__k': 30, 'model__learning_rate': 0.4539814191949393, 'model__n_estimators': 486, 'model__max_depth': 42, 'model__num_leaves': 38, 'model__min_child_samples': 15, 'model__subsample': 0.4894223033305904, 'model__colsample_bytree': 0.6998215362407627}. Best is trial 23 with value: 0.9269221321542619.
# [I 2024-05-25 00:19:56,596] Trial 25 finished with value: 0.9044460820437239 and parameters: {'selector__k': 9, 'model__learning_rate': 0.6440297691728819, 'model__n_estimators': 1299, 'model__max_depth': 42, 'model__num_leaves': 38, 'model__min_child_samples': 15, 'model__subsample': 0.5346162947876504, 'model__colsample_bytree': 0.6851948631370937}. Best is trial 23 with value: 0.9269221321542619.
# [I 2024-05-25 00:20:00,553] Trial 26 finished with value: 0.8465978874969295 and parameters: {'selector__k': 28, 'model__learning_rate': 0.4620082733449711, 'model__n_estimators': 508, 'model__max_depth': 49, 'model__num_leaves': 46, 'model__min_child_samples': 12, 'model__subsample': 0.4685057804598787, 'model__colsample_bytree': 0.8437143506212413}. Best is trial 23 with value: 0.9269221321542619.
# [I 2024-05-25 00:20:05,068] Trial 27 finished with value: 0.9240972733971997 and parameters: {'selector__k': 32, 'model__learning_rate': 0.31095243073722556, 'model__n_estimators': 502, 'model__max_depth': 38, 'model__num_leaves': 41, 'model__min_child_samples': 12, 'model__subsample': 0.7446017191042924, 'model__colsample_bytree': 0.6934848791363316}. Best is trial 23 with value: 0.9269221321542619.
# [I 2024-05-25 00:20:10,295] Trial 28 finished with value: 0.8635470400393024 and parameters: {'selector__k': 23, 'model__learning_rate': 0.6328396239660138, 'model__n_estimators': 1171, 'model__max_depth': 50, 'model__num_leaves': 50, 'model__min_child_samples': 14, 'model__subsample': 0.5579078552005462, 'model__colsample_bytree': 0.6355238894550073}. Best is trial 23 with value: 0.9269221321542619.
# [I 2024-05-25 00:20:12,083] Trial 29 finished with value: 0.8971997052321297 and parameters: {'selector__k': 33, 'model__learning_rate': 0.46332792022210384, 'model__n_estimators': 179, 'model__max_depth': 45, 'model__num_leaves': 36, 'model__min_child_samples': 10, 'model__subsample': 0.8750027216178221, 'model__colsample_bytree': 0.787501891432973}. Best is trial 23 with value: 0.9269221321542619.
# [I 2024-05-25 00:20:23,445] Trial 30 finished with value: 0.9253868828297716 and parameters: {'selector__k': 42, 'model__learning_rate': 0.48904328003471664, 'model__n_estimators': 1666, 'model__max_depth': 42, 'model__num_leaves': 27, 'model__min_child_samples': 18, 'model__subsample': 0.7008039050653756, 'model__colsample_bytree': 0.906136618796832}. Best is trial 23 with value: 0.9269221321542619.
# [I 2024-05-25 00:20:39,605] Trial 31 finished with value: 0.9253868828297716 and parameters: {'selector__k': 41, 'model__learning_rate': 0.4806094880139439, 'model__n_estimators': 1638, 'model__max_depth': 42, 'model__num_leaves': 27, 'model__min_child_samples': 18, 'model__subsample': 0.7069785362811493, 'model__colsample_bytree': 0.8732011993607689}. Best is trial 23 with value: 0.9269221321542619.
# [I 2024-05-25 00:20:49,982] Trial 32 finished with value: 0.7920658314910342 and parameters: {'selector__k': 40, 'model__learning_rate': 0.4706884176664559, 'model__n_estimators': 1780, 'model__max_depth': 43, 'model__num_leaves': 29, 'model__min_child_samples': 17, 'model__subsample': 0.6683930040107715, 'model__colsample_bytree': 0.9102213497267017}. Best is trial 23 with value: 0.9269221321542619.
# [I 2024-05-25 00:21:00,402] Trial 33 finished with value: 0.8470277573077868 and parameters: {'selector__k': 29, 'model__learning_rate': 0.4279564168260751, 'model__n_estimators': 2608, 'model__max_depth': 47, 'model__num_leaves': 19, 'model__min_child_samples': 16, 'model__subsample': 0.6118668782033821, 'model__colsample_bytree': 0.8931934838921252}. Best is trial 23 with value: 0.9269221321542619.
# [I 2024-05-25 00:21:14,044] Trial 34 finished with value: 0.9279661016949152 and parameters: {'selector__k': 42, 'model__learning_rate': 0.5167805651306003, 'model__n_estimators': 1806, 'model__max_depth': 41, 'model__num_leaves': 28, 'model__min_child_samples': 16, 'model__subsample': 0.7087296666380967, 'model__colsample_bytree': 0.7463844331030199}. Best is trial 34 with value: 0.9279661016949152.
# [I 2024-05-25 00:21:24,757] Trial 35 finished with value: 0.9096045197740112 and parameters: {'selector__k': 22, 'model__learning_rate': 0.33385360166621314, 'model__n_estimators': 2471, 'model__max_depth': 34, 'model__num_leaves': 21, 'model__min_child_samples': 15, 'model__subsample': 0.5955644801340773, 'model__colsample_bytree': 0.7541523516629144}. Best is trial 34 with value: 0.9279661016949152.
# [I 2024-05-25 00:21:33,196] Trial 36 finished with value: 0.8378162613608451 and parameters: {'selector__k': 37, 'model__learning_rate': 0.9906244138751095, 'model__n_estimators': 2951, 'model__max_depth': 40, 'model__num_leaves': 36, 'model__min_child_samples': 16, 'model__subsample': 0.4549661494968737, 'model__colsample_bytree': 0.6596147905572683}. Best is trial 34 with value: 0.9279661016949152.
# [I 2024-05-25 00:21:39,511] Trial 37 finished with value: 0.8380619012527635 and parameters: {'selector__k': 34, 'model__learning_rate': 0.7032751243843871, 'model__n_estimators': 1925, 'model__max_depth': 47, 'model__num_leaves': 23, 'model__min_child_samples': 13, 'model__subsample': 0.8352768743607514, 'model__colsample_bytree': 0.6070395201981744}. Best is trial 34 with value: 0.9279661016949152.
# [I 2024-05-25 00:21:41,468] Trial 38 finished with value: 0.9123065585851142 and parameters: {'selector__k': 38, 'model__learning_rate': 0.5268853926061638, 'model__n_estimators': 697, 'model__max_depth': 35, 'model__num_leaves': 4, 'model__min_child_samples': 8, 'model__subsample': 0.6927380548190255, 'model__colsample_bytree': 0.5339568039819085}. Best is trial 34 with value: 0.9279661016949152.
# [I 2024-05-25 00:21:45,954] Trial 39 finished with value: 0.6859493981822647 and parameters: {'selector__k': 18, 'model__learning_rate': 0.5769571109698289, 'model__n_estimators': 1045, 'model__max_depth': 40, 'model__num_leaves': 29, 'model__min_child_samples': 10, 'model__subsample': 0.6333582143333675, 'model__colsample_bytree': 0.7353662438437594}. Best is trial 34 with value: 0.9279661016949152.
# [I 2024-05-25 00:21:49,946] Trial 40 finished with value: 0.8701179071481209 and parameters: {'selector__k': 25, 'model__learning_rate': 0.6922183559258925, 'model__n_estimators': 926, 'model__max_depth': 29, 'model__num_leaves': 35, 'model__min_child_samples': 15, 'model__subsample': 0.5763167896370698, 'model__colsample_bytree': 0.9597177460735723}. Best is trial 34 with value: 0.9279661016949152.
# [I 2024-05-25 00:22:00,378] Trial 41 finished with value: 0.9292557111274871 and parameters: {'selector__k': 42, 'model__learning_rate': 0.4900249388667229, 'model__n_estimators': 1600, 'model__max_depth': 43, 'model__num_leaves': 27, 'model__min_child_samples': 18, 'model__subsample': 0.7304490863981088, 'model__colsample_bytree': 0.8080147871815575}. Best is trial 41 with value: 0.9292557111274871.
# [I 2024-05-25 00:22:11,449] Trial 42 finished with value: 0.9270449521002211 and parameters: {'selector__k': 42, 'model__learning_rate': 0.42947943890217877, 'model__n_estimators': 1543, 'model__max_depth': 43, 'model__num_leaves': 30, 'model__min_child_samples': 18, 'model__subsample': 0.7125382988841787, 'model__colsample_bytree': 0.8061895567962314}. Best is trial 41 with value: 0.9292557111274871.
# [I 2024-05-25 00:22:31,204] Trial 43 finished with value: 0.928641611397691 and parameters: {'selector__k': 46, 'model__learning_rate': 0.3604473512223953, 'model__n_estimators': 2176, 'model__max_depth': 44, 'model__num_leaves': 40, 'model__min_child_samples': 16, 'model__subsample': 0.942673383001543, 'model__colsample_bytree': 0.8209538100893475}. Best is trial 41 with value: 0.9292557111274871.
# [I 2024-05-25 00:22:51,227] Trial 44 finished with value: 0.9299926308032425 and parameters: {'selector__k': 45, 'model__learning_rate': 0.19372433268301079, 'model__n_estimators': 2139, 'model__max_depth': 45, 'model__num_leaves': 40, 'model__min_child_samples': 17, 'model__subsample': 0.9805786626207231, 'model__colsample_bytree': 0.7925646843511155}. Best is trial 44 with value: 0.9299926308032425.
# [I 2024-05-25 00:23:12,161] Trial 45 finished with value: 0.9276590518300172 and parameters: {'selector__k': 46, 'model__learning_rate': 0.07090274897339338, 'model__n_estimators': 2198, 'model__max_depth': 45, 'model__num_leaves': 41, 'model__min_child_samples': 19, 'model__subsample': 0.9744267583596558, 'model__colsample_bytree': 0.8171588167073546}. Best is trial 44 with value: 0.9299926308032425.
# [I 2024-05-25 00:23:39,481] Trial 46 finished with value: 0.926430852370425 and parameters: {'selector__k': 45, 'model__learning_rate': 0.045991518873403026, 'model__n_estimators': 2214, 'model__max_depth': 45, 'model__num_leaves': 43, 'model__min_child_samples': 5, 'model__subsample': 0.9875352919984465, 'model__colsample_bytree': 0.8202817245617368}. Best is trial 44 with value: 0.9299926308032425.
# [I 2024-05-25 00:23:47,407] Trial 47 finished with value: 0.9218865143699336 and parameters: {'selector__k': 48, 'model__learning_rate': 0.15597592355387557, 'model__n_estimators': 2171, 'model__max_depth': 48, 'model__num_leaves': 8, 'model__min_child_samples': 19, 'model__subsample': 0.9394318991297644, 'model__colsample_bytree': 0.7746931793727254}. Best is trial 44 with value: 0.9299926308032425.
# [I 2024-05-25 00:24:15,124] Trial 48 finished with value: 0.9270449521002211 and parameters: {'selector__k': 46, 'model__learning_rate': 0.10780304698141684, 'model__n_estimators': 2875, 'model__max_depth': 45, 'model__num_leaves': 40, 'model__min_child_samples': 17, 'model__subsample': 0.9333538356940008, 'model__colsample_bytree': 0.9476175745284157}. Best is trial 44 with value: 0.9299926308032425.
# [I 2024-05-25 00:24:28,918] Trial 49 finished with value: 0.9279046917219357 and parameters: {'selector__k': 46, 'model__learning_rate': 0.1919709079565322, 'model__n_estimators': 1378, 'model__max_depth': 38, 'model__num_leaves': 46, 'model__min_child_samples': 19, 'model__subsample': 0.8372572495888758, 'model__colsample_bytree': 0.8465378434327}. Best is trial 44 with value: 0.9299926308032425.
# [I 2024-05-25 00:24:38,953] A new study created in memory with name: no-name-8a015399-93b3-498b-b0db-ec8b47dc9201
# [I 2024-05-25 00:28:48,522] Trial 0 finished with value: 0.9125521984770326 and parameters: {'selector__k': 41, 'model__max_features': 'log2', 'model__n_estimators': 2011, 'model__max_depth': 94, 'model__min_samples_leaf': 4}. Best is trial 0 with value: 0.9125521984770326.
# [I 2024-05-25 00:29:57,172] Trial 1 finished with value: 0.908867600098256 and parameters: {'selector__k': 33, 'model__max_features': 'sqrt', 'model__n_estimators': 917, 'model__max_depth': 133, 'model__min_samples_leaf': 15}. Best is trial 0 with value: 0.9125521984770326.
# [I 2024-05-25 00:31:15,824] Trial 2 finished with value: 0.9197985752886269 and parameters: {'selector__k': 41, 'model__max_features': 'sqrt', 'model__n_estimators': 459, 'model__max_depth': 88, 'model__min_samples_leaf': 2}. Best is trial 2 with value: 0.9197985752886269.
# [I 2024-05-25 00:31:29,653] Trial 3 finished with value: 0.9126750184229919 and parameters: {'selector__k': 31, 'model__max_features': 'sqrt', 'model__n_estimators': 131, 'model__max_depth': 124, 'model__min_samples_leaf': 4}. Best is trial 2 with value: 0.9197985752886269.
# [I 2024-05-25 00:31:34,199] Trial 4 finished with value: 0.9083763203144191 and parameters: {'selector__k': 26, 'model__max_features': 'log2', 'model__n_estimators': 60, 'model__max_depth': 92, 'model__min_samples_leaf': 8}. Best is trial 2 with value: 0.9197985752886269.
# [I 2024-05-25 00:31:46,877] Trial 5 finished with value: 0.9093588798820929 and parameters: {'selector__k': 28, 'model__max_features': 'sqrt', 'model__n_estimators': 132, 'model__max_depth': 80, 'model__min_samples_leaf': 6}. Best is trial 2 with value: 0.9197985752886269.
# [I 2024-05-25 00:33:25,223] Trial 6 finished with value: 0.908867600098256 and parameters: {'selector__k': 35, 'model__max_features': 'sqrt', 'model__n_estimators': 1198, 'model__max_depth': 147, 'model__min_samples_leaf': 15}. Best is trial 2 with value: 0.9197985752886269.
# [I 2024-05-25 00:33:30,181] Trial 7 finished with value: 0.9086219602063376 and parameters: {'selector__k': 34, 'model__max_features': 'sqrt', 'model__n_estimators': 62, 'model__max_depth': 36, 'model__min_samples_leaf': 11}. Best is trial 2 with value: 0.9197985752886269.
# [I 2024-05-25 00:34:38,469] Trial 8 finished with value: 0.9279046917219357 and parameters: {'selector__k': 39, 'model__max_features': 'log2', 'model__n_estimators': 473, 'model__max_depth': 56, 'model__min_samples_leaf': 1}. Best is trial 8 with value: 0.9279046917219357.
# [I 2024-05-25 00:35:38,720] Trial 9 finished with value: 0.9040776222058462 and parameters: {'selector__k': 16, 'model__max_features': 'sqrt', 'model__n_estimators': 1836, 'model__max_depth': 125, 'model__min_samples_leaf': 13}. Best is trial 8 with value: 0.9279046917219357.
# [I 2024-05-25 00:35:44,532] Trial 10 finished with value: 0.8995332842053549 and parameters: {'selector__k': 4, 'model__max_features': 'log2', 'model__n_estimators': 380, 'model__max_depth': 183, 'model__min_samples_leaf': 19}. Best is trial 8 with value: 0.9279046917219357.
# [I 2024-05-25 00:36:56,265] Trial 11 finished with value: 0.9287644313436502 and parameters: {'selector__k': 45, 'model__max_features': 'log2', 'model__n_estimators': 501, 'model__max_depth': 28, 'model__min_samples_leaf': 1}. Best is trial 11 with value: 0.9287644313436502.
# [I 2024-05-25 00:37:04,205] Trial 12 finished with value: 0.8298943748464751 and parameters: {'selector__k': 48, 'model__max_features': 'log2', 'model__n_estimators': 410, 'model__max_depth': 1, 'model__min_samples_leaf': 1}. Best is trial 11 with value: 0.9287644313436502.
# [I 2024-05-25 00:38:39,635] Trial 13 finished with value: 0.9116924588553181 and parameters: {'selector__k': 48, 'model__max_features': 'log2', 'model__n_estimators': 624, 'model__max_depth': 44, 'model__min_samples_leaf': 7}. Best is trial 11 with value: 0.9287644313436502.
# [I 2024-05-25 00:38:50,046] Trial 14 finished with value: 0.9114468189633996 and parameters: {'selector__k': 18, 'model__max_features': 'log2', 'model__n_estimators': 235, 'model__max_depth': 44, 'model__min_samples_leaf': 1}. Best is trial 11 with value: 0.9287644313436502.
# [I 2024-05-25 00:38:55,303] Trial 15 finished with value: 0.8298943748464751 and parameters: {'selector__k': 41, 'model__max_features': 'log2', 'model__n_estimators': 213, 'model__max_depth': 2, 'model__min_samples_leaf': 4}. Best is trial 11 with value: 0.9287644313436502.
# [I 2024-05-25 00:41:37,357] Trial 16 finished with value: 0.9054286416113977 and parameters: {'selector__k': 19, 'model__max_features': 'log2', 'model__n_estimators': 2962, 'model__max_depth': 62, 'model__min_samples_leaf': 9}. Best is trial 11 with value: 0.9287644313436502.
# [I 2024-05-25 00:43:27,385] Trial 17 finished with value: 0.9127978383689511 and parameters: {'selector__k': 43, 'model__max_features': 'log2', 'model__n_estimators': 886, 'model__max_depth': 24, 'model__min_samples_leaf': 5}. Best is trial 11 with value: 0.9287644313436502.
# [I 2024-05-25 00:44:00,417] Trial 18 finished with value: 0.9135347580447064 and parameters: {'selector__k': 37, 'model__max_features': 'log2', 'model__n_estimators': 256, 'model__max_depth': 70, 'model__min_samples_leaf': 3}. Best is trial 11 with value: 0.9287644313436502.
# [I 2024-05-25 00:44:15,062] Trial 19 finished with value: 0.90665684107099 and parameters: {'selector__k': 46, 'model__max_features': 'log2', 'model__n_estimators': 135, 'model__max_depth': 24, 'model__min_samples_leaf': 20}. Best is trial 11 with value: 0.9287644313436502.
# [I 2024-05-25 00:44:45,750] Trial 20 finished with value: 0.9044460820437239 and parameters: {'selector__k': 22, 'model__max_features': 'log2', 'model__n_estimators': 658, 'model__max_depth': 59, 'model__min_samples_leaf': 10}. Best is trial 11 with value: 0.9287644313436502.
# [I 2024-05-25 00:46:00,902] Trial 21 finished with value: 0.9274134119380988 and parameters: {'selector__k': 39, 'model__max_features': 'sqrt', 'model__n_estimators': 424, 'model__max_depth': 109, 'model__min_samples_leaf': 1}. Best is trial 11 with value: 0.9287644313436502.
# [I 2024-05-25 00:46:54,163] Trial 22 finished with value: 0.924834193072955 and parameters: {'selector__k': 37, 'model__max_features': 'sqrt', 'model__n_estimators': 316, 'model__max_depth': 103, 'model__min_samples_leaf': 1}. Best is trial 11 with value: 0.9287644313436502.
# [I 2024-05-25 00:48:35,759] Trial 23 finished with value: 0.9158683370179317 and parameters: {'selector__k': 44, 'model__max_features': 'sqrt', 'model__n_estimators': 650, 'model__max_depth': 163, 'model__min_samples_leaf': 3}. Best is trial 11 with value: 0.9287644313436502.
# [I 2024-05-25 00:49:36,240] Trial 24 finished with value: 0.9102186195038074 and parameters: {'selector__k': 38, 'model__max_features': 'log2', 'model__n_estimators': 507, 'model__max_depth': 110, 'model__min_samples_leaf': 6}. Best is trial 11 with value: 0.9287644313436502.
# [I 2024-05-25 00:50:02,322] Trial 25 finished with value: 0.9081306804225007 and parameters: {'selector__k': 11, 'model__max_features': 'log2', 'model__n_estimators': 1172, 'model__max_depth': 18, 'model__min_samples_leaf': 2}. Best is trial 11 with value: 0.9287644313436502.
# [I 2024-05-25 00:50:18,867] Trial 26 finished with value: 0.9136575779906657 and parameters: {'selector__k': 30, 'model__max_features': 'sqrt', 'model__n_estimators': 167, 'model__max_depth': 54, 'model__min_samples_leaf': 3}. Best is trial 11 with value: 0.9287644313436502.
# [I 2024-05-25 00:50:30,351] Trial 27 finished with value: 0.9272905919921395 and parameters: {'selector__k': 39, 'model__max_features': 'log2', 'model__n_estimators': 83, 'model__max_depth': 81, 'model__min_samples_leaf': 1}. Best is trial 11 with value: 0.9287644313436502.
# [I 2024-05-25 00:51:11,331] Trial 28 finished with value: 0.9130434782608695 and parameters: {'selector__k': 45, 'model__max_features': 'sqrt', 'model__n_estimators': 320, 'model__max_depth': 73, 'model__min_samples_leaf': 6}. Best is trial 11 with value: 0.9287644313436502.
# [I 2024-05-25 00:52:55,248] Trial 29 finished with value: 0.9115696389093588 and parameters: {'selector__k': 41, 'model__max_features': 'log2', 'model__n_estimators': 886, 'model__max_depth': 113, 'model__min_samples_leaf': 5}. Best is trial 11 with value: 0.9287644313436502.
# [I 2024-05-25 00:54:31,280] Trial 30 finished with value: 0.9130434782608695 and parameters: {'selector__k': 24, 'model__max_features': 'log2', 'model__n_estimators': 1590, 'model__max_depth': 197, 'model__min_samples_leaf': 3}. Best is trial 11 with value: 0.9287644313436502.
# [I 2024-05-25 00:54:50,964] Trial 31 finished with value: 0.9271677720461803 and parameters: {'selector__k': 39, 'model__max_features': 'log2', 'model__n_estimators': 104, 'model__max_depth': 87, 'model__min_samples_leaf': 1}. Best is trial 11 with value: 0.9287644313436502.
# [I 2024-05-25 00:55:51,662] Trial 32 finished with value: 0.9173421763694424 and parameters: {'selector__k': 32, 'model__max_features': 'log2', 'model__n_estimators': 554, 'model__max_depth': 40, 'model__min_samples_leaf': 2}. Best is trial 11 with value: 0.9287644313436502.
# [I 2024-05-25 00:56:29,569] Trial 33 finished with value: 0.926430852370425 and parameters: {'selector__k': 35, 'model__max_features': 'log2', 'model__n_estimators': 312, 'model__max_depth': 98, 'model__min_samples_leaf': 1}. Best is trial 11 with value: 0.9287644313436502.
# [I 2024-05-25 00:56:41,444] Trial 34 finished with value: 0.9125521984770326 and parameters: {'selector__k': 42, 'model__max_features': 'log2', 'model__n_estimators': 93, 'model__max_depth': 75, 'model__min_samples_leaf': 4}. Best is trial 11 with value: 0.9287644313436502.
# [I 2024-05-25 00:57:09,423] Trial 35 finished with value: 0.9178334561532793 and parameters: {'selector__k': 39, 'model__max_features': 'sqrt', 'model__n_estimators': 183, 'model__max_depth': 56, 'model__min_samples_leaf': 2}. Best is trial 11 with value: 0.9287644313436502.
# [I 2024-05-25 00:58:02,554] Trial 36 finished with value: 0.910587079341685 and parameters: {'selector__k': 29, 'model__max_features': 'log2', 'model__n_estimators': 774, 'model__max_depth': 133, 'model__min_samples_leaf': 5}. Best is trial 11 with value: 0.9287644313436502.
# [I 2024-05-25 00:59:01,520] Trial 37 finished with value: 0.9139032178825841 and parameters: {'selector__k': 46, 'model__max_features': 'sqrt', 'model__n_estimators': 406, 'model__max_depth': 86, 'model__min_samples_leaf': 4}. Best is trial 11 with value: 0.9287644313436502.
# [I 2024-05-25 00:59:09,080] Trial 38 finished with value: 0.9145173176123802 and parameters: {'selector__k': 33, 'model__max_features': 'sqrt', 'model__n_estimators': 74, 'model__max_depth': 34, 'model__min_samples_leaf': 2}. Best is trial 11 with value: 0.9287644313436502.
# [I 2024-05-25 00:59:50,316] Trial 39 finished with value: 0.9084991402603783 and parameters: {'selector__k': 36, 'model__max_features': 'log2', 'model__n_estimators': 497, 'model__max_depth': 154, 'model__min_samples_leaf': 16}. Best is trial 11 with value: 0.9287644313436502.
# [I 2024-05-25 01:02:25,386] Trial 40 finished with value: 0.9098501596659297 and parameters: {'selector__k': 40, 'model__max_features': 'sqrt', 'model__n_estimators': 1187, 'model__max_depth': 116, 'model__min_samples_leaf': 12}. Best is trial 11 with value: 0.9287644313436502.
# [I 2024-05-25 01:02:38,043] Trial 41 finished with value: 0.9269221321542619 and parameters: {'selector__k': 44, 'model__max_features': 'log2', 'model__n_estimators': 85, 'model__max_depth': 100, 'model__min_samples_leaf': 1}. Best is trial 11 with value: 0.9287644313436502.
# [I 2024-05-25 01:02:52,664] Trial 42 finished with value: 0.9177106362073201 and parameters: {'selector__k': 39, 'model__max_features': 'log2', 'model__n_estimators': 109, 'model__max_depth': 82, 'model__min_samples_leaf': 2}. Best is trial 11 with value: 0.9287644313436502.
# [I 2024-05-25 01:03:00,596] Trial 43 finished with value: 0.9233603537214443 and parameters: {'selector__k': 42, 'model__max_features': 'log2', 'model__n_estimators': 55, 'model__max_depth': 93, 'model__min_samples_leaf': 1}. Best is trial 11 with value: 0.9287644313436502.
# [I 2024-05-25 01:03:18,215] Trial 44 finished with value: 0.9127978383689511 and parameters: {'selector__k': 27, 'model__max_features': 'log2', 'model__n_estimators': 148, 'model__max_depth': 67, 'model__min_samples_leaf': 3}. Best is trial 11 with value: 0.9287644313436502.
# [I 2024-05-25 01:03:30,457] Trial 45 finished with value: 0.9096045197740112 and parameters: {'selector__k': 34, 'model__max_features': 'log2', 'model__n_estimators': 112, 'model__max_depth': 50, 'model__min_samples_leaf': 7}. Best is trial 11 with value: 0.9287644313436502.
# [I 2024-05-25 01:04:11,594] Trial 46 finished with value: 0.9113239990174404 and parameters: {'selector__k': 47, 'model__max_features': 'log2', 'model__n_estimators': 379, 'model__max_depth': 12, 'model__min_samples_leaf': 4}. Best is trial 11 with value: 0.9287644313436502.
# [I 2024-05-25 01:04:50,914] Trial 47 finished with value: 0.9271677720461803 and parameters: {'selector__k': 39, 'model__max_features': 'log2', 'model__n_estimators': 264, 'model__max_depth': 86, 'model__min_samples_leaf': 1}. Best is trial 11 with value: 0.9287644313436502.
# [I 2024-05-25 01:04:58,005] Trial 48 finished with value: 0.9092360599361337 and parameters: {'selector__k': 31, 'model__max_features': 'sqrt', 'model__n_estimators': 76, 'model__max_depth': 126, 'model__min_samples_leaf': 16}. Best is trial 11 with value: 0.9287644313436502.
# [I 2024-05-25 01:05:26,614] Trial 49 finished with value: 0.9147629575042987 and parameters: {'selector__k': 43, 'model__max_features': 'log2', 'model__n_estimators': 214, 'model__max_depth': 31, 'model__min_samples_leaf': 3}. Best is trial 11 with value: 0.9287644313436502.
# RF 0.9267993122083026 0.9452267148947164

# %%
for i in best_model_clf.keys():
    print(i, best_model_clf[i][1],best_model_clf[i][3])
# Out:
# KNN 0.9194301154507492 0.9336003100374629
# LGBM 0.9299926308032425 0.9438057098566077
# RF 0.9287644313436502 0.9456142617232915

# %% [markdown]
# ### Check the best result and put the predict results into test dataset

# %%
best_md_from_clf = sorted(best_model_clf.items(), key=lambda t: t[1][1])[-1]
temp_tr = test_data_tr.copy(deep=True)
temp_tr['y_pred_clf'] = best_md_from_clf[1][2]

import pickle
with open('CLF_berlin.pickle', 'wb') as f:
    pickle.dump(temp_tr, f, pickle.HIGHEST_PROTOCOL)
# best_model_clf = pd.read_pickle("best_model_clf.pickle")

# %%
import pickle
with open('CLF_berlin.pickle', 'rb') as handle:
    temp_tr = pickle.load(handle)

# %% [markdown]
# ### Group the used link from training and validation dataset and later group the predicted used link in test dataset

# %%
used_link_1 = temp[temp['used_link']==1]
used_link_1_train = used_link_1[used_link_1['remainder__dataset']=='train']
used_link_1_validate = used_link_1[used_link_1['remainder__dataset']=='validate']
temp_2 = pd.concat([used_link_1_train, used_link_1_validate], ignore_index=True)
X_t = temp_2.drop(columns=['remainder__dataset', 'remainder__link_counts', 'used_link'])
y_t = temp_2['remainder__link_counts']

train_index = list(temp_2[temp_2['remainder__dataset']=='train'].index)
validate_index = list(temp_2[temp_2['remainder__dataset']=='validate'].index)

X_te = temp_tr[temp_tr['y_pred_clf']==1].drop(columns=['remainder__dataset', 'remainder__link_counts', 'used_link', 'y_pred_clf'])
y_te = temp_tr[temp_tr['y_pred_clf']==1]['remainder__link_counts']

X_te_0 = temp_tr[temp_tr['y_pred_clf']==0].drop(columns=['remainder__dataset', 'remainder__link_counts', 'used_link', 'y_pred_clf'])
X_te_0['y_pred'] = 0
y_te_0 = temp_tr[temp_tr['y_pred_clf']==0]['remainder__link_counts']
y_te_all = pd.concat([y_te, y_te_0])

# %%
best_model_reg = {}
for model_name in model_space.keys():   
    model = model_space[model_name]
    pipeline  = Pipeline([('selector', SelectKBest(f_regression)),
                  ('model', model)])
    param_grid = {}
    param_grid['selector__k']=optuna.distributions.IntDistribution(2, len(X_t.columns))
    for key in param_space[model_name].keys():
        param_grid[f'model__{key}']=param_space[model_name][key]
    
    # BayesSearchCV
    opt = OptunaSearchCV(
        pipeline,
        param_grid,
        n_trials=50,
        cv=[(train_index, validate_index), (train_index, validate_index)],
        scoring='neg_mean_absolute_error',
        random_state=101
    )
    opt.fit(X_t, y_t)
    y_pred = opt.predict(X_te)
    y_pred_all = np.concatenate([y_pred, np.array(X_te_0['y_pred'])])
    mae = mean_absolute_error(y_te_all, y_pred_all)
    mse = mean_squared_error(y_te_all, y_pred_all)
    me = max_error(y_te_all, y_pred_all)
    best_model_reg[model_name] = (opt.best_score_, mae, mse, me, y_te_all, y_pred_all)
with open('CLFFSREG_berlin_woGNN.pickle', 'wb') as handle:
    pickle.dump(best_model_reg, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# [I 2024-05-25 01:06:27,676] A new study created in memory with name: no-name-f0cc0142-c396-45ef-be9c-20c9806b69f3
# [I 2024-05-25 01:06:28,634] Trial 0 finished with value: -19.783798283261802 and parameters: {'selector__k': 41, 'model__n_neighbors': 24, 'model__weights': 'uniform', 'model__algorithm': 'brute'}. Best is trial 0 with value: -19.783798283261802.
# [I 2024-05-25 01:06:29,744] Trial 1 finished with value: -11.552288277154696 and parameters: {'selector__k': 15, 'model__n_neighbors': 36, 'model__weights': 'distance', 'model__algorithm': 'auto'}. Best is trial 1 with value: -11.552288277154696.
# [I 2024-05-25 01:06:30,185] Trial 2 finished with value: -16.351812934734347 and parameters: {'selector__k': 22, 'model__n_neighbors': 5, 'model__weights': 'uniform', 'model__algorithm': 'kd_tree'}. Best is trial 1 with value: -11.552288277154696.
# [I 2024-05-25 01:06
. Best is trial 4 with value: -9.998685590538457.
# [I 2024-05-25 01:07:52,672] Trial 5 finished with value: -16.391430115048486 and parameters: {'selector__k': 36, 'model__learning_rate': 0.7348343646077565, 'model__n_estimators': 883, 'model__max_depth': 45, 'model__num_leaves': 27, 'model__min_child_samples': 2, 'model__subsample': 0.26105168401625667, 'model__colsample_bytree': 0.5812856748843152}. Best is trial 4 with value: -9.998685590538457.
# [I 2024-05-25 01:07:56,544] Trial 6 finished with value: -13.22964229638836 and parameters: {'selector__k': 39, 'model__learning_rate': 0.16714039138018438, 'model__n_estimators': 855, 'model__max_depth': 28, 'model__num_leaves': 15, 'model__min_child_samples': 1, 'model__subsample': 0.3801380721849661, 'model__colsample_bytree': 0.48664110585160403}. Best is trial 4 with value: -9.998685590538457.
# [I 2024-05-25 01:07:58,460] Trial 7 finished with value: -13.251055500638774 and parameters: {'selector__k': 18, 'model__learning_rate': 0.8814075521649741, 'model__n_estimators': 643, 'model__max_depth': 31, 'model__num_leaves': 13, 'model__min_child_samples': 8, 'model__subsample': 0.8950578430196747, 'model__colsample_bytree': 0.3843555466196359}. Best is trial 4 with value: -9.998685590538457.
# [I 2024-05-25 01:08:02,188] Trial 8 finished with value: -18.242433556073525 and parameters: {'selector__k': 2, 'model__learning_rate': 0.7804422164429433, 'model__n_estimators': 800, 'model__max_depth': 7, 'model__num_leaves': 25, 'model__min_child_samples': 3, 'model__subsample': 0.9976135241390007, 'model__colsample_bytree': 0.9870497120577045}. Best is trial 4 with value: -9.998685590538457.
# [I 2024-05-25 01:08:02,982] Trial 9 finished with value: -15.538988848770058 and parameters: {'selector__k': 26, 'model__learning_rate': 0.21916290208197312, 'model__n_estimators': 239, 'model__max_depth': 4, 'model__num_leaves': 42, 'model__min_child_samples': 2, 'model__subsample': 0.19279496704249927, 'model__colsample_bytree': 0.1848595052786653}. Best is trial 4 with value: -9.998685590538457.
# [I 2024-05-25 01:08:03,543] Trial 10 finished with value: -11.440599353623918 and parameters: {'selector__k': 6, 'model__learning_rate': 0.3945663497453614, 'model__n_estimators': 63, 'model__max_depth': 18, 'model__num_leaves': 36, 'model__min_child_samples': 16, 'model__subsample': 0.1091387268186454, 'model__colsample_bytree': 0.7655303478341471}. Best is trial 4 with value: -9.998685590538457.
# [I 2024-05-25 01:08:03,998] Trial 11 finished with value: -11.597307917077131 and parameters: {'selector__k': 5, 'model__learning_rate': 0.3838699274270503, 'model__n_estimators': 56, 'model__max_depth': 17, 'model__num_leaves': 36, 'model__min_child_samples': 17, 'model__subsample': 0.11637454011198355, 'model__colsample_bytree': 0.7884690393384459}. Best is trial 4 with value: -9.998685590538457.
# [I 2024-05-25 01:08:04,717] Trial 12 finished with value: -10.571828635779845 and parameters: {'selector__k': 10, 'model__learning_rate': 0.32416604059231774, 'model__n_estimators': 90, 'model__max_depth': 18, 'model__num_leaves': 50, 'model__min_child_samples': 13, 'model__subsample': 0.368587663205228, 'model__colsample_bytree': 0.7758020088921904}. Best is trial 4 with value: -9.998685590538457.
# [I 2024-05-25 01:08:05,909] Trial 13 finished with value: -10.511059605077673 and parameters: {'selector__k': 11, 'model__learning_rate': 0.26416100016890354, 'model__n_estimators': 156, 'model__max_depth': 18, 'model__num_leaves': 50, 'model__min_child_samples': 11, 'model__subsample': 0.37782636979210327, 'model__colsample_bytree': 0.8543685440457539}. Best is trial 4 with value: -9.998685590538457.
# [I 2024-05-25 01:08:07,194] Trial 14 finished with value: -11.429517350490906 and parameters: {'selector__k': 13, 'model__learning_rate': 0.5679380648413552, 'model__n_estimators': 177, 'model__max_depth': 15, 'model__num_leaves': 50, 'model__min_child_samples': 12, 'model__subsample': 0.40836635921246356, 'model__colsample_bytree': 0.8832226857588656}. Best is trial 4 with value: -9.998685590538457.
# [I 2024-05-25 01:08:08,706] Trial 15 finished with value: -14.621072330404521 and parameters: {'selector__k': 33, 'model__learning_rate': 0.22700775890733932, 'model__n_estimators': 154, 'model__max_depth': 22, 'model__num_leaves': 42, 'model__min_child_samples': 8, 'model__subsample': 0.5037254330041072, 'model__colsample_bytree': 0.6741922632986136}. Best is trial 4 with value: -9.998685590538457.
# [I 2024-05-25 01:08:10,672] Trial 16 finished with value: -12.486772351774011 and parameters: {'selector__k': 22, 'model__learning_rate': 0.0626015233154815, 'model__n_estimators': 334, 'model__max_depth': 11, 'model__num_leaves': 34, 'model__min_child_samples': 20, 'model__subsample': 0.2795381425131611, 'model__colsample_bytree': 0.9010209994592282}. Best is trial 4 with value: -9.998685590538457.
# [I 2024-05-25 01:08:11,939] Trial 17 finished with value: -13.466896753082848 and parameters: {'selector__k': 47, 'model__learning_rate': 0.5608023682581753, 'model__n_estimators': 107, 'model__max_depth': 25, 'model__num_leaves': 45, 'model__min_child_samples': 10, 'model__subsample': 0.4932222939987957, 'model__colsample_bytree': 0.8895055996307102}. Best is trial 4 with value: -9.998685590538457.
# [I 2024-05-25 01:08:13,376] Trial 18 finished with value: -10.647325971711282 and parameters: {'selector__k': 10, 'model__learning_rate': 0.3163667496840549, 'model__n_estimators': 299, 'model__max_depth': 33, 'model__num_leaves': 30, 'model__min_child_samples': 6, 'model__subsample': 0.2534232692035532, 'model__colsample_bytree': 0.6415955077802067}. Best is trial 4 with value: -9.998685590538457.
# [I 2024-05-25 01:08:17,414] Trial 19 finished with value: -12.475088976097947 and parameters: {'selector__k': 30, 'model__learning_rate': 0.04573991252167592, 'model__n_estimators': 434, 'model__max_depth': 12, 'model__num_leaves': 46, 'model__min_child_samples': 13, 'model__subsample': 0.334446435068021, 'model__colsample_bytree': 0.47285076314457425}. Best is trial 4 with value: -9.998685590538457.
# [I 2024-05-25 01:08:18,527] Trial 20 finished with value: -10.511324065122356 and parameters: {'selector__k': 18, 'model__learning_rate': 0.16180179987637874, 'model__n_estimators': 161, 'model__max_depth': 40, 'model__num_leaves': 38, 'model__min_child_samples': 10, 'model__subsample': 0.7921528370391719, 'model__colsample_bytree': 0.8558831567654831}. Best is trial 4 with value: -9.998685590538457.
# [I 2024-05-25 01:08:19,648] Trial 21 finished with value: -10.115826535796526 and parameters: {'selector__k': 19, 'model__learning_rate': 0.1560714987088614, 'model__n_estimators': 161, 'model__max_depth': 39, 'model__num_leaves': 38, 'model__min_child_samples': 10, 'model__subsample': 0.7856553302739441, 'model__colsample_bytree': 0.8465274256990606}. Best is trial 4 with value: -9.998685590538457.
# [I 2024-05-25 01:08:20,348] Trial 22 finished with value: -10.23467624997515 and parameters: {'selector__k': 19, 'model__learning_rate': 0.2394865615613868, 'model__n_estimators': 103, 'model__max_depth': 22, 'model__num_leaves': 31, 'model__min_child_samples': 6, 'model__subsample': 0.7639211744132275, 'model__colsample_bytree': 0.8340997716897031}. Best is trial 4 with value: -9.998685590538457.
# [I 2024-05-25 01:08:21,104] Trial 23 finished with value: -10.100433663533055 and parameters: {'selector__k': 19, 'model__learning_rate': 0.1448812434512553, 'model__n_estimators': 97, 'model__max_depth': 23, 'model__num_leaves': 31, 'model__min_child_samples': 7, 'model__subsample': 0.7814548272801839, 'model__colsample_bytree': 0.6919588416914537}. Best is trial 4 with value: -9.998685590538457.
# [I 2024-05-25 01:08:22,871] Trial 24 finished with value: -13.46312714833744 and parameters: {'selector__k': 29, 'model__learning_rate': 0.10062705110826958, 'model__n_estimators': 218, 'model__max_depth': 41, 'model__num_leaves': 18, 'model__min_child_samples': 7, 'model__subsample': 0.8669346586790558, 'model__colsample_bytree': 0.6843107836314034}. Best is trial 4 with value: -9.998685590538457.
# [I 2024-05-25 01:08:23,713] Trial 25 finished with value: -12.886514774765285 and parameters: {'selector__k': 23, 'model__learning_rate': 0.17010243356036037, 'model__n_estimators': 88, 'model__max_depth': 24, 'model__num_leaves': 39, 'model__min_child_samples': 4, 'model__subsample': 0.7692136391417236, 'model__colsample_bytree': 0.7246579795635425}. Best is trial 4 with value: -9.998685590538457.
# [I 2024-05-25 01:08:24,231] Trial 26 finished with value: -11.983591956684716 and parameters: {'selector__k': 15, 'model__learning_rate': 0.026593766207702846, 'model__n_estimators': 69, 'model__max_depth': 29, 'model__num_leaves': 31, 'model__min_child_samples': 9, 'model__subsample': 0.9213057990322333, 'model__colsample_bytree': 0.5048399175320162}. Best is trial 4 with value: -9.998685590538457.
# [I 2024-05-25 01:08:25,839] Trial 27 finished with value: -14.184342060793394 and parameters: {'selector__k': 20, 'model__learning_rate': 0.420278689446671, 'model__n_estimators': 466, 'model__max_depth': 37, 'model__num_leaves': 20, 'model__min_child_samples': 5, 'model__subsample': 0.5697760559173639, 'model__colsample_bytree': 0.6276433638070429}. Best is trial 4 with value: -9.998685590538457.
# [I 2024-05-25 01:08:27,124] Trial 28 finished with value: -10.395843197688885 and parameters: {'selector__k': 15, 'model__learning_rate': 0.3296357154157793, 'model__n_estimators': 243, 'model__max_depth': 26, 'model__num_leaves': 33, 'model__min_child_samples': 6, 'model__subsample': 0.7096428820254954, 'model__colsample_bytree': 0.9475444295880996}. Best is trial 4 with value: -9.998685590538457.
# [I 2024-05-25 01:08:28,284] Trial 29 finished with value: -13.7893541483177 and parameters: {'selector__k': 28, 'model__learning_rate': 0.5016753843692049, 'model__n_estimators': 122, 'model__max_depth': 48, 'model__num_leaves': 38, 'model__min_child_samples': 4, 'model__subsample': 0.8218020640300068, 'model__colsample_bytree': 0.7377109404586789}. Best is trial 4 with value: -9.998685590538457.
# [I 2024-05-25 01:08:29,323] Trial 30 finished with value: -13.435187578316466 and parameters: {'selector__k': 33, 'model__learning_rate': 0.13006297062868052, 'model__n_estimators': 122, 'model__max_depth': 50, 'model__num_leaves': 28, 'model__min_child_samples': 1, 'model__subsample': 0.985606121845125, 'model__colsample_bytree': 0.8074385769286724}. Best is trial 4 with value: -9.998685590538457.
# [I 2024-05-25 01:08:29,942] Trial 31 finished with value: -10.48263050761427 and parameters: {'selector__k': 18, 'model__learning_rate': 0.2535339196209295, 'model__n_estimators': 80, 'model__max_depth': 15, 'model__num_leaves': 32, 'model__min_child_samples': 6, 'model__subsample': 0.7293130782844665, 'model__colsample_bytree': 0.824043814352345}. Best is trial 4 with value: -9.998685590538457.
# [I 2024-05-25 01:08:36,305] Trial 32 finished with value: -13.249650643863315 and parameters: {'selector__k': 20, 'model__learning_rate': 0.20647406432371812, 'model__n_estimators': 1454, 'model__max_depth': 21, 'model__num_leaves': 30, 'model__min_child_samples': 7, 'model__subsample': 0.8411244337255156, 'model__colsample_bytree': 0.70856319053866}. Best is trial 4 with value: -9.998685590538457.
# [I 2024-05-25 01:08:36,976] Trial 33 finished with value: -13.483087245085748 and parameters: {'selector__k': 24, 'model__learning_rate': 0.269204377966054, 'model__n_estimators': 107, 'model__max_depth': 22, 'model__num_leaves': 22, 'model__min_child_samples': 3, 'model__subsample': 0.6824069765367468, 'model__colsample_bytree': 0.9196492531092733}. Best is trial 4 with value: -9.998685590538457.
# [I 2024-05-25 01:08:38,417] Trial 34 finished with value: -10.105969042975287 and parameters: {'selector__k': 16, 'model__learning_rate': 0.09088097692948705, 'model__n_estimators': 204, 'model__max_depth': 34, 'model__num_leaves': 41, 'model__min_child_samples': 9, 'model__subsample': 0.6284430596910783, 'model__colsample_bytree': 0.8321782281202772}. Best is trial 4 with value: -9.998685590538457.
# [I 2024-05-25 01:08:39,846] Trial 35 finished with value: -10.064165504144 and parameters: {'selector__k': 14, 'model__learning_rate': 0.021009919329484428, 'model__n_estimators': 201, 'model__max_depth': 34, 'model__num_leaves': 45, 'model__min_child_samples': 11, 'model__subsample': 0.6248666073281652, 'model__colsample_bytree': 0.5820531269053931}. Best is trial 4 with value: -9.998685590538457.
# [I 2024-05-25 01:08:41,911] Trial 36 finished with value: -9.91857019640894 and parameters: {'selector__k': 13, 'model__learning_rate': 0.014368831143869484, 'model__n_estimators': 301, 'model__max_depth': 34, 'model__num_leaves': 46, 'model__min_child_samples': 12, 'model__subsample': 0.610804424472119, 'model__colsample_bytree': 0.5792883722755744}. Best is trial 36 with value: -9.91857019640894.
# [I 2024-05-25 01:08:44,567] Trial 37 finished with value: -11.01399848955894 and parameters: {'selector__k': 8, 'model__learning_rate': 0.07162957219338668, 'model__n_estimators': 307, 'model__max_depth': 43, 'model__num_leaves': 46, 'model__min_child_samples': 13, 'model__subsample': 0.47923486863786174, 'model__colsample_bytree': 0.558141455865628}. Best is trial 36 with value: -9.91857019640894.
# [I 2024-05-25 01:08:45,797] Trial 38 finished with value: -10.164409256050513 and parameters: {'selector__k': 15, 'model__learning_rate': 0.03243007390009317, 'model__n_estimators': 525, 'model__max_depth': 30, 'model__num_leaves': 4, 'model__min_child_samples': 16, 'model__subsample': 0.6033152712674137, 'model__colsample_bytree': 0.39700074227865784}. Best is trial 36 with value: -9.91857019640894.
# [I 2024-05-25 01:08:52,410] Trial 39 finished with value: -10.837949561828385 and parameters: {'selector__k': 12, 'model__learning_rate': 0.11236719510013511, 'model__n_estimators': 1106, 'model__max_depth': 36, 'model__num_leaves': 44, 'model__min_child_samples': 12, 'model__subsample': 0.5474152087166311, 'model__colsample_bytree': 0.5891097760491877}. Best is trial 36 with value: -9.91857019640894.
# [I 2024-05-25 01:08:54,730] Trial 40 finished with value: -11.222096509990047 and parameters: {'selector__k': 7, 'model__learning_rate': 0.031063722976743924, 'model__n_estimators': 372, 'model__max_depth': 32, 'model__num_leaves': 48, 'model__min_child_samples': 11, 'model__subsample': 0.6458502010071117, 'model__colsample_bytree': 0.4310229298407698}. Best is trial 36 with value: -9.91857019640894.
# [I 2024-05-25 01:08:56,056] Trial 41 finished with value: -10.199141531439594 and parameters: {'selector__k': 16, 'model__learning_rate': 0.09484024158146402, 'model__n_estimators': 205, 'model__max_depth': 34, 'model__num_leaves': 41, 'model__min_child_samples': 9, 'model__subsample': 0.5939929959691628, 'model__colsample_bytree': 0.5247517343291637}. Best is trial 36 with value: -9.91857019640894.
# [I 2024-05-25 01:08:57,624] Trial 42 finished with value: -10.091870063905482 and parameters: {'selector__k': 13, 'model__learning_rate': 0.013686412598012121, 'model__n_estimators': 261, 'model__max_depth': 27, 'model__num_leaves': 40, 'model__min_child_samples': 14, 'model__subsample': 0.6432404009651305, 'model__colsample_bytree': 0.633095870685125}. Best is trial 36 with value: -9.91857019640894.
# [I 2024-05-25 01:08:59,138] Trial 43 finished with value: -10.00702065793062 and parameters: {'selector__k': 13, 'model__learning_rate': 0.01431331513283688, 'model__n_estimators': 280, 'model__max_depth': 27, 'model__num_leaves': 35, 'model__min_child_samples': 15, 'model__subsample': 0.7368987069912466, 'model__colsample_bytree': 0.6049253323954076}. Best is trial 36 with value: -9.91857019640894.
# [I 2024-05-25 01:09:00,197] Trial 44 finished with value: -13.581319680353905 and parameters: {'selector__k': 4, 'model__learning_rate': 0.012331727823636823, 'model__n_estimators': 269, 'model__max_depth': 28, 'model__num_leaves': 35, 'model__min_child_samples': 15, 'model__subsample': 0.6765227411702961, 'model__colsample_bytree': 0.303803402654038}. Best is trial 36 with value: -9.91857019640894.
# [I 2024-05-25 01:09:02,428] Trial 45 finished with value: -10.511517636798072 and parameters: {'selector__k': 13, 'model__learning_rate': 0.19122201624232718, 'model__n_estimators': 381, 'model__max_depth': 27, 'model__num_leaves': 40, 'model__min_child_samples': 14, 'model__subsample': 0.5369524355128233, 'model__colsample_bytree': 0.6152898903556042}. Best is trial 36 with value: -9.91857019640894.
# [I 2024-05-25 01:09:06,997] Trial 46 finished with value: -12.575080214493278 and parameters: {'selector__k': 9, 'model__learning_rate': 0.663528224010228, 'model__n_estimators': 593, 'model__max_depth': 36, 'model__num_leaves': 43, 'model__min_child_samples': 18, 'model__subsample': 0.7312485511658082, 'model__colsample_bytree': 0.563088229090799}. Best is trial 36 with value: -9.91857019640894.
# [I 2024-05-25 01:09:10,785] Trial 47 finished with value: -16.620191121935143 and parameters: {'selector__k': 3, 'model__learning_rate': 0.011469044724130052, 'model__n_estimators': 2670, 'model__max_depth': 6, 'model__num_leaves': 8, 'model__min_child_samples': 14, 'model__subsample': 0.45308942381066025, 'model__colsample_bytree': 0.45824552202789837}. Best is trial 36 with value: -9.91857019640894.
# [I 2024-05-25 01:09:12,814] Trial 48 finished with value: -10.026838152716115 and parameters: {'selector__k': 13, 'model__learning_rate': 0.07044531601455589, 'model__n_estimators': 283, 'model__max_depth': 31, 'model__num_leaves': 47, 'model__min_child_samples': 18, 'model__subsample': 0.6501048264580555, 'model__colsample_bytree': 0.6438698313393367}. Best is trial 36 with value: -9.91857019640894.
# [I 2024-05-25 01:09:14,947] Trial 49 finished with value: -13.180871190064684 and parameters: {'selector__k': 11, 'model__learning_rate': 0.9907862636485593, 'model__n_estimators': 324, 'model__max_depth': 31, 'model__num_leaves': 48, 'model__min_child_samples': 19, 'model__subsample': 0.5985135831113373, 'model__colsample_bytree': 0.532603979133174}. Best is trial 36 with value: -9.91857019640894.
# [I 2024-05-25 01:09:16,014] A new study created in memory with name: no-name-965176ce-4596-487f-8b4f-c209ca107ea9
# [I 2024-05-25 01:14:31,908] Trial 0 finished with value: -13.616663178441623 and parameters: {'selector__k': 41, 'model__max_features': 'log2', 'model__n_estimators': 2011, 'model__max_depth': 94, 'model__min_samples_leaf': 4}. Best is trial 0 with value: -13.616663178441623.
# [I 2024-05-25 01:16:14,945] Trial 1 finished with value: -13.516943062311928 and parameters: {'selector__k': 33, 'model__max_features': 'sqrt', 'model__n_estimators': 917, 'model__max_depth': 133, 'model__min_samples_leaf': 15}. Best is trial 1 with value: -13.516943062311928.
# [I 2024-05-25 01:17:54,894] Trial 2 finished with value: -13.315023626897775 and parameters: {'selector__k': 41, 'model__max_features': 'sqrt', 'model__n_estimators': 459, 'model__max_depth': 88, 'model__min_samples_leaf': 2}. Best is trial 2 with value: -13.315023626897775.
# [I 2024-05-25 01:18:14,061] Trial 3 finished with value: -13.19722683594235 and parameters: {'selector__k': 31, 'model__max_features': 'sqrt', 'model__n_estimators': 131, 'model__max_depth': 124, 'model__min_samples_leaf': 4}. Best is trial 3 with value: -13.19722683594235.
# [I 2024-05-25 01:18:19,328] Trial 4 finished with value: -13.19479950387061 and parameters: {'selector__k': 26, 'model__max_features': 'log2', 'model__n_estimators': 60, 'model__max_depth': 92, 'model__min_samples_leaf': 8}. Best is trial 4 with value: -13.19479950387061.
# [I 2024-05-25 01:18:35,332] Trial 5 finished with value: -13.070920663249899 and parameters: {'selector__k': 28, 'model__max_features': 'sqrt', 'model__n_estimators': 132, 'model__max_depth': 80, 'model__min_samples_leaf': 6}. Best is trial 5 with value: -13.070920663249899.
# [I 2024-05-25 01:20:30,916] Trial 6 finished with value: -13.636847339321688 and parameters: {'selector__k': 35, 'model__max_features': 'sqrt', 'model__n_estimators': 1198, 'model__max_depth': 147, 'model__min_samples_leaf': 15}. Best is trial 5 with value: -13.070920663249899.
# [I 2024-05-25 01:20:38,193] Trial 7 finished with value: -13.497219469858605 and parameters: {'selector__k': 34, 'model__max_features': 'sqrt', 'model__n_estimators': 62, 'model__max_depth': 36, 'model__min_samples_leaf': 11}. Best is trial 5 with value: -13.070920663249899.
# [I 2024-05-25 01:22:17,481] Trial 8 finished with value: -13.09566338064261 and parameters: {'selector__k': 39, 'model__max_features': 'log2', 'model__n_estimators': 473, 'model__max_depth': 56, 'model__min_samples_leaf': 1}. Best is trial 5 with value: -13.070920663249899.
# [I 2024-05-25 01:24:23,448] Trial 9 finished with value: -10.688164712100996 and parameters: {'selector__k': 16, 'model__max_features': 'sqrt', 'model__n_estimators': 1836, 'model__max_depth': 125, 'model__min_samples_leaf': 13}. Best is trial 9 with value: -10.688164712100996.
# [I 2024-05-25 01:25:05,885] Trial 10 finished with value: -10.920312788976547 and parameters: {'selector__k': 10, 'model__max_features': 'log2', 'model__n_estimators': 2951, 'model__max_depth': 194, 'model__min_samples_leaf': 19}. Best is trial 9 with value: -10.688164712100996.
# [I 2024-05-25 01:25:39,740] Trial 11 finished with value: -10.864281617035157 and parameters: {'selector__k': 11, 'model__max_features': 'log2', 'model__n_estimators': 2267, 'model__max_depth': 200, 'model__min_samples_leaf': 20}. Best is trial 9 with value: -10.688164712100996.
# [I 2024-05-25 01:26:12,799] Trial 12 finished with value: -10.963905774805282 and parameters: {'selector__k': 13, 'model__max_features': 'log2', 'model__n_estimators': 1134, 'model__max_depth': 190, 'model__min_samples_leaf': 20}. Best is trial 9 with value: -10.688164712100996.
# [I 2024-05-25 01:28:09,614] Trial 13 finished with value: -10.740576667808073 and parameters: {'selector__k': 17, 'model__max_features': 'log2', 'model__n_estimators': 1908, 'model__max_depth': 164, 'model__min_samples_leaf': 15}. Best is trial 9 with value: -10.688164712100996.
# [I 2024-05-25 01:28:53,077] Trial 14 finished with value: -10.795964752084714 and parameters: {'selector__k': 19, 'model__max_features': 'sqrt', 'model__n_estimators': 673, 'model__max_depth': 160, 'model__min_samples_leaf': 13}. Best is trial 9 with value: -10.688164712100996.
# [I 2024-05-25 01:29:06,173] Trial 15 finished with value: -10.931419881551944 and parameters: {'selector__k': 19, 'model__max_features': 'log2', 'model__n_estimators': 247, 'model__max_depth': 164, 'model__min_samples_leaf': 16}. Best is trial 9 with value: -10.688164712100996.
# [I 2024-05-25 01:29:14,181] Trial 16 finished with value: -18.139621944152786 and parameters: {'selector__k': 2, 'model__max_features': 'log2', 'model__n_estimators': 1420, 'model__max_depth': 120, 'model__min_samples_leaf': 11}. Best is trial 9 with value: -10.688164712100996.
# [I 2024-05-25 01:30:17,793] Trial 17 finished with value: -15.375426599930412 and parameters: {'selector__k': 48, 'model__max_features': 'sqrt', 'model__n_estimators': 1614, 'model__max_depth': 4, 'model__min_samples_leaf': 17}. Best is trial 9 with value: -10.688164712100996.
# [I 2024-05-25 01:31:06,382] Trial 18 finished with value: -10.793815026230316 and parameters: {'selector__k': 19, 'model__max_features': 'log2', 'model__n_estimators': 697, 'model__max_depth': 171, 'model__min_samples_leaf': 13}. Best is trial 9 with value: -10.688164712100996.
# [I 2024-05-25 01:31:34,127] Trial 19 finished with value: -13.264278650707624 and parameters: {'selector__k': 22, 'model__max_features': 'sqrt', 'model__n_estimators': 271, 'model__max_depth': 112, 'model__min_samples_leaf': 9}. Best is trial 9 with value: -10.688164712100996.
# [I 2024-05-25 01:32:04,505] Trial 20 finished with value: -11.60958695661621 and parameters: {'selector__k': 5, 'model__max_features': 'log2', 'model__n_estimators': 2209, 'model__max_depth': 140, 'model__min_samples_leaf': 13}. Best is trial 9 with value: -10.688164712100996.
# [I 2024-05-25 01:32:49,265] Trial 21 finished with value: -10.79369362877443 and parameters: {'selector__k': 18, 'model__max_features': 'log2', 'model__n_estimators': 750, 'model__max_depth': 170, 'model__min_samples_leaf': 14}. Best is trial 9 with value: -10.688164712100996.
# [I 2024-05-25 01:33:13,151] Trial 22 finished with value: -11.103530629221286 and parameters: {'selector__k': 14, 'model__max_features': 'log2', 'model__n_estimators': 884, 'model__max_depth': 176, 'model__min_samples_leaf': 17}. Best is trial 9 with value: -10.688164712100996.
# [I 2024-05-25 01:36:11,530] Trial 23 finished with value: -10.77977372733556 and parameters: {'selector__k': 16, 'model__max_features': 'log2', 'model__n_estimators': 2934, 'model__max_depth': 150, 'model__min_samples_leaf': 14}. Best is trial 9 with value: -10.688164712100996.
# [I 2024-05-25 01:39:36,652] Trial 24 finished with value: -13.482626672585884 and parameters: {'selector__k': 23, 'model__max_features': 'log2', 'model__n_estimators': 2781, 'model__max_depth': 150, 'model__min_samples_leaf': 18}. Best is trial 9 with value: -10.688164712100996.
# [I 2024-05-25 01:40:02,057] Trial 25 finished with value: -10.712876028826162 and parameters: {'selector__k': 8, 'model__max_features': 'log2', 'model__n_estimators': 1610, 'model__max_depth': 110, 'model__min_samples_leaf': 10}. Best is trial 9 with value: -10.688164712100996.
# [I 2024-05-25 01:40:22,336] Trial 26 finished with value: -11.007725001037423 and parameters: {'selector__k': 8, 'model__max_features': 'sqrt', 'model__n_estimators': 1690, 'model__max_depth': 109, 'model__min_samples_leaf': 9}. Best is trial 9 with value: -10.688164712100996.
# [I 2024-05-25 01:40:36,096] Trial 27 finished with value: -11.70221110559679 and parameters: {'selector__k': 7, 'model__max_features': 'log2', 'model__n_estimators': 1209, 'model__max_depth': 65, 'model__min_samples_leaf': 11}. Best is trial 9 with value: -10.688164712100996.
# [I 2024-05-25 01:41:01,457] Trial 28 finished with value: -11.571579785938969 and parameters: {'selector__k': 4, 'model__max_features': 'sqrt', 'model__n_estimators': 1675, 'model__max_depth': 134, 'model__min_samples_leaf': 7}. Best is trial 9 with value: -10.688164712100996.
# [I 2024-05-25 01:42:23,379] Trial 29 finished with value: -10.948373161267021 and parameters: {'selector__k': 15, 'model__max_features': 'log2', 'model__n_estimators': 2124, 'model__max_depth': 108, 'model__min_samples_leaf': 12}. Best is trial 9 with value: -10.688164712100996.
# [I 2024-05-25 01:42:34,124] Trial 30 finished with value: -10.443983370751765 and parameters: {'selector__k': 11, 'model__max_features': 'log2', 'model__n_estimators': 553, 'model__max_depth': 74, 'model__min_samples_leaf': 9}. Best is trial 30 with value: -10.443983370751765.
# [I 2024-05-25 01:42:40,473] Trial 31 finished with value: -10.4685738205545 and parameters: {'selector__k': 11, 'model__max_features': 'log2', 'model__n_estimators': 316, 'model__max_depth': 67, 'model__min_samples_leaf': 9}. Best is trial 30 with value: -10.443983370751765.
# [I 2024-05-25 01:42:45,735] Trial 32 finished with value: -10.603487379712968 and parameters: {'selector__k': 10, 'model__max_features': 'log2', 'model__n_estimators': 301, 'model__max_depth': 71, 'model__min_samples_leaf': 9}. Best is trial 30 with value: -10.443983370751765.
# [I 2024-05-25 01:42:52,800] Trial 33 finished with value: -10.306966476631938 and parameters: {'selector__k': 11, 'model__max_features': 'log2', 'model__n_estimators': 300, 'model__max_depth': 43, 'model__min_samples_leaf': 5}. Best is trial 33 with value: -10.306966476631938.
# [I 2024-05-25 01:42:59,712] Trial 34 finished with value: -10.305503519173552 and parameters: {'selector__k': 11, 'model__max_features': 'log2', 'model__n_estimators': 299, 'model__max_depth': 37, 'model__min_samples_leaf': 5}. Best is trial 34 with value: -10.305503519173552.
# [I 2024-05-25 01:43:03,859] Trial 35 finished with value: -10.2848382401808 and parameters: {'selector__k': 12, 'model__max_features': 'log2', 'model__n_estimators': 163, 'model__max_depth': 41, 'model__min_samples_leaf': 4}. Best is trial 35 with value: -10.2848382401808.
# [I 2024-05-25 01:43:07,450] Trial 36 finished with value: -11.684631691560625 and parameters: {'selector__k': 5, 'model__max_features': 'log2', 'model__n_estimators': 191, 'model__max_depth': 33, 'model__min_samples_leaf': 4}. Best is trial 35 with value: -10.2848382401808.
# [I 2024-05-25 01:43:08,546] Trial 37 finished with value: -18.14324731457868 and parameters: {'selector__k': 2, 'model__max_features': 'log2', 'model__n_estimators': 169, 'model__max_depth': 42, 'model__min_samples_leaf': 5}. Best is trial 35 with value: -10.2848382401808.
# [I 2024-05-25 01:43:27,128] Trial 38 finished with value: -10.257715401187172 and parameters: {'selector__k': 13, 'model__max_features': 'log2', 'model__n_estimators': 441, 'model__max_depth': 16, 'model__min_samples_leaf': 3}. Best is trial 38 with value: -10.257715401187172.
# [I 2024-05-25 01:43:35,213] Trial 39 finished with value: -13.321263604917835 and parameters: {'selector__k': 28, 'model__max_features': 'log2', 'model__n_estimators': 99, 'model__max_depth': 12, 'model__min_samples_leaf': 2}. Best is trial 38 with value: -10.257715401187172.
# [I 2024-05-25 01:44:18,131] Trial 40 finished with value: -13.234137717887144 and parameters: {'selector__k': 22, 'model__max_features': 'log2', 'model__n_estimators': 348, 'model__max_depth': 27, 'model__min_samples_leaf': 3}. Best is trial 38 with value: -10.257715401187172.
# [I 2024-05-25 01:44:36,598] Trial 41 finished with value: -10.459816404244778 and parameters: {'selector__k': 13, 'model__max_features': 'log2', 'model__n_estimators': 480, 'model__max_depth': 21, 'model__min_samples_leaf': 6}. Best is trial 38 with value: -10.257715401187172.
# [I 2024-05-25 01:44:47,341] Trial 42 finished with value: -10.275204928665316 and parameters: {'selector__k': 12, 'model__max_features': 'log2', 'model__n_estimators': 418, 'model__max_depth': 49, 'model__min_samples_leaf': 4}. Best is trial 38 with value: -10.257715401187172.
# [I 2024-05-25 01:44:51,204] Trial 43 finished with value: -11.709449117179577 and parameters: {'selector__k': 7, 'model__max_features': 'log2', 'model__n_estimators': 206, 'model__max_depth': 51, 'model__min_samples_leaf': 3}. Best is trial 38 with value: -10.257715401187172.
# [I 2024-05-25 01:45:07,204] Trial 44 finished with value: -10.360563503845148 and parameters: {'selector__k': 13, 'model__max_features': 'log2', 'model__n_estimators': 390, 'model__max_depth': 47, 'model__min_samples_leaf': 5}. Best is trial 38 with value: -10.257715401187172.
# [I 2024-05-25 01:45:11,850] Trial 45 finished with value: -11.408130312374977 and parameters: {'selector__k': 9, 'model__max_features': 'log2', 'model__n_estimators': 131, 'model__max_depth': 84, 'model__min_samples_leaf': 1}. Best is trial 38 with value: -10.257715401187172.
# [I 2024-05-25 01:45:21,728] Trial 46 finished with value: -10.250460086314733 and parameters: {'selector__k': 12, 'model__max_features': 'log2', 'model__n_estimators': 379, 'model__max_depth': 16, 'model__min_samples_leaf': 3}. Best is trial 46 with value: -10.250460086314733.
# [I 2024-05-25 01:45:46,330] Trial 47 finished with value: -10.524410610537512 and parameters: {'selector__k': 15, 'model__max_features': 'log2', 'model__n_estimators': 412, 'model__max_depth': 19, 'model__min_samples_leaf': 3}. Best is trial 46 with value: -10.250460086314733.
# [I 2024-05-25 01:45:49,286] Trial 48 finished with value: -16.218942461535235 and parameters: {'selector__k': 6, 'model__max_features': 'log2', 'model__n_estimators': 558, 'model__max_depth': 2, 'model__min_samples_leaf': 2}. Best is trial 46 with value: -10.250460086314733.
# [I 2024-05-25 01:45:57,598] Trial 49 finished with value: -13.171801059574552 and parameters: {'selector__k': 25, 'model__max_features': 'log2', 'model__n_estimators': 90, 'model__max_depth': 58, 'model__min_samples_leaf': 7}. Best is trial 46 with value: -10.250460086314733.
# [I 2024-05-25 01:46:05,001] A new study created in memory with name: no-name-d69b22ee-b0c6-4714-9619-d3e2fb9cc9cc
# [I 2024-05-25 01:46:29,718] Trial 0 finished with value: -21.0358556431264 and parameters: {'selector__k': 41, 'model__hidden_layer_sizes': (50,), 'model__activation': 'relu', 'model__solver': 'adam', 'model__alpha':
 'model__n_neighbors': 48, 'model__weights': 'distance', 'model__algorithm': 'auto'}. Best is trial 41 with value: -9.845537881856819.
# [I 2024-05-25 02:21:54,823] A new study created in memory with name: no-name-c970dfbc-ba73-4a2a-970f-7ad6daf79f7f
# [I 2024-05-25 02:22:02,910] Trial 0 finished with value: -11.020412689887571 and parameters: {'selector__k': 41, 'model__learning_rate': 0.47709375017765787, 'model__n_estimators': 2087, 'model__max_depth': 46, 'model__num_leaves': 24, 'model__min_child_samples': 4, 'model__subsample': 0.6970838440204888, 'model__colsample_bytree': 0.728018307398864}. Best is trial 0 with value: -11.020412689887571.
# [I 2024-05-25 02:22:06,353] Trial 1 finished with value: -10.547543931730248 and parameters: {'selector__k': 15, 'model__learning_rate': 0.7139779752177985, 'model__n_estimators': 748, 'model__max_depth': 36, 'model__num_leaves': 43, 'model__min_child_samples': 16, 'model__subsample': 0.6455620801605072, 'model__colsample_bytree': 0.5881762889751062}. Best is trial 1 with value: -10.547543931730248.
# [I 2024-05-25 02:22:07,250] Trial 2 finished with value: -9.106786075433604 and parameters: {'selector__k': 22, 'model__learning_rate': 0.09163704259521264, 'model__n_estimators': 625, 'model__max_depth': 9, 'model__num_leaves': 4, 'model__min_child_samples': 5, 'model__subsample': 0.6575390682226948, 'model__colsample_bytree': 0.2713416677416557}. Best is trial 2 with value: -9.106786075433604.
# [I 2024-05-25 02:22:11,151] Trial 3 finished with value: -13.552686002123405 and parameters: {'selector__k': 26, 'model__learning_rate': 0.8814838783846549, 'model__n_estimators': 2156, 'model__max_depth': 3, 'model__num_leaves': 24, 'model__min_child_samples': 8, 'model__subsample': 0.6024851063126109, 'model__colsample_bytree': 0.9875539806439302}. Best is trial 2 with value: -9.106786075433604.
# [I 2024-05-25 02:22:12,421] Trial 4 finished with value: -8.951323026944626 and parameters: {'selector__k': 18, 'model__learning_rate': 0.24705746508656587, 'model__n_estimators': 255, 'model__max_depth': 15, 'model__num_leaves': 37, 'model__min_child_samples': 3, 'model__subsample': 0.18150730090436135, 'model__colsample_bytree': 0.7986574492511642}. Best is trial 4 with value: -8.951323026944626.
# [I 2024-05-25 02:22:16,504] Trial 5 finished with value: -11.328204610646317 and parameters: {'selector__k': 36, 'model__learning_rate': 0.7348343646077565, 'model__n_estimators': 883, 'model__max_depth': 45, 'model__num_leaves': 27, 'model__min_child_samples': 2, 'model__subsample': 0.26105168401625667, 'model__colsample_bytree': 0.5812856748843152}. Best is trial 4 with value: -8.951323026944626.
# [I 2024-05-25 02:22:20,005] Trial 6 finished with value: -10.417206766462671 and parameters: {'selector__k': 39, 'model__learning_rate': 0.16714039138018438, 'model__n_estimators': 855, 'model__max_depth': 28, 'model__num_leaves': 15, 'model__min_child_samples': 1, 'model__subsample': 0.3801380721849661, 'model__colsample_bytree': 0.48664110585160403}. Best is trial 4 with value: -8.951323026944626.
# [I 2024-05-25 02:22:21,299] Trial 7 finished with value: -11.49043432269119 and parameters: {'selector__k': 18, 'model__learning_rate': 0.8814075521649741, 'model__n_estimators': 643, 'model__max_depth': 31, 'model__num_leaves': 13, 'model__min_child_samples': 8, 'model__subsample': 0.8950578430196747, 'model__colsample_bytree': 0.3843555466196359}. Best is trial 4 with value: -8.951323026944626.
# [I 2024-05-25 02:22:23,581] Trial 8 finished with value: -16.24020403622987 and parameters: {'selector__k': 2, 'model__learning_rate': 0.7804422164429433, 'model__n_estimators': 800, 'model__max_depth': 7, 'model__num_leaves': 25, 'model__min_child_samples': 3, 'model__subsample': 0.9976135241390007, 'model__colsample_bytree': 0.9870497120577045}. Best is trial 4 with value: -8.951323026944626.
# [I 2024-05-25 02:22:24,270] Trial 9 finished with value: -12.072524033828575 and parameters: {'selector__k': 26, 'model__learning_rate': 0.21916290208197312, 'model__n_estimators': 239, 'model__max_depth': 4, 'model__num_leaves': 42, 'model__min_child_samples': 2, 'model__subsample': 0.19279496704249927, 'model__colsample_bytree': 0.1848595052786653}. Best is trial 4 with value: -8.951323026944626.
# [I 2024-05-25 02:22:24,715] Trial 10 finished with value: -10.54999019870177 and parameters: {'selector__k': 6, 'model__learning_rate': 0.3945663497453614, 'model__n_estimators': 63, 'model__max_depth': 18, 'model__num_leaves': 36, 'model__min_child_samples': 16, 'model__subsample': 0.1091387268186454, 'model__colsample_bytree': 0.7655303478341471}. Best is trial 4 with value: -8.951323026944626.
# [I 2024-05-25 02:22:25,017] Trial 11 finished with value: -13.21659100550825 and parameters: {'selector__k': 15, 'model__learning_rate': 0.018850289050526298, 'model__n_estimators': 160, 'model__max_depth': 16, 'model__num_leaves': 3, 'model__min_child_samples': 7, 'model__subsample': 0.4322867681336492, 'model__colsample_bytree': 0.15246939749216892}. Best is trial 4 with value: -8.951323026944626.
# [I 2024-05-25 02:22:26,987] Trial 12 finished with value: -12.608365677793994 and parameters: {'selector__k': 29, 'model__learning_rate': 0.28557401505400687, 'model__n_estimators': 253, 'model__max_depth': 15, 'model__num_leaves': 50, 'model__min_child_samples': 6, 'model__subsample': 0.7855456590554672, 'model__colsample_bytree': 0.3574626378744423}. Best is trial 4 with value: -8.951323026944626.
# [I 2024-05-25 02:22:27,305] Trial 13 finished with value: -11.965904007873153 and parameters: {'selector__k': 20, 'model__learning_rate': 0.041714406048290194, 'model__n_estimators': 124, 'model__max_depth': 13, 'model__num_leaves': 2, 'model__min_child_samples': 13, 'model__subsample': 0.46823263715983304, 'model__colsample_bytree': 0.7697563518515336}. Best is trial 4 with value: -8.951323026944626.
# [I 2024-05-25 02:22:29,868] Trial 14 finished with value: -11.400402182790671 and parameters: {'selector__k': 48, 'model__learning_rate': 0.33153869080708925, 'model__n_estimators': 424, 'model__max_depth': 22, 'model__num_leaves': 34, 'model__min_child_samples': 13, 'model__subsample': 0.3100032315911824, 'model__colsample_bytree': 0.2610219441349478}. Best is trial 4 with value: -8.951323026944626.
# [I 2024-05-25 02:22:30,673] Trial 15 finished with value: -8.639216048426322 and parameters: {'selector__k': 12, 'model__learning_rate': 0.12429169913170723, 'model__n_estimators': 390, 'model__max_depth': 10, 'model__num_leaves': 11, 'model__min_child_samples': 5, 'model__subsample': 0.556924020539222, 'model__colsample_bytree': 0.8604139695759339}. Best is trial 15 with value: -8.639216048426322.
# [I 2024-05-25 02:22:31,010] Trial 16 finished with value: -9.184256696030536 and parameters: {'selector__k': 10, 'model__learning_rate': 0.5572451514764426, 'model__n_estimators': 74, 'model__max_depth': 22, 'model__num_leaves': 13, 'model__min_child_samples': 20, 'model__subsample': 0.5183816620623868, 'model__colsample_bytree': 0.852121825544921}. Best is trial 15 with value: -8.639216048426322.
# [I 2024-05-25 02:22:32,206] Trial 17 finished with value: -9.136535656959323 and parameters: {'selector__k': 10, 'model__learning_rate': 0.1740870053951013, 'model__n_estimators': 327, 'model__max_depth': 10, 'model__num_leaves': 33, 'model__min_child_samples': 10, 'model__subsample': 0.7654988427867482, 'model__colsample_bytree': 0.8917557626749633}. Best is trial 15 with value: -8.639216048426322.
# [I 2024-05-25 02:22:32,560] Trial 18 finished with value: -11.4704617854769 and parameters: {'selector__k': 32, 'model__learning_rate': 0.531193204928354, 'model__n_estimators': 128, 'model__max_depth': 1, 'model__num_leaves': 17, 'model__min_child_samples': 10, 'model__subsample': 0.3746618763642165, 'model__colsample_bytree': 0.6458158556964121}. Best is trial 15 with value: -8.639216048426322.
# [I 2024-05-25 02:22:35,742] Trial 19 finished with value: -9.388598448630104 and parameters: {'selector__k': 12, 'model__learning_rate': 0.3481414465824454, 'model__n_estimators': 1352, 'model__max_depth': 35, 'model__num_leaves': 19, 'model__min_child_samples': 5, 'model__subsample': 0.10316871722674742, 'model__colsample_bytree': 0.8591281216076484}. Best is trial 15 with value: -8.639216048426322.
# [I 2024-05-25 02:22:36,445] Trial 20 finished with value: -9.599776395661248 and parameters: {'selector__k': 4, 'model__learning_rate': 0.14154690370982417, 'model__n_estimators': 454, 'model__max_depth': 21, 'model__num_leaves': 8, 'model__min_child_samples': 1, 'model__subsample': 0.542524826744103, 'model__colsample_bytree': 0.6755193513163902}. Best is trial 15 with value: -8.639216048426322.
# [I 2024-05-25 02:22:36,993] Trial 21 finished with value: -8.841988236901994 and parameters: {'selector__k': 20, 'model__learning_rate': 0.08904459945790538, 'model__n_estimators': 210, 'model__max_depth': 9, 'model__num_leaves': 8, 'model__min_child_samples': 5, 'model__subsample': 0.7140913147858967, 'model__colsample_bytree': 0.47341474559844454}. Best is trial 15 with value: -8.639216048426322.
# [I 2024-05-25 02:22:37,563] Trial 22 finished with value: -8.856375672127434 and parameters: {'selector__k': 23, 'model__learning_rate': 0.23909914286417244, 'model__n_estimators': 189, 'model__max_depth': 11, 'model__num_leaves': 9, 'model__min_child_samples': 4, 'model__subsample': 0.7592298002644503, 'model__colsample_bytree': 0.8929299226929164}. Best is trial 15 with value: -8.639216048426322.
# [I 2024-05-25 02:22:38,130] Trial 23 finished with value: -8.664257583153903 and parameters: {'selector__k': 23, 'model__learning_rate': 0.09677044648428776, 'model__n_estimators': 185, 'model__max_depth': 10, 'model__num_leaves': 9, 'model__min_child_samples': 7, 'model__subsample': 0.8563443722738022, 'model__colsample_bytree': 0.45724190855945757}. Best is trial 15 with value: -8.639216048426322.
# [I 2024-05-25 02:22:38,570] Trial 24 finished with value: -12.491862044593605 and parameters: {'selector__k': 30, 'model__learning_rate': 0.0850030749101408, 'model__n_estimators': 91, 'model__max_depth': 7, 'model__num_leaves': 8, 'model__min_child_samples': 8, 'model__subsample': 0.8686322139161229, 'model__colsample_bytree': 0.4835359610750376}. Best is trial 15 with value: -8.639216048426322.
# [I 2024-05-25 02:22:39,435] Trial 25 finished with value: -8.66244326026972 and parameters: {'selector__k': 15, 'model__learning_rate': 0.0975911849095923, 'model__n_estimators': 341, 'model__max_depth': 5, 'model__num_leaves': 20, 'model__min_child_samples': 6, 'model__subsample': 0.8259590186688697, 'model__colsample_bytree': 0.4582291530312968}. Best is trial 15 with value: -8.639216048426322.
# [I 2024-05-25 02:22:40,239] Trial 26 finished with value: -9.301939255903479 and parameters: {'selector__k': 14, 'model__learning_rate': 0.4206160492528532, 'model__n_estimators': 347, 'model__max_depth': 5, 'model__num_leaves': 19, 'model__min_child_samples': 12, 'model__subsample': 0.8681907373151794, 'model__colsample_bytree': 0.4060434342321251}. Best is trial 15 with value: -8.639216048426322.
# [I 2024-05-25 02:22:40,709] Trial 27 finished with value: -10.810621921604753 and parameters: {'selector__k': 8, 'model__learning_rate': 0.621074755261777, 'model__n_estimators': 499, 'model__max_depth': 1, 'model__num_leaves': 21, 'model__min_child_samples': 7, 'model__subsample': 0.9691833263834397, 'model__colsample_bytree': 0.5366805709816096}. Best is trial 15 with value: -8.639216048426322.
# [I 2024-05-25 02:22:42,666] Trial 28 finished with value: -8.889701374972779 and parameters: {'selector__k': 17, 'model__learning_rate': 0.014110919544870967, 'model__n_estimators': 1157, 'model__max_depth': 18, 'model__num_leaves': 11, 'model__min_child_samples': 9, 'model__subsample': 0.924031833682442, 'model__colsample_bytree': 0.31218885533639884}. Best is trial 15 with value: -8.639216048426322.
# [I 2024-05-25 02:22:43,206] Trial 29 finished with value: -9.19545285543089 and parameters: {'selector__k': 12, 'model__learning_rate': 0.4550803966312921, 'model__n_estimators': 135, 'model__max_depth': 48, 'model__num_leaves': 21, 'model__min_child_samples': 6, 'model__subsample': 0.8273685182196476, 'model__colsample_bytree': 0.6878379130137587}. Best is trial 15 with value: -8.639216048426322.
# [I 2024-05-25 02:22:44,880] Trial 30 finished with value: -8.943974020224895 and parameters: {'selector__k': 24, 'model__learning_rate': 0.14091341307903513, 'model__n_estimators': 318, 'model__max_depth': 12, 'model__num_leaves': 30, 'model__min_child_samples': 4, 'model__subsample': 0.5986595687672366, 'model__colsample_bytree': 0.45399207749955767}. Best is trial 15 with value: -8.639216048426322.
# [I 2024-05-25 02:22:45,411] Trial 31 finished with value: -9.041676108172243 and parameters: {'selector__k': 21, 'model__learning_rate': 0.08768357311002713, 'model__n_estimators': 210, 'model__max_depth': 7, 'model__num_leaves': 6, 'model__min_child_samples': 6, 'model__subsample': 0.725665294470195, 'model__colsample_bytree': 0.4252668613851511}. Best is trial 15 with value: -8.639216048426322.
# [I 2024-05-25 02:22:45,774] Trial 32 finished with value: -8.998585391187902 and parameters: {'selector__k': 18, 'model__learning_rate': 0.11307661254353917, 'model__n_estimators': 94, 'model__max_depth': 9, 'model__num_leaves': 10, 'model__min_child_samples': 5, 'model__subsample': 0.6593308431782359, 'model__colsample_bytree': 0.5396501265500433}. Best is trial 15 with value: -8.639216048426322.
# [I 2024-05-25 02:22:46,238] Trial 33 finished with value: -8.635922441922459 and parameters: {'selector__k': 13, 'model__learning_rate': 0.21387087443716787, 'model__n_estimators': 172, 'model__max_depth': 5, 'model__num_leaves': 14, 'model__min_child_samples': 7, 'model__subsample': 0.7039517008900051, 'model__colsample_bytree': 0.6219365478430801}. Best is trial 33 with value: -8.635922441922459.
# [I 2024-05-25 02:22:46,650] Trial 34 finished with value: -8.785990660157402 and parameters: {'selector__k': 13, 'model__learning_rate': 0.2095851128934036, 'model__n_estimators': 161, 'model__max_depth': 4, 'model__num_leaves': 15, 'model__min_child_samples': 11, 'model__subsample': 0.819933411742255, 'model__colsample_bytree': 0.5948827286943782}. Best is trial 33 with value: -8.635922441922459.
# [I 2024-05-25 02:22:46,980] Trial 35 finished with value: -10.72260714483818 and parameters: {'selector__k': 7, 'model__learning_rate': 0.3030385703236479, 'model__n_estimators': 278, 'model__max_depth': 1, 'model__num_leaves': 5, 'model__min_child_samples': 9, 'model__subsample': 0.6384225865595207, 'model__colsample_bytree': 0.6175304592704389}. Best is trial 33 with value: -8.635922441922459.
# [I 2024-05-25 02:22:47,285] Trial 36 finished with value: -10.273169541660634 and parameters: {'selector__k': 15, 'model__learning_rate': 0.9906244138751095, 'model__n_estimators': 50, 'model__max_depth': 6, 'model__num_leaves': 13, 'model__min_child_samples': 7, 'model__subsample': 0.59514143315646, 'model__colsample_bytree': 0.7288130866928092}. Best is trial 33 with value: -8.635922441922459.
# [I 2024-05-25 02:22:48,725] Trial 37 finished with value: -9.280103951974727 and parameters: {'selector__k': 16, 'model__learning_rate': 0.18093438524215996, 'model__n_estimators': 515, 'model__max_depth': 13, 'model__num_leaves': 23, 'model__min_child_samples': 9, 'model__subsample': 0.6868154841678029, 'model__colsample_bytree': 0.32955244863588773}. Best is trial 33 with value: -8.635922441922459.
# [I 2024-05-25 02:22:49,651] Trial 38 finished with value: -9.262655743767544 and parameters: {'selector__k': 11, 'model__learning_rate': 0.2674478885361953, 'model__n_estimators': 402, 'model__max_depth': 44, 'model__num_leaves': 16, 'model__min_child_samples': 4, 'model__subsample': 0.9226072198481858, 'model__colsample_bytree': 0.5179330807345333}. Best is trial 33 with value: -8.635922441922459.
# [I 2024-05-25 02:22:52,597] Trial 39 finished with value: -10.189687565247517 and parameters: {'selector__k': 25, 'model__learning_rate': 0.05185527946632626, 'model__n_estimators': 620, 'model__max_depth': 40, 'model__num_leaves': 29, 'model__min_child_samples': 3, 'model__subsample': 0.8124890572009001, 'model__colsample_bytree': 0.2365239250974742}. Best is trial 33 with value: -8.635922441922459.
# [I 2024-05-25 02:22:53,254] Trial 40 finished with value: -11.920474655722602 and parameters: {'selector__k': 28, 'model__learning_rate': 0.1328917372155559, 'model__n_estimators': 173, 'model__max_depth': 27, 'model__num_leaves': 12, 'model__min_child_samples': 7, 'model__subsample': 0.7388290354651506, 'model__colsample_bytree': 0.5805891537499231}. Best is trial 33 with value: -8.635922441922459.
# [I 2024-05-25 02:22:53,628] Trial 41 finished with value: -8.626850115740513 and parameters: {'selector__k': 13, 'model__learning_rate': 0.19686009196500456, 'model__n_estimators': 108, 'model__max_depth': 4, 'model__num_leaves': 16, 'model__min_child_samples': 11, 'model__subsample': 0.8288086090154443, 'model__colsample_bytree': 0.5988659911710665}. Best is trial 41 with value: -8.626850115740513.
# [I 2024-05-25 02:22:54,035] Trial 42 finished with value: -9.107963895736775 and parameters: {'selector__k': 9, 'model__learning_rate': 0.20690901324701225, 'model__n_estimators': 103, 'model__max_depth': 9, 'model__num_leaves': 19, 'model__min_child_samples': 15, 'model__subsample': 0.8464991974701117, 'model__colsample_bytree': 0.4305269983773324}. Best is trial 41 with value: -8.626850115740513.
# [I 2024-05-25 02:22:54,626] Trial 43 finished with value: -9.669416693322548 and parameters: {'selector__k': 4, 'model__learning_rate': 0.07162960410481112, 'model__n_estimators': 293, 'model__max_depth': 4, 'model__num_leaves': 15, 'model__min_child_samples': 8, 'model__subsample': 0.9366256067069312, 'model__colsample_bytree': 0.9531211541153878}. Best is trial 41 with value: -8.626850115740513.
# [I 2024-05-25 02:22:55,049] Trial 44 finished with value: -8.962581990417798 and parameters: {'selector__k': 20, 'model__learning_rate': 0.3806864495302868, 'model__n_estimators': 143, 'model__max_depth': 3, 'model__num_leaves': 22, 'model__min_child_samples': 11, 'model__subsample': 0.8928896657100951, 'model__colsample_bytree': 0.7174564988967428}. Best is trial 41 with value: -8.626850115740513.
# [I 2024-05-25 02:22:55,490] Trial 45 finished with value: -8.762219025736497 and parameters: {'selector__k': 14, 'model__learning_rate': 0.18585437595129742, 'model__n_estimators': 111, 'model__max_depth': 7, 'model__num_leaves': 17, 'model__min_child_samples': 6, 'model__subsample': 0.7819527202477488, 'model__colsample_bytree': 0.5024531129616641}. Best is trial 41 with value: -8.626850115740513.
# [I 2024-05-25 02:22:56,343] Trial 46 finished with value: -10.182061716850193 and parameters: {'selector__k': 6, 'model__learning_rate': 0.25148913959629465, 'model__n_estimators': 216, 'model__max_depth': 13, 'model__num_leaves': 26, 'model__min_child_samples': 3, 'model__subsample': 0.6884486014485743, 'model__colsample_bytree': 0.6362437373980557}. Best is trial 41 with value: -8.626850115740513.
# [I 2024-05-25 02:22:59,425] Trial 47 finished with value: -9.627271003784605 and parameters: {'selector__k': 18, 'model__learning_rate': 0.3117947687823224, 'model__n_estimators': 2670, 'model__max_depth': 15, 'model__num_leaves': 6, 'model__min_child_samples': 14, 'model__subsample': 0.49477335032747194, 'model__colsample_bytree': 0.3786612412939182}. Best is trial 41 with value: -8.626850115740513.
# [I 2024-05-25 02:22:59,955] Trial 48 finished with value: -11.033072404555003 and parameters: {'selector__k': 36, 'model__learning_rate': 0.14108005862206432, 'model__n_estimators': 83, 'model__max_depth': 19, 'model__num_leaves': 13, 'model__min_child_samples': 8, 'model__subsample': 0.5776013269532616, 'model__colsample_bytree': 0.5654045844136955}. Best is trial 41 with value: -8.626850115740513.
# [I 2024-05-25 02:23:00,593] Trial 49 finished with value: -8.765119257918421 and parameters: {'selector__k': 22, 'model__learning_rate': 0.03925313861021429, 'model__n_estimators': 242, 'model__max_depth': 3, 'model__num_leaves': 10, 'model__min_child_samples': 18, 'model__subsample': 0.6315291911459434, 'model__colsample_bytree': 0.8068952515453048}. Best is trial 41 with value: -8.626850115740513.
# [I 2024-05-25 02:23:00,738] A new study created in memory with name: no-name-10b77c18-08b3-4842-addd-9ceea4ed40b2
# [I 2024-05-25 02:27:21,824] Trial 0 finished with value: -11.893500070086263 and parameters: {'selector__k': 41, 'model__max_features': 'log2', 'model__n_estimators': 2011, 'model__max_depth': 94, 'model__min_samples_leaf': 4}. Best is trial 0 with value: -11.893500070086263.
# [I 2024-05-25 02:28:41,903] Trial 1 finished with value: -11.874049885092465 and parameters: {'selector__k': 33, 'model__max_features': 'sqrt', 'model__n_estimators': 917, 'model__max_depth': 133, 'model__min_samples_leaf': 15}. Best is trial 1 with value: -11.874049885092465.
# [I 2024-05-25 02:30:08,844] Trial 2 finished with value: -11.651506970255005 and parameters: {'selector__k': 41, 'model__max_features': 'sqrt', 'model__n_estimators': 459, 'model__max_depth': 88, 'model__min_samples_leaf': 2}. Best is trial 2 with value: -11.651506970255005.
# [I 2024-05-25 02:30:26,293] Trial 3 finished with value: -11.734070762607304 and parameters: {'selector__k': 31, 'model__max_features': 'sqrt', 'model__n_estimators': 131, 'model__max_depth': 124, 'model__min_samples_leaf': 4}. Best is trial 2 with value: -11.651506970255005.
# [I 2024-05-25 02:30:31,610] Trial 4 finished with value: -11.784308489105344 and parameters: {'selector__k': 26, 'model__max_features': 'log2', 'model__n_estimators': 60, 'model__max_depth': 92, 'model__min_samples_leaf': 8}. Best is trial 2 with value: -11.651506970255005.
# [I 2024-05-25 02:30:45,924] Trial 5 finished with value: -12.111016833476157 and parameters: {'selector__k': 28, 'model__max_features': 'sqrt', 'model__n_estimators': 132, 'model__max_depth': 80, 'model__min_samples_leaf': 6}. Best is trial 2 with value: -11.651506970255005.
# [I 2024-05-25 02:32:28,209] Trial 6 finished with value: -11.82955213107752 and parameters: {'selector__k': 35, 'model__max_features': 'sqrt', 'model__n_estimators': 1198, 'model__max_depth': 147, 'model__min_samples_leaf': 15}. Best is trial 2 with value: -11.651506970255005.
# [I 2024-05-25 02:32:34,025] Trial 7 finished with value: -11.90089296239243 and parameters: {'selector__k': 34, 'model__max_features': 'sqrt', 'model__n_estimators': 62, 'model__max_depth': 36, 'model__min_samples_leaf': 11}. Best is trial 2 with value: -11.651506970255005.
# [I 2024-05-25 02:34:11,008] Trial 8 finished with value: -11.638720411774857 and parameters: {'selector__k': 39, 'model__max_features': 'log2', 'model__n_estimators': 473, 'model__max_depth': 56, 'model__min_samples_leaf': 1}. Best is trial 8 with value: -11.638720411774857.
# [I 2024-05-25 02:36:08,875] Trial 9 finished with value: -9.266008062990272 and parameters: {'selector__k': 16, 'model__max_features': 'sqrt', 'model__n_estimators': 1836, 'model__max_depth': 125, 'model__min_samples_leaf': 13}. Best is trial 9 with value: -9.266008062990272.
# [I 2024-05-25 02:36:48,339] Trial 10 finished with value: -9.458248025135966 and parameters: {'selector__k': 10, 'model__max_features': 'log2', 'model__n_estimators': 2951, 'model__max_depth': 194, 'model__min_samples_leaf': 19}. Best is trial 9 with value: -9.266008062990272.
# [I 2024-05-25 02:37:21,256] Trial 11 finished with value: -9.433337568964191 and parameters: {'selector__k': 11, 'model__max_features': 'log2', 'model__n_estimators': 2267, 'model__max_depth': 200, 'model__min_samples_leaf': 20}. Best is trial 9 with value: -9.266008062990272.
# [I 2024-05-25 02:37:51,253] Trial 12 finished with value: -9.607580373749693 and parameters: {'selector__k': 13, 'model__max_features': 'log2', 'model__n_estimators': 1134, 'model__max_depth': 190, 'model__min_samples_leaf': 20}. Best is trial 9 with value: -9.266008062990272.
# [I 2024-05-25 02:39:43,276] Trial 13 finished with value: -9.433302443490916 and parameters: {'selector__k': 17, 'model__max_features': 'log2', 'model__n_estimators': 1908, 'model__max_depth': 164, 'model__min_samples_leaf': 15}. Best is trial 9 with value: -9.266008062990272.
# [I 2024-05-25 02:40:21,111] Trial 14 finished with value: -9.349404711952278 and parameters: {'selector__k': 19, 'model__max_features': 'sqrt', 'model__n_estimators': 673, 'model__max_depth': 160, 'model__min_samples_leaf': 13}. Best is trial 9 with value: -9.266008062990272.
# [I 2024-05-25 02:41:03,792] Trial 15 finished with value: -9.305837289840634 and parameters: {'selector__k': 19, 'model__max_features': 'sqrt', 'model__n_estimators': 741, 'model__max_depth': 162, 'model__min_samples_leaf': 11}. Best is trial 9 with value: -9.266008062990272.
# [I 2024-05-25 02:41:04,969] Trial 16 finished with value: -16.172562577627318 and parameters: {'selector__k': 2, 'model__max_features': 'sqrt', 'model__n_estimators': 213, 'model__max_depth': 119, 'model__min_samples_leaf': 10}. Best is trial 9 with value: -9.266008062990272.
# [I 2024-05-25 02:41:15,399] Trial 17 finished with value: -13.68626323943482 and parameters: {'selector__k': 48, 'model__max_features': 'sqrt', 'model__n_estimators': 282, 'model__max_depth': 4, 'model__min_samples_leaf': 11}. Best is trial 9 with value: -9.266008062990272.
# [I 2024-05-25 02:41:55,631] Trial 18 finished with value: -9.647951758400149 and parameters: {'selector__k': 21, 'model__max_features': 'sqrt', 'model__n_estimators': 722, 'model__max_depth': 170, 'model__min_samples_leaf': 17}. Best is trial 9 with value: -9.266008062990272.
# [I 2024-05-25 02:43:33,455] Trial 19 finished with value: -9.34055100843998 and parameters: {'selector__k': 23, 'model__max_features': 'sqrt', 'model__n_estimators': 1429, 'model__max_depth': 112, 'model__min_samples_leaf': 8}. Best is trial 9 with value: -9.266008062990272.
# [I 2024-05-25 02:43:44,306] Trial 20 finished with value: -9.950203181888229 and parameters: {'selector__k': 4, 'model__max_features': 'sqrt', 'model__n_estimators': 852, 'model__max_depth': 140, 'model__min_samples_leaf': 13}. Best is trial 9 with value: -9.266008062990272.
# [I 2024-05-25 02:45:28,427] Trial 21 finished with value: -9.34648155791959 and parameters: {'selector__k': 23, 'model__max_features': 'sqrt', 'model__n_estimators': 1526, 'model__max_depth': 111, 'model__min_samples_leaf': 8}. Best is trial 9 with value: -9.266008062990272.
# [I 2024-05-25 02:46:57,581] Trial 22 finished with value: -9.201612127900852 and parameters: {'selector__k': 16, 'model__max_features': 'sqrt', 'model__n_estimators': 1286, 'model__max_depth': 73, 'model__min_samples_leaf': 9}. Best is trial 22 with value: -9.201612127900852.
# [I 2024-05-25 02:47:27,903] Trial 23 finished with value: -10.196409820129356 and parameters: {'selector__k': 7, 'model__max_features': 'sqrt', 'model__n_estimators': 2936, 'model__max_depth': 62, 'model__min_samples_leaf': 13}. Best is trial 22 with value: -9.201612127900852.
# [I 2024-05-25 02:48:07,713] Trial 24 finished with value: -9.213879278788367 and parameters: {'selector__k': 17, 'model__max_features': 'sqrt', 'model__n_estimators': 602, 'model__max_depth': 71, 'model__min_samples_leaf': 9}. Best is trial 22 with value: -9.201612127900852.
# [I 2024-05-25 02:48:35,196] Trial 25 finished with value: -9.212116489697424 and parameters: {'selector__k': 16, 'model__max_features': 'sqrt', 'model__n_estimators': 396, 'model__max_depth': 58, 'model__min_samples_leaf': 9}. Best is trial 22 with value: -9.201612127900852.
# [I 2024-05-25 02:48:48,980] Trial 26 finished with value: -9.113613996469043 and parameters: {'selector__k': 14, 'model__max_features': 'sqrt', 'model__n_estimators': 389, 'model__max_depth': 35, 'model__min_samples_leaf': 6}. Best is trial 26 with value: -9.113613996469043.
# [I 2024-05-25 02:48:58,691] Trial 27 finished with value: -9.134420968323377 and parameters: {'selector__k': 14, 'model__max_features': 'sqrt', 'model__n_estimators': 275, 'model__max_depth': 37, 'model__min_samples_leaf': 6}. Best is trial 26 with value: -9.113613996469043.
# [I 2024-05-25 02:49:02,247] Trial 28 finished with value: -10.043794732366232 and parameters: {'selector__k': 7, 'model__max_features': 'sqrt', 'model__n_estimators': 272, 'model__max_depth': 28, 'model__min_samples_leaf': 6}. Best is trial 26 with value: -9.113613996469043.
# [I 2024-05-25 02:49:10,139] Trial 29 finished with value: -9.02853285122634 and parameters: {'selector__k': 13, 'model__max_features': 'sqrt', 'model__n_estimators': 194, 'model__max_depth': 35, 'model__min_samples_leaf': 5}. Best is trial 29 with value: -9.02853285122634.
# [I 2024-05-25 02:49:11,354] Trial 30 finished with value: -11.621496480726302 and parameters: {'selector__k': 12, 'model__max_features': 'sqrt', 'model__n_estimators': 146, 'model__max_depth': 4, 'model__min_samples_leaf': 4}. Best is trial 29 with value: -9.02853285122634.
# [I 2024-05-25 02:49:14,097] Trial 31 finished with value: -9.511097530155444 and parameters: {'selector__k': 8, 'model__max_features': 'sqrt', 'model__n_estimators': 200, 'model__max_depth': 37, 'model__min_samples_leaf': 6}. Best is trial 29 with value: -9.02853285122634.
# [I 2024-05-25 02:49:25,571] Trial 32 finished with value: -9.080759561404703 and parameters: {'selector__k': 14, 'model__max_features': 'sqrt', 'model__n_estimators': 301, 'model__max_depth': 22, 'model__min_samples_leaf': 5}. Best is trial 29 with value: -9.02853285122634.
# [I 2024-05-25 02:49:39,914] Trial 33 finished with value: -8.876670022699969 and parameters: {'selector__k': 13, 'model__max_features': 'sqrt', 'model__n_estimators': 302, 'model__max_depth': 21, 'model__min_samples_leaf': 3}. Best is trial 33 with value: -8.876670022699969.
# [I 2024-05-25 02:49:41,829] Trial 34 finished with value: -9.516771358150605 and parameters: {'selector__k': 9, 'model__max_features': 'sqrt', 'model__n_estimators': 97, 'model__max_depth': 20, 'model__min_samples_leaf': 3}. Best is trial 33 with value: -8.876670022699969.
# [I 2024-05-25 02:49:53,011] Trial 35 finished with value: -9.099401324235771 and parameters: {'selector__k': 13, 'model__max_features': 'sqrt', 'model__n_estimators': 335, 'model__max_depth': 13, 'model__min_samples_leaf': 4}. Best is trial 33 with value: -8.876670022699969.
# [I 2024-05-25 02:49:57,253] Trial 36 finished with value: -10.28463068762213 and parameters: {'selector__k': 5, 'model__max_features': 'sqrt', 'model__n_estimators': 205, 'model__max_depth': 19, 'model__min_samples_leaf': 2}. Best is trial 33 with value: -8.876670022699969.
# [I 2024-05-25 02:50:49,348] Trial 37 finished with value: -11.776733401301842 and parameters: {'selector__k': 28, 'model__max_features': 'sqrt', 'model__n_estimators': 507, 'model__max_depth': 15, 'model__min_samples_leaf': 4}. Best is trial 33 with value: -8.876670022699969.
# [I 2024-05-25 02:51:11,750] Trial 38 finished with value: -8.761604814091056 and parameters: {'selector__k': 21, 'model__max_features': 'log2', 'model__n_estimators': 160, 'model__max_depth': 50, 'model__min_samples_leaf': 1}. Best is trial 38 with value: -8.761604814091056.
# [I 2024-05-25 02:51:27,915] Trial 39 finished with value: -11.511214996315402 and parameters: {'selector__k': 26, 'model__max_features': 'log2', 'model__n_estimators': 96, 'model__max_depth': 45, 'model__min_samples_leaf': 1}. Best is trial 38 with value: -8.761604814091056.
# [I 2024-05-25 02:51:45,152] Trial 40 finished with value: -8.946426462636909 and parameters: {'selector__k': 20, 'model__max_features': 'log2', 'model__n_estimators': 173, 'model__max_depth': 52, 'model__min_samples_leaf': 2}. Best is trial 38 with value: -8.761604814091056.
# [I 2024-05-25 02:52:00,821] Trial 41 finished with value: -8.920356827877336 and parameters: {'selector__k': 20, 'model__max_features': 'log2', 'model__n_estimators': 157, 'model__max_depth': 46, 'model__min_samples_leaf': 2}. Best is trial 38 with value: -8.761604814091056.
# [I 2024-05-25 02:52:16,621] Trial 42 finished with value: -8.959245161887386 and parameters: {'selector__k': 21, 'model__max_features': 'log2', 'model__n_estimators': 156, 'model__max_depth': 48, 'model__min_samples_leaf': 2}. Best is trial 38 with value: -8.761604814091056.
# [I 2024-05-25 02:52:36,621] Trial 43 finished with value: -11.673380118934846 and parameters: {'selector__k': 30, 'model__max_features': 'log2', 'model__n_estimators': 155, 'model__max_depth': 50, 'model__min_samples_leaf': 2}. Best is trial 38 with value: -8.761604814091056.
# [I 2024-05-25 02:52:47,303] Trial 44 finished with value: -9.000995911841773 and parameters: {'selector__k': 23, 'model__max_features': 'log2', 'model__n_estimators': 104, 'model__max_depth': 83, 'model__min_samples_leaf': 2}. Best is trial 38 with value: -8.761604814091056.
# [I 2024-05-25 02:53:02,975] Trial 45 finished with value: -8.941328453195444 and parameters: {'selector__k': 20, 'model__max_features': 'log2', 'model__n_estimators': 114, 'model__max_depth': 48, 'model__min_samples_leaf': 1}. Best is trial 38 with value: -8.761604814091056.
# [I 2024-05-25 02:53:13,669] Trial 46 finished with value: -8.969932012711755 and parameters: {'selector__k': 20, 'model__max_features': 'log2', 'model__n_estimators': 77, 'model__max_depth': 68, 'model__min_samples_leaf': 1}. Best is trial 38 with value: -8.761604814091056.
# [I 2024-05-25 02:53:26,621] Trial 47 finished with value: -11.330479254836739 and parameters: {'selector__k': 26, 'model__max_features': 'log2', 'model__n_estimators': 115, 'model__max_depth': 94, 'model__min_samples_leaf': 3}. Best is trial 38 with value: -8.761604814091056.
# [I 2024-05-25 02:53:33,533] Trial 48 finished with value: -8.802132979884822 and parameters: {'selector__k': 18, 'model__max_features': 'log2', 'model__n_estimators': 50, 'model__max_depth': 54, 'model__min_samples_leaf': 1}. Best is trial 38 with value: -8.761604814091056.
# [I 2024-05-25 02:53:38,397] Trial 49 finished with value: -8.868805178311096 and parameters: {'selector__k': 18, 'model__max_features': 'log2', 'model__n_estimators': 53, 'model__max_depth': 63, 'model__min_samples_leaf': 3}. Best is trial 38 with value: -8.761604814091056.
# [I 2024-05-25 02:53:55,023] A new study created in memory with name: no-name-24c6e03b-fa64-4a27-822c-903964ed716f
# [I 2024-05-25 02:54:17,528] Trial 0 finished with value: -20.550773662481244 and parameters: {'selector__k': 41, 'model__hidden_layer_sizes': (50,), 'model__activation': 'relu', 'model__solver': 'adam', 'model__alpha': 125.81192758176606}. Best is trial 0 with value: -20.550773662481244.
# [I 2024-05-25 02:54:47,753] Trial 1 finished with value: -15.900981752635166 and parameters: {'selector__k': 41, 'model__hidden_layer_sizes': (100,), 'model__activation': 'tanh', 'model__solver': 'lbfgs', 'model__alpha': 0.0008013021504212184}. Best is trial 1 with value: -15.900981752635166.
# [I 2024-05-25 02:54:57,499] Trial 2 finished with value: -42.21318206395862 and parameters: {'selector__k': 26, 'model__hidden_layer_sizes': (50,), 'model__activation': 'relu', 'model__solver': 'lbfgs', 'model__alpha': 0.007957234980393321}. Best is trial 1 with value: -15.900981752635166.
# [I 2024-05-25 02:55:22,967] Trial 3 finished with value: -13.755943848380587 and parameters: {'selector__k': 35, 'model__hidden_layer_sizes': (50, 50), 'model__activation': 'relu', 'model__solver': 'lbfgs', 'model__alpha': 2.226479033710199}. Best is trial 3 with value: -13.755943848380587.
# ...
# [I 2024-05-25 03:47:20,301] Trial 4 finished with value: -11.038395314009643 and parameters: {'selector__k': 23}. Best is trial 1 with value: -11.038395314009643.
# [I 2024-05-25 03:47:20,823] Trial 5 finished with value: -11.038391234382399 and parameters: {'selector__k': 11}. Best is trial 5 with value: -11.038391234382399.
. Best is trial 3 with value: -11.046567278200353.
# [I 2024-05-25 03:50:16,037] Trial 8 finished with value: -11.132307359651772 and parameters: {'learning_rate': 0.35831875365235816, 'n_estimators': 1836, 'max_depth': 32, 'num_leaves': 32, 'min_child_samples': 5, 'subsample': 0.4194340733669767, 'colsample_bytree': 0.8950578430196747}. Best is trial 3 with value: -11.046567278200353.
# [I 2024-05-25 03:50:16,582] Trial 9 finished with value: -11.73843894076571 and parameters: {'learning_rate': 0.3227911012815995, 'n_estimators': 51, 'max_depth': 39, 'num_leaves': 35, 'min_child_samples': 3, 'subsample': 0.5383205094204976, 'colsample_bytree': 0.19830766651484466}. Best is trial 3 with value: -11.046567278200353.
# [I 2024-05-25 03:50:16,961] Trial 10 finished with value: -12.450102875731721 and parameters: {'learning_rate': 0.05170957945400395, 'n_estimators': 88, 'max_depth': 2, 'num_leaves': 19, 'min_child_samples': 19, 'subsample': 0.9320652979571068, 'colsample_bytree': 0.3116606694195668}. Best is trial 3 with value: -11.046567278200353.
# [I 2024-05-25 03:50:19,140] Trial 11 finished with value: -11.179846303667164 and parameters: {'learning_rate': 0.4792288675084952, 'n_estimators': 246, 'max_depth': 17, 'num_leaves': 50, 'min_child_samples': 8, 'subsample': 0.686514123989417, 'colsample_bytree': 0.4528594494780428}. Best is trial 3 with value: -11.046567278200353.
# [I 2024-05-25 03:50:24,365] Trial 12 finished with value: -13.299404366612665 and parameters: {'learning_rate': 0.4858228001735447, 'n_estimators': 703, 'max_depth': 14, 'num_leaves': 42, 'min_child_samples': 20, 'subsample': 0.16415961506647464, 'colsample_bytree': 0.3252395098483273}. Best is trial 3 with value: -11.046567278200353.
# [I 2024-05-25 03:50:25,332] Trial 13 finished with value: -16.03649561892125 and parameters: {'learning_rate': 0.9876398053692377, 'n_estimators': 164, 'max_depth': 13, 'num_leaves': 23, 'min_child_samples': 8, 'subsample': 0.9931990742268859, 'colsample_bytree': 0.6126486716992691}. Best is trial 3 with value: -11.046567278200353.
# [I 2024-05-25 03:50:27,636] Trial 14 finished with value: -11.083328751026608 and parameters: {'learning_rate': 0.1874050336943116, 'n_estimators': 423, 'max_depth': 21, 'num_leaves': 27, 'min_child_samples': 11, 'subsample': 0.5115669543655769, 'colsample_bytree': 0.9982939096644052}. Best is trial 3 with value: -11.046567278200353.
# [I 2024-05-25 03:50:41,524] Trial 15 finished with value: -10.87833265804981 and parameters: {'learning_rate': 0.0755365212284218, 'n_estimators': 2959, 'max_depth': 7, 'num_leaves': 27, 'min_child_samples': 17, 'subsample': 0.5361148085473665, 'colsample_bytree': 0.9933611268243332}. Best is trial 15 with value: -10.87833265804981.
# [I 2024-05-25 03:50:44,523] Trial 16 finished with value: -11.492983238229852 and parameters: {'learning_rate': 0.061681366893725026, 'n_estimators': 2521, 'max_depth': 1, 'num_leaves': 15, 'min_child_samples': 17, 'subsample': 0.6857515475965759, 'colsample_bytree': 0.6266453378854726}. Best is trial 15 with value: -10.87833265804981.
# [I 2024-05-25 03:50:51,424] Trial 17 finished with value: -11.66879711653167 and parameters: {'learning_rate': 0.2062929833969501, 'n_estimators': 1394, 'max_depth': 8, 'num_leaves': 28, 'min_child_samples': 18, 'subsample': 0.7908973449631849, 'colsample_bytree': 0.36459430693320194}. Best is trial 15 with value: -10.87833265804981.
# [I 2024-05-25 03:51:10,646] Trial 18 finished with value: -10.654704675315573 and parameters: {'learning_rate': 0.049717114135024096, 'n_estimators': 2895, 'max_depth': 9, 'num_leaves': 41, 'min_child_samples': 15, 'subsample': 0.6183493459109594, 'colsample_bytree': 0.9634274766402104}. Best is trial 18 with value: -10.654704675315573.
. Best is trial 22 with value: -10.597835968495408.
# [I 2024-05-25 03:55:14,706] Trial 41 finished with value: -11.57414290668663 and parameters: {'learning_rate': 0.1257404196310559, 'n_estimators': 2931, 'max_depth': 10, 'num_leaves': 48, 'min_child_samples': 17, 'subsample': 0.4989331060176518, 'colsample_bytree': 0.8825450929311192}. Best is trial 22 with value: -10.597835968495408.
# [I 2024-05-25 03:55:30,845] Trial 42 finished with value: -11.49126295741833 and parameters: {'learning_rate': 0.2158824867098721, 'n_estimators': 2405, 'max_depth': 8, 'num_leaves': 46, 'min_child_samples': 16, 'subsample': 0.5516327558936798, 'colsample_bytree': 0.8143063645716712}. Best is trial 22 with value: -10.597835968495408.
# [I 2024-05-25 03:55:44,107] Trial 43 finished with value: -11.035920684001397 and parameters: {'learning_rate': 0.08703770533637639, 'n_estimators': 1687, 'max_depth': 11, 'num_leaves': 50, 'min_child_samples': 19, 'subsample': 0.6203016869026063, 'colsample_bytree': 0.9697081032984288}. Best is trial 22 with value: -10.597835968495408.
# [I 2024-05-25 03:56:04,598] Trial 44 finished with value: -11.555445042905452 and parameters: {'learning_rate': 0.06014455771011791, 'n_estimators': 2966, 'max_depth': 8, 'num_leaves': 43, 'min_child_samples': 17, 'subsample': 0.729162501518334, 'colsample_bytree': 0.8636343644747544}. Best is trial 22 with value: -10.597835968495408.
# [I 2024-05-25 03:56:10,344] Trial 45 finished with value: -11.475713906686277 and parameters: {'learning_rate': 0.01139508313853993, 'n_estimators': 2298, 'max_depth': 15, 'num_leaves': 9, 'min_child_samples': 15, 'subsample': 0.3436931290137852, 'colsample_bytree': 0.9223658711683721}. Best is trial 22 with value: -10.597835968495408.
# [I 2024-05-25 03:56:14,602] Trial 46 finished with value: -11.527212120639907 and parameters: {'learning_rate': 0.16467087363442973, 'n_estimators': 1554, 'max_depth': 4, 'num_leaves': 39, 'min_child_samples': 16, 'subsample': 0.42699115799794696, 'colsample_bytree': 0.9633386416762086}. Best is trial 22 with value: -10.597835968495408.
# [I 2024-05-25 03:56:28,306] Trial 47 finished with value: -11.682718832008744 and parameters: {'learning_rate': 0.3308755604947533, 'n_estimators': 1837, 'max_depth': 33, 'num_leaves': 48, 'min_child_samples': 19, 'subsample': 0.48509407228643414, 'colsample_bytree': 0.834121190931384}. Best is trial 22 with value: -10.597835968495408.
# [I 2024-05-25 03:56:28,654] Trial 48 finished with value: -10.891599143187335 and parameters: {'learning_rate': 0.24055990294953, 'n_estimators': 70, 'max_depth': 1, 'num_leaves': 19, 'min_child_samples': 20, 'subsample': 0.5265158104988579, 'colsample_bytree': 0.9940319577413428}. Best is trial 22 with value: -10.597835968495408.
# [I 2024-05-25 03:56:28,964] Trial 49 finished with value: -10.786977101178454 and parameters: {'learning_rate': 0.2382911773117909, 'n_estimators': 59, 'max_depth': 1, 'num_leaves': 17, 'min_child_samples': 20, 'subsample': 0.5448276165074916, 'colsample_bytree': 0.9959337340972658}. Best is trial 22 with value: -10.597835968495408.
# [I 2024-05-25 03:56:35,199] A new study created in memory with name: no-name-9c354134-6610-4304-b846-537667dad558
# [I 2024-05-25 04:01:11,604] Trial 0 finished with value: -12.12743974899479 and parameters: {'max_features': 'sqrt', 'n_estimators': 2087, 'max_depth': 181, 'min_samples_leaf': 10}. Best is trial 0 with value: -12.12743974899479.
# [I 2024-05-25 04:02:39,862] Trial 1 finished with value: -12.43906701111299 and parameters: {'max_features': 'log2', 'n_estimators': 868, 'max_depth': 58, 'min_samples_leaf': 15}. Best is trial 0 with value: -12.12743974899479.
# [I 2024-05-25 04:05:22,713] Trial 2 finished with value: -12.31327013943576 and parameters: {'max_features': 'log2', 'n_estimators': 1550, 'max_depth': 156, 'min_samples_leaf': 13}. Best is trial 0 with value: -12.12743974899479.
. Best is trial 10 with value: -11.779365140841845.
# [I 2024-05-25 04:17:39,941] Trial 19 finished with value: -12.077229259106863 and parameters: {'max_features': 'sqrt', 'n_estimators': 118, 'max_depth': 106, 'min_samples_leaf': 6}. Best is trial 10 with value: -11.779365140841845.
# [I 2024-05-25 04:19:09,104] Trial 20 finished with value: -11.987816910071599 and parameters: {'max_features': 'sqrt', 'n_estimators': 596, 'max_depth': 75, 'min_samples_leaf': 6}. Best is trial 10 with value: -11.779365140841845.
# [I 2024-05-25 04:20:18,017] Trial 21 finished with value: -11.8084987093132 and parameters: {'max_features': 'sqrt', 'n_estimators': 285, 'max_depth': 136, 'min_samples_leaf': 1}. Best is trial 10 with value: -11.779365140841845.
# [I 2024-05-25 04:21:13,617] Trial 22 finished with value: -11.733099026104018 and parameters: {'max_features': 'sqrt', 'n_estimators': 281, 'max_depth': 119, 'min_samples_leaf': 2}. Best is trial 22 with value: -11.733099026104018.
# [I 2024-05-25 04:22:09,382] Trial 23 finished with value: -11.935281163074428 and parameters: {'max_features': 'sqrt', 'n_estimators': 313, 'max_depth': 158, 'min_samples_leaf': 3}. Best is trial 22 with value: -11.733099026104018.
# [I 2024-05-25 04:22:35,535] Trial 24 finished with value: -11.968334411828229 and parameters: {'max_features': 'sqrt', 'n_estimators': 149, 'max_depth': 107, 'min_samples_leaf': 3}. Best is trial 22 with value: -11.733099026104018.
# [I 2024-05-25 04:24:00,480] Trial 25 finished with value: -11.938210819390425 and parameters: {'max_features': 'sqrt', 'n_estimators': 546, 'max_depth': 150, 'min_samples_leaf': 5}. Best is trial 22 with value: -11.733099026104018.
# [I 2024-05-25 04:24:24,006] Trial 26 finished with value: -11.851062098986175 and parameters: {'max_features': 'sqrt', 'n_estimators': 169, 'max_depth': 118, 'min_samples_leaf': 8}. Best is trial 22 with value: -11.733099026104018.
# [I 2024-05-25 04:27:48,187] Trial 27 finished with value: -11.852725930449425 and parameters: {'max_features': 'sqrt', 'n_estimators': 1029, 'max_depth': 172, 'min_samples_leaf': 2}. Best is trial 22 with value: -11.733099026104018.
# [I 2024-05-25 04:28:06,262] Trial 28 finished with value: -11.905928518818655 and parameters: {'max_features': 'sqrt', 'n_estimators': 91, 'max_depth': 81, 'min_samples_leaf': 2}. Best is trial 22 with value: -11.733099026104018.
# [I 2024-05-25 04:31:45,698] Trial 29 finished with value: -12.08876948546525 and parameters: {'max_features': 'sqrt', 'n_estimators': 1610, 'max_depth': 195, 'min_samples_leaf': 9}. Best is trial 22 with value: -11.733099026104018.
# [I 2024-05-25 04:32:41,316] Trial 30 finished with value: -12.318014095852238 and parameters: {'max_features': 'sqrt', 'n_estimators': 492, 'max_depth': 109, 'min_samples_leaf': 20}. Best is trial 22 with value: -11.733099026104018.
# [I 2024-05-25 04:33:52,952] Trial 31 finished with value: -11.808673678265214 and parameters: {'max_features': 'sqrt', 'n_estimators': 294, 'max_depth': 127, 'min_samples_leaf': 1}. Best is trial 22 with value: -11.733099026104018.
# [I 2024-05-25 04:34:37,837] Trial 32 finished with value: -11.7855490270639 and parameters: {'max_features': 'sqrt', 'n_estimators': 226, 'max_depth': 128, 'min_samples_leaf': 2}. Best is trial 22 with value: -11.733099026104018.
# [I 2024-05-25 04:35:07,282] Trial 33 finished with value: -11.706695213157445 and parameters: {'max_features': 'sqrt', 'n_estimators': 189, 'max_depth': 151, 'min_samples_leaf': 5}. Best is trial 33 with value: -11.706695213157445.
# [I 2024-05-25 04:35:34,758] Trial 34 finished with value: -11.711071418893814 and parameters: {'max_features': 'sqrt', 'n_estimators': 178, 'max_depth': 166, 'min_samples_leaf': 5}. Best is trial 33 with value: -11.706695213157445.
# [I 2024-05-25 04:35:59,386] Trial 35 finished with value: -11.716645701235706 and parameters: {'max_features': 'sqrt', 'n_estimators': 158, 'max_depth': 164, 'min_samples_leaf': 5}. Best is trial 33 with value: -11.706695213157445.
finished with value: -14.13272111708349 and parameters: {}. Best is trial 0 with value: -14.13272111708349.
# [I 2024-05-25 05:14:49,909] Trial 49 finished with value: -14.13272111708349 and parameters: {}. Best is trial 0 with value: -14.13272111708349.

# %% [markdown]
# # GNN for classification & regression

# %%
import torch
from torch_geometric.nn import GATConv
import torch.nn.functional as F
class GATNet(torch.nn.Module):
    def __init__(self, num_features, num_classes,
                hid, in_head, out_head, dor):
        super(GATNet, self).__init__()
        self.hid = hid
        self.in_head = in_head
        self.out_head = out_head
        self.dor = dor
        # self.extra_layer = extra_layer
        self.gat1 = GATConv(num_features, self.hid, heads=self.in_head, dropout=self.dor)
        # if self.extra_layer:
        #     self.gat2 = GATConv(self.hid*self.in_head, self.hid, heads=self.in_head, dropout=self.dor)
        #     self.gat3 = GATConv(self.hid*self.in_head, num_classes, concat=False, heads=self.out_head, dropout=self.dor)
        # else:
        self.gat2 = GATConv(self.hid*self.in_head, num_classes, concat=False, heads=self.out_head, dropout=self.dor)

    def forward(self, x, edge_index):
        x = F.dropout(x, p=self.dor, training=self.training)
        x = F.elu(self.gat1(x, edge_index))
        x = F.dropout(x, p=self.dor, training=self.training)
        # if self.extra_layer:
        #     x = F.elu(self.gat2(x, edge_index))  # Add non-linearity after the second layer
        #     x = F.dropout(x, p=self.dor, training=self.training)
        #     x = self.gat3(x, edge_index) 
        # else:
        x = self.gat2(x, edge_index)
        return x

# %%
# all_features = list(temp_2.columns)#CLF
all_features = list(temp.columns)
nodes_features = ['remainder__link_from', 'remainder__link_to']
drop_featrues = ['remainder__dataset', 'remainder__link_counts', 'used_link']
temp_features = list(set(all_features) - set(nodes_features))
other_features = list(set(temp_features) - set(drop_featrues))

# %%
import random
def seed_everything(seed: int) -> None:
    r"""Sets the seed for generating random numbers in :pytorch:`PyTorch`,
    :obj:`numpy` and :python:`Python`.

    Args:
        seed (int): The desired seed.
    """
    random.seed(101)
    np.random.seed(101)
    torch.manual_seed(101)
    torch.cuda.manual_seed_all(101)

# %%
from torch_geometric.data import Data

best_k = None
best_performance = float('inf')
performance_history = []

def objective(trial):
    # Hyperparameters to tune
    k = trial.suggest_int('k', len(other_features), len(other_features))
    hid = trial.suggest_categorical('hid', [16, 32, 64, 128, 256])
    in_head = trial.suggest_categorical('in_head', [1, 2, 4, 8, 16])
    out_head = trial.suggest_categorical('out_head', [1, 2])
    dor = trial.suggest_categorical('dor', [0, 0.05, 0.1])
    # extra_layer = trial.suggest_categorical('extra_layer', [False])
    
    # Create a tensor of your labels/targets
    y = torch.tensor(temp['remainder__link_counts'].values, dtype=torch.float).unsqueeze(1)
    
    # Feature selection for the current k
    selector = SelectKBest(score_func=f_regression, k=k)
    X_new = selector.fit_transform(temp[other_features], y)
    selected_columns = list(temp[other_features].columns[selector.get_support(indices=True)])
    
    edge_index = torch.tensor(temp[nodes_features].values.T, dtype=torch.long)
    x = torch.tensor(temp[selected_columns].values, dtype=torch.float)
    data = Data(x=x, edge_index=edge_index, y=y)

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    train_data = data.to(device)
    model = GATNet(k, 1, hid=hid, in_head=in_head, out_head=out_head, dor=dor).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.005, weight_decay=5e-4)
    criterion_MAE = torch.nn.L1Loss()
    def train():
        model.train()
        optimizer.zero_grad()
        out = model(train_data.x, train_data.edge_index)
        loss = criterion_MAE(out, train_data.y)
        loss.backward()
        optimizer.step()
        return loss
    for epoch in range(50):
        loss = train()

    return loss.item()

#     # Store the performance for each k
#     performance_history.append((k, test_loss))

#     # Update the best k if the current performance is better
#     if performance < best_performance:
#         best_performance = performance
#         best_k = k
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50)
# Out:
# [I 2024
. Best is trial 21 with value: 10.668281555175781.
# [I 2024-05-25 23:00:53,225] Trial 26 finished with value: 12.179272651672363 and parameters: {'k': 46, 'hid': 16, 'in_head': 2, 'out_head': 2, 'dor': 0}. Best is trial 21 with value: 10.668281555175781.
# [I 2024-05-25 23:02:05,607] Trial 27 finished with value: 19.651315689086914 and parameters: {'k': 46, 'hid': 128, 'in_head': 8, 'out_head': 1, 'dor': 0}. Best is trial 21 with value: 10.668281555175781.
# [I 2024-05-25 23:06:36,202] Trial 28 finished with value: 12.624085426330566 and parameters: {'k': 46, 'hid': 256, 'in_head': 16, 'out_head': 1, 'dor': 0}. Best is trial 21 with value: 10.668281555175781.
# [I 2024-05-25 23:07:02,665] Trial 29 finished with value: 16.420026779174805 and parameters: {'k': 46, 'hid': 32, 'in_head': 8, 'out_head': 2, 'dor': 0.05}. Best is trial 21 with value: 10.668281555175781.
# [I 2024-05-25 23:07:15,922] Trial 30 finished with value: 10.890707969665527 and parameters: {'k': 46, 'hid': 16, 'in_head': 8, 'out_head': 1, 'dor': 0}. Best is trial 21 with value: 10.668281555175781.
# [I 2024-05-25 23:07:27,956] Trial 31 finished with value: 10.971126556396484 and parameters: {'k': 46, 'hid': 16, 'in_head': 8, 'out_head': 1, 'dor': 0}. Best is trial 21 with value: 10.668281555175781.
# [I 2024-05-25 23:07:40,481] Trial 32 finished with value: 11.87411117553711 and parameters: {'k': 46, 'hid': 16, 'in_head': 8, 'out_head': 1, 'dor': 0}. Best is trial 21 with value: 10.668281555175781.
# [I 2024-05-25 23:07:53,733] Trial 33 finished with value: 11.370418548583984 and parameters: {'k': 46, 'hid': 16, 'in_head': 8, 'out_head': 1, 'dor': 0}. Best is trial 21 with value: 10.668281555175781.
# [I 2024-05-25 23:08:19,114] Trial 34 finished with value: 22.130979537963867 and parameters: {'k': 46, 'hid': 16, 'in_head': 16, 'out_head': 1, 'dor': 0.1}. Best is trial 21 with value: 10.668281555175781.
# [I 2024-05-25 23:09:32,691] Trial 35 finished with value: 11.983530044555664 and parameters: {'k': 46, 'hid': 128, 'in_head': 8, 'out_head': 1, 'dor': 0}. Best is trial 21 with value: 10.668281555175781.
# [I 2024-05-25 23:09:49,782] Trial 36 finished with value: 10.973194122314453 and parameters: {'k': 46, 'hid': 16, 'in_head': 8, 'out_head': 1, 'dor': 0}. Best is trial 21 with value: 10.668281555175781.
# [I 2024-05-25 23:14:54,506] Trial 37 finished with value: 13.460393905639648 and parameters: {'k': 46, 'hid': 256, 'in_head': 16, 'out_head': 2, 'dor': 0.1}. Best is trial 21 with value: 10.668281555175781.
# [I 2024-05-25 23:15:13,224] Trial 38 finished with value: 12.883566856384277 and parameters: {'k': 46, 'hid': 16, 'in_head': 8, 'out_head': 1, 'dor': 0}. Best is trial 21 with value: 10.668281555175781.
# [I 2024-05-25 23:15:18,121] Trial 39 finished with value: 35.673709869384766 and parameters: {'k': 46, 'hid': 16, 'in_head': 2, 'out_head': 1, 'dor': 0.1}. Best is trial 21 with value: 10.668281555175781.
# [I 2024-05-25 23:15:29,026] Trial 40 finished with value: 10.820761680603027 and parameters: {'k': 46, 'hid': 32, 'in_head': 4, 'out_head': 1, 'dor': 0}. Best is trial 21 with value: 10.668281555175781.
# [I 2024-05-25 23:15:41,384] Trial 41 finished with value: 14.706603050231934 and parameters: {'k': 46, 'hid': 32, 'in_head': 4, 'out_head': 1, 'dor': 0}. Best is trial 21 with value: 10.668281555175781.
# [I 2024-05-25 23:15:53,317] Trial 42 finished with value: 11.694772720336914 and parameters: {'k': 46, 'hid': 32, 'in_head': 4, 'out_head': 1, 'dor': 0}. Best is trial 21 with value: 10.668281555175781.
# [I 2024-05-25 23:16:04,186] Trial 43 finished with value: 12.531962394714355 and parameters: {'k': 46, 'hid': 32, 'in_head': 4, 'out_head': 1, 'dor': 0}. Best is trial 21 with value: 10.668281555175781.
# [I 2024-05-25 23:16:16,610] Trial 44 finished with value: 10.907081604003906 and parameters: {'k': 46, 'hid': 32, 'in_head': 4, 'out_head': 1, 'dor': 0}. Best is trial 21 with value: 10.668281555175781.
# [I 2024-05-25 23:16:29,503] Trial 45 finished with value: 10.87116813659668 and parameters: {'k': 46, 'hid': 32, 'in_head': 4, 'out_head': 1, 'dor': 0}. Best is trial 21 with value: 10.668281555175781.
# [I 2024-05-25 23:16:41,859] Trial 46 finished with value: 12.695693016052246 and parameters: {'k': 46, 'hid': 32, 'in_head': 4, 'out_head': 1, 'dor': 0}. Best is trial 21 with value: 10.668281555175781.
# [I 2024-05-25 23:16:53,825] Trial 47 finished with value: 17.766565322875977 and parameters: {'k': 46, 'hid': 32, 'in_head': 4, 'out_head': 2, 'dor': 0.05}. Best is trial 21 with value: 10.668281555175781.
# [I 2024-05-25 23:17:05,922] Trial 48 finished with value: 11.43038272857666 and parameters: {'k': 46, 'hid': 32, 'in_head': 4, 'out_head': 1, 'dor': 0}. Best is trial 21 with value: 10.668281555175781.
# [I 2024-05-25 23:17:18,138] Trial 49 finished with value: 28.08109474182129 and parameters: {'k': 46, 'hid': 32, 'in_head': 4, 'out_head': 1, 'dor': 0.1}. Best is trial 21 with value: 10.668281555175781.

# %%
best_params = study.best_params
best_k = best_params['k']
best_hid = best_params['hid']
best_in_head = best_params['in_head']
best_out_head = best_params['out_head']
best_dor = best_params['dor']
# best_extra_layer = best_params['extra_layer']

# %%
# Feature selection for the current k
selector = SelectKBest(score_func=f_regression, k=best_k)
y = torch.tensor(temp['remainder__link_counts'].values, dtype=torch.float).unsqueeze(1)
X_new = selector.fit_transform(temp[other_features], y)
selected_columns = list(temp[other_features].columns[selector.get_support(indices=True)])

edge_index = torch.tensor(temp[nodes_features].values.T, dtype=torch.long)
x = torch.tensor(temp[selected_columns].values, dtype=torch.float)
data = Data(x=x, edge_index=edge_index, y=y)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
train_data = data.to(device)

best_model = GATNet(best_k, 1, hid=best_hid, in_head=best_in_head,
                    out_head=best_out_head, dor=best_dor).to(device)
optimizer = torch.optim.Adam(best_model.parameters(), lr=0.005, weight_decay=5e-4)
criterion_MAE = torch.nn.L1Loss()
def train():
    best_model.train()
    optimizer.zero_grad()
    out = best_model(train_data.x, train_data.edge_index)
    loss = criterion_MAE(out, train_data.y)
    loss.backward()
    optimizer.step()
    return loss
for epoch in range(250):
    loss = train()

# %%
test_edge_index = torch.tensor(test_data_tr[nodes_features].values.T, dtype=torch.long)
# test_x = torch.tensor(X_te[selected_columns].values, dtype=torch.float)#CLF
# test_y = torch.tensor(y_te.values, dtype=torch.float).unsqueeze(1)#CLF
test_x = torch.tensor(test_data_tr[selected_columns].values, dtype=torch.float)
test_y = torch.tensor(test_data_tr['remainder__link_counts'].values, dtype=torch.float).unsqueeze(1)
test_data = Data(x=test_x, edge_index=test_edge_index, y=test_y)
test_data = test_data.to(device)

best_model.eval()
with torch.no_grad():
    pred = best_model(test_data.x, test_data.edge_index)
    # y_pred_all = np.concatenate([np.array(pd.DataFrame(pred).astype("float")[0]), np.array(X_te_0['y_pred'])])
    # mae = mean_absolute_error(y_te_all, y_pred_all)#CLF
    # mse = mean_squared_error(y_te_all, y_pred_all)#CLF
    # me = max_error(y_te_all, y_pred_all)#CLF
    y_pred = np.array(pd.DataFrame(pred).astype("float")[0])
    mae = mean_absolute_error(y_te_onlyreg, y_pred)
    mse = mean_squared_error(y_te_onlyreg, y_pred)
    me = max_error(y_te_onlyreg, y_pred)
# gnn_result = [study.best_value, mae, mse, me, y_te_all, y_pred_all]#CLF
gnn_result = [study.best_value, mae, mse, me, y_te_onlyreg, y_pred]

# %%
gnn_result
# Out:
# [10.668281555175781,
#  13.60643840421984,
#  589.6298640995565,
#  279.629674911499,
#  25127    29.0
#  25128    36.0
#  25129     5.0
#  25130    11.0
#  25131    45.0
#           ...
#  32863     0.0
#  32864    35.0
#  32865    22.0
#  32866    29.0
#  32867    16.0
#  Name: remainder__link_counts, Length: 7741, dtype: float64,
#  array([ 8.14610195,  7.04525995,  3.52692962, ..., 63.8319397 ,
#         63.77139282, 13.384655  ])]

# %%
with open('REG_berlin_woGNN.pickle', 'rb') as handle:
    best_model_onlyreg_wofeatureselect = pickle.load(handle)

# %%
best_model_onlyreg_wofeatureselect['GNN']=gnn_result

# %%
best_model_onlyreg_wofeatureselect
# Out:
# {'KNN': [-21.01353823161296,
#   19.460556381045404,
#   944.2913129855698,
#   264.69056424254234,
#   25127    29.0
#   25128    36.0
#   25129     5.0
#   25130    11.0
#   25131    45.0
#            ...
#   32863     0.0
#   32864    35.0
#   32865    22.0
#   32866    29.0
#   32867    16.0
#   Name: remainder__link_counts, Length: 7741, dtype: float64,
#   array([10.25576388, 25.28268107,  5.98112397, ..., 15.7225694 ,
#          11.30912421, 12.51757481])],
#  'LGBM': [-10.597835968495408,
#   10.368911195049533,
#   557.7671953077378,
#   246.08191533866113,
#   25127    29.0
#   25128    36.0
#   25129     5.0
#   25130    11.0
#   25131    45.0
#            ...
#   32863     0.0
#   32864    35.0
#   32865    22.0
#   32866    29.0
#   32867    16.0
#   Name: remainder__link_counts, Length: 7741, dtype: float64,
#   array([23.4882817 , 35.98982775,  5.75805963, ..., 37.88550176,
#          44.47754558,  7.12064327])],
#  'RF': [-11.369038698589767,
#   10.28698153621951,
#   381.577128129858,
#   207.85521891431404,
#   25127    29.0
#   25128    36.0
#   25129     5.0
#   25130    11.0
#   25131    45.0
#            ...
#   32863     0.0
#   32864    35.0
#   32865    22.0
#   32866    29.0
#   32867    16.0
#   Name: remainder__link_counts, Length: 7741, dtype: float64,
#   array([23.93748173, 55.3336632 ,  8.7134209 , ..., 46.47160022,
#          47.73746519, 13.02981385])],
#  'ANN': [-12.468642679144823,
#   11.574425123672738,
#   448.45745326237795,
#   220.2414705929201,
#   25127    29.0
#   25128    36.0
#   25129     5.0
#   25130    11.0
#   25131    45.0
#            ...
#   32863     0.0
#   32864    35.0
#   32865    22.0
#   32866    29.0
#   32867    16.0
#   Name: remainder__link_counts, Length: 7741, dtype: float64,
#   array([16.63575953, 37.29479841,  3.15970579, ..., 69.64955859,
#          66.71215381,  5.69741207])],
#  'Linear': [-14.142394024538062,
#   24.767316288423718,
#   1380.7805118630117,
#   225.18216102913635,
#   25127    29.0
#   25128    36.0
#   25129     5.0
#   25130    11.0
#   25131    45.0
#            ...
#   32863     0.0
#   32864    35.0
#   32865    22.0
#   32866    29.0
#   32867    16.0
#   Name: remainder__link_counts, Length: 7741, dtype: float64,
#   array([ 21.65021675,  48.14917033,  -3.87877679, ..., 107.65203217,
#          107.97349983,  56.7587928 ])],
#  'Lasso': [-11.35830588618331,
#   12.058147862275161,
#   465.671133163488,
#   220.95448448533094,
#   25127    29.0
#   25128    36.0
#   25129     5.0
#   25130    11.0
#   25131    45.0
#            ...
#   32863     0.0
#   32864    35.0
#   32865    22.0
#   32866    29.0
#   32867    16.0
#   Name: remainder__link_counts, Length: 7741, dtype: float64,
#   array([14.53383492, 37.86282413,  5.5920879 , ..., 65.6094643 ,
#          66.24979378,  3.73711153])],
#  'Ridge': [-14.13272111708349,
#   24.7496467518496,
#   1378.9662154654231,
#   224.63655458488466,
#   25127    29.0
#   25128    36.0
#   25129     5.0
#   25130    11.0
#   25131    45.0
#            ...
#   32863     0.0
#   32864    35.0
#   32865    22.0
#   32866    29.0
#   32867    16.0
#   Name: remainder__link_counts, Length: 7741, dtype: float64,
#   array([ 21.54589819,  48.25463613,  -3.78372528, ..., 107.61519307,
#          107.96909153,  56.79135964])],
#  'GNN': [10.668281555175781,
#   13.60643840421984,
#   589.6298640995565,
#   279.629674911499,
#   25127    29.0
#   25128    36.0
#   25129     5.0
#   25130    11.0
#   25131    45.0
#            ...
#   32863     0.0
#   32864    35.0
#   32865    22.0
#   32866    29.0
#   32867    16.0
#   Name: remainder__link_counts, Length: 7741, dtype: float64,
#   array([ 8.14610195,  7.04525995,  3.52692962, ..., 63.8319397 ,
#          63.77139282, 13.384655  ])]}

# %%
def load_json(file_list):
    index_list = []
    n=test_data_tr.index[0]
    m=test_data_tr.index[0]
    for file in file_list:
        with open(file, 'r') as f:
            data = json.load(f)
            df_links = pd.DataFrame({
                'link_id': data['links_id'],
                'link_from': data['link_from'],
                'link_to': data['link_to'],
            })
        n += len(df_links)
        index_list.append(list(range(m, n)))
        m += len(df_links)
    return index_list

test_files = ['s-15.json', 's-16.json', 's-17.json', 's-18.json','s-19.json']
test_files = ['Data/cutoutWorlds/Test/po-1_pn-1.0_sn-1/' + j for j in test_files]
berlin_test_index = load_json(test_files)

def split_five_instance(original_result):
    split5test = {}
    for i in original_result.keys():
        test=pd.DataFrame({
            'true_y':original_result[i][4],
            'pred_y':original_result[i][5]
        })
        split5test[i]={'all':{
            'MAE': original_result[i][1],
            'MSE': original_result[i][2],
            'ME': original_result[i][3],
        }}
        for j in range(1, len(berlin_test_index)+1):
            split5test[i][f'instance_{j}']={}
            test_df = test.loc[berlin_test_index[j-1]]
            split5test[i][f'instance_{j}']['MAE'] = mean_absolute_error(test_df['true_y'], test_df['pred_y'])
            split5test[i][f'instance_{j}']['MSE'] = mean_squared_error(test_df['true_y'], test_df['pred_y'])
            split5test[i][f'instance_{j}']['ME'] = max_error(test_df['true_y'], test_df['pred_y'])
    return split5test

# %%
REG_berlin = split_five_instance(best_model_onlyreg_wofeatureselect)
with open('REG_berlin.pickle', 'wb') as handle:
    pickle.dump(REG_berlin, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
REG_berlin
# Out:
# {'KNN': {'all': {'MAE': 19.460556381045404,
#    'MSE': 944.2913129855698,
#    'ME': 264.69056424254234},
#   'instance_1': {'MAE': 23.94019498984334,
#    'MSE': 1677.710162351738,
#    'ME': 264.69056424254234},
#   'instance_2': {'MAE': 14.559252777667188,
#    'MSE': 442.74443157608533,
#    'ME': 159.98118645586067},
#   'instance_3': {'MAE': 22.06393081550303,
#    'MSE': 1293.1039848334221,
#    'ME': 193.47775539150996},
#   'instance_4': {'MAE': 18.884808833794825,
#    'MSE': 704.5117681469293,
#    'ME': 123.34117941464032},
#   'instance_5': {'MAE': 18.020115633947857,
#    'MSE': 603.5362931589807,
#    'ME': 99.76429939799937}},
#  'LGBM': {'all': {'MAE': 10.368911195049533,
#    'MSE': 557.7671953077378,
#    'ME': 246.08191533866113},
#   'instance_1': {'MAE': 8.743872104996091,
#    'MSE': 591.9509354387845,
#    'ME': 221.60976541421795},
#   'instance_2': {'MAE': 5.718729549326989,
#    'MSE': 98.73010425856675,
#    'ME': 89.43849584139492},
#   'instance_3': {'MAE': 7.695048460226954,
#    'MSE': 262.0485196579048,
#    'ME': 109.89871568739854},
#   'instance_4': {'MAE': 18.85469567842512,
#    'MSE': 1616.4806147717156,
#    'ME': 246.08191533866113},
#   'instance_5': {'MAE': 12.14756775811108,
#    'MSE': 391.8615761763192,
#    'ME': 227.8566760518363}},
#  'RF': {'all': {'MAE': 10.28698153621951,
#    'MSE': 381.577128129858,
#    'ME': 207.85521891431404},
#   'instance_1': {'MAE': 10.382522969194554,
#    'MSE': 534.3960233435678,
#    'ME': 207.85521891431404},
#   'instance_2': {'MAE': 5.643755965546041,
#    'MSE': 103.12224605185705,
#    'ME': 106.20574533090087},
#   'instance_3': {'MAE': 7.959077193717457,
#    'MSE': 309.25504800344,
#    'ME': 131.53950857306342},
#   'instance_4': {'MAE': 16.68448258897212,
#    'MSE': 750.7696276967122,
#    'ME': 177.99025511954886},
#   'instance_5': {'MAE': 11.982032436995363,
#    'MSE': 280.819796019,
#    'ME': 174.9803592995569}},
#  'ANN': {'all': {'MAE': 11.574425123672738,
#    'MSE': 448.45745326237795,
#    'ME': 220.2414705929201},
#   'instance_1': {'MAE': 17.050266864489856,
#    'MSE': 997.8866674107753,
#    'ME': 220.2414705929201},
#   'instance_2': {'MAE': 4.695810540315994,
#    'MSE': 90.32850091619034,
#    'ME': 110.24413182569484},
#   'instance_3': {'MAE': 10.384428572508357,
#    'MSE': 482.0348191589753,
#    'ME': 172.50079771522024},
#   'instance_4': {'MAE': 15.219465340438422,
#    'MSE': 472.51901507886845,
#    'ME': 103.5961165137663},
#   'instance_5': {'MAE': 11.771275811397867,
#    'MSE': 248.82084866003018,
#    'ME': 62.04547104861559}},
#  'Linear': {'all': {'MAE': 24.767316288423718,
#    'MSE': 1380.7805118630117,
#    'ME': 225.18216102913635},
#   'instance_1': {'MAE': 15.337328291022768,
#    'MSE': 713.200901773649,
#    'ME': 225.18216102913635},
#   'instance_2': {'MAE': 11.169523031748673,
#    'MSE': 166.5740351806121,
#    'ME': 69.60158008762338},
#   'instance_3': {'MAE': 10.193929420775937,
#    'MSE': 413.2258581566957,
#    'ME': 171.1589621552443},
#   'instance_4': {'MAE': 21.417225691819574,
#    'MSE': 751.290872619749,
#    'ME': 101.46433206653711},
#   'instance_5': {'MAE': 68.0801107481397,
#    'MSE': 4989.39558304548,
#    'ME': 168.34451655124371}},
#  'Lasso': {'all': {'MAE': 12.058147862275161,
#    'MSE': 465.671133163488,
#    'ME': 220.95448448533094},
#   'instance_1': {'MAE': 17.294852195100574,
#    'MSE': 967.2694898759433,
#    'ME': 220.95448448533094},
#   'instance_2': {'MAE': 5.528240207480095,
#    'MSE': 116.9976423813443,
#    'ME': 143.2348882057192},
#   'instance_3': {'MAE': 11.397976404245327,
#    'MSE': 487.68886615882997,
#    'ME': 171.06296774755717},
#   'instance_4': {'MAE': 16.637218543490402,
#    'MSE': 585.2290701522336,
#    'ME': 102.11222623424521},
#   'instance_5': {'MAE': 10.658627035885194,
#    'MSE': 228.8180162636685,
#    'ME': 66.8278744948421}},
#  'Ridge': {'all': {'MAE': 24.7496467518496,
#    'MSE': 1378.9662154654231,
#    'ME': 224.63655458488466},
#   'instance_1': {'MAE': 15.333467155041028,
#    'MSE': 713.0086748709829,
#    'ME': 224.63655458488466},
#   'instance_2': {'MAE': 11.153283531926604,
#    'MSE': 165.8127739064546,
#    'ME': 68.5380864101437},
#   'instance_3': {'MAE': 10.181535920035609,
#    'MSE': 412.175706341667,
#    'ME': 170.95424377057074},
#   'instance_4': {'MAE': 21.367631014153876,
#    'MSE': 746.667710296386,
#    'ME': 100.6373920355467},
#   'instance_5': {'MAE': 68.07079315153942,
#    'MSE': 4986.601249867203,
#    'ME': 168.27443000682845}},
#  'GNN': {'all': {'MAE': 13.60643840421984,
#    'MSE': 589.6298640995565,
#    'ME': 279.629674911499},
#   'instance_1': {'MAE': 23.798273158765337,
#    'MSE': 1758.897013661025,
#    'ME': 279.629674911499},
#   'instance_2': {'MAE': 7.190265532665023,
#    'MSE': 111.48429913945428,
#    'ME': 112.41448211669922},
#   'instance_3': {'MAE': 11.784511080033937,
#    'MSE': 557.559307344877,
#    'ME': 175.0168914794922},
#   'instance_4': {'MAE': 10.875083713804429,
#    'MSE': 272.772899015171,
#    'ME': 102.35726547241211},
#   'instance_5': {'MAE': 15.386819866907636,
#    'MSE': 316.7933547424483,
#    'ME': 61.836700439453125}}}

# %%
all_berlin={
    'CLF-FS-REG':CLFFSREG_berlin,
    'FS-REG':FSREG_berlin,
    'REG':REG_berlin
          }

# %%
with open('all_berlin.pickle', 'wb') as handle:
    pickle.dump(all_berlin, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
df_berlin_result = pd.DataFrame.from_dict({(i, j, k): all_berlin[i][j][k]
                             for i in all_berlin.keys()
                             for j in all_berlin[i].keys()
                             for k in all_berlin[i][j].keys()},
                            orient='index')

# %%
# Reset the index to separate the keys into individual columns
df_berlin_result = df_berlin_result.reset_index().rename(columns={"level_0": "Approaches", "level_1": "Algorithms", "level_2": "Instances"})


# Create an Excel writer object
with pd.ExcelWriter('Model result_berlin_0525.xlsx', engine='xlsxwriter') as writer:
    # Write the DataFrame to the Excel file
    df_berlin_result.to_excel(writer, sheet_name='Sheet1', index=False)
    
    # Get the workbook and worksheet objects
    workbook = writer.book
    worksheet = writer.sheets['Sheet1']
    
    # Apply formatting to the worksheet
    header_format = workbook.add_format({'bold': True, 'bg_color': '#FFD700'})
    worksheet.set_column('A:E', 15)
    worksheet.set_column('F:G', 10)
    # worksheet.conditional_format('F2:G9', {'type': '3_color_scale'})
    
    # Write the header with the specified format
    for col_num, value in enumerate(df_berlin_result.columns.values):
        worksheet.write(0, col_num, value, header_format)

print("Excel file created successfully.")
# Out:
# Excel file created successfully.
