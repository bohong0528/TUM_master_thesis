# %%
import json
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsRegressor, KNeighborsClassifier
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder, MinMaxScaler, RobustScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso, RidgeCV, LassoCV, LogisticRegression, LogisticRegressionCV
from sklearn.svm import SVR, SVC
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, GradientBoostingClassifier, RandomForestClassifier
from sklearn.neural_network import MLPRegressor, MLPClassifier
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error, make_scorer, max_error, accuracy_score
from sklearn.model_selection import GridSearchCV, cross_val_score, KFold, RandomizedSearchCV, ShuffleSplit, cross_validate, train_test_split
from scipy.stats import expon, reciprocal, uniform
from sklearn.gaussian_process.kernels import RBF, WhiteKernel, DotProduct, ExpSineSquared, RationalQuadratic, ConstantKernel, Matern
from sklearn.feature_selection import RFE, SelectFromModel, RFECV, SelectKBest, chi2, f_regression
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline, Pipeline
from mango import Tuner, scheduler
import xgboost as xgb
from skopt  import BayesSearchCV 
import lightgbm as lgb
from sklearn.cluster import OPTICS, MiniBatchKMeans
from pyGRNN import GRNN
from skopt.space import Categorical, Space, Dimension, Integer
from sklearn.inspection import permutation_importance
from optuna.integration import OptunaSearchCV
import optuna
import matplotlib.pyplot as plt
from loading import load_data
# Out:
# C:\Users\LinBoH\AppData\Local\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
numerical_features = ['start_node_x', 'start_node_y', 'end_node_x', 'end_node_y', 'link_length', 'link_freespeed', 
                      'link_capacity', 'link_permlanes', 'start_count', 'end_count', 'go_to_sum', 'rush_hour', 
                      'max_dur', 'cemdapStopDuration_s', 'length_per_capacity_ratio', 'speed_capacity_ratio',
                      'length_times_lanes', 'speed_times_capacity', 'length_times', 'capacity_divided_by_lanes',
                      'income', 'score', 'income_avg', 'score_avg'
                     ]
category_feature = ['type', 'home-activity-zone']
scaler = StandardScaler()
le = LabelEncoder()
ohe = OneHotEncoder(sparse_output=False)
ct = ColumnTransformer(
     [("num_preprocess", scaler, numerical_features),
      ("text_preprocess", ohe, category_feature)], remainder='passthrough').set_output(transform="pandas")
clf = {
    'KNN': KNeighborsClassifier(),
#     'XGB': xgb.XGBClassifier(random_state=101),
    'LGBM': lgb.LGBMClassifier(random_state=101, verbose=-1),
    'RF': RandomForestClassifier(random_state=101),
#     'GB': GradientBoostingClassifier(random_state=101),
#     'ANN': MLPClassifier(random_state=101)
}

model_space = {
    'KNN': KNeighborsRegressor(),
    # 'XGB': xgb.XGBRegressor(random_state=101),
    'LGBM': lgb.LGBMRegressor(random_state=101, verbose=-1),
    'RF': RandomForestRegressor(random_state=101),
#     'GB': GradientBoostingRegressor(random_state=101),
    'ANN': MLPRegressor(random_state=101),
    # 'SVR': SVR(),
#     'Linear':,
#     'Ridge':,
#     'Lasso':,
}
model_space_feature = {
    'SVR': RandomForestRegressor(random_state=101),
    'KNN': RandomForestRegressor(random_state=101),
    'XGB': xgb.XGBRegressor(random_state=101),
    'LGBM': lgb.LGBMRegressor(random_state=101, verbose=-1),
    'RF': RandomForestRegressor(random_state=101),
    'GB': GradientBoostingRegressor(random_state=101),
    'ANN': RandomForestRegressor(random_state=101),
    # 'GRNN': RandomForestRegressor(random_state=101)
}
param_space = {
'SVR': {
    "C": optuna.distributions.FloatDistribution(1e-5, 1e5, log=True),
    'gamma': optuna.distributions.CategoricalDistribution(['scale', 'auto']), 
    'kernel': optuna.distributions.CategoricalDistribution(['linear', 'poly', 'rbf', 'sigmoid']),  
    # 'epsilon': optuna.distributions.FloatDistribution(0.01, 1),  
},
'RF':  {
    'max_features': optuna.distributions.CategoricalDistribution(['sqrt', 'log2']),
    'n_estimators': optuna.distributions.IntDistribution(50, 3001, 50),
    'max_depth': optuna.distributions.IntDistribution(1, 200),
    'min_samples_leaf': optuna.distributions.IntDistribution(1, 20),
    # 'criterion': Categorical(['absolute_error', 'friedman_mse'])
},
'GB':{
    'learning_rate': optuna.distributions.FloatDistribution(0.01, 1.0),
    'n_estimators': optuna.distributions.IntDistribution(50, 3001, 50),
    'max_depth': optuna.distributions.IntDistribution(1, 200),
    'min_samples_split': optuna.distributions.IntDistribution(2, 11),
    'min_samples_leaf': optuna.distributions.IntDistribution(1, 10),
    'subsample': optuna.distributions.FloatDistribution(0.1, 1.0),
},
'ANN': {
    'hidden_layer_sizes': optuna.distributions.CategoricalDistribution([(100,), (50,), (50, 50), (100, 100), (30, 30, 30)]),
    'activation': optuna.distributions.CategoricalDistribution(['tanh', 'relu', 'logistic']),
    'solver': optuna.distributions.CategoricalDistribution(['sgd', 'adam']),
    'alpha': optuna.distributions.FloatDistribution(1e-5, 1e5, log=True),
},
'KNN':{
    'n_neighbors': optuna.distributions.IntDistribution(1, 50),
    'weights': optuna.distributions.CategoricalDistribution(['uniform', 'distance']),
    'algorithm': optuna.distributions.CategoricalDistribution(['auto', 'ball_tree', 'kd_tree', 'brute'])
},    
'LGBM': {
    'learning_rate': optuna.distributions.FloatDistribution(0.01, 1.0),
    'n_estimators': optuna.distributions.IntDistribution(50, 3001, 50),
    'max_depth': optuna.distributions.IntDistribution(1, 50),
    'num_leaves': optuna.distributions.IntDistribution(2, 50),
    'min_child_samples': optuna.distributions.IntDistribution(1, 20),
    'subsample': optuna.distributions.FloatDistribution(0.1, 1.0),
    'colsample_bytree': optuna.distributions.FloatDistribution(0.1, 1.0),
},
'XGB': {
    'learning_rate': optuna.distributions.FloatDistribution(0.01, 1.0),
    'n_estimators': optuna.distributions.IntDistribution(50, 3001, 50),
    'max_depth': optuna.distributions.IntDistribution(1, 20),
    'max_leaves': optuna.distributions.IntDistribution(2, 50),
    'max_bin': optuna.distributions.IntDistribution(2, 50),
    'gamma': optuna.distributions.IntDistribution(1, 20),
},
# 'GRNN':{
#     'sigma' : np.arange(0.1, 4, 0.01)
# }
}

# %%
train_files = ['s-0.json', 's-1.json', 's-2.json', 's-3.json', 's-4.json','s-5.json', 's-6.json', 's-7.json', 's-8.json', 's-9.json'] 
test_files = ['s-15.json', 's-16.json', 's-17.json', 's-18.json','s-19.json']
validate_files = ['s-10.json', 's-11.json', 's-12.json', 's-13.json','s-14.json']
train_files = ['Data/cutoutWorlds/Train/po-1_pn-1.0_sn-1/' + i for i in train_files]
test_files = ['Data/cutoutWorlds/Test/po-1_pn-1.0_sn-1/' + j for j in test_files]
validate_files = ['Data/cutoutWorlds/Validate/po-1_pn-1.0_sn-1/' + k for k in validate_files]
df_activities = pd.read_pickle("Data/cutoutWorlds/Train/po-1_pn-1.0_sn-1/df_activities.pkl")
df_links_network = pd.read_pickle("Data/cutoutWorlds/Train/po-1_pn-1.0_sn-1/df_links_network.pkl")
train_data = load_data(train_files, df_activities, df_links_network)
validate_data = load_data(validate_files, df_activities, df_links_network)
test_data = load_data(test_files, df_activities, df_links_network)
train_data['dataset'] = 'train'
validate_data['dataset'] = 'validate'
test_data['dataset'] = 'test'
Big_data = pd.concat([train_data, validate_data, test_data], ignore_index=True)

# %%
# Find the indices where 'link_id' is 0
indices = Big_data.index[Big_data['link_id'] == 0].tolist()

# Add the end of the DataFrame to the indices list
indices.append(len(Big_data))

# Split the DataFrame using the indices
dfs = [Big_data.iloc[indices[n]:indices[n+1]] for n in range(len(indices)-1)]
list_od = []
list_nodes = []
all_files = train_files + validate_files + test_files
for i in all_files:
    with open(i) as f:
        d = json.load(f)
        list_od.append(d['o_d_pairs'])
        list_nodes.append(d['nodes_id'])
tuples_links = [ list(zip(dfs[i]['link_from'], dfs[i]['link_to'], dfs[i]['link_length'])) for i in range(20)]
list_od_tuples = [[(origin, destination) for origin, destination in list_od[i]]for i in range(20)]
import networkx as nx

# Assume `nodes` is a list of all node IDs and `edges` is a list of tuples (start_node, end_node, weight)
# For example:
# nodes = [1, 2, 3, 4, ...]
# edges = [(1, 2, 1.0), (2, 3, 2.5), (1, 3, 1.5), ...]
# And `o_d_pairs` is a list of tuples representing the O-D pairs:
# o_d_pairs = [(origin_1, destination_1), (origin_2, destination_2), ...]

shortest_paths_list = []
for i in range(20):
    G = nx.Graph()
    G.add_nodes_from(list_nodes[i])
    G.add_weighted_edges_from(tuples_links[i])
    shortest_paths = {}
    for origin, destination in list_od_tuples[i]:
        # This will find the shortest path by weight
        try:
            shortest_path = nx.shortest_path(G, source=origin, target=destination, weight='weight')
        except:
            shortest_path = []
        shortest_paths[(origin, destination)] = shortest_path
    shortest_paths_list.append(shortest_paths)
from collections import defaultdict
for i in range(20):
    link_usage_counts = defaultdict(int)

    # Iterate over each path and each link in the path
    for path in shortest_paths_list[i].values():
        for start_node, end_node in zip(path, path[1:]):
            # Order the nodes to avoid counting (node1, node2) and (node2, node1) separately
            ordered_link = tuple(sorted((start_node, end_node)))
            link_usage_counts[ordered_link] += 1

    # Now you have a dictionary with the count of usage for each link

    # Assume you have a DataFrame 'links_df' with columns ['node_start', 'node_end']
    # links_df = ...

    # Add a 'used_count' column to your links data
    dfs[i]['used_count'] = dfs[i].apply(
        lambda row: link_usage_counts[tuple(sorted((row['link_from'], row['link_to'])))],
        axis=1
    )
Big_data_new = pd.concat(dfs)

# %%
cluster = MiniBatchKMeans(n_clusters=500, random_state=101)
Big_data_new['x_y_coor'] = cluster.fit_predict(Big_data_new[['start_node_x', 'start_node_y',
                                                           'end_node_x', 'end_node_y']])
cluster1 = MiniBatchKMeans(n_clusters=500, random_state=101)
Big_data_new['similar_link'] = cluster1.fit_predict(Big_data_new[['link_length', 'link_freespeed',
                                                           'link_capacity', 'link_permlanes']])
cluster2 = MiniBatchKMeans(n_clusters=500, random_state=101)
Big_data_new['planxml'] = cluster2.fit_predict(Big_data_new[['income', 'score', 'rush_hour',
                                                               'max_dur', 'cemdapStopDuration_s']])

Big_data_new = Big_data_new.astype({'x_y_coor':'int64','similar_link':'int64', 'planxml':'int64'})

# %%
Big_data_tr = ct.fit_transform(Big_data_new)
Big_data_tr['used_link'] = 1
Big_data_tr['used_link'][Big_data_tr['remainder__link_counts']==0] = 0
Big_data_tr = Big_data_tr.reset_index(drop=True)
train_data_tr = Big_data_tr[Big_data_tr['remainder__dataset']=='train']
validate_data_tr = Big_data_tr[Big_data_tr['remainder__dataset']=='validate']
test_data_tr = Big_data_tr[Big_data_tr['remainder__dataset']=='test']

train_index = list(train_data_tr.index)
validate_index = list(validate_data_tr.index)

temp = pd.concat([train_data_tr, validate_data_tr], ignore_index=True)

# %%
X_t_clf = temp.drop(columns=['remainder__dataset', 'remainder__link_counts', 'used_link'])
y_t_clf = temp['used_link']

X_te_clf = test_data_tr.drop(columns=['remainder__dataset', 'remainder__link_counts', 'used_link'])
y_te_clf = test_data_tr['used_link']

# %%
best_model_clf = {}
for model_name in clf.keys():   
    model = clf[model_name]
    pipeline  = Pipeline([('selector', SelectKBest(f_regression)),
                  ('model', model)])
    param_grid = {}
    param_grid['selector__k']=optuna.distributions.IntDistribution(10, 48)
    for key in param_space[model_name].keys():
        param_grid[f'model__{key}']=param_space[model_name][key]
    
    # BayesSearchCV
    opt = OptunaSearchCV(
        pipeline,
        param_grid,
        n_trials=50,
        cv=[(train_index, validate_index), (train_index, validate_index)]
    )
    opt.fit(X_t_clf, y_t_clf)
    y_pred_clf = opt.predict(X_te_clf)
    best_model_clf[model_name] = [opt, opt.best_score_, y_pred_clf]
    print(model_name, opt.best_score_, accuracy_score(y_te_clf, y_pred_clf))
# Out:
# [I 2024-03-05 23:51:41,739] A new study created in memory with name: no-name-4813c196-b84e-462f-a668-28ef1a75d5c0
# [I 2024-03-05 23:51:42,574] Trial 0 finished with value: 0.8578973225251781 and parameters: {'selector__k': 38, 'model__n_neighbors': 3, 'model__weights': 'distance', 'model__algorithm': 'brute'}. Best is trial 0 with value: 0.8578973225251781.
# [I 2024-03-05 23:51:46,704] Trial 1 finished with value: 0.8985507246376812 and parameters: {'selector__k': 32, 'model__n_neighbors': 45, 'model__weights': 'uniform', 'model__algorithm': 'kd_tree'}. Best is trial 1 with value
 'model__n_neighbors': 47, 'model__weights': 'distance', 'model__algorithm': 'brute'}. Best is trial 27 with value: 0.9184475558830754.
# [I 2024-03-05 23:52:38,310] Trial 32 finished with value: 0.9174649963154016 and parameters: {'selector__k': 27, 'model__n_neighbors': 42, 'model__weights': 'distance', 'model__algorithm': 'brute'}. Best is trial 27 with value: 0.9184475558830754.
# [I 2024-03-05 23:52:39,357] Trial 33 finished with value: 0.9163596168017686 and parameters: {'selector__k': 32, 'model__n_neighbors': 36, 'model__weights': 'distance', 'model__algorithm': 'brute'}. Best is trial 27 with value: 0.9184475558830754.
# [I 2024-03-05 23:52:40,059] Trial 34 finished with value: 0.9064112011790715 and parameters: {'selector__k': 22, 'model__n_neighbors': 5, 'model__weights': 'distance', 'model__algorithm': 'brute'}. Best is trial 27 with value: 0.9184475558830754.
# [I 2024-03-05 23:52:42,149] Trial 35 finished with value: 0.8987963645295997 and parameters: {'selector__k': 34, 'model__n_neighbors': 46, 'model__weights': 'uniform', 'model__algorithm': 'brute'}. Best is trial 27 with value: 0.9184475558830754.
# [I 2024-03-05 23:52:43,298] Trial 36 finished with value: 0.9167280766396463 and parameters: {'selector__k': 30, 'model__n_neighbors': 47, 'model__weights': 'distance', 'model__algorithm': 'auto'}. Best is trial 27 with value: 0.9184475558830754.
# [I 2024-03-05 23:52:46,363] Trial 37 finished with value: 0.9129206583149103 and parameters: {'selector__k': 21, 'model__n_neighbors': 41, 'model__weights': 'distance', 'model__algorithm': 'ball_tree'}. Best is trial 27 with value: 0.9184475558830754.
# [I 2024-03-05 23:52:48,236] Trial 38 finished with value: 0.8992876443134366 and parameters: {'selector__k': 25, 'model__n_neighbors': 35, 'model__weights': 'uniform', 'model__algorithm': 'brute'}. Best is trial 27 with value: 0.9184475558830754.
# [I 2024-03-05 23:52:49,336] Trial 39 finished with value: 0.9166052566936871 and parameters: {'selector__k': 34, 'model__n_neighbors': 39, 'model__weights': 'distance', 'model__algorithm': 'brute'}. Best is trial 27 with value: 0.9184475558830754.
# [I 2024-03-05 23:52:50,359] Trial 40 finished with value: 0.9129206583149103 and parameters: {'selector__k': 14, 'model__n_neighbors': 49, 'model__weights': 'distance', 'model__algorithm': 'brute'}. Best is trial 27 with value: 0.9184475558830754.
# [I 2024-03-05 23:52:51,479] Trial 41 finished with value: 0.9183247359371162 and parameters: {'selector__k': 26, 'model__n_neighbors': 47, 'model__weights': 'distance', 'model__algorithm': 'brute'}. Best is trial 27 with value: 0.9184475558830754.
# [I 2024-03-05 23:52:52,602] Trial 42 finished with value: 0.9178334561532793 and parameters: {'selector__k': 27, 'model__n_neighbors': 45, 'model__weights': 'distance', 'model__algorithm': 'brute'}. Best is trial 27 with value: 0.9184475558830754.
# [I 2024-03-05 23:52:53,734] Trial 43 finished with value: 0.913289118152788 and parameters: {'selector__k': 24, 'model__n_neighbors': 47, 'model__weights': 'distance', 'model__algorithm': 'brute'}. Best is trial 27 with value: 0.9184475558830754.
# [I 2024-03-05 23:52:54,808] Trial 44 finished with value: 0.9118152788012773 and parameters: {'selector__k': 23, 'model__n_neighbors': 42, 'model__weights': 'distance', 'model__algorithm': 'brute'}. Best is trial 27 with value: 0.9184475558830754.
# [I 2024-03-05 23:52:56,021] Trial 45 finished with value: 0.9166052566936871 and parameters: {'selector__k': 30, 'model__n_neighbors': 44, 'model__weights': 'distance', 'model__algorithm': 'brute'}. Best is trial 27 with value: 0.9184475558830754.
# [I 2024-03-05 23:52:59,198] Trial 46 finished with value: 0.9123065585851142 and parameters: {'selector__k': 20, 'model__n_neighbors': 49, 'model__weights': 'distance', 'model__algorithm': 'ball_tree'}. Best is trial 27 with value: 0.9184475558830754.
# [I 2024-03-05 23:53:01,149] Trial 47 finished with value: 0.9000245639891918 and parameters: {'selector__k': 26, 'model__n_neighbors': 34, 'model__weights': 'uniform', 'model__algorithm': 'auto'}. Best is trial 27 with value: 0.9184475558830754.
# [I 2024-03-05 23:53:02,187] Trial 48 finished with value: 0.9116924588553181 and parameters: {'selector__k': 16, 'model__n_neighbors': 48, 'model__weights': 'distance', 'model__algorithm': 'brute'}. Best is trial 27 with value: 0.9184475558830754.
# [I 2024-03-05 23:53:03,197] Trial 49 finished with value: 0.8259641365757799 and parameters: {'selector__k': 46, 'model__n_neighbors': 9, 'model__weights': 'distance', 'model__algorithm': 'brute'}. Best is trial 27 with value: 0.9184475558830754.
# [I 2024-03-05 23:53:03,718] A new study created in memory with name: no-name-b8f44449-2842-4e47-a6fb-0429bd7c0504
# KNN 0.9184475558830754 0.9338586745898463
# [I 2024-03-05 23:53:04,771] Trial 0 finished with value: 0.8807418324735937 and parameters: {'selector__k': 16, 'model__learning_rate': 0.9285522933713125, 'model__n_estimators': 396, 'model__max_depth': 39, 'model__num_leaves': 14, 'model__min_child_samples': 10, 'model__subsample': 0.9900204663236737, 'model__colsample_bytree': 0.3644544821196235}. Best is trial 0 with value: 0.8807418324735937.
# [I 2024-03-05 23:53:05,910] Trial 1 finished with value: 0.8929010071235569 and parameters: {'selector__k': 26, 'model__learning_rate': 0.5323687712891098, 'model__n_estimators': 250, 'model__max_depth': 26, 'model__num_leaves': 18, 'model__min_child_samples': 1, 'model__subsample': 0.860764693575216, 'model__colsample_bytree': 0.11199347182659802}. Best is trial 1 with value: 0.8929010071235569.
# [I 2024-03-05 23:53:06,482] Trial 2 finished with value: 0.8602309014984033 and parameters: {'selector__k': 12, 'model__learning_rate': 0.8184882780562812, 'model__n_estimators': 74, 'model__max_depth': 15, 'model__num_leaves': 24, 'model__min_child_samples': 7, 'model__subsample': 0.14254326022523162, 'model__colsample_bytree': 0.7438835955660311}. Best is trial 1 with value: 0.8929010071235569.
# [I 2024-03-05 23:53:08,179] Trial 3 finished with value: 0.9060427413411938 and parameters: {'selector__k': 21, 'model__learning_rate': 0.9371991269265666, 'model__n_estimators': 982, 'model__max_depth': 2, 'model__num_leaves': 10, 'model__min_child_samples': 17, 'model__subsample': 0.1741529821727699, 'model__colsample_bytree': 0.12289628500676401}. Best is trial 3 with value: 0.9060427413411938.
# [I 2024-03-05 23:53:08,869] Trial 4 finished with value: 0.9112011790714812 and parameters: {'selector__k': 20, 'model__learning_rate': 0.3919991578092783, 'model__n_estimators': 156, 'model__max_depth': 4, 'model__num_leaves': 43, 'model__min_child_samples': 20, 'model__subsample': 0.21534315850488736, 'model__colsample_bytree': 0.6357529378594572}. Best is trial 4 with value: 0.9112011790714812.
# [I 2024-03-05 23:53:10,457] Trial 5 finished with value: 0.9123065585851142 and parameters: {'selector__k': 45, 'model__learning_rate': 0.616408513682723, 'model__n_estimators': 768, 'model__max_depth': 25, 'model__num_leaves': 3, 'model__min_child_samples': 10, 'model__subsample': 0.1647046384958697, 'model__colsample_bytree': 0.1017219841323504}. Best is trial 5 with value: 0.9123065585851142.
# [I 2024-03-05 23:53:11,152] Trial 6 finished with value: 0.9067796610169492 and parameters: {'selector__k': 44, 'model__learning_rate': 0.48886392309462506, 'model__n_estimators': 94, 'model__max_depth': 33, 'model__num_leaves': 9, 'model__min_child_samples': 13, 'model__subsample': 0.4417291671053907, 'model__colsample_bytree': 0.5714779186223129}. Best is trial 5 with value: 0.9123065585851142.
# [I 2024-03-05 23:53:17,004] Trial 7 finished with value: 0.8797592729059199 and parameters: {'selector__k': 12, 'model__learning_rate': 0.5831832471892267, 'model__n_estimators': 1882, 'model__max_depth': 30, 'model__num_leaves': 46, 'model__min_child_samples': 6, 'model__subsample': 0.8244408089979621, 'model__colsample_bytree': 0.8409289774197215}. Best is trial 5 with value: 0.9123065585851142.
# [I 2024-03-05 23:53:17,808] Trial 8 finished with value: 0.9083763203144191 and parameters: {'selector__k': 14, 'model__learning_rate': 0.971681820064993, 'model__n_estimators': 156, 'model__max_depth': 45, 'model__num_leaves': 30, 'model__min_child_samples': 19, 'model__subsample': 0.7750508925589237, 'model__colsample_bytree': 0.12725877829639945}. Best is trial 5 with value: 0.9123065585851142.
# [I 2024-03-05 23:53:19,185] Trial 9 finished with value: 0.9086219602063376 and parameters: {'selector__k': 18, 'model__learning_rate': 0.1417365221728708, 'model__n_estimators': 463, 'model__max_depth': 24, 'model__num_leaves': 13, 'model__min_child_samples': 3, 'model__subsample': 0.8511972703592798, 'model__colsample_bytree': 0.27932245850617354}. Best is trial 5 with value: 0.9123065585851142.
# [I 2024-03-05 23:53:21,462] Trial 10 finished with value: 0.9177106362073201 and parameters: {'selector__k': 48, 'model__learning_rate': 0.21511954044787596, 'model__n_estimators': 962, 'model__max_depth': 15, 'model__num_leaves': 4, 'model__min_child_samples': 14, 'model__subsample': 0.40756821318232933, 'model__colsample_bytree': 0.36223614858734043}. Best is trial 10 with value: 0.9177106362073201.
# [I 2024-03-05 23:53:23,876] Trial 11 finished with value: 0.9156226971260133 and parameters: {'selector__k': 47, 'model__learning_rate': 0.1261301051593064, 'model__n_estimators': 940, 'model__max_depth': 16, 'model__num_leaves': 5, 'model__min_child_samples': 13, 'model__subsample': 0.40937815409057543, 'model__colsample_bytree': 0.37643629480928564}. Best is trial 10 with value: 0.9177106362073201.
# [I 2024-03-05 23:53:27,956] Trial 12 finished with value: 0.9169737165315647 and parameters: {'selector__k': 37, 'model__learning_rate': 0.0638906013310037, 'model__n_estimators': 2413, 'model__max_depth': 14, 'model__num_leaves': 2, 'model__min_child_samples': 14, 'model__subsample': 0.47030725118771294, 'model__colsample_bytree': 0.4171203588628517}. Best is trial 10 with value: 0.9177106362073201.
# [I 2024-03-05 23:53:32,962] Trial 13 finished with value: 0.9123065585851142 and parameters: {'selector__k': 37, 'model__learning_rate': 0.26926345132679463, 'model__n_estimators': 2582, 'model__max_depth': 13, 'model__num_leaves': 3, 'model__min_child_samples': 15, 'model__subsample': 0.5850551805879733, 'model__colsample_bytree': 0.4442451720587496}. Best is trial 10 with value: 0.9177106362073201.
# [I 2024-03-05 23:53:41,623] Trial 14 finished with value: 0.9250798329648735 and parameters: {'selector__k': 36, 'model__learning_rate': 0.04178906146781794, 'model__n_estimators': 1642, 'model__max_depth': 9, 'model__num_leaves': 34, 'model__min_child_samples': 15, 'model__subsample': 0.5819334626536751, 'model__colsample_bytree': 0.48618046924669117}. Best is trial 14 with value: 0.9250798329648735.
# [I 2024-03-05 23:53:48,396] Trial 15 finished with value: 0.9200442151805454 and parameters: {'selector__k': 37, 'model__learning_rate': 0.26340808844340635, 'model__n_estimators': 1365, 'model__max_depth': 7, 'model__num_leaves': 36, 'model__min_child_samples': 16, 'model__subsample': 0.6220068941261327, 'model__colsample_bytree': 0.5235407292815585}. Best is trial 14 with value: 0.9250798329648735.
# [I 2024-03-05 23:53:56,748] Trial 16 finished with value: 0.9229918938835667 and parameters: {'selector__k': 35, 'model__learning_rate': 0.33069003548021425, 'model__n_estimators': 1434, 'model__max_depth': 9, 'model__num_leaves': 37, 'model__min_child_samples': 17, 'model__subsample': 0.6615398854324699, 'model__colsample_bytree': 0.6784481486057667}. Best is trial 14 with value: 0.9250798329648735.
# [I 2024-03-05 23:54:09,333] Trial 17 finished with value: 0.9234831736674036 and parameters: {'selector__k': 30, 'model__learning_rate': 0.028007064577922437, 'model__n_estimators': 1717, 'model__max_depth': 8, 'model__num_leaves': 37, 'model__min_child_samples': 18, 'model__subsample': 0.6896458054824238, 'model__colsample_bytree': 0.942768405119031}. Best is trial 14 with value: 0.9250798329648735.
# [I 2024-03-05 23:54:29,242] Trial 18 finished with value: 0.922623434045689 and parameters: {'selector__k': 30, 'model__learning_rate': 0.015074610416214107, 'model__n_estimators': 2973, 'model__max_depth': 19, 'model__num_leaves': 50, 'model__min_child_samples': 18, 'model__subsample': 0.7137793420461805, 'model__colsample_bytree': 0.9081206506885963}. Best is trial 14 with value: 0.9250798329648735.
# [I 2024-03-05 23:54:30,289] Trial 19 finished with value: 0.9153770572340948 and parameters: {'selector__k': 31, 'model__learning_rate': 0.15752241068597278, 'model__n_estimators': 513, 'model__max_depth': 1, 'model__num_leaves': 29, 'model__min_child_samples': 20, 'model__subsample': 0.327766832295237, 'model__colsample_bytree': 0.9355358399019092}. Best is trial 14 with value: 0.9250798329648735.
# [I 2024-03-05 23:54:32,532] Trial 20 finished with value: 0.8554409236059937 and parameters: {'selector__k': 25, 'model__learning_rate': 0.7124789522382228, 'model__n_estimators': 624, 'model__max_depth': 9, 'model__num_leaves': 37, 'model__min_child_samples': 12, 'model__subsample': 0.5345242121245801, 'model__colsample_bytree': 0.794095868327551}. Best is trial 14 with value: 0.9250798329648735.
# [I 2024-03-05 23:54:39,161] Trial 21 finished with value: 0.9228690739376074 and parameters: {'selector__k': 34, 'model__learning_rate': 0.3603416800679635, 'model__n_estimators': 1468, 'model__max_depth': 9, 'model__num_leaves': 37, 'model__min_child_samples': 16, 'model__subsample': 0.6791419174936939, 'model__colsample_bytree': 0.6948580205642807}. Best is trial 14 with value: 0.9250798329648735.
# [I 2024-03-05 23:54:47,381] Trial 22 finished with value: 0.927536231884058 and parameters: {'selector__k': 41, 'model__learning_rate': 0.3619915633638472, 'model__n_estimators': 1537, 'model__max_depth': 20, 'model__num_leaves': 33, 'model__min_child_samples': 18, 'model__subsample': 0.701261768954891, 'model__colsample_bytree': 0.5584190325660325}. Best is trial 22 with value: 0.927536231884058.
# [I 2024-03-05 23:54:55,283] Trial 23 finished with value: 0.9179562760992385 and parameters: {'selector__k': 41, 'model__learning_rate': 0.022739366059086184, 'model__n_estimators': 1895, 'model__max_depth': 20, 'model__num_leaves': 24, 'model__min_child_samples': 18, 'model__subsample': 0.5283504417603027, 'model__colsample_bytree': 0.24966276836283802}. Best is trial 22 with value: 0.927536231884058.
# [I 2024-03-05 23:54:57,247] Trial 24 finished with value: 0.9211495946941783 and parameters: {'selector__k': 41, 'model__learning_rate': 0.462972278859254, 'model__n_estimators': 281, 'model__max_depth': 20, 'model__num_leaves': 31, 'model__min_child_samples': 18, 'model__subsample': 0.7358862876436724, 'model__colsample_bytree': 0.5953602716542084}. Best is trial 22 with value: 0.927536231884058.
# [I 2024-03-05 23:55:05,824] Trial 25 finished with value: 0.9225006140997298 and parameters: {'selector__k': 41, 'model__learning_rate': 0.0878867090159498, 'model__n_estimators': 1872, 'model__max_depth': 5, 'model__num_leaves': 42, 'model__min_child_samples': 16, 'model__subsample': 0.9114099418944296, 'model__colsample_bytree': 0.5005539323657482}. Best is trial 22 with value: 0.927536231884058.
# [I 2024-03-05 23:55:12,141] Trial 26 finished with value: 0.918201915991157 and parameters: {'selector__k': 26, 'model__learning_rate': 0.2556799205596222, 'model__n_estimators': 1226, 'model__max_depth': 11, 'model__num_leaves': 34, 'model__min_child_samples': 20, 'model__subsample': 0.620106018571824, 'model__colsample_bytree': 0.9667338585659486}. Best is trial 22 with value: 0.927536231884058.
# [I 2024-03-05 23:55:16,565] Trial 27 finished with value: 0.9227462539916482 and parameters: {'selector__k': 33, 'model__learning_rate': 0.19333570927682617, 'model__n_estimators': 692, 'model__max_depth': 34, 'model__num_leaves': 42, 'model__min_child_samples': 11, 'model__subsample': 0.7725343259107752, 'model__colsample_bytree': 0.8450942682583553}. Best is trial 22 with value: 0.927536231884058.
# [I 2024-03-05 23:55:25,472] Trial 28 finished with value: 0.9252026529108327 and parameters: {'selector__k': 39, 'model__learning_rate': 0.4154151760240321, 'model__n_estimators': 2154, 'model__max_depth': 19, 'model__num_leaves': 20, 'model__min_child_samples': 8, 'model__subsample': 0.2888264759326004, 'model__colsample_bytree': 0.28663260506030075}. Best is trial 22 with value: 0.927536231884058.
# [I 2024-03-05 23:55:30,692] Trial 29 finished with value: 0.8300171947924343 and parameters: {'selector__k': 39, 'model__learning_rate': 0.4296847283937003, 'model__n_estimators': 2290, 'model__max_depth': 39, 'model__num_leaves': 20, 'model__min_child_samples': 8, 'model__subsample': 0.28505631995867137, 'model__colsample_bytree': 0.2646009723417426}. Best is trial 22 with value: 0.927536231884058.
# [I 2024-03-05 23:55:32,400] Trial 30 finished with value: 0.867231638418079 and parameters: {'selector__k': 44, 'model__learning_rate': 0.6779894269007725, 'model__n_estimators': 323, 'model__max_depth': 22, 'model__num_leaves': 19, 'model__min_child_samples': 9, 'model__subsample': 0.9687771286480777, 'model__colsample_bytree': 0.31608334801356885}. Best is trial 22 with value: 0.927536231884058.
# [I 2024-03-05 23:55:37,746] Trial 31 finished with value: 0.8273151559813313 and parameters: {'selector__k': 28, 'model__learning_rate': 0.32016955319764473, 'model__n_estimators': 1785, 'model__max_depth': 17, 'model__num_leaves': 28, 'model__min_child_samples': 5, 'model__subsample': 0.5029944477981328, 'model__colsample_bytree': 0.4625964445544402}. Best is trial 22 with value: 0.927536231884058.
# [I 2024-03-05 23:55:40,567] Trial 32 finished with value: 0.5315647261115205 and parameters: {'selector__k': 34, 'model__learning_rate': 0.5268393315430229, 'model__n_estimators': 1156, 'model__max_depth': 28, 'model__num_leaves': 33, 'model__min_child_samples': 4, 'model__subsample': 0.5845964892591509, 'model__colsample_bytree': 0.21107114386785558}. Best is trial 22 with value: 0.927536231884058.
# [I 2024-03-05 23:55:45,469] Trial 33 finished with value: 0.8699950872021616 and parameters: {'selector__k': 32, 'model__learning_rate': 0.8673873085202741, 'model__n_estimators': 2911, 'model__max_depth': 12, 'model__num_leaves': 25, 'model__min_child_samples': 8, 'model__subsample': 0.34167423719494094, 'model__colsample_bytree': 0.7535540484324933}. Best is trial 22 with value: 0.927536231884058.
# [I 2024-03-05 23:55:52,210] Trial 34 finished with value: 0.9205354949643823 and parameters: {'selector__k': 28, 'model__learning_rate': 0.4168417601621678, 'model__n_estimators': 1635, 'model__max_depth': 6, 'model__num_leaves': 39, 'model__min_child_samples': 11, 'model__subsample': 0.1008434989957177, 'model__colsample_bytree': 0.18476794506001604}. Best is trial 22 with value: 0.927536231884058.
# [I 2024-03-05 23:56:01,406] Trial 35 finished with value: 0.9249570130189143 and parameters: {'selector__k': 40, 'model__learning_rate': 0.0756733110984776, 'model__n_estimators': 2082, 'model__max_depth': 23, 'model__num_leaves': 22, 'model__min_child_samples': 1, 'model__subsample': 0.6640486016749656, 'model__colsample_bytree': 0.6200353338379865}. Best is trial 22 with value: 0.927536231884058.
# [I 2024-03-05 23:56:10,876] Trial 36 finished with value: 0.9259395725865881 and parameters: {'selector__k': 42, 'model__learning_rate': 0.08570053537450857, 'model__n_estimators': 2231, 'model__max_depth': 28, 'model__num_leaves': 21, 'model__min_child_samples': 1, 'model__subsample': 0.2527412489584629, 'model__colsample_bytree': 0.6358247781216597}. Best is trial 22 with value: 0.927536231884058.
# [I 2024-03-05 23:56:15,089] Trial 37 finished with value: 0.9189388356669123 and parameters: {'selector__k': 43, 'model__learning_rate': 0.1988968360524526, 'model__n_estimators': 1097, 'model__max_depth': 27, 'model__num_leaves': 14, 'model__min_child_samples': 2, 'model__subsample': 0.23261041857278353, 'model__colsample_bytree': 0.5221191786322291}. Best is trial 22 with value: 0.927536231884058.
# [I 2024-03-05 23:56:18,344] Trial 38 finished with value: 0.8206828788995333 and parameters: {'selector__k': 46, 'model__learning_rate': 0.7524195123109096, 'model__n_estimators': 828, 'model__max_depth': 31, 'model__num_leaves': 15, 'model__min_child_samples': 9, 'model__subsample': 0.2539006568863232, 'model__colsample_bytree': 0.6665187193925894}. Best is trial 22 with value: 0.927536231884058.
# [I 2024-03-05 23:56:29,184] Trial 39 finished with value: 0.9263694423974453 and parameters: {'selector__k': 38, 'model__learning_rate': 0.31783688214412875, 'model__n_estimators': 2278, 'model__max_depth': 36, 'model__num_leaves': 22, 'model__min_child_samples': 6, 'model__subsample': 0.33405751962181446, 'model__colsample_bytree': 0.5784158034141906}. Best is trial 22 with value: 0.927536231884058.
# [I 2024-03-05 23:56:30,305] Trial 40 finished with value: 0.8997789240972734 and parameters: {'selector__k': 43, 'model__learning_rate': 0.5588546187293215, 'model__n_estimators': 170, 'model__max_depth': 37, 'model__num_leaves': 17, 'model__min_child_samples': 6, 'model__subsample': 0.19635829167300628, 'model__colsample_bytree': 0.5733220445365781}. Best is trial 22 with value: 0.927536231884058.
# [I 2024-03-05 23:56:40,892] Trial 41 finished with value: 0.9279046917219357 and parameters: {'selector__k': 38, 'model__learning_rate': 0.3175553297538714, 'model__n_estimators': 2269, 'model__max_depth': 48, 'model__num_leaves': 27, 'model__min_child_samples': 7, 'model__subsample': 0.3517435389053023, 'model__colsample_bytree': 0.4889903463301983}. Best is trial 41 with value: 0.9279046917219357.
# [I 2024-03-05 23:56:50,617] Trial 42 finished with value: 0.9267993122083026 and parameters: {'selector__k': 38, 'model__learning_rate': 0.372138063391367, 'model__n_estimators': 2296, 'model__max_depth': 50, 'model__num_leaves': 23, 'model__min_child_samples': 7, 'model__subsample': 0.3364407076179901, 'model__colsample_bytree': 0.5510029037341723}. Best is trial 41 with value: 0.9279046917219357.
# [I 2024-03-05 23:57:03,408] Trial 43 finished with value: 0.9281503316138541 and parameters: {'selector__k': 38, 'model__learning_rate': 0.3057990550193053, 'model__n_estimators': 2958, 'model__max_depth': 48, 'model__num_leaves': 27, 'model__min_child_samples': 6, 'model__subsample': 0.3472644957166618, 'model__colsample_bytree': 0.6250927319118981}. Best is trial 43 with value: 0.9281503316138541.
# [I 2024-03-05 23:57:10,624] Trial 44 finished with value: 0.8596782117415869 and parameters: {'selector__k': 38, 'model__learning_rate': 0.3569711406124567, 'model__n_estimators': 2885, 'model__max_depth': 50, 'model__num_leaves': 23, 'model__min_child_samples': 6, 'model__subsample': 0.3715047395953514, 'model__colsample_bytree': 0.5472510637801726}. Best is trial 43 with value: 0.9281503316138541.
# [I 2024-03-05 23:57:11,506] Trial 45 finished with value: 0.9043232620977647 and parameters: {'selector__k': 45, 'model__learning_rate': 0.47349974836185804, 'model__n_estimators': 71, 'model__max_depth': 46, 'model__num_leaves': 27, 'model__min_child_samples': 5, 'model__subsample': 0.43714737536389525, 'model__colsample_bytree': 0.7168844236944109}. Best is trial 43 with value: 0.9281503316138541.
# [I 2024-03-05 23:57:23,364] Trial 46 finished with value: 0.9307295504789979 and parameters: {'selector__k': 39, 'model__learning_rate': 0.3016837592398889, 'model__n_estimators': 2493, 'model__max_depth': 44, 'model__num_leaves': 27, 'model__min_child_samples': 7, 'model__subsample': 0.3769423304252496, 'model__colsample_bytree': 0.4384695709016736}. Best is trial 46 with value: 0.9307295504789979.
# [I 2024-03-05 23:57:24,103] Trial 47 finished with value: 0.914394497666421 and parameters: {'selector__k': 35, 'model__learning_rate': 0.28652384400921416, 'model__n_estimators': 54, 'model__max_depth': 46, 'model__num_leaves': 31, 'model__min_child_samples': 7, 'model__subsample': 0.3697449310290693, 'model__colsample_bytree': 0.3774125681426823}. Best is trial 46 with value: 0.9307295504789979.
# [I 2024-03-05 23:57:36,414] Trial 48 finished with value: 0.9260623925325473 and parameters: {'selector__k': 39, 'model__learning_rate': 0.3651694584423415, 'model__n_estimators': 2587, 'model__max_depth': 43, 'model__num_leaves': 26, 'model__min_child_samples': 4, 'model__subsample': 0.45186062060071536, 'model__colsample_bytree': 0.430227099741831}. Best is trial 46 with value: 0.9307295504789979.
# [I 2024-03-05 23:57:42,573] Trial 49 finished with value: 0.9227462539916482 and parameters: {'selector__k': 36, 'model__learning_rate': 0.22115404864932345, 'model__n_estimators': 1381, 'model__max_depth': 50, 'model__num_leaves': 27, 'model__min_child_samples': 10, 'model__subsample': 0.39505349332156103, 'model__colsample_bytree': 0.39576448439181466}. Best is trial 46 with value: 0.9307295504789979.
# [I 2024-03-05 23:57:46,977] A new study created in memory with name: no-name-ceb4e493-ed55-4c33-a310-a38a3bafdccf
# LGBM 0.9307295504789979 0.8137191577315592
# [I 2024-03-05 23:57:50,735] Trial 0 finished with value: 0.9118152788012773 and parameters: {'selector__k': 24, 'model__max_features': 'log2', 'model__n_estimators': 63, 'model__max_depth': 91, 'model__min_samples_leaf': 5}. Best is trial 0 with value: 0.9118152788012773.
# [I 2024-03-05 23:58:38,570] Trial 1 finished with value: 0.9053058216654385 and parameters: {'selector__k': 24, 'model__max_features': 'log2', 'model__n_estimators': 947, 'model__max_depth': 34, 'model__min_samples_leaf': 10}. Best is trial 0 with value: 0.9118152788012773.
# [I 2024-03-05 23:58:41,492] Trial 2 finished with value: 0.9048145418816016 and parameters: {'selector__k': 16, 'model__max_features': 'log2', 'model__n_estimators': 74, 'model__max_depth': 158, 'model__min_samples_leaf': 18}. Best is trial 0 with value: 0.9118152788012773.
# [I 2024-03-05 23:59:00,899] Trial 3 finished with value: 0.9073937607467453 and parameters: {'selector__k': 11, 'model__max_features': 'log2', 'model__n_estimators': 628, 'model__max_depth': 92, 'model__min_samples_leaf': 3}. Best is trial 0 with value: 0.9118152788012773.
# [I 2024-03-06 00:00:19,334] Trial 4 finished with value: 0.9097273397199706 and parameters: {'selector__k': 33, 'model__max_features': 'log2', 'model__n_estimators': 987, 'model__max_depth': 158, 'model__min_samples_leaf': 9}. Best is trial 0 with value: 0.9118152788012773.
# [I 2024-03-06 00:03:11,959] Trial 5 finished with value: 0.9089904200442152 and parameters: {'selector__k': 38, 'model__max_features': 'sqrt', 'model__n_estimators': 1713, 'model__max_depth': 101, 'model__min_samples_leaf': 20}. Best is trial 0 with value: 0.9118152788012773.
# [I 2024-03-06 00:04:25,351] Trial 6 finished with value: 0.9107098992876443 and parameters: {'selector__k': 26, 'model__max_features': 'log2', 'model__n_estimators': 996, 'model__max_depth': 179, 'model__min_samples_leaf': 4}. Best is trial 0 with value: 0.9118152788012773.
# [I 2024-03-06 00:04:29,945] Trial 7 finished with value: 0.9092360599361337 and parameters: {'selector__k': 34, 'model__max_features': 'sqrt', 'model__n_estimators': 57, 'model__max_depth': 37, 'model__min_samples_leaf': 9}. Best is trial 0 with value: 0.9118152788012773.
# [I 2024-03-06 00:05:14,945] Trial 8 finished with value: 0.9087447801522968 and parameters: {'selector__k': 47, 'model__max_features': 'sqrt', 'model__n_estimators': 374, 'model__max_depth': 120, 'model__min_samples_leaf': 15}. Best is trial 0 with value: 0.9118152788012773.
# [I 2024-03-06 00:05:28,321] Trial 9 finished with value: 0.908867600098256 and parameters: {'selector__k': 32, 'model__max_features': 'log2', 'model__n_estimators': 178, 'model__max_depth': 193, 'model__min_samples_leaf': 19}. Best is trial 0 with value: 0.9118152788012773.
# [I 2024-03-06 00:05:35,943] Trial 10 finished with value: 0.912183738639155 and parameters: {'selector__k': 18, 'model__max_features': 'sqrt', 'model__n_estimators': 150, 'model__max_depth': 67, 'model__min_samples_leaf': 1}. Best is trial 10 with value: 0.912183738639155.
# [I 2024-03-06 00:05:47,317] Trial 11 finished with value: 0.909481699828052 and parameters: {'selector__k': 19, 'model__max_features': 'sqrt', 'model__n_estimators': 136, 'model__max_depth': 66, 'model__min_samples_leaf': 1}. Best is trial 10 with value: 0.912183738639155.
# [I 2024-03-06 00:05:55,731] Trial 12 finished with value: 0.9098501596659297 and parameters: {'selector__k': 21, 'model__max_features': 'sqrt', 'model__n_estimators': 143, 'model__max_depth': 66, 'model__min_samples_leaf': 5}. Best is trial 10 with value: 0.912183738639155.
# [I 2024-03-06 00:06:03,937] Trial 13 finished with value: 0.9048145418816016 and parameters: {'selector__k': 11, 'model__max_features': 'sqrt', 'model__n_estimators': 306, 'model__max_depth': 9, 'model__min_samples_leaf': 7}. Best is trial 10 with value: 0.912183738639155.
# [I 2024-03-06 00:06:08,427] Trial 14 finished with value: 0.9116924588553181 and parameters: {'selector__k': 16, 'model__max_features': 'log2', 'model__n_estimators': 88, 'model__max_depth': 128, 'model__min_samples_leaf': 1}. Best is trial 10 with value: 0.912183738639155.
# [I 2024-03-06 00:06:12,674] Trial 15 finished with value: 0.9084991402603783 and parameters: {'selector__k': 26, 'model__max_features': 'sqrt', 'model__n_estimators': 51, 'model__max_depth': 72, 'model__min_samples_leaf': 13}. Best is trial 10 with value: 0.912183738639155.
# [I 2024-03-06 00:06:33,896] Trial 16 finished with value: 0.9112011790714812 and parameters: {'selector__k': 39, 'model__max_features': 'log2', 'model__n_estimators': 204, 'model__max_depth': 39, 'model__min_samples_leaf': 7}. Best is trial 10 with value: 0.912183738639155.
# [I 2024-03-06 00:06:39,638] Trial 17 finished with value: 0.9087447801522968 and parameters: {'selector__k': 19, 'model__max_features': 'sqrt', 'model__n_estimators': 97, 'model__max_depth': 91, 'model__min_samples_leaf': 6}. Best is trial 10 with value: 0.912183738639155.
# [I 2024-03-06 00:07:04,780] Trial 18 finished with value: 0.9164824367477278 and parameters: {'selector__k': 29, 'model__max_features': 'sqrt', 'model__n_estimators': 271, 'model__max_depth': 123, 'model__min_samples_leaf': 2}. Best is trial 18 with value: 0.9164824367477278.
# [I 2024-03-06 00:07:45,203] Trial 19 finished with value: 0.9166052566936871 and parameters: {'selector__k': 48, 'model__max_features': 'sqrt', 'model__n_estimators': 275, 'model__max_depth': 128, 'model__min_samples_leaf': 3}. Best is trial 19 with value: 0.9166052566936871.
# [I 2024-03-06 00:08:54,858] Trial 20 finished with value: 0.9100957995578481 and parameters: {'selector__k': 48, 'model__max_features': 'sqrt', 'model__n_estimators': 561, 'model__max_depth': 135, 'model__min_samples_leaf': 14}. Best is trial 19 with value: 0.9166052566936871.
# [I 2024-03-06 00:09:28,280] Trial 21 finished with value: 0.9200442151805454 and parameters: {'selector__k': 41, 'model__max_features': 'sqrt', 'model__n_estimators': 252, 'model__max_depth': 148, 'model__min_samples_leaf': 2}. Best is trial 21 with value: 0.9200442151805454.
# [I 2024-03-06 00:10:03,752] Trial 22 finished with value: 0.917096536477524 and parameters: {'selector__k': 43, 'model__max_features': 'sqrt', 'model__n_estimators': 264, 'model__max_depth': 149, 'model__min_samples_leaf': 3}. Best is trial 21 with value: 0.9200442151805454.
# [I 2024-03-06 00:11:06,834] Trial 23 finished with value: 0.9167280766396463 and parameters: {'selector__k': 42, 'model__max_features': 'sqrt', 'model__n_estimators': 484, 'model__max_depth': 153, 'model__min_samples_leaf': 3}. Best is trial 21 with value: 0.9200442151805454.
# [I 2024-03-06 00:12:21,131] Trial 24 finished with value: 0.9163596168017686 and parameters: {'selector__k': 43, 'model__max_features': 'sqrt', 'model__n_estimators': 562, 'model__max_depth': 154, 'model__min_samples_leaf': 3}. Best is trial 21 with value: 0.9200442151805454.
# [I 2024-03-06 00:13:18,043] Trial 25 finished with value: 0.9114468189633996 and parameters: {'selector__k': 43, 'model__max_features': 'sqrt', 'model__n_estimators': 469, 'model__max_depth': 176, 'model__min_samples_leaf': 7}. Best is trial 21 with value: 0.9200442151805454.
# [I 2024-03-06 00:18:42,342] Trial 26 finished with value: 0.9098501596659297 and parameters: {'selector__k': 42, 'model__max_features': 'sqrt', 'model__n_estimators': 2880, 'model__max_depth': 145, 'model__min_samples_leaf': 12}. Best is trial 21 with value: 0.9200442151805454.
# [I 2024-03-06 00:19:06,744] Trial 27 finished with value: 0.9113239990174404 and parameters: {'selector__k': 37, 'model__max_features': 'sqrt', 'model__n_estimators': 216, 'model__max_depth': 174, 'model__min_samples_leaf': 5}. Best is trial 21 with value: 0.9200442151805454.
# [I 2024-03-06 00:19:59,516] Trial 28 finished with value: 0.9127978383689511 and parameters: {'selector__k': 45, 'model__max_features': 'sqrt', 'model__n_estimators': 416, 'model__max_depth': 194, 'model__min_samples_leaf': 4}. Best is trial 21 with value: 0.9200442151805454.
# [I 2024-03-06 00:20:43,238] Trial 29 finished with value: 0.9186931957749939 and parameters: {'selector__k': 40, 'model__max_features': 'sqrt', 'model__n_estimators': 328, 'model__max_depth': 112, 'model__min_samples_leaf': 2}. Best is trial 21 with value: 0.9200442151805454.
# [I 2024-03-06 00:20:56,883] Trial 30 finished with value: 0.9113239990174404 and parameters: {'selector__k': 40, 'model__max_features': 'sqrt', 'model__n_estimators': 112, 'model__max_depth': 109, 'model__min_samples_leaf': 6}. Best is trial 21 with value: 0.9200442151805454.
# [I 2024-03-06 00:21:34,933] Trial 31 finished with value: 0.917096536477524 and parameters: {'selector__k': 36, 'model__max_features': 'sqrt', 'model__n_estimators': 335, 'model__max_depth': 142, 'model__min_samples_leaf': 2}. Best is trial 21 with value: 0.9200442151805454.
# [I 2024-03-06 00:22:09,618] Trial 32 finished with value: 0.9172193564234832 and parameters: {'selector__k': 35, 'model__max_features': 'sqrt', 'model__n_estimators': 342, 'model__max_depth': 141, 'model__min_samples_leaf': 2}. Best is trial 21 with value: 0.9200442151805454.
# [I 2024-03-06 00:22:43,747] Trial 33 finished with value: 0.9188160157209531 and parameters: {'selector__k': 40, 'model__max_features': 'sqrt', 'model__n_estimators': 253, 'model__max_depth': 114, 'model__min_samples_leaf': 2}. Best is trial 21 with value: 0.9200442151805454.
# [I 2024-03-06 00:23:07,023] Trial 34 finished with value: 0.926430852370425 and parameters: {'selector__k': 35, 'model__max_features': 'sqrt', 'model__n_estimators': 214, 'model__max_depth': 112, 'model__min_samples_leaf': 1}. Best is trial 34 with value: 0.926430852370425.
# [I 2024-03-06 00:23:29,492] Trial 35 finished with value: 0.9240972733971997 and parameters: {'selector__k': 30, 'model__max_features': 'sqrt', 'model__n_estimators': 199, 'model__max_depth': 112, 'model__min_samples_leaf': 1}. Best is trial 34 with value: 0.926430852370425.
# [I 2024-03-06 00:24:50,198] Trial 36 finished with value: 0.9236059936133628 and parameters: {'selector__k': 31, 'model__max_features': 'sqrt', 'model__n_estimators': 749, 'model__max_depth': 91, 'model__min_samples_leaf': 1}. Best is trial 34 with value: 0.926430852370425.
# [I 2024-03-06 00:26:13,718] Trial 37 finished with value: 0.9254482928027512 and parameters: {'selector__k': 30, 'model__max_features': 'log2', 'model__n_estimators': 816, 'model__max_depth': 82, 'model__min_samples_leaf': 1}. Best is trial 34 with value: 0.926430852370425.
# [I 2024-03-06 00:27:04,974] Trial 38 finished with value: 0.9084991402603783 and parameters: {'selector__k': 31, 'model__max_features': 'log2', 'model__n_estimators': 781, 'model__max_depth': 81, 'model__min_samples_leaf': 16}. Best is trial 34 with value: 0.926430852370425.
# [I 2024-03-06 00:28:48,801] Trial 39 finished with value: 0.9109555391795627 and parameters: {'selector__k': 29, 'model__max_features': 'log2', 'model__n_estimators': 1467, 'model__max_depth': 53, 'model__min_samples_leaf': 4}. Best is trial 34 with value: 0.926430852370425.
# [I 2024-03-06 00:29:31,764] Trial 40 finished with value: 0.9065340211250307 and parameters: {'selector__k': 25, 'model__max_features': 'log2', 'model__n_estimators': 735, 'model__max_depth': 101, 'model__min_samples_leaf': 10}. Best is trial 34 with value: 0.926430852370425.
# [I 2024-03-06 00:31:11,636] Trial 41 finished with value: 0.9238516335052812 and parameters: {'selector__k': 31, 'model__max_features': 'log2', 'model__n_estimators': 1008, 'model__max_depth': 80, 'model__min_samples_leaf': 1}. Best is trial 34 with value: 0.926430852370425.
# [I 2024-03-06 00:33:15,145] Trial 42 finished with value: 0.9240972733971997 and parameters: {'selector__k': 31, 'model__max_features': 'log2', 'model__n_estimators': 1258, 'model__max_depth': 81, 'model__min_samples_leaf': 1}. Best is trial 34 with value: 0.926430852370425.
# [I 2024-03-06 00:35:19,156] Trial 43 finished with value: 0.9218865143699336 and parameters: {'selector__k': 27, 'model__max_features': 'log2', 'model__n_estimators': 1294, 'model__max_depth': 79, 'model__min_samples_leaf': 1}. Best is trial 34 with value: 0.926430852370425.
# [I 2024-03-06 00:38:39,431] Trial 44 finished with value: 0.912183738639155 and parameters: {'selector__k': 33, 'model__max_features': 'log2', 'model__n_estimators': 2295, 'model__max_depth': 55, 'model__min_samples_leaf': 4}. Best is trial 34 with value: 0.926430852370425.
# [I 2024-03-06 00:40:24,321] Trial 45 finished with value: 0.9227462539916482 and parameters: {'selector__k': 28, 'model__max_features': 'log2', 'model__n_estimators': 1134, 'model__max_depth': 98, 'model__min_samples_leaf': 1}. Best is trial 34 with value: 0.926430852370425.
# [I 2024-03-06 00:42:17,961] Trial 46 finished with value: 0.9115696389093588 and parameters: {'selector__k': 31, 'model__max_features': 'log2', 'model__n_estimators': 1606, 'model__max_depth': 81, 'model__min_samples_leaf': 5}. Best is trial 34 with value: 0.926430852370425.
# [I 2024-03-06 00:44:36,884] Trial 47 finished with value: 0.908867600098256 and parameters: {'selector__k': 34, 'model__max_features': 'log2', 'model__n_estimators': 1965, 'model__max_depth': 103, 'model__min_samples_leaf': 17}. Best is trial 34 with value: 0.926430852370425.
# [I 2024-03-06 00:45:32,004] Trial 48 finished with value: 0.9116924588553181 and parameters: {'selector__k': 23, 'model__max_features': 'log2', 'model__n_estimators': 931, 'model__max_depth': 55, 'model__min_samples_leaf': 3}. Best is trial 34 with value: 0.926430852370425.
# [I 2024-03-06 00:45:46,003] Trial 49 finished with value: 0.9127978383689511 and parameters: {'selector__k': 24, 'model__max_features': 'log2', 'model__n_estimators': 175, 'model__max_depth': 89, 'model__min_samples_leaf': 1}. Best is trial 34 with value: 0.926430852370425.
# RF 0.926430852370425 0.9484562717995091

# %%
import pickle
with open('best_model_clf.pickle', 'wb') as f:
    pickle.dump(best_model_clf, f, pickle.HIGHEST_PROTOCOL)

# %%
best_model_clf = pd.read_pickle("best_model_clf.pickle")

# %%
best_md_from_clf = sorted(best_model_clf.items(), key=lambda t: t[1][1])[-1]
temp_tr = test_data_tr.copy(deep=True)
temp_tr['y_pred_clf'] = best_md_from_clf[1][2]

# %%
used_link_1 = temp[temp['used_link']==1]
used_link_1_train = used_link_1[used_link_1['remainder__dataset']=='train']
used_link_1_validate = used_link_1[used_link_1['remainder__dataset']=='validate']
temp_2 = pd.concat([used_link_1_train, used_link_1_validate], ignore_index=True)
X_t = temp_2.drop(columns=['remainder__dataset', 'remainder__link_counts', 'used_link'])
y_t = temp_2['remainder__link_counts']

train_index = list(temp_2[temp_2['remainder__dataset']=='train'].index)
validate_index = list(temp_2[temp_2['remainder__dataset']=='validate'].index)

X_te = temp_tr[temp_tr['y_pred_clf']==1].drop(columns=['remainder__dataset', 'remainder__link_counts', 'used_link', 'y_pred_clf'])
y_te = temp_tr[temp_tr['y_pred_clf']==1]['remainder__link_counts']

X_te_0 = temp_tr[temp_tr['y_pred_clf']==0].drop(columns=['remainder__dataset', 'remainder__link_counts', 'used_link', 'y_pred_clf'])
X_te_0['y_pred'] = 0
y_te_0 = temp_tr[temp_tr['y_pred_clf']==0]['remainder__link_counts']
y_te_all = pd.concat([y_te, y_te_0])

# %%
best_model_reg = {}
for model_name in model_space.keys():   
    model = model_space[model_name]
    pipeline  = Pipeline([('selector', SelectKBest(f_regression)),
                  ('model', model)])
    param_grid = {}
    param_grid['selector__k']=optuna.distributions.IntDistribution(10, 48)
    for key in param_space[model_name].keys():
        param_grid[f'model__{key}']=param_space[model_name][key]
    
    # BayesSearchCV
    opt = OptunaSearchCV(
        pipeline,
        param_grid,
        n_trials=50,
        cv=[(train_index, validate_index), (train_index, validate_index)],
        scoring='neg_mean_absolute_error'
    )
    opt.fit(X_t, y_t)
    y_pred = opt.predict(X_te)
    y_pred_all = np.concatenate([y_pred, np.array(X_te_0['y_pred'])])
    mae = mean_absolute_error(y_te_all, y_pred_all)
    mse = mean_squared_error(y_te_all, y_pred_all)
    me = max_error(y_te_all, y_pred_all)
    best_model_reg[model_name] = (opt, mae, mse, me)
    print(model_name, opt.best_score_, mae, mse, me)
# Out:
# [I 2024
 'model__n_neighbors': 47, 'model__weights': 'distance', 'model__algorithm': 'ball_tree'}. Best is trial 47 with value: -11.729695603298707.
# [I 2024-03-06 00:59:40,752] A new study created in memory with name: no-name-3c335ee5-8e40-49d2-9d64-9dde09143e21
# KNN -11.729695603298707 10.655773210894187 469.18341351036077 202.08510638297872
# [I 2024-03-06 00:59:43,087] Trial 0 finished with value: -11.06442904178088 and parameters: {'selector__k': 10, 'model__learning_rate': 0.1298898032070535, 'model__n_estimators': 241, 'model__max_depth': 15, 'model__num_leaves': 4, 'model__min_child_samples': 9, 'model__subsample': 0.5963704922453544, 'model__colsample_bytree': 0.23812346620435793}. Best is trial 0 with value: -11.06442904178088.
# [I 2024-03-06 01:00:46,026] Trial 1 finished with value: -10.626640809333264 and parameters: {'selector__k': 20, 'model__learning_rate': 0.23929067052538722, 'model__n_estimators': 1218, 'model__max_depth': 13, 'model__num_leaves': 48, 'model__min_child_samples': 15, 'model__subsample': 0.8690904168459698, 'model__colsample_bytree': 0.5731903704434453}. Best is trial 1 with value: -10.626640809333264.
# [I 2024-03-06 01:00:56,108] Trial 2 finished with value: -11.609364502056392 and parameters: {'selector__k': 38, 'model__learning_rate': 0.11910505409670201, 'model__n_estimators': 693, 'model__max_depth': 13, 'model__num_leaves': 27, 'model__min_child_samples': 19, 'model__subsample': 0.5389039527879113, 'model__colsample_bytree': 0.24211251802940453}. Best is trial 1 with value: -10.626640809333264.
# [I 2024-03-06 01:00:59,036] Trial 3 finished with value: -11.420244795376785 and parameters: {'selector__k': 21, 'model__learning_rate': 0.2643038214524605, 'model__n_estimators': 257, 'model__max_depth': 14, 'model__num_leaves': 25, 'model__min_child_samples': 5, 'model__subsample': 0.4875443512343409, 'model__colsample_bytree': 0.2679917169361615}. Best is trial 1 with value: -10.626640809333264.
# [I 2024-03-06 01:01:04,608] Trial 4 finished with value: -12.895609550091397 and parameters: {'selector__k': 32, 'model__learning_rate': 0.48752005623407757, 'model__n_estimators': 456, 'model__max_depth': 42, 'model__num_leaves': 22, 'model__min_child_samples': 5, 'model__subsample': 0.32702184974463544, 'model__colsample_bytree': 0.296002061514499}. Best is trial 1 with value: -10.626640809333264.
# [I 2024-03-06 01:01:06,940] Trial 5 finished with value: -14.575239083332157 and parameters: {'selector__k': 34, 'model__learning_rate': 0.9118786129265738, 'model__n_estimators': 417, 'model__max_depth': 8, 'model__num_leaves': 8, 'model__min_child_samples': 8, 'model__subsample': 0.11024266087558232, 'model__colsample_bytree': 0.10231854417500946}. Best is trial 1 with value: -10.626640809333264.
# [I 2024-03-06 01:01:12,806] Trial 6 finished with value: -15.797792328380114 and parameters: {'selector__k': 37, 'model__learning_rate': 0.7084751447904576, 'model__n_estimators': 341, 'model__max_depth': 31, 'model__num_leaves': 31, 'model__min_child_samples': 5, 'model__subsample': 0.36204446025085213, 'model__colsample_bytree': 0.5342440068067943}. Best is trial 1 with value: -10.626640809333264.
# [I 2024-03-06 01:01:30,399] Trial 7 finished with value: -11.94767455792183 and parameters: {'selector__k': 32, 'model__learning_rate': 0.13447034613939984, 'model__n_estimators': 1482, 'model__max_depth': 49, 'model__num_leaves': 27, 'model__min_child_samples': 3, 'model__subsample': 0.3522766010073034, 'model__colsample_bytree': 0.10000613044736666}. Best is trial 1 with value: -10.626640809333264.
# [I 2024-03-06 01:01:41,935] Trial 8 finished with value: -14.022720143738233 and parameters: {'selector__k': 27, 'model__learning_rate': 0.3728098433535268, 'model__n_estimators': 796, 'model__max_depth': 13, 'model__num_leaves': 32, 'model__min_child_samples': 14, 'model__subsample': 0.5611467941823923, 'model__colsample_bytree': 0.46419748303357644}. Best is trial 1 with value: -10.626640809333264.
# [I 2024-03-06 01:01:51,161] Trial 9 finished with value: -15.298619090262104 and parameters: {'selector__k': 26, 'model__learning_rate': 0.7258670394087479, 'model__n_estimators': 1561, 'model__max_depth': 4, 'model__num_leaves': 16, 'model__min_child_samples': 9, 'model__subsample': 0.16247341845151186, 'model__colsample_bytree': 0.533733841598426}. Best is trial 1 with value: -10.626640809333264.
# [I 2024-03-06 01:01:52,194] Trial 10 finished with value: -10.499253499528471 and parameters: {'selector__k': 15, 'model__learning_rate': 0.3411748742213302, 'model__n_estimators': 62, 'model__max_depth': 26, 'model__num_leaves': 50, 'model__min_child_samples': 15, 'model__subsample': 0.9487235304369023, 'model__colsample_bytree': 0.878266272780604}. Best is trial 10 with value: -10.499253499528471.
# [I 2024-03-06 01:01:54,098] Trial 11 finished with value: -10.30036970356959 and parameters: {'selector__k': 14, 'model__learning_rate': 0.33933582880506996, 'model__n_estimators': 82, 'model__max_depth': 25, 'model__num_leaves': 49, 'model__min_child_samples': 15, 'model__subsample': 0.9937972123091222, 'model__colsample_bytree': 0.9432465345165273}. Best is trial 11 with value: -10.30036970356959.
# [I 2024-03-06 01:01:55,491] Trial 12 finished with value: -10.973375827497941 and parameters: {'selector__k': 10, 'model__learning_rate': 0.4795117932342016, 'model__n_estimators': 56, 'model__max_depth': 26, 'model__num_leaves': 50, 'model__min_child_samples': 14, 'model__subsample': 0.9577511763163742, 'model__colsample_bytree': 0.9992503674529121}. Best is trial 11 with value: -10.30036970356959.
# [I 2024-03-06 01:01:57,373] Trial 13 finished with value: -13.176818553655169 and parameters: {'selector__k': 47, 'model__learning_rate': 0.6163983576577259, 'model__n_estimators': 53, 'model__max_depth': 33, 'model__num_leaves': 41, 'model__min_child_samples': 20, 'model__subsample': 0.7744624359485002, 'model__colsample_bytree': 0.9643501756985906}. Best is trial 11 with value: -10.30036970356959.
# [I 2024-03-06 01:01:59,395] Trial 14 finished with value: -10.672769742463382 and parameters: {'selector__k': 17, 'model__learning_rate': 0.3550284377516939, 'model__n_estimators': 113, 'model__max_depth': 24, 'model__num_leaves': 40, 'model__min_child_samples': 17, 'model__subsample': 0.9920975012060392, 'model__colsample_bytree': 0.7959497883981437}. Best is trial 11 with value: -10.30036970356959.
# [I 2024-03-06 01:02:01,107] Trial 15 finished with value: -10.452768287738465 and parameters: {'selector__k': 15, 'model__learning_rate': 0.3095573287682073, 'model__n_estimators': 122, 'model__max_depth': 22, 'model__num_leaves': 42, 'model__min_child_samples': 12, 'model__subsample': 0.7603420528343516, 'model__colsample_bytree': 0.8160044934145687}. Best is trial 11 with value: -10.30036970356959.
# [I 2024-03-06 01:02:03,114] Trial 16 finished with value: -9.888009741744261 and parameters: {'selector__k': 14, 'model__learning_rate': 0.03706519918306911, 'model__n_estimators': 116, 'model__max_depth': 21, 'model__num_leaves': 41, 'model__min_child_samples': 11, 'model__subsample': 0.7736597868707671, 'model__colsample_bytree': 0.7143418263651581}. Best is trial 16 with value: -9.888009741744261.
# [I 2024-03-06 01:02:05,127] Trial 17 finished with value: -9.784270808033506 and parameters: {'selector__k': 21, 'model__learning_rate': 0.0951096641896044, 'model__n_estimators': 116, 'model__max_depth': 32, 'model__num_leaves': 36, 'model__min_child_samples': 12, 'model__subsample': 0.70518560618282, 'model__colsample_bytree': 0.7086267730258506}. Best is trial 17 with value: -9.784270808033506.
# [I 2024-03-06 01:02:07,646] Trial 18 finished with value: -10.900740666647861 and parameters: {'selector__k': 20, 'model__learning_rate': 0.014201447473978834, 'model__n_estimators': 158, 'model__max_depth': 37, 'model__num_leaves': 36, 'model__min_child_samples': 11, 'model__subsample': 0.6910160681014056, 'model__colsample_bytree': 0.6842656774334683}. Best is trial 17 with value: -9.784270808033506.
# [I 2024-03-06 01:02:10,471] Trial 19 finished with value: -12.749376546875524 and parameters: {'selector__k': 24, 'model__learning_rate': 0.05008022873683926, 'model__n_estimators': 169, 'model__max_depth': 40, 'model__num_leaves': 36, 'model__min_child_samples': 12, 'model__subsample': 0.6685087830075098, 'model__colsample_bytree': 0.6884598086827799}. Best is trial 17 with value: -9.784270808033506.
# [I 2024-03-06 01:02:12,240] Trial 20 finished with value: -12.167986535454947 and parameters: {'selector__k': 22, 'model__learning_rate': 0.20442187251235175, 'model__n_estimators': 88, 'model__max_depth': 20, 'model__num_leaves': 44, 'model__min_child_samples': 7, 'model__subsample': 0.8483404419785813, 'model__colsample_bytree': 0.6990302407211746}. Best is trial 17 with value: -9.784270808033506.
# [I 2024-03-06 01:02:13,991] Trial 21 finished with value: -10.272400166041798 and parameters: {'selector__k': 13, 'model__learning_rate': 0.035682919277187065, 'model__n_estimators': 89, 'model__max_depth': 32, 'model__num_leaves': 46, 'model__min_child_samples': 17, 'model__subsample': 0.8623060247183754, 'model__colsample_bytree': 0.7734465690108295}. Best is trial 17 with value: -9.784270808033506.
# [I 2024-03-06 01:02:16,648] Trial 22 finished with value: -9.95496239199219 and parameters: {'selector__k': 13, 'model__learning_rate': 0.042514453307390274, 'model__n_estimators': 192, 'model__max_depth': 31, 'model__num_leaves': 36, 'model__min_child_samples': 17, 'model__subsample': 0.8402015080159935, 'model__colsample_bytree': 0.7790281163073846}. Best is trial 17 with value: -9.784270808033506.
# [I 2024-03-06 01:02:19,426] Trial 23 finished with value: -9.95423254144458 and parameters: {'selector__k': 18, 'model__learning_rate': 0.10811085960949543, 'model__n_estimators': 189, 'model__max_depth': 30, 'model__num_leaves': 34, 'model__min_child_samples': 18, 'model__subsample': 0.715701922431222, 'model__colsample_bytree': 0.6226808900166082}. Best is trial 17 with value: -9.784270808033506.
# [I 2024-03-06 01:02:54,326] Trial 24 finished with value: -10.848189155089726 and parameters: {'selector__k': 18, 'model__learning_rate': 0.19309488111857676, 'model__n_estimators': 2996, 'model__max_depth': 19, 'model__num_leaves': 33, 'model__min_child_samples': 11, 'model__subsample': 0.6834625936871537, 'model__colsample_bytree': 0.6328319201262687}. Best is trial 17 with value: -9.784270808033506.
# [I 2024-03-06 01:02:56,777] Trial 25 finished with value: -13.191536940725012 and parameters: {'selector__k': 24, 'model__learning_rate': 0.1269616454334044, 'model__n_estimators': 143, 'model__max_depth': 35, 'model__num_leaves': 39, 'model__min_child_samples': 1, 'model__subsample': 0.7541001876111061, 'model__colsample_bytree': 0.43809610551407674}. Best is trial 17 with value: -9.784270808033506.
# [I 2024-03-06 01:02:58,825] Trial 26 finished with value: -13.277885683933132 and parameters: {'selector__k': 18, 'model__learning_rate': 0.9232530820998929, 'model__n_estimators': 222, 'model__max_depth': 28, 'model__num_leaves': 19, 'model__min_child_samples': 13, 'model__subsample': 0.6498300850140417, 'model__colsample_bytree': 0.6044510244018262}. Best is trial 17 with value: -9.784270808033506.
# [I 2024-03-06 01:03:00,730] Trial 27 finished with value: -12.762996079907305 and parameters: {'selector__k': 24, 'model__learning_rate': 0.41389186976765113, 'model__n_estimators': 108, 'model__max_depth': 46, 'model__num_leaves': 30, 'model__min_child_samples': 18, 'model__subsample': 0.46048917396388084, 'model__colsample_bytree': 0.4438071415211601}. Best is trial 17 with value: -9.784270808033506.
# [I 2024-03-06 01:03:04,895] Trial 28 finished with value: -10.274998646979503 and parameters: {'selector__k': 17, 'model__learning_rate': 0.1838807429922312, 'model__n_estimators': 298, 'model__max_depth': 37, 'model__num_leaves': 36, 'model__min_child_samples': 10, 'model__subsample': 0.7899856131516745, 'model__colsample_bytree': 0.8734223684194689}. Best is trial 17 with value: -9.784270808033506.
# [I 2024-03-06 01:03:05,432] Trial 29 finished with value: -10.359748152497701 and parameters: {'selector__k': 10, 'model__learning_rate': 0.12554041475887961, 'model__n_estimators': 71, 'model__max_depth': 18, 'model__num_leaves': 4, 'model__min_child_samples': 7, 'model__subsample': 0.6179299263969845, 'model__colsample_bytree': 0.7369821426598977}. Best is trial 17 with value: -9.784270808033506.
# [I 2024-03-06 01:03:09,596] Trial 30 finished with value: -13.419269038081518 and parameters: {'selector__k': 28, 'model__learning_rate': 0.10523604691877514, 'model__n_estimators': 232, 'model__max_depth': 29, 'model__num_leaves': 38, 'model__min_child_samples': 13, 'model__subsample': 0.7118052367734343, 'model__colsample_bytree': 0.336011315440428}. Best is trial 17 with value: -9.784270808033506.
# [I 2024-03-06 01:03:12,217] Trial 31 finished with value: -9.847461187063224 and parameters: {'selector__k': 13, 'model__learning_rate': 0.06114634590246611, 'model__n_estimators': 200, 'model__max_depth': 41, 'model__num_leaves': 34, 'model__min_child_samples': 17, 'model__subsample': 0.8142990089763353, 'model__colsample_bytree': 0.6365579443058987}. Best is trial 17 with value: -9.784270808033506.
# [I 2024-03-06 01:03:14,663] Trial 32 finished with value: -10.036379697226689 and parameters: {'selector__k': 10, 'model__learning_rate': 0.08141148722289585, 'model__n_estimators': 143, 'model__max_depth': 41, 'model__num_leaves': 45, 'model__min_child_samples': 20, 'model__subsample': 0.915357078375312, 'model__colsample_bytree': 0.6346996846180808}. Best is trial 17 with value: -9.784270808033506.
# [I 2024-03-06 01:03:17,206] Trial 33 finished with value: -10.080894002093272 and parameters: {'selector__k': 12, 'model__learning_rate': 0.26345315391787105, 'model__n_estimators': 189, 'model__max_depth': 44, 'model__num_leaves': 33, 'model__min_child_samples': 16, 'model__subsample': 0.8114980654725371, 'model__colsample_bytree': 0.5844183699326655}. Best is trial 17 with value: -9.784270808033506.
# [I 2024-03-06 01:03:20,876] Trial 34 finished with value: -10.408431359063295 and parameters: {'selector__k': 19, 'model__learning_rate': 0.17568989614290456, 'model__n_estimators': 280, 'model__max_depth': 38, 'model__num_leaves': 29, 'model__min_child_samples': 16, 'model__subsample': 0.7295573629572677, 'model__colsample_bytree': 0.502793586089383}. Best is trial 17 with value: -9.784270808033506.
# [I 2024-03-06 01:03:26,451] Trial 35 finished with value: -12.006466029114375 and parameters: {'selector__k': 22, 'model__learning_rate': 0.25129704829589883, 'model__n_estimators': 519, 'model__max_depth': 50, 'model__num_leaves': 24, 'model__min_child_samples': 19, 'model__subsample': 0.5913874491697666, 'model__colsample_bytree': 0.6489148613545243}. Best is trial 17 with value: -9.784270808033506.
# [I 2024-03-06 01:03:28,394] Trial 36 finished with value: -9.895457673999822 and parameters: {'selector__k': 16, 'model__learning_rate': 0.07920443925598036, 'model__n_estimators': 111, 'model__max_depth': 10, 'model__num_leaves': 43, 'model__min_child_samples': 9, 'model__subsample': 0.90717126460482, 'model__colsample_bytree': 0.7175070037660203}. Best is trial 17 with value: -9.784270808033506.
# [I 2024-03-06 01:03:30,225] Trial 37 finished with value: -12.018801005001785 and parameters: {'selector__k': 12, 'model__learning_rate': 0.014010039264484714, 'model__n_estimators': 100, 'model__max_depth': 8, 'model__num_leaves': 42, 'model__min_child_samples': 9, 'model__subsample': 0.8993315548495167, 'model__colsample_bytree': 0.862904101300672}. Best is trial 17 with value: -9.784270808033506.
# [I 2024-03-06 01:03:32,386] Trial 38 finished with value: -9.836216287417955 and parameters: {'selector__k': 15, 'model__learning_rate': 0.07291747086760772, 'model__n_estimators': 128, 'model__max_depth': 10, 'model__num_leaves': 46, 'model__min_child_samples': 7, 'model__subsample': 0.8251317150656351, 'model__colsample_bytree': 0.7382858155554511}. Best is trial 17 with value: -9.784270808033506.
# [I 2024-03-06 01:03:34,078] Trial 39 finished with value: -9.94457138577338 and parameters: {'selector__k': 21, 'model__learning_rate': 0.154261684101881, 'model__n_estimators': 72, 'model__max_depth': 16, 'model__num_leaves': 47, 'model__min_child_samples': 6, 'model__subsample': 0.47978603346525633, 'model__colsample_bytree': 0.7412086959801656}. Best is trial 17 with value: -9.784270808033506.
# [I 2024-03-06 01:03:41,842] Trial 40 finished with value: -17.1431741776737 and parameters: {'selector__k': 45, 'model__learning_rate': 0.8498169485786812, 'model__n_estimators': 361, 'model__max_depth': 6, 'model__num_leaves': 39, 'model__min_child_samples': 3, 'model__subsample': 0.8026407652584682, 'model__colsample_bytree': 0.845704691924975}. Best is trial 17 with value: -9.784270808033506.
# [I 2024-03-06 01:03:44,163] Trial 41 finished with value: -10.051260769097802 and parameters: {'selector__k': 16, 'model__learning_rate': 0.07108956345503079, 'model__n_estimators': 144, 'model__max_depth': 11, 'model__num_leaves': 43, 'model__min_child_samples': 9, 'model__subsample': 0.9009942142825023, 'model__colsample_bytree': 0.7512868639680748}. Best is trial 17 with value: -9.784270808033506.
# [I 2024-03-06 01:03:44,772] Trial 42 finished with value: -12.59117753087435 and parameters: {'selector__k': 15, 'model__learning_rate': 0.08062632650947862, 'model__n_estimators': 120, 'model__max_depth': 1, 'model__num_leaves': 46, 'model__min_child_samples': 8, 'model__subsample': 0.837789643427303, 'model__colsample_bytree': 0.7130482015651745}. Best is trial 17 with value: -9.784270808033506.
# [I 2024-03-06 01:03:46,633] Trial 43 finished with value: -10.012085121656492 and parameters: {'selector__k': 12, 'model__learning_rate': 0.15518197070600442, 'model__n_estimators': 128, 'model__max_depth': 11, 'model__num_leaves': 44, 'model__min_child_samples': 10, 'model__subsample': 0.8873509354222566, 'model__colsample_bytree': 0.6780284252178166}. Best is trial 17 with value: -9.784270808033506.
# [I 2024-03-06 01:03:48,214] Trial 44 finished with value: -10.488943944359242 and parameters: {'selector__k': 16, 'model__learning_rate': 0.21965006386865515, 'model__n_estimators': 90, 'model__max_depth': 16, 'model__num_leaves': 38, 'model__min_child_samples': 8, 'model__subsample': 0.9398755057754535, 'model__colsample_bytree': 0.5451674229595294}. Best is trial 17 with value: -9.784270808033506.
# [I 2024-03-06 01:03:49,695] Trial 45 finished with value: -11.209343887405382 and parameters: {'selector__k': 14, 'model__learning_rate': 0.6007013143754111, 'model__n_estimators': 64, 'model__max_depth': 10, 'model__num_leaves': 48, 'model__min_child_samples': 4, 'model__subsample': 0.8153743515876422, 'model__colsample_bytree': 0.9162959359517466}. Best is trial 17 with value: -9.784270808033506.
# [I 2024-03-06 01:03:52,472] Trial 46 finished with value: -10.599267495571898 and parameters: {'selector__k': 19, 'model__learning_rate': 0.28675135350586095, 'model__n_estimators': 243, 'model__max_depth': 7, 'model__num_leaves': 29, 'model__min_child_samples': 12, 'model__subsample': 0.7473457097666535, 'model__colsample_bytree': 0.8180244302422371}. Best is trial 17 with value: -9.784270808033506.
# [I 2024-03-06 01:03:53,128] Trial 47 finished with value: -10.422814032119039 and parameters: {'selector__k': 11, 'model__learning_rate': 0.07278240404008461, 'model__n_estimators': 74, 'model__max_depth': 3, 'model__num_leaves': 11, 'model__min_child_samples': 6, 'model__subsample': 0.6308123222518823, 'model__colsample_bytree': 0.5742282270035381}. Best is trial 17 with value: -9.784270808033506.
# [I 2024-03-06 01:03:55,514] Trial 48 finished with value: -17.462834830934632 and parameters: {'selector__k': 30, 'model__learning_rate': 0.010247524585126205, 'model__n_estimators': 100, 'model__max_depth': 14, 'model__num_leaves': 41, 'model__min_child_samples': 10, 'model__subsample': 0.4217867122550088, 'model__colsample_bytree': 0.17393253390614138}. Best is trial 17 with value: -9.784270808033506.
# [I 2024-03-06 01:03:56,418] Trial 49 finished with value: -10.324575892300292 and parameters: {'selector__k': 16, 'model__learning_rate': 0.23303644875375287, 'model__n_estimators': 51, 'model__max_depth': 22, 'model__num_leaves': 27, 'model__min_child_samples': 8, 'model__subsample': 0.2500485310463366, 'model__colsample_bytree': 0.6693143333686655}. Best is trial 17 with value: -9.784270808033506.
# [I 2024-03-06 01:03:57,629] A new study created in memory with name: no-name-8cc28e38-5090-44e0-b181-719ba470b2b0
# LGBM -9.784270808033506 9.479743234205126 315.8507670605643 177.21487829380516
# [I 2024-03-06 01:04:04,916] Trial 0 finished with value: -13.611644294629343 and parameters: {'selector__k': 24, 'model__max_features': 'log2', 'model__n_estimators': 96, 'model__max_depth': 11, 'model__min_samples_leaf': 1}. Best is trial 0 with value: -13.611644294629343.
# [I 2024-03-06 01:04:09,797] Trial 1 finished with value: -12.863949947021672 and parameters: {'selector__k': 29, 'model__max_features': 'log2', 'model__n_estimators': 65, 'model__max_depth': 157, 'model__min_samples_leaf': 17}. Best is trial 1 with value: -12.863949947021672.
# [I 2024-03-06 01:04:33,328] Trial 2 finished with value: -14.041840118058976 and parameters: {'selector__k': 41, 'model__max_features': 'log2', 'model__n_estimators': 265, 'model__max_depth': 44, 'model__min_samples_leaf': 20}. Best is trial 1 with value: -12.863949947021672.
# [I 2024-03-06 01:04:56,287] Trial 3 finished with value: -13.191760263558354 and parameters: {'selector__k': 30, 'model__max_features': 'log2', 'model__n_estimators': 306, 'model__max_depth': 13, 'model__min_samples_leaf': 5}. Best is trial 1 with value: -12.863949947021672.
# [I 2024-03-06 01:10:56,970] Trial 4 finished with value: -12.912646109692673 and parameters: {'selector__k': 38, 'model__max_features': 'log2', 'model__n_estimators': 2065, 'model__max_depth': 41, 'model__min_samples_leaf': 1}. Best is trial 1 with value: -12.863949947021672.
# [I 2024-03-06 01:13:21,276] Trial 5 finished with value: -13.407214301610523 and parameters: {'selector__k': 35, 'model__max_features': 'log2', 'model__n_estimators': 1637, 'model__max_depth': 145, 'model__min_samples_leaf': 19}. Best is trial 1 with value: -12.863949947021672.
# [I 2024-03-06 01:14:12,236] Trial 6 finished with value: -13.375254359916617 and parameters: {'selector__k': 30, 'model__max_features': 'sqrt', 'model__n_estimators': 577, 'model__max_depth': 182, 'model__min_samples_leaf': 17}. Best is trial 1 with value: -12.863949947021672.
# [I 2024-03-06 01:14:16,945] Trial 7 finished with value: -12.833476992613564 and parameters: {'selector__k': 27, 'model__max_features': 'sqrt', 'model__n_estimators': 51, 'model__max_depth': 70, 'model__min_samples_leaf': 13}. Best is trial 7 with value: -12.833476992613564.
# [I 2024-03-06 01:14:23,805] Trial 8 finished with value: -10.491798728912066 and parameters: {'selector__k': 11, 'model__max_features': 'sqrt', 'model__n_estimators': 260, 'model__max_depth': 12, 'model__min_samples_leaf': 8}. Best is trial 8 with value: -10.491798728912066.
# [I 2024-03-06 01:14:33,382] Trial 9 finished with value: -13.485006975501628 and parameters: {'selector__k': 40, 'model__max_features': 'log2', 'model__n_estimators': 106, 'model__max_depth': 96, 'model__min_samples_leaf': 15}. Best is trial 8 with value: -10.491798728912066.
# [I 2024-03-06 01:14:52,854] Trial 10 finished with value: -10.516179081007351 and parameters: {'selector__k': 10, 'model__max_features': 'sqrt', 'model__n_estimators': 786, 'model__max_depth': 112, 'model__min_samples_leaf': 8}. Best is trial 8 with value: -10.491798728912066.
# [I 2024-03-06 01:15:10,731] Trial 11 finished with value: -10.566554112826191 and parameters: {'selector__k': 10, 'model__max_features': 'sqrt', 'model__n_estimators': 734, 'model__max_depth': 115, 'model__min_samples_leaf': 9}. Best is trial 8 with value: -10.491798728912066.
# [I 2024-03-06 01:15:33,954] Trial 12 finished with value: -10.53274244176701 and parameters: {'selector__k': 10, 'model__max_features': 'sqrt', 'model__n_estimators': 933, 'model__max_depth': 108, 'model__min_samples_leaf': 8}. Best is trial 8 with value: -10.491798728912066.
# [I 2024-03-06 01:15:48,515] Trial 13 finished with value: -10.46533220403949 and parameters: {'selector__k': 18, 'model__max_features': 'sqrt', 'model__n_estimators': 190, 'model__max_depth': 69, 'model__min_samples_leaf': 6}. Best is trial 13 with value: -10.46533220403949.
# [I 2024-03-06 01:16:01,633] Trial 14 finished with value: -10.508342211475695 and parameters: {'selector__k': 19, 'model__max_features': 'sqrt', 'model__n_estimators': 169, 'model__max_depth': 54, 'model__min_samples_leaf': 4}. Best is trial 13 with value: -10.46533220403949.
# [I 2024-03-06 01:16:03,887] Trial 15 finished with value: -18.210708590446583 and parameters: {'selector__k': 18, 'model__max_features': 'sqrt', 'model__n_estimators': 176, 'model__max_depth': 1, 'model__min_samples_leaf': 12}. Best is trial 13 with value: -10.46533220403949.
# [I 2024-03-06 01:16:34,257] Trial 16 finished with value: -10.482597317592413 and parameters: {'selector__k': 16, 'model__max_features': 'sqrt', 'model__n_estimators': 422, 'model__max_depth': 86, 'model__min_samples_leaf': 6}. Best is trial 13 with value: -10.46533220403949.
# [I 2024-03-06 01:17:09,170] Trial 17 finished with value: -10.358790238039376 and parameters: {'selector__k': 17, 'model__max_features': 'sqrt', 'model__n_estimators': 470, 'model__max_depth': 76, 'model__min_samples_leaf': 5}. Best is trial 17 with value: -10.358790238039376.
# [I 2024-03-06 01:17:38,187] Trial 18 finished with value: -13.376752402510736 and parameters: {'selector__k': 46, 'model__max_features': 'sqrt', 'model__n_estimators': 188, 'model__max_depth': 70, 'model__min_samples_leaf': 3}. Best is trial 17 with value: -10.358790238039376.
# [I 2024-03-06 01:19:18,131] Trial 19 finished with value: -12.216715061553767 and parameters: {'selector__k': 22, 'model__max_features': 'sqrt', 'model__n_estimators': 1260, 'model__max_depth': 135, 'model__min_samples_leaf': 6}. Best is trial 17 with value: -10.358790238039376.
# [I 2024-03-06 01:19:36,775] Trial 20 finished with value: -10.959239096458406 and parameters: {'selector__k': 15, 'model__max_features': 'sqrt', 'model__n_estimators': 442, 'model__max_depth': 79, 'model__min_samples_leaf': 11}. Best is trial 17 with value: -10.358790238039376.
# [I 2024-03-06 01:20:04,907] Trial 21 finished with value: -10.41332394845895 and parameters: {'selector__k': 17, 'model__max_features': 'sqrt', 'model__n_estimators': 402, 'model__max_depth': 85, 'model__min_samples_leaf': 6}. Best is trial 17 with value: -10.358790238039376.
# [I 2024-03-06 01:20:54,010] Trial 22 finished with value: -12.195270024651414 and parameters: {'selector__k': 22, 'model__max_features': 'sqrt', 'model__n_estimators': 533, 'model__max_depth': 60, 'model__min_samples_leaf': 3}. Best is trial 17 with value: -10.358790238039376.
# [I 2024-03-06 01:21:08,803] Trial 23 finished with value: -10.51120175007025 and parameters: {'selector__k': 14, 'model__max_features': 'sqrt', 'model__n_estimators': 348, 'model__max_depth': 36, 'model__min_samples_leaf': 6}. Best is trial 17 with value: -10.358790238039376.
# [I 2024-03-06 01:21:16,053] Trial 24 finished with value: -10.722999610358286 and parameters: {'selector__k': 19, 'model__max_features': 'sqrt', 'model__n_estimators': 103, 'model__max_depth': 92, 'model__min_samples_leaf': 10}. Best is trial 17 with value: -10.358790238039376.
# [I 2024-03-06 01:21:45,439] Trial 25 finished with value: -13.043378948833181 and parameters: {'selector__k': 26, 'model__max_features': 'sqrt', 'model__n_estimators': 225, 'model__max_depth': 130, 'model__min_samples_leaf': 3}. Best is trial 17 with value: -10.358790238039376.
# [I 2024-03-06 01:21:50,838] Trial 26 finished with value: -10.536900423871908 and parameters: {'selector__k': 14, 'model__max_features': 'sqrt', 'model__n_estimators': 134, 'model__max_depth': 32, 'model__min_samples_leaf': 7}. Best is trial 17 with value: -10.358790238039376.
# [I 2024-03-06 01:23:23,989] Trial 27 finished with value: -10.499177726950558 and parameters: {'selector__k': 21, 'model__max_features': 'sqrt', 'model__n_estimators': 1178, 'model__max_depth': 75, 'model__min_samples_leaf': 4}. Best is trial 17 with value: -10.358790238039376.
# [I 2024-03-06 01:24:01,038] Trial 28 finished with value: -10.688131314477921 and parameters: {'selector__k': 17, 'model__max_features': 'sqrt', 'model__n_estimators': 581, 'model__max_depth': 57, 'model__min_samples_leaf': 10}. Best is trial 17 with value: -10.358790238039376.
# [I 2024-03-06 01:24:44,325] Trial 29 finished with value: -12.890053467694006 and parameters: {'selector__k': 24, 'model__max_features': 'sqrt', 'model__n_estimators': 367, 'model__max_depth': 100, 'model__min_samples_leaf': 2}. Best is trial 17 with value: -10.358790238039376.
# [I 2024-03-06 01:28:11,452] Trial 30 finished with value: -10.221225927697978 and parameters: {'selector__k': 13, 'model__max_features': 'sqrt', 'model__n_estimators': 2595, 'model__max_depth': 26, 'model__min_samples_leaf': 1}. Best is trial 30 with value: -10.221225927697978.
# [I 2024-03-06 01:30:51,050] Trial 31 finished with value: -10.2489709551963 and parameters: {'selector__k': 14, 'model__max_features': 'sqrt', 'model__n_estimators': 2014, 'model__max_depth': 28, 'model__min_samples_leaf': 1}. Best is trial 30 with value: -10.221225927697978.
# [I 2024-03-06 01:34:06,485] Trial 32 finished with value: -10.229518517173478 and parameters: {'selector__k': 13, 'model__max_features': 'sqrt', 'model__n_estimators': 2458, 'model__max_depth': 25, 'model__min_samples_leaf': 1}. Best is trial 30 with value: -10.221225927697978.
# [I 2024-03-06 01:39:16,792] Trial 33 finished with value: -10.226524976896675 and parameters: {'selector__k': 13, 'model__max_features': 'sqrt', 'model__n_estimators': 2993, 'model__max_depth': 26, 'model__min_samples_leaf': 1}. Best is trial 30 with value: -10.221225927697978.
# [I 2024-03-06 01:44:28,908] Trial 34 finished with value: -10.190886546565185 and parameters: {'selector__k': 13, 'model__max_features': 'log2', 'model__n_estimators': 2881, 'model__max_depth': 24, 'model__min_samples_leaf': 1}. Best is trial 34 with value: -10.190886546565185.
# [I 2024-03-06 01:47:08,641] Trial 35 finished with value: -10.514226863149348 and parameters: {'selector__k': 12, 'model__max_features': 'log2', 'model__n_estimators': 2913, 'model__max_depth': 22, 'model__min_samples_leaf': 1}. Best is trial 34 with value: -10.190886546565185.
# [I 2024-03-06 01:47:34,384] Trial 36 finished with value: -15.487774354598837 and parameters: {'selector__k': 12, 'model__max_features': 'log2', 'model__n_estimators': 2743, 'model__max_depth': 2, 'model__min_samples_leaf': 2}. Best is trial 34 with value: -10.190886546565185.
# [I 2024-03-06 01:49:35,913] Trial 37 finished with value: -10.208933508353896 and parameters: {'selector__k': 13, 'model__max_features': 'log2', 'model__n_estimators': 2205, 'model__max_depth': 21, 'model__min_samples_leaf': 2}. Best is trial 34 with value: -10.190886546565185.
# [I 2024-03-06 01:52:17,415] Trial 38 finished with value: -10.282554508946742 and parameters: {'selector__k': 20, 'model__max_features': 'log2', 'model__n_estimators': 1661, 'model__max_depth': 45, 'model__min_samples_leaf': 2}. Best is trial 34 with value: -10.190886546565185.
# [I 2024-03-06 01:54:49,296] Trial 39 finished with value: -13.350702283841308 and parameters: {'selector__k': 24, 'model__max_features': 'log2', 'model__n_estimators': 1985, 'model__max_depth': 12, 'model__min_samples_leaf': 4}. Best is trial 34 with value: -10.190886546565185.
# [I 2024-03-06 01:58:18,767] Trial 40 finished with value: -12.99809392358354 and parameters: {'selector__k': 33, 'model__max_features': 'log2', 'model__n_estimators': 1523, 'model__max_depth': 198, 'model__min_samples_leaf': 2}. Best is trial 34 with value: -10.190886546565185.
# [I 2024-03-06 02:00:12,720] Trial 41 finished with value: -10.369078899625974 and parameters: {'selector__k': 12, 'model__max_features': 'log2', 'model__n_estimators': 2326, 'model__max_depth': 18, 'model__min_samples_leaf': 1}. Best is trial 34 with value: -10.190886546565185.
# [I 2024-03-06 02:03:50,512] Trial 42 finished with value: -10.237368656758719 and parameters: {'selector__k': 13, 'model__max_features': 'log2', 'model__n_estimators': 2627, 'model__max_depth': 44, 'model__min_samples_leaf': 1}. Best is trial 34 with value: -10.190886546565185.
# [I 2024-03-06 02:06:01,463] Trial 43 finished with value: -10.453669933342773 and parameters: {'selector__k': 15, 'model__max_features': 'log2', 'model__n_estimators': 2236, 'model__max_depth': 28, 'model__min_samples_leaf': 3}. Best is trial 34 with value: -10.190886546565185.
# [I 2024-03-06 02:08:40,568] Trial 44 finished with value: -10.465107357226639 and parameters: {'selector__k': 12, 'model__max_features': 'log2', 'model__n_estimators':
 'model__hidden_layer_sizes': (100, 100), 'model__activation': 'relu', 'model__solver': 'sgd', 'model__alpha': 0.007862874035336004} because of the following error: The value nan is not acceptable.
# [W 2024-03-06 03:50:46,750] Trial 38 failed with value nan.
# [W 2024-03-06 03:53:49,414] Trial 39 failed with parameters: {'selector__k': 16, 'model__hidden_layer_sizes': (100, 100), 'model__activation': 'relu', 'model__solver': 'sgd', 'model__alpha': 0.005898026477788446} because of the following error: The value nan is not acceptable.
# [W 2024-03-06 03:53:49,415] Trial 39 failed with value nan.
# [W 2024-03-06 03:57:06,514] Trial 40 failed with parameters: {'selector__k': 32, 'model__hidden_layer_sizes': (100, 100), 'model__activation': 'relu', 'model__solver': 'sgd', 'model__alpha': 0.0002030194692516913} because of the following error: The value nan is not acceptable.
# [W 2024-03-06 03:57:06,515] Trial 40 failed with value nan.
# [W 2024-03-06 04:00:15,741] Trial 41 failed with parameters: {'selector__k': 34, 'model__hidden_layer_sizes': (100, 100), 'model__activation': 'relu', 'model__solver': 'sgd', 'model__alpha': 0.007960768105447484} because of the following error: The value nan is not acceptable.
# [W 2024-03-06 04:00:15,743] Trial 41 failed with value nan.
# [W 2024-03-06 04:03:26,244] Trial 42 failed with parameters: {'selector__k': 16, 'model__hidden_layer_sizes': (100, 100), 'model__activation': 'relu', 'model__solver': 'sgd', 'model__alpha': 0.008401556921945988} because of the following error: The value nan is not acceptable.
# [W 2024-03-06 04:03:26,246] Trial 42 failed with value nan.
# [W 2024-03-06 04:06:32,180] Trial 43 failed with parameters: {'selector__k': 16, 'model__hidden_layer_sizes': (100, 100), 'model__activation': 'relu', 'model__solver': 'sgd', 'model__alpha': 0.00024390980778722171} because of the following error: The value nan is not acceptable.
# [W 2024-03-06 04:06:32,182] Trial 43 failed with value nan.
# [W 2024-03-06 04:09:53,258] Trial 44 failed with parameters: {'selector__k': 34, 'model__hidden_layer_sizes': (100, 100), 'model__activation': 'relu', 'model__solver': 'sgd', 'model__alpha': 0.005128605795769704} because of the following error: The value nan is not acceptable.
# [W 2024-03-06 04:09:53,259] Trial 44 failed with value nan.
# [W 2024-03-06 04:13:14,506] Trial 45 failed with parameters: {'selector__k': 33, 'model__hidden_layer_sizes': (100, 100), 'model__activation': 'relu', 'model__solver': 'sgd', 'model__alpha': 0.005641207416572319} because of the following error: The value nan is not acceptable.
# [W 2024-03-06 04:13:14,507] Trial 45 failed with value nan.
# [W 2024-03-06 04:16:33,908] Trial 46 failed with parameters: {'selector__k': 34, 'model__hidden_layer_sizes': (100, 100), 'model__activation': 'relu', 'model__solver': 'sgd', 'model__alpha': 0.008063304289743119} because of the following error: The value nan is not acceptable.
# [W 2024-03-06 04:16:33,909] Trial 46 failed with value nan.
# [W 2024-03-06 04:19:41,717] Trial 47 failed with parameters: {'selector__k': 16, 'model__hidden_layer_sizes': (100, 100), 'model__activation': 'relu', 'model__solver': 'sgd', 'model__alpha': 0.003977757709027097} because of the following error: The value nan is not acceptable.
# [W 2024-03-06 04:19:41,719] Trial 47 failed with value nan.
# [W 2024-03-06 04:23:03,787] Trial 48 failed with parameters: {'selector__k': 33, 'model__hidden_layer_sizes': (100, 100), 'model__activation': 'relu', 'model__solver': 'sgd', 'model__alpha': 0.0059513530787276715} because of the following error: The value nan is not acceptable.
# [W 2024-03-06 04:23:03,788] Trial 48 failed with value nan.
# [W 2024-03-06 04:26:23,729] Trial 49 failed with parameters: {'selector__k': 34, 'model__hidden_layer_sizes': (100, 100), 'model__activation': 'relu', 'model__solver': 'sgd', 'model__alpha': 0.005420633767792437} because of the following error: The value nan is not acceptable.
# [W 2024-03-06 04:26:23,731] Trial 49 failed with value nan.
# ANN -10.293587393841841 11.0429549565129 441.85978423764556 283.84423682092455

# %%
X_t_onlyreg = temp.drop(columns=['remainder__dataset', 'remainder__link_counts', 'used_link'])
y_t_onlyreg = temp['remainder__link_counts']

X_te_onlyreg = test_data_tr.drop(columns=['remainder__dataset', 'remainder__link_counts', 'used_link'])
y_te_onlyreg = test_data_tr['remainder__link_counts']

train_index_onlyreg = list(train_data_tr.index)
validate_index_onlyreg = list(validate_data_tr.index)

# %%
X_t_onlyreg

# %%
best_model_onlyreg = {}
for model_name in model_space.keys():   
    model = model_space[model_name]
    pipeline  = Pipeline([('selector', SelectKBest(f_regression)),
                  ('model', model)])
    param_grid = {}
    param_grid['selector__k']=optuna.distributions.IntDistribution(10, 48)
    for key in param_space[model_name].keys():
        param_grid[f'model__{key}']=param_space[model_name][key]
    
    # BayesSearchCV
    opt = OptunaSearchCV(
        pipeline,
        param_grid,
        n_trials=50,
        cv=[(train_index_onlyreg, validate_index_onlyreg), (train_index_onlyreg, validate_index_onlyreg)],
        scoring='neg_mean_absolute_error'
    )
    opt.fit(X_t_onlyreg, y_t_onlyreg)
    y_pred = opt.predict(X_te_onlyreg)
    mae = mean_absolute_error(y_te_onlyreg, y_pred)
    mse = mean_squared_error(y_te_onlyreg, y_pred)
    me = max_error(y_te_onlyreg, y_pred)
    best_model_onlyreg[model_name] = [opt, mae, mse, me]
    print(model_name, opt.best_score_, mae, mse, me)
# Out:
# [I 2024-03-06 10:01:27,022] A new study created in memory with name: no-name-d0efc9e6-775d-4638-9000-0ddd3f06b6e5
# [I 2024-03-06 10:01:29,282] Trial 0 finished with value: -10.153258323298045 and parameters: {'selector__k': 10, 'model__n_neighbors': 41, 'model__weights': 'uniform', 'model__algorithm': 'ball_tree'}. Best is trial 0 with value: -10.153258323298045.
# [I 2024-03-06 10:01:32,208] Trial 1 finished with value: -18.88677293824096 and parameters: {'selector__k': 39, 'model__n_neighbors': 38, 'model__weights': 'uniform', 'model__algorithm': 'ball_tree'}. Best is trial 0 with value: -10.153258323298045.
# [I 2024-03-06 10:01:33,427] Trial 2 finished with value: -15.741680754836938 and parameters: {'selector__k': 36, 'model__n_neighbors': 17, 'model__weights': 'uniform', 'model__algorithm': 'auto'}. Best is trial 0 with value: -10.153258323298045.
# [I 2024-03-06 10:01:34,782] Trial 3 finished with value: -20.17635920359382 and parameters: {'selector__k': 45, 'model__n_neighbors': 3, 'model__weights': 'distance', 'model__algorithm': 'auto'}. Best is trial 0 with value: -10.153258323298045.
# [I 2024-03-06 10:01:36,936] Trial 4 finished with value: -14.898673544583641 and parameters: {'selector__k': 31, 'model__n_neighbors': 46, 'model__weights': 'uniform', 'model__algorithm': 'brute'}. Best is trial 0 with value: -10.153258323298045.
# [I 2024-03-06 10:01:37,872] Trial 5 finished with value: -9.910235907795027 and parameters: {'selector__k': 17, 'model__n_neighbors': 34, 'model__weights': 'distance', 'model__algorithm': 'brute'}. Best is trial 5 with value: -9.910235907795027.
# [I 2024-03-06 10:01:38,956] Trial 6 finished with value: -10.785904848526108 and parameters: {'selector__k': 29, 'model__n_neighbors': 12, 'model__weights': 'distance', 'model__algorithm': 'brute'}. Best is trial 5 with value: -9.910235907795027.
# [I 2024-03-06 10:01:40,640] Trial 7 finished with value: -11.939950257921886 and parameters: {'selector__k': 27, 'model__n_neighbors': 40, 'model__weights': 'uniform', 'model__algorithm': 'kd_tree'}. Best is trial 5 with value: -9.910235907795027.
# [I 2024-03-06 10:01:41,914] Trial 8 finished with value: -14.81824330283411 and parameters: {'selector__k': 33, 'model__n_neighbors': 7, 'model__weights': 'distance', 'model__algorithm': 'brute'}. Best is trial 5 with value: -9.910235907795027.
# [I 2024-03-06 10:01
 'model__weights': 'uniform', 'model__algorithm': 'brute'}. Best is trial 35 with value: -9.872493089235354.
# [I 2024-03-06 10:02:36,380] Trial 40 finished with value: -21.33944404678072 and parameters: {'selector__k': 47, 'model__n_neighbors': 50, 'model__weights': 'distance', 'model__algorithm': 'brute'}. Best is trial 35 with value: -9.872493089235354.
# [I 2024-03-06 10:02:37,347] Trial 41 finished with value: -9.88031939689942 and parameters: {'selector__k': 15, 'model__n_neighbors': 44, 'model__weights': 'distance', 'model__algorithm': 'brute'}. Best is trial 35 with value: -9.872493089235354.
# [I 2024-03-06 10:02:38,259] Trial 42 finished with value: -10.27370467431244 and parameters: {'selector__k': 12, 'model__n_neighbors': 38, 'model__weights': 'distance', 'model__algorithm': 'brute'}. Best is trial 35 with value: -9.872493089235354.
# [I 2024-03-06 10:02:40,549] Trial 43 finished with value: -9.876013812569836 and parameters: {'selector__k': 15, 'model__n_neighbors': 46, 'model__weights': 'distance', 'model__algorithm': 'auto'}. Best is trial 35 with value: -9.872493089235354.
# [I 2024-03-06 10:02:41,610] Trial 44 finished with value: -11.094411850350324 and parameters: {'selector__k': 22, 'model__n_neighbors': 47, 'model__weights': 'distance', 'model__algorithm': 'auto'}. Best is trial 35 with value: -9.872493089235354.
# [I 2024-03-06 10:02:42,579] Trial 45 finished with value: -10.950151455262215 and parameters: {'selector__k': 19, 'model__n_neighbors': 41, 'model__weights': 'distance', 'model__algorithm': 'auto'}. Best is trial 35 with value: -9.872493089235354.
# [I 2024-03-06 10:02:44,304] Trial 46 finished with value: -10.257158883986035 and parameters: {'selector__k': 12, 'model__n_neighbors': 45, 'model__weights': 'distance', 'model__algorithm': 'auto'}. Best is trial 35 with value: -9.872493089235354.
# [I 2024-03-06 10:02:45,238] Trial 47 finished with value: -9.90089738856514 and parameters: {'selector__k': 16, 'model__n_neighbors': 38, 'model__weights': 'distance', 'model__algorithm': 'auto'}. Best is trial 35 with value: -9.872493089235354.
# [I 2024-03-06 10:02:46,350] Trial 48 finished with value: -14.394692131335463 and parameters: {'selector__k': 32, 'model__n_neighbors': 12, 'model__weights': 'uniform', 'model__algorithm': 'auto'}. Best is trial 35 with value: -9.872493089235354.
# [I 2024-03-06 10:02:47,325] Trial 49 finished with value: -10.43305693652052 and parameters: {'selector__k': 10, 'model__n_neighbors': 48, 'model__weights': 'distance', 'model__algorithm': 'brute'}. Best is trial 35 with value: -9.872493089235354.
# [I 2024-03-06 10:02:47,805] A new study created in memory with name: no-name-4fd65c7f-f2b6-4407-a41e-4b1691af5d0b
# KNN -9.872493089235354 9.932608661553136 418.10448024140703 200.7568774030666
# [I 2024-03-06 10:02:48,449] Trial 0 finished with value: -12.363398117333155 and parameters: {'selector__k': 42, 'model__learning_rate': 0.6115598031644136, 'model__n_estimators': 80, 'model__max_depth': 43, 'model__num_leaves': 12, 'model__min_child_samples': 13, 'model__subsample': 0.9470338545057777, 'model__colsample_bytree': 0.27576027240696266}. Best is trial 0 with value: -12.363398117333155.
# [I 2024-03-06 10:02:51,267] Trial 1 finished with value: -12.649426674964259 and parameters: {'selector__k': 47, 'model__learning_rate': 0.8104617047021242, 'model__n_estimators': 382, 'model__max_depth': 18, 'model__num_leaves': 47, 'model__min_child_samples': 14, 'model__subsample': 0.26027252322513034, 'model__colsample_bytree': 0.4955214583705506}. Best is trial 0 with value: -12.363398117333155.
# [I 2024-03-06 10:02:52,538] Trial 2 finished with value: -8.697597782213556 and parameters: {'selector__k': 21, 'model__learning_rate': 0.07354689053405343, 'model__n_estimators': 612, 'model__max_depth': 10, 'model__num_leaves': 9, 'model__min_child_samples': 6, 'model__subsample': 0.5138508192858284, 'model__colsample_bytree': 0.41558394443317404}. Best is trial 2 with value: -8.697597782213556.
# [I 2024-03-06 10:02:53,142] Trial 3 finished with value: -10.6881344820287 and parameters: {'selector__k': 30, 'model__learning_rate': 0.20116781185427715, 'model__n_estimators': 78, 'model__max_depth': 38, 'model__num_leaves': 20, 'model__min_child_samples': 3, 'model__subsample': 0.6142182845942594, 'model__colsample_bytree': 0.34975197727666957}. Best is trial 2 with value: -8.697597782213556.
# [I 2024-03-06 10:02:53,974] Trial 4 finished with value: -11.999296917036391 and parameters: {'selector__k': 10, 'model__learning_rate': 0.9943335305797363, 'model__n_estimators': 178, 'model__max_depth': 20, 'model__num_leaves': 36, 'model__min_child_samples': 6, 'model__subsample': 0.6316859774748715, 'model__colsample_bytree': 0.2505263963445396}. Best is trial 2 with value: -8.697597782213556.
# [I 2024-03-06 10:02:56,524] Trial 5 finished with value: -11.403839999217407 and parameters: {'selector__k': 40, 'model__learning_rate': 0.051888094537766126, 'model__n_estimators': 1837, 'model__max_depth': 45, 'model__num_leaves': 2, 'model__min_child_samples': 17, 'model__subsample': 0.2965209224697186, 'model__colsample_bytree': 0.2506325063823282}. Best is trial 2 with value: -8.697597782213556.
# [I 2024-03-06 10:02:56,965] Trial 6 finished with value: -8.554330922987736 and parameters: {'selector__k': 12, 'model__learning_rate': 0.18204566731120206, 'model__n_estimators': 57, 'model__max_depth': 7, 'model__num_leaves': 28, 'model__min_child_samples': 11, 'model__subsample': 0.3899058456801888, 'model__colsample_bytree': 0.6284311493905078}. Best is trial 6 with value: -8.554330922987736.
# [I 2024-03-06 10:02:57,727] Trial 7 finished with value: -10.95070702787663 and parameters: {'selector__k': 38, 'model__learning_rate': 0.17401637487311936, 'model__n_estimators': 134, 'model__max_depth': 26, 'model__num_leaves': 18, 'model__min_child_samples': 4, 'model__subsample': 0.6499756415646462, 'model__colsample_bytree': 0.20117128930419864}. Best is trial 6 with value: -8.554330922987736.
# [I 2024-03-06 10:02:58,303] Trial 8 finished with value: -11.243774046027449 and parameters: {'selector__k': 45, 'model__learning_rate': 0.11144146366761327, 'model__n_estimators': 79, 'model__max_depth': 46, 'model__num_leaves': 8, 'model__min_child_samples': 9, 'model__subsample': 0.9630351563685429, 'model__colsample_bytree': 0.8450452922674415}. Best is trial 6 with value: -8.554330922987736.
# [I 2024-03-06 10:03:02,062] Trial 9 finished with value: -9.843776887353384 and parameters: {'selector__k': 14, 'model__learning_rate': 0.42389392844688295, 'model__n_estimators': 997, 'model__max_depth': 19, 'model__num_leaves': 43, 'model__min_child_samples': 5, 'model__subsample': 0.17912299399966314, 'model__colsample_bytree': 0.8410240974116641}. Best is trial 6 with value: -8.554330922987736.
# [I 2024-03-06 10:03:02,866] Trial 10 finished with value: -9.309139242038261 and parameters: {'selector__k': 21, 'model__learning_rate': 0.38810401670330613, 'model__n_estimators': 237, 'model__max_depth': 4, 'model__num_leaves': 30, 'model__min_child_samples': 10, 'model__subsample': 0.4387517107772105, 'model__colsample_bytree': 0.6468692791747296}. Best is trial 6 with value: -8.554330922987736.
# [I 2024-03-06 10:03:03,938] Trial 11 finished with value: -9.30738503806945 and parameters: {'selector__k': 20, 'model__learning_rate': 0.2838163366019073, 'model__n_estimators': 752, 'model__max_depth': 2, 'model__num_leaves': 28, 'model__min_child_samples': 8, 'model__subsample': 0.43485700899627827, 'model__colsample_bytree': 0.613079838856923}. Best is trial 6 with value: -8.554330922987736.
# [I 2024-03-06 10:03:05,660] Trial 12 finished with value: -8.697107604723197 and parameters: {'selector__k': 20, 'model__learning_rate': 0.031069019204806002, 'model__n_estimators': 616, 'model__max_depth': 9, 'model__num_leaves': 21, 'model__min_child_samples': 19, 'model__subsample': 0.44573009562783167, 'model__colsample_bytree': 0.46750732796483496}. Best is trial 6 with value: -8.554330922987736.
# [I 2024-03-06 10:03:13,064] Trial 13 finished with value: -9.998578187348794 and parameters: {'selector__k': 15, 'model__learning_rate': 0.5615808727278394, 'model__n_estimators': 2859, 'model__max_depth': 12, 'model__num_leaves': 22, 'model__min_child_samples': 20, 'model__subsample': 0.7819339349983426, 'model__colsample_bytree': 0.7114511901834734}. Best is trial 6 with value: -8.554330922987736.
# [I 2024-03-06 10:03:14,947] Trial 14 finished with value: -10.192754527031374 and parameters: {'selector__k': 26, 'model__learning_rate': 0.2970981755366929, 'model__n_estimators': 353, 'model__max_depth': 31, 'model__num_leaves': 35, 'model__min_child_samples': 20, 'model__subsample': 0.3625904924838242, 'model__colsample_bytree': 0.5050849406164225}. Best is trial 6 with value: -8.554330922987736.
# [I 2024-03-06 10:03:17,971] Trial 15 finished with value: -11.137718811341312 and parameters: {'selector__k': 31, 'model__learning_rate': 0.022908584402667354, 'model__n_estimators': 563, 'model__max_depth': 9, 'model__num_leaves': 34, 'model__min_child_samples': 1, 'model__subsample': 0.13203718136878528, 'model__colsample_bytree': 0.9398132393681589}. Best is trial 6 with value: -8.554330922987736.
# [I 2024-03-06 10:03:18,488] Trial 16 finished with value: -8.439148094560041 and parameters: {'selector__k': 11, 'model__learning_rate': 0.23443652242104945, 'model__n_estimators': 53, 'model__max_depth': 15, 'model__num_leaves': 26, 'model__min_child_samples': 13, 'model__subsample': 0.7730054995500458, 'model__colsample_bytree': 0.7242065174966068}. Best is trial 16 with value: -8.439148094560041.
# [I 2024-03-06 10:03:19,047] Trial 17 finished with value: -9.496704936028001 and parameters: {'selector__k': 12, 'model__learning_rate': 0.664738160433137, 'model__n_estimators': 55, 'model__max_depth': 15, 'model__num_leaves': 41, 'model__min_child_samples': 13, 'model__subsample': 0.8136116308383838, 'model__colsample_bytree': 0.7452716850077912}. Best is trial 16 with value: -8.439148094560041.
# [I 2024-03-06 10:03:19,560] Trial 18 finished with value: -9.257842670023534 and parameters: {'selector__k': 16, 'model__learning_rate': 0.43586504623609945, 'model__n_estimators': 50, 'model__max_depth': 25, 'model__num_leaves': 26, 'model__min_child_samples': 16, 'model__subsample': 0.7485763043117781, 'model__colsample_bytree': 0.5986168898175388}. Best is trial 16 with value: -8.439148094560041.
# [I 2024-03-06 10:03:20,076] Trial 19 finished with value: -11.678106353843145 and parameters: {'selector__k': 26, 'model__learning_rate': 0.27875007764226756, 'model__n_estimators': 131, 'model__max_depth': 1, 'model__num_leaves': 15, 'model__min_child_samples': 12, 'model__subsample': 0.5387262225732112, 'model__colsample_bytree': 0.11452437189709236}. Best is trial 16 with value: -8.439148094560041.
# [I 2024-03-06 10:03:20,878] Trial 20 finished with value: -10.913753974917809 and parameters: {'selector__k': 35, 'model__learning_rate': 0.1832239777572859, 'model__n_estimators': 115, 'model__max_depth': 6, 'model__num_leaves': 25, 'model__min_child_samples': 15, 'model__subsample': 0.8648914012630047, 'model__colsample_bytree': 0.7406501841336695}. Best is trial 16 with value: -8.439148094560041.
# [I 2024-03-06 10:03:24,961] Trial 21 finished with value: -9.217489669596935 and parameters: {'selector__k': 17, 'model__learning_rate': 0.12891389489170402, 'model__n_estimators': 1179, 'model__max_depth': 13, 'model__num_leaves': 32, 'model__min_child_samples': 18, 'model__subsample': 0.4315730785031385, 'model__colsample_bytree': 0.4158092153912235}. Best is trial 16 with value: -8.439148094560041.
# [I 2024-03-06 10:03:25,847] Trial 22 finished with value: -8.94861766568091 and parameters: {'selector__k': 10, 'model__learning_rate': 0.26073867119529304, 'model__n_estimators': 272, 'model__max_depth': 7, 'model__num_leaves': 24, 'model__min_child_samples': 12, 'model__subsample': 0.7081182331329363, 'model__colsample_bytree': 0.5393034361202179}. Best is trial 16 with value: -8.439148094560041.
# [I 2024-03-06 10:03:26,394] Trial 23 finished with value: -12.552522941059618 and parameters: {'selector__k': 19, 'model__learning_rate': 0.017210939166991762, 'model__n_estimators': 64, 'model__max_depth': 15, 'model__num_leaves': 17, 'model__min_child_samples': 18, 'model__subsample': 0.34196379461002496, 'model__colsample_bytree': 0.8335273763280736}. Best is trial 16 with value: -8.439148094560041.
# [I 2024-03-06 10:03:27,150] Trial 24 finished with value: -8.86910706550502 and parameters: {'selector__k': 23, 'model__learning_rate': 0.20707818120468657, 'model__n_estimators': 104, 'model__max_depth': 8, 'model__num_leaves': 29, 'model__min_child_samples': 11, 'model__subsample': 0.5329695699071519, 'model__colsample_bytree': 0.6910614496818184}. Best is trial 16 with value: -8.439148094560041.
# [I 2024-03-06 10:03:27,942] Trial 25 finished with value: -8.795243730026957 and parameters: {'selector__k': 13, 'model__learning_rate': 0.34120749541855583, 'model__n_estimators': 192, 'model__max_depth': 22, 'model__num_leaves': 21, 'model__min_child_samples': 9, 'model__subsample': 0.22722834688430668, 'model__colsample_bytree': 0.9838319300661379}. Best is trial 16 with value: -8.439148094560041.
# [I 2024-03-06 10:03:29,154] Trial 26 finished with value: -10.095844004801982 and parameters: {'selector__k': 17, 'model__learning_rate': 0.4948580490293224, 'model__n_estimators': 502, 'model__max_depth': 31, 'model__num_leaves': 13, 'model__min_child_samples': 16, 'model__subsample': 0.4683350681450195, 'model__colsample_bytree': 0.4365840841168498}. Best is trial 16 with value: -8.439148094560041.
# [I 2024-03-06 10:03:34,712] Trial 27 finished with value: -8.75527190373839 and parameters: {'selector__k': 24, 'model__learning_rate': 0.12793375640036014, 'model__n_estimators': 1285, 'model__max_depth': 15, 'model__num_leaves': 37, 'model__min_child_samples': 8, 'model__subsample': 0.3645587714047813, 'model__colsample_bytree': 0.5723486932314517}. Best is trial 16 with value: -8.439148094560041.
# [I 2024-03-06 10:03:36,439] Trial 28 finished with value: -9.855212568553199 and parameters: {'selector__k': 10, 'model__learning_rate': 0.35512805880969067, 'model__n_estimators': 819, 'model__max_depth': 5, 'model__num_leaves': 23, 'model__min_child_samples': 14, 'model__subsample': 0.6852161401813377, 'model__colsample_bytree': 0.8011975753787001}. Best is trial 16 with value: -8.439148094560041.
# [I 2024-03-06 10:03:37,141] Trial 29 finished with value: -10.107782557013492 and parameters: {'selector__k': 18, 'model__learning_rate': 0.64513696423059, 'model__n_estimators': 89, 'model__max_depth': 50, 'model__num_leaves': 40, 'model__min_child_samples': 19, 'model__subsample': 0.8893583482867851, 'model__colsample_bytree': 0.6735960679392583}. Best is trial 16 with value: -8.439148094560041.
# [I 2024-03-06 10:03:37,705] Trial 30 finished with value: -8.600974062531952 and parameters: {'selector__k': 12, 'model__learning_rate': 0.22806009841233987, 'model__n_estimators': 63, 'model__max_depth': 11, 'model__num_leaves': 32, 'model__min_child_samples': 11, 'model__subsample': 0.5744082572834521, 'model__colsample_bytree': 0.48836966931261133}. Best is trial 16 with value: -8.439148094560041.
# [I 2024-03-06 10:03:38,294] Trial 31 finished with value: -8.8751694931036 and parameters: {'selector__k': 13, 'model__learning_rate': 0.22165423077044116, 'model__n_estimators': 70, 'model__max_depth': 11, 'model__num_leaves': 30, 'model__min_child_samples': 11, 'model__subsample': 0.5819919482601397, 'model__colsample_bytree': 0.4860695147215003}. Best is trial 16 with value: -8.439148094560041.
# [I 2024-03-06 10:03:38,806] Trial 32 finished with value: -8.855323895469441 and parameters: {'selector__k': 12, 'model__learning_rate': 0.10750484544366368, 'model__n_estimators': 50, 'model__max_depth': 17, 'model__num_leaves': 27, 'model__min_child_samples': 13, 'model__subsample': 0.37258325605723447, 'model__colsample_bytree': 0.3362075230039995}. Best is trial 16 with value: -8.439148094560041.
# [I 2024-03-06 10:03:39,556] Trial 33 finished with value: -8.722398382408121 and parameters: {'selector__k': 14, 'model__learning_rate': 0.07774701510174008, 'model__n_estimators': 94, 'model__max_depth': 10, 'model__num_leaves': 48, 'model__min_child_samples': 14, 'model__subsample': 0.9993512708745373, 'model__colsample_bytree': 0.3515269913907857}. Best is trial 16 with value: -8.439148094560041.
# [I 2024-03-06 10:03:40,054] Trial 34 finished with value: -8.816550279453152 and parameters: {'selector__k': 16, 'model__learning_rate': 0.14272470817932464, 'model__n_estimators': 65, 'model__max_depth': 4, 'model__num_leaves': 32, 'model__min_child_samples': 10, 'model__subsample': 0.5020383151257044, 'model__colsample_bytree': 0.45948505911758825}. Best is trial 16 with value: -8.439148094560041.
# [I 2024-03-06 10:03:41,635] Trial 35 finished with value: -11.67117626202527 and parameters: {'selector__k': 22, 'model__learning_rate': 0.8836702761044126, 'model__n_estimators': 440, 'model__max_depth': 12, 'model__num_leaves': 19, 'model__min_child_samples': 7, 'model__subsample': 0.5821109499103204, 'model__colsample_bytree': 0.5393144648429749}. Best is trial 16 with value: -8.439148094560041.
# [I 2024-03-06 10:03:42,519] Trial 36 finished with value: -8.987628109197274 and parameters: {'selector__k': 11, 'model__learning_rate': 0.33186681044932775, 'model__n_estimators': 170, 'model__max_depth': 24, 'model__num_leaves': 32, 'model__min_child_samples': 12, 'model__subsample': 0.28926167107291834, 'model__colsample_bytree': 0.6260598271539565}. Best is trial 16 with value: -8.439148094560041.
# [I 2024-03-06 10:03:43,369] Trial 37 finished with value: -9.154894112650476 and parameters: {'selector__k': 19, 'model__learning_rate': 0.2372619474727959, 'model__n_estimators': 322, 'model__max_depth': 16, 'model__num_leaves': 10, 'model__min_child_samples': 15, 'model__subsample': 0.6771850614440894, 'model__colsample_bytree': 0.35185233072052047}. Best is trial 16 with value: -8.439148094560041.
# [I 2024-03-06 10:03:44,039] Trial 38 finished with value: -8.666091562149887 and parameters: {'selector__k': 15, 'model__learning_rate': 0.18639293810591137, 'model__n_estimators': 76, 'model__max_depth': 21, 'model__num_leaves': 39, 'model__min_child_samples': 9, 'model__subsample': 0.48770670421680834, 'model__colsample_bytree': 0.7699203175113742}. Best is trial 16 with value: -8.439148094560041.
# [I 2024-03-06 10:03:44,702] Trial 39 finished with value: -8.91000119433476 and parameters: {'selector__k': 15, 'model__learning_rate': 0.1769967603097777, 'model__n_estimators': 78, 'model__max_depth': 28, 'model__num_leaves': 38, 'model__min_child_samples': 9, 'model__subsample': 0.6181651861140124, 'model__colsample_bytree': 0.8958245408040729}. Best is trial 16 with value: -8.439148094560041.
# [I 2024-03-06 10:03:45,578] Trial 40 finished with value: -9.748714643366316 and parameters: {'selector__k': 10, 'model__learning_rate': 0.5324429087616629, 'model__n_estimators': 141, 'model__max_depth': 20, 'model__num_leaves': 46, 'model__min_child_samples': 6, 'model__subsample': 0.49007771914173276, 'model__colsample_bytree': 0.783071740486152}. Best is trial 16 with value: -8.439148094560041.
# [I 2024-03-06 10:03:46,220] Trial 41 finished with value: -8.713582072096573 and parameters: {'selector__k': 13, 'model__learning_rate': 0.07582970118232547, 'model__n_estimators': 61, 'model__max_depth': 21, 'model__num_leaves': 44, 'model__min_child_samples': 10, 'model__subsample': 0.40294771132248286, 'model__colsample_bytree': 0.5132043072568431}. Best is trial 16 with value: -8.439148094560041.
# [I 2024-03-06 10:03:46,876] Trial 42 finished with value: -8.638429382694278 and parameters: {'selector__k': 15, 'model__learning_rate': 0.16144161760439374, 'model__n_estimators': 81, 'model__max_depth': 9, 'model__num_leaves': 34, 'model__min_child_samples': 8, 'model__subsample': 0.30880636503586834, 'model__colsample_bytree': 0.646071355484503}. Best is trial 16 with value: -8.439148094560041.
# [I 2024-03-06 10:03:47,574] Trial 43 finished with value: -8.792343432152038 and parameters: {'selector__k': 15, 'model__learning_rate': 0.2312744144438529, 'model__n_estimators': 90, 'model__max_depth': 18, 'model__num_leaves': 39, 'model__min_child_samples': 8, 'model__subsample': 0.31039958000792633, 'model__colsample_bytree': 0.6634244469223737}. Best is trial 16 with value: -8.439148094560041.
# [I 2024-03-06 10:03:48,288] Trial 44 finished with value: -8.553138088543747 and parameters: {'selector__k': 12, 'model__learning_rate': 0.16935402102559274, 'model__n_estimators': 76, 'model__max_depth': 36, 'model__num_leaves': 50, 'model__min_child_samples': 7, 'model__subsample': 0.5778194091498033, 'model__colsample_bytree': 0.7390165299209797}. Best is trial 16 with value: -8.439148094560041.
# [I 2024-03-06 10:03:49,085] Trial 45 finished with value: -9.269362796804296 and parameters: {'selector__k': 12, 'model__learning_rate': 0.4028773807965442, 'model__n_estimators': 109, 'model__max_depth': 38, 'model__num_leaves': 50, 'model__min_child_samples': 4, 'model__subsample': 0.19885946580117198, 'model__colsample_bytree': 0.7135618938193119}. Best is trial 16 with value: -8.439148094560041.
# [I 2024-03-06 10:03:49,659] Trial 46 finished with value: -8.910853345496205 and parameters: {'selector__k': 11, 'model__learning_rate': 0.2978142193065276, 'model__n_estimators': 57, 'model__max_depth': 38, 'model__num_leaves': 34, 'model__min_child_samples': 7, 'model__subsample': 0.5732169286092059, 'model__colsample_bytree': 0.5908037552454366}. Best is trial 16 with value: -8.439148094560041.
# [I 2024-03-06 10:03:50,292] Trial 47 finished with value: -9.28555149567097 and parameters: {'selector__k': 13, 'model__learning_rate': 0.46131585929339114, 'model__n_estimators': 68, 'model__max_depth': 41, 'model__num_leaves': 42, 'model__min_child_samples': 6, 'model__subsample': 0.23218206716671735, 'model__colsample_bytree': 0.643964894878989}. Best is trial 16 with value: -8.439148094560041.
# [I 2024-03-06 10:03:50,991] Trial 48 finished with value: -11.603587602893617 and parameters: {'selector__k': 45, 'model__learning_rate': 0.7240093755476763, 'model__n_estimators': 159, 'model__max_depth': 35, 'model__num_leaves': 2, 'model__min_child_samples': 11, 'model__subsample': 0.6421879590725947, 'model__colsample_bytree': 0.5605333766253646}. Best is trial 16 with value: -8.439148094560041.
# [I 2024-03-06 10:03:51,503] Trial 49 finished with value: -8.890047992754694 and parameters: {'selector__k': 17, 'model__learning_rate': 0.08582249403451175, 'model__n_estimators': 85, 'model__max_depth': 3, 'model__num_leaves': 28, 'model__min_child_samples': 7, 'model__subsample': 0.1293125178432583, 'model__colsample_bytree': 0.7222030427435303}. Best is trial 16 with value: -8.439148094560041.
# [I 2024-03-06 10:03:51,660] A new study created in memory with name: no-name-e939283a-0fb2-407c-b3bb-7f2fea4e807b
# LGBM -8.439148094560041 10.347945784227322 457.0516525237453 256.7074891522627
# [I 2024-03-06 10:04:25,916] Trial 0 finished with value: -12.12611884664912 and parameters: {'selector__k': 44, 'model__max_features': 'sqrt', 'model__n_estimators': 266, 'model__max_depth': 94, 'model__min_samples_leaf': 19}. Best is trial 0 with value: -12.12611884664912.
# [I 2024-03-06 10:06:34,395] Trial 1 finished with value: -11.83282643197764 and parameters: {'selector__k': 34, 'model__max_features': 'log2', 'model__n_estimators': 1123, 'model__max_depth': 32, 'model__min_samples_leaf': 11}. Best is trial 1 with value: -11.83282643197764.
# [I 2024-03-06 10:07:05,257] Trial 2 finished with value: -9.117393316321644 and parameters: {'selector__k': 19, 'model__max_features': 'log2', 'model__n_estimators': 350, 'model__max_depth': 184, 'model__min_samples_leaf': 7}. Best is trial 2 with value: -9.117393316321644.
# [I 2024-03-06 10:09:51,770] Trial 3 finished with value: -11.908909639572974 and parameters: {'selector__k': 40, 'model__max_features': 'log2', 'model__n_estimators': 1130, 'model__max_depth': 169, 'model__min_samples_leaf': 6}. Best is trial 2 with value: -9.117393316321644.
# [I 2024-03-06 10:11:26,283] Trial 4 finished with value: -12.403858959035578 and parameters: {'selector__k': 47, 'model__max_features': 'log2', 'model__n_estimators': 834, 'model__max_depth': 139, 'model__min_samples_leaf': 20}. Best is trial 2 with value: -9.117393316321644.
# [I 2024-03-06 10:12:09,773] Trial 5 finished with value: -11.676443885854068 and parameters: {'selector__k': 42, 'model__max_features': 'sqrt', 'model__n_estimators': 243, 'model__max_depth': 163, 'model__min_samples_leaf': 4}. Best is trial 2 with value: -9.117393316321644.
# [I 2024-03-06 10:15:04,257] Trial 6 finished with value: -12.07423647080299 and parameters: {'selector__k': 45, 'model__max_features': 'sqrt', 'model__n_estimators': 1184, 'model__max_depth': 107, 'model__min_samples_leaf': 13}. Best is trial 2 with value: -9.117393316321644.
# [I 2024-03-06 10:15:43,969] Trial 7 finished with value: -9.162214188668425 and parameters: {'selector__k': 12, 'model__max_features': 'sqrt', 'model__n_estimators': 1121, 'model__max_depth': 198, 'model__min_samples_leaf': 9}. Best is trial 2 with value: -9.117393316321644.
# [I 2024-03-06 10:16:08,293] Trial 8 finished with value: -12.2206268641495 and parameters: {'selector__k': 46, 'model__max_features': 'log2', 'model__n_estimators': 201, 'model__max_depth': 67, 'model__min_samples_leaf': 13}. Best is trial 2 with value: -9.117393316321644.
# [I 2024-03-06 10:17:14,939] Trial 9 finished with value: -9.4426408421599 and parameters: {'selector__k': 22, 'model__max_features': 'log2', 'model__n_estimators': 809, 'model__max_depth': 96, 'model__min_samples_leaf': 11}. Best is trial 2 with value: -9.117393316321644.
# [I 2024-03-06 10:17:16,650] Trial 10 finished with value: -14.469213878377083 and parameters: {'selector__k': 21, 'model__max_features': 'log2', 'model__n_estimators': 66, 'model__max_depth': 2, 'model__min_samples_leaf': 1}. Best is trial 2 with value: -9.117393316321644.
# [I 2024-03-06 10:18:48,002] Trial 11 finished with value: -9.134106879931467 and parameters: {'selector__k': 10, 'model__max_features': 'sqrt', 'model__n_estimators': 2773, 'model__max_depth': 198, 'model__min_samples_leaf': 7}. Best is trial 2 with value: -9.117393316321644.
# [I 2024-03-06 10:20:23,040] Trial 12 finished with value: -9.136856757896751 and parameters: {'selector__k': 10, 'model__max_features': 'sqrt', 'model__n_estimators': 2940, 'model__max_depth': 199, 'model__min_samples_leaf': 7}. Best is trial 2 with value: -9.117393316321644.
# [I 2024-03-06 10:20:33,763] Trial 13 finished with value: -9.012675995690758 and parameters: {'selector__k': 17, 'model__max_features': 'sqrt', 'model__n_estimators': 95, 'model__max_depth': 154, 'model__min_samples_leaf': 3}. Best is trial 13 with value: -9.012675995690758.
# [I 2024-03-06 10:20:47,011] Trial 14 finished with value: -8.997195009006553 and parameters: {'selector__k': 20, 'model__max_features': 'sqrt', 'model__n_estimators': 88, 'model__max_depth': 145, 'model__min_samples_leaf': 1}. Best is trial 14 with value: -8.997195009006553.
# [I 2024-03-06 10:20:57,110] Trial 15 finished with value: -10.660615579867606 and parameters: {'selector__k': 26, 'model__max_features': 'sqrt', 'model__n_estimators': 52, 'model__max_depth': 143, 'model__min_samples_leaf': 1}. Best is trial 14 with value: -8.997195009006553.
# [I 2024-03-06 10:21:07,835] Trial 16 finished with value: -8.918286602204544 and parameters: {'selector__k': 18, 'model__max_features': 'sqrt', 'model__n_estimators': 104, 'model__max_depth': 132, 'model__min_samples_leaf': 3}. Best is trial 16 with value: -8.918286602204544.
# [I 2024-03-06 10:21:25,291] Trial 17 finished with value: -11.782137264143246 and parameters: {'selector__k': 30, 'model__max_features': 'sqrt', 'model__n_estimators': 121, 'model__max_depth': 135, 'model__min_samples_leaf': 4}. Best is trial 16 with value: -8.918286602204544.
# [I 2024-03-06 10:21:41,308] Trial 18 finished with value: -8.907392975626967 and parameters: {'selector__k': 15, 'model__max_features': 'sqrt', 'model__n_estimators': 141, 'model__max_depth': 114, 'model__min_samples_leaf': 1}. Best is trial 18 with value: -8.907392975626967.
# [I 2024-03-06 10:21:52,756] Trial 19 finished with value: -9.127854388218909 and parameters: {'selector__k': 15, 'model__max_features': 'sqrt', 'model__n_estimators': 152, 'model__max_depth': 112, 'model__min_samples_leaf': 3}. Best is trial 18 with value: -8.907392975626967.
# [I 2024-03-06 10:22:36,719] Trial 20 finished with value: -9.58092855273946 and parameters: {'selector__k': 25, 'model__max_features': 'sqrt', 'model__n_estimators': 496, 'model__max_depth': 70, 'model__min_samples_leaf': 17}. Best is trial 18 with value: -8.907392975626967.
# [I 2024-03-06 10:22:45,431] Trial 21 finished with value: -8.841386742620978 and parameters: {'selector__k': 14, 'model__max_features': 'sqrt', 'model__n_estimators': 87, 'model__max_depth': 128, 'model__min_samples_leaf': 1}. Best is trial 21 with value: -8.841386742620978.
# [I 2024-03-06 10:22:55,796] Trial 22 finished with value: -9.13002091095904 and parameters: {'selector__k': 15, 'model__max_features': 'sqrt', 'model__n_estimators': 153, 'model__max_depth': 126, 'model__min_samples_leaf': 5}. Best is trial 21 with value: -8.841386742620978.
# [I 2024-03-06 10:23:01,618] Trial 23 finished with value: -8.821483713584065 and parameters: {'selector__k': 14, 'model__max_features': 'sqrt', 'model__n_estimators': 76, 'model__max_depth': 83, 'model__min_samples_leaf': 2}. Best is trial 23 with value: -8.821483713584065.
# [I 2024-03-06 10:23:06,303] Trial 24 finished with value: -8.878473261249997 and parameters: {'selector__k': 14, 'model__max_features': 'sqrt', 'model__n_estimators': 61, 'model__max_depth': 70, 'model__min_samples_leaf': 2}. Best is trial 23 with value: -8.821483713584065.
# [I 2024-03-06 10:23:10,541] Trial 25 finished with value: -8.91002546906834 and parameters: {'selector__k': 13, 'model__max_features': 'sqrt', 'model__n_estimators': 52, 'model__max_depth': 72, 'model__min_samples_leaf': 2}. Best is trial 23 with value: -8.821483713584065.
# [I 2024-03-06 10:23:17,676] Trial 26 finished with value: -9.519420513239353 and parameters: {'selector__k': 24, 'model__max_features': 'sqrt', 'model__n_estimators': 73, 'model__max_depth': 42, 'model__min_samples_leaf': 9}. Best is trial 23 with value: -8.821483713584065.
# [I 2024-03-06 10:23:28,942] Trial 27 finished with value: -11.932992240573292 and parameters: {'selector__k': 34, 'model__max_features': 'sqrt', 'model__n_estimators': 72, 'model__max_depth': 84, 'model__min_samples_leaf': 5}. Best is trial 23 with value: -8.821483713584065.
# [I 2024-03-06 10:23:38,180] Trial 28 finished with value: -11.482976021003179 and parameters: {'selector__k': 29, 'model__max_features': 'sqrt', 'model__n_estimators': 56, 'model__max_depth': 39, 'model__min_samples_leaf': 3}. Best is trial 23 with value: -8.821483713584065.
# [I 2024-03-06 10:23:58,293] Trial 29 finished with value: -9.475413824347443 and parameters: {'selector__k': 13, 'model__max_features': 'sqrt', 'model__n_estimators': 405, 'model__max_depth': 52, 'model__min_samples_leaf': 18}. Best is trial 23 with value: -8.821483713584065.
# [I 2024-03-06 10:24:15,456] Trial 30 finished with value: -9.416670078302415 and parameters: {'selector__k': 17, 'model__max_features': 'sqrt', 'model__n_estimators': 210, 'model__max_depth': 85, 'model__min_samples_leaf': 14}. Best is trial 23 with value: -8.821483713584065.
# [I 2024-03-06 10:24:32,078] Trial 31 finished with value: -8.919255293403063 and parameters: {'selector__k': 15, 'model__max_features': 'sqrt', 'model__n_estimators': 137, 'model__max_depth': 120, 'model__min_samples_leaf': 1}. Best is trial 23 with value: -8.821483713584065.
# [I 2024-03-06 10:24:36,452] Trial 32 finished with value: -8.93530803397586 and parameters: {'selector__k': 12, 'model__max_features': 'sqrt', 'model__n_estimators': 81, 'model__max_depth': 100, 'model__min_samples_leaf': 2}. Best is trial 23 with value: -8.821483713584065.
# [I 2024-03-06 10:24:47,155] Trial 33 finished with value: -9.190008018849706 and parameters: {'selector__k': 17, 'model__max_features': 'sqrt', 'model__n_estimators': 109, 'model__max_depth': 58, 'model__min_samples_leaf': 5}. Best is trial 23 with value: -8.821483713584065.
# [I 2024-03-06 10:25:07,429] Trial 34 finished with value: -8.959755845079908 and parameters: {'selector__k': 22, 'model__max_features': 'sqrt', 'model__n_estimators': 165, 'model__max_depth': 86, 'model__min_samples_leaf': 2}. Best is trial 23 with value: -8.821483713584065.
# [I 2024-03-06 10:25:29,444] Trial 35 finished with value: -9.101939185732425 and parameters: {'selector__k': 15, 'model__max_features': 'log2', 'model__n_estimators': 304, 'model__max_depth': 118, 'model__min_samples_leaf': 4}. Best is trial 23 with value: -8.821483713584065.
# [I 2024-03-06 10:25:31,916] Trial 36 finished with value: -9.194359196842544 and parameters: {'selector__k': 10, 'model__max_features': 'sqrt', 'model__n_estimators': 65, 'model__max_depth': 13, 'model__min_samples_leaf': 6}. Best is trial 23 with value: -8.821483713584065.
# [I 2024-03-06 10:25:46,975] Trial 37 finished with value: -11.705246163511756 and parameters: {'selector__k': 34, 'model__max_features': 'sqrt', 'model__n_estimators': 119, 'model__max_depth': 101, 'model__min_samples_leaf': 9}. Best is trial 23 with value: -8.821483713584065.
# [I 2024-03-06 10:25:58,070] Trial 38 finished with value: -9.056429359623124 and parameters: {'selector__k': 20, 'model__max_features': 'log2', 'model__n_estimators': 91, 'model__max_depth': 172, 'model__min_samples_leaf': 2}. Best is trial 23 with value: -8.821483713584065.
# [I 2024-03-06 10:26:08,423] Trial 39 finished with value: -9.088046708465559 and parameters: {'selector__k': 14, 'model__max_features': 'sqrt', 'model__n_estimators': 192, 'model__max_depth': 23, 'model__min_samples_leaf': 6}. Best is trial 23 with value: -8.821483713584065.
# [I 2024-03-06 10:26:51,208] Trial 40 finished with value: -11.737983391943063 and parameters: {'selector__k': 40, 'model__max_features': 'log2', 'model__n_estimators': 266, 'model__max_depth': 79, 'model__min_samples_leaf': 4}. Best is trial 23 with value: -8.821483713584065.
# [I 2024-03-06 10:26:54,008] Trial 41 finished with value: -8.955285953191195 and parameters: {'selector__k': 12, 'model__max_features': 'sqrt', 'model__n_estimators': 51, 'model__max_depth': 70, 'model__min_samples_leaf': 2}. Best is trial 23 with value: -8.821483713584065.
# [I 2024-03-06 10
# [I 2024-03-06 12:45:33,363] Trial 7 finished with value: -13.385406761381306 and parameters: {'learning_rate': 0.4741494103460564, 'n_estimators': 62, 'max_depth': 18, 'num_leaves': 26, 'min_child_samples': 18, 'subsample': 0.9370211037361788, 'colsample_bytree': 0.19551562172759465}. Best is trial 6 with value: -11.368901152661472.
# [I 2024-03-06 12:45:41,260] Trial 8 finished with value: -10.728799143324686 and parameters: {'learning_rate': 0.48886352817332074, 'n_estimators': 786, 'max_depth': 13, 'num_leaves': 35, 'min_child_samples': 17, 'subsample': 0.22693664537028538, 'colsample_bytree': 0.25818405900359176}. Best is trial 8 with value: -10.728799143324686.
# [I 2024-03-06 12:45:42,343] Trial 9 finished with value: -12.29667054115943 and parameters: {'learning_rate': 0.6156833161908947, 'n_estimators': 52, 'max_depth': 14, 'num_leaves': 13, 'min_child_samples': 3, 'subsample': 0.7156962408551141, 'colsample_bytree': 0.5272177793459323}. Best is trial 8 with value: -10.728799143324686.
# [I 2024-03-06 12:45:43,609] Trial 10 finished with value: -12.313608149880288 and parameters: {'learning_rate': 0.9865296952312411, 'n_estimators': 326, 'max_depth': 2, 'num_leaves': 44, 'min_child_samples': 12, 'subsample': 0.1403590782401799, 'colsample_bytree': 0.6451700699561638}. Best is trial 8 with value: -10.728799143324686.
# [I 2024-03-06 12:45:56,861] Trial 11 finished with value: -11.200963357136592 and parameters: {'learning_rate': 0.13680917341935378, 'n_estimators': 1229, 'max_depth': 26, 'num_leaves': 38, 'min_child_samples': 10, 'subsample': 0.5067791563779911, 'colsample_bytree': 0.4518819819528026}. Best is trial 8 with value: -10.728799143324686.
# [I 2024-03-06 12:46:00,220] Trial 12 finished with value: -10.374137880994173 and parameters: {'learning_rate': 0.23255756132828828, 'n_estimators': 696, 'max_depth': 3, 'num_leaves': 38, 'min_child_samples': 10, 'subsample': 0.4844690569712041, 'colsample_bytree': 0.48136306973331877}. Best is trial 12 with value: -10.374137880994173.
# [I 2024-03-06 12:46:06,641] Trial 13 finished with value: -12.395677472575812 and parameters: {'learning_rate': 0.26699730822691664, 'n_estimators': 632, 'max_depth': 7, 'num_leaves': 37, 'min_child_samples': 11, 'subsample': 0.32593503640533306, 'colsample_bytree': 0.6114357571932638}. Best is trial 12 with value: -10.374137880994173.
# [I 2024-03-06 12:46:08,832] Trial 14 finished with value: -14.187018733756993 and parameters: {'learning_rate': 0.776546753648059, 'n_estimators': 182, 'max_depth': 7, 'num_leaves': 37, 'min_child_samples': 8, 'subsample': 0.5276786917056722, 'colsample_bytree': 0.3785246774756248}. Best is trial 12 with value: -10.374137880994173.
# [I 2024-03-06 12:46:10,586] Trial 15 finished with value: -11.044434606626204 and parameters: {'learning_rate': 0.34494133162755236, 'n_estimators': 543, 'max_depth': 2, 'num_leaves': 43, 'min_child_samples': 14, 'subsample': 0.23811639478046595, 'colsample_bytree': 0.9822959662532735}. Best is trial 12 with value: -10.374137880994173.
# [I 2024-03-06 12:46:40,978] Trial 16 finished with value: -12.46213659038122 and parameters: {'learning_rate': 0.34247211412655143, 'n_estimators': 2944, 'max_depth': 10, 'num_leaves': 33, 'min_child_samples': 20, 'subsample': 0.42126320322136446, 'colsample_bytree': 0.5630894763414864}. Best is trial 12 with value: -10.374137880994173.
# [I 2024-03-06 12:46:56,108] Trial 17 finished with value: -14.285909313065428 and parameters: {'learning_rate': 0.7212386720739208, 'n_estimators': 1204, 'max_depth': 21, 'num_leaves': 49, 'min_child_samples': 8, 'subsample': 0.24122576582979205, 'colsample_bytree': 0.14885326887584827}. Best is trial 12 with value: -10.374137880994173.
# [I 2024-03-06 12:46:59,226] Trial 18 finished with value: -12.075474283286768 and parameters: {'learning_rate': 0.05477402117142249, 'n_estimators': 451, 'max_depth': 10, 'num_leaves': 18, 'min_child_samples': 14, 'subsample': 0.45147124530378213, 'colsample_bytree': 0.11382122534703737}. Best is trial 12 with value: -10.374137880994173.
# [I 2024-03-06 12:47:03,084] Trial 19 finished with value: -11.832558664478908 and parameters: {'learning_rate': 0.35819960876350926, 'n_estimators': 1836, 'max_depth': 1, 'num_leaves': 32, 'min_child_samples': 7, 'subsample': 0.5450797062062158, 'colsample_bytree': 0.7175278495599373}. Best is trial 12 with value: -10.374137880994173.
# [I 2024-03-06 12:47:14,488] Trial 20 finished with value: -14.984192571872756 and parameters: {'learning_rate': 0.7045708798346519, 'n_estimators': 978, 'max_depth': 30, 'num_leaves': 42, 'min_child_samples': 14, 'subsample': 0.26021611287504054, 'colsample_bytree': 0.47434481161958897}. Best is trial 12 with value: -10.374137880994173.
# [I 2024-03-06 12:47:17,389] Trial 21 finished with value: -11.026692362756348 and parameters: {'learning_rate': 0.3194438389462051, 'n_estimators': 552, 'max_depth': 4, 'num_leaves': 44, 'min_child_samples': 14, 'subsample': 0.20902097826383548, 'colsample_bytree': 0.3027103102922919}. Best is trial 12 with value: -10.374137880994173.
# [I 2024-03-06 12:47:20,841] Trial 22 finished with value: -11.506810530608918 and parameters: {'learning_rate': 0.2017297751454114, 'n_estimators': 309, 'max_depth': 8, 'num_leaves': 45, 'min_child_samples': 16, 'subsample': 0.18054895802325216, 'colsample_bytree': 0.3061372913726046}. Best is trial 12 with value: -10.374137880994173.
# [I 2024-03-06 12:47:27,687] Trial 23 finished with value: -11.62039262192072 and parameters: {'learning_rate': 0.39473665568538374, 'n_estimators': 788, 'max_depth': 13, 'num_leaves': 32, 'min_child_samples': 12, 'subsample': 0.3414892498665587, 'colsample_bytree': 0.27531715763915554}. Best is trial 12 with value: -10.374137880994173.
# [I 2024-03-06 12:47:29,022] Trial 24 finished with value: -11.429770269051533 and parameters: {'learning_rate': 0.27183965279486577, 'n_estimators': 146, 'max_depth': 5, 'num_leaves': 40, 'min_child_samples': 16, 'subsample': 0.10284981522778765, 'colsample_bytree': 0.3759992836002674}. Best is trial 12 with value: -10.374137880994173.
# [I 2024-03-06 12:47:34,518] Trial 25 finished with value: -11.212551647390281 and parameters: {'learning_rate': 0.13125215148682318, 'n_estimators': 436, 'max_depth': 21, 'num_leaves': 47, 'min_child_samples': 10, 'subsample': 0.6245704732798223, 'colsample_bytree': 0.5137364475199928}. Best is trial 12 with value: -10.374137880994173.
# [I 2024-03-06 12:47:49,160] Trial 26 finished with value: -11.938038547223567 and parameters: {'learning_rate': 0.40280579851516707, 'n_estimators': 1720, 'max_depth': 11, 'num_leaves': 34, 'min_child_samples': 20, 'subsample': 0.2009132831441548, 'colsample_bytree': 0.4362418257725746}. Best is trial 12 with value: -10.374137880994173.
# [I 2024-03-06 12:47:53,640] Trial 27 finished with value: -10.764968837495546 and parameters: {'learning_rate': 0.28465371839396053, 'n_estimators': 959, 'max_depth': 4, 'num_leaves': 40, 'min_child_samples': 13, 'subsample': 0.4664940989846848, 'colsample_bytree': 0.2564883912325336}. Best is trial 12 with value: -10.374137880994173.
# [I 2024-03-06 12:47:59,652] Trial 28 finished with value: -12.80376761439742 and parameters: {'learning_rate': 0.1226747414494011, 'n_estimators': 898, 'max_depth': 33, 'num_leaves': 36, 'min_child_samples': 18, 'subsample': 0.4564617674231977, 'colsample_bytree': 0.10133122754092205}. Best is trial 12 with value: -10.374137880994173.
# [I 2024-03-06 12:48:04,047] Trial 29 finished with value: -9.813017166878337 and parameters: {'learning_rate': 0.5708136297695899, 'n_estimators': 714, 'max_depth': 19, 'num_leaves': 30, 'min_child_samples': 6, 'subsample': 0.5848463496613948, 'colsample_bytree': 0.24537393924145093}. Best is trial 29 with value: -9.813017166878337.
# [I 2024-03-06 12:48:08,356] Trial 30 finished with value: -14.66952683314274 and parameters: {'learning_rate': 0.8596547219679758, 'n_estimators': 701, 'max_depth': 19, 'num_leaves': 21, 'min_child_samples': 6, 'subsample': 0.6003564856729213, 'colsample_bytree': 0.18179311389114228}. Best is trial 29 with value: -9.813017166878337.
# [I 2024-03-06 12:48:16,189] Trial 31 finished with value: -10.886096327378457 and parameters: {'learning_rate': 0.5715784304027223, 'n_estimators': 1019, 'max_depth': 15, 'num_leaves': 29, 'min_child_samples': 9, 'subsample': 0.8119364302764617, 'colsample_bytree': 0.2598046446377426}. Best is trial 29 with value: -9.813017166878337.
# [I 2024-03-06 12:48:27,754] Trial 32 finished with value: -14.672139586943448 and parameters: {'learning_rate': 0.6186261320812674, 'n_estimators': 1646, 'max_depth': 5, 'num_leaves': 30, 'min_child_samples': 6, 'subsample': 0.5962620757130489, 'colsample_bytree': 0.3401944635937263}. Best is trial 29 with value: -9.813017166878337.
# [I 2024-03-06 12:48:34,599] Trial 33 finished with value: -10.309929778530142 and parameters: {'learning_rate': 0.22668205580011486, 'n_estimators': 732, 'max_depth': 23, 'num_leaves': 39, 'min_child_samples': 12, 'subsample': 0.39818151568194843, 'colsample_bytree': 0.2500445805325464}. Best is trial 29 with value: -9.813017166878337.
# [I 2024-03-06 12:48:40,966] Trial 34 finished with value: -10.556952291279327 and parameters: {'learning_rate': 0.21041452960640067, 'n_estimators': 691, 'max_depth': 22, 'num_leaves': 35, 'min_child_samples': 5, 'subsample': 0.368707961699793, 'colsample_bytree': 0.16091604747303728}. Best is trial 29 with value: -9.813017166878337.
# [I 2024-03-06 12:48:45,515] Trial 35 finished with value: -10.4261383181051 and parameters: {'learning_rate': 0.20169954339474058, 'n_estimators': 532, 'max_depth': 33, 'num_leaves': 30, 'min_child_samples': 5, 'subsample': 0.38263386463366794, 'colsample_bytree': 0.16267049767870784}. Best is trial 29 with value: -9.813017166878337.
# [I 2024-03-06 12:48:48,261] Trial 36 finished with value: -11.39258498241076 and parameters: {'learning_rate': 0.1838571467441451, 'n_estimators': 310, 'max_depth': 35, 'num_leaves': 21, 'min_child_samples': 5, 'subsample': 0.4143316937931997, 'colsample_bytree': 0.9280479834670008}. Best is trial 29 with value: -9.813017166878337.
# [I 2024-03-06 12:48:50,570] Trial 37 finished with value: -11.696281861849462 and parameters: {'learning_rate': 0.4239657750899918, 'n_estimators': 235, 'max_depth': 39, 'num_leaves': 24, 'min_child_samples': 1, 'subsample': 0.2915168864929883, 'colsample_bytree': 0.8083624861196609}. Best is trial 29 with value: -9.813017166878337.
# [I 2024-03-06 12:48:56,058] Trial 38 finished with value: -11.141451790007277 and parameters: {'learning_rate': 0.06158194854538834, 'n_estimators': 502, 'max_depth': 29, 'num_leaves': 40, 'min_child_samples': 4, 'subsample': 0.4965695997195398, 'colsample_bytree': 0.22396323734334123}. Best is trial 29 with value: -9.813017166878337.
# [I 2024-03-06 12:48:59,607] Trial 39 finished with value: -12.152022579666573 and parameters: {'learning_rate': 0.5436359603506401, 'n_estimators': 367, 'max_depth': 35, 'num_leaves': 30, 'min_child_samples': 8, 'subsample': 0.7580621217650276, 'colsample_bytree': 0.33141675075115}. Best is trial 29 with value: -9.813017166878337.
# [I 2024-03-06 12:49:00,874] Trial 40 finished with value: -11.938549404003732 and parameters: {'learning_rate': 0.2488745763561581, 'n_estimators': 248, 'max_depth': 25, 'num_leaves': 3, 'min_child_samples': 3, 'subsample': 0.36906070905954264, 'colsample_bytree': 0.1440147298089532}. Best is trial 29 with value: -9.813017166878337.
# [I 2024-03-06 12:49:05,579] Trial 41 finished with value: -10.249862316321977 and parameters: {'learning_rate': 0.17259951097936235, 'n_estimators': 618, 'max_depth': 22, 'num_leaves': 28, 'min_child_samples': 5, 'subsample': 0.3950606575312716, 'colsample_bytree': 0.17622566274299067}. Best is trial 29 with value: -9.813017166878337.
# [I 2024-03-06 12:49:09,907] Trial 42 finished with value: -11.190308114758192 and parameters: {'learning_rate': 0.17361618421293845, 'n_estimators': 585, 'max_depth': 45, 'num_leaves': 24, 'min_child_samples': 6, 'subsample': 0.39946881684213426, 'colsample_bytree': 0.21106252350114457}. Best is trial 29 with value: -9.813017166878337.
# [I 2024-03-06 12:49:13,538] Trial 43 finished with value: -10.94066949859269 and parameters: {'learning_rate': 0.08907928516457228, 'n_estimators': 428, 'max_depth': 27, 'num_leaves': 27, 'min_child_samples': 4, 'subsample': 0.3106934673679569, 'colsample_bytree': 0.1863212800442884}. Best is trial 29 with value: -9.813017166878337.
# [I 2024-03-06 12:49:19,736] Trial 44 finished with value: -10.664102402044126 and parameters: {'learning_rate': 0.2384683326217473, 'n_estimators': 795, 'max_depth': 23, 'num_leaves': 24, 'min_child_samples': 7, 'subsample': 0.5692429388265663, 'colsample_bytree': 0.3975612658687734}. Best is trial 29 with value: -9.813017166878337.
# [I 2024-03-06 12:49:28,828] Trial 45 finished with value: -11.202606405914402 and parameters: {'learning_rate': 0.01528375799925899, 'n_estimators': 1507, 'max_depth': 18, 'num_leaves': 16, 'min_child_samples': 9, 'subsample': 0.48105974223113124, 'colsample_bytree': 0.24261373984818618}. Best is trial 29 with value: -9.813017166878337.
# [I 2024-03-06 12:49:38,189] Trial 46 finished with value: -11.382790280168772 and parameters: {'learning_rate': 0.17264684914338807, 'n_estimators': 1154, 'max_depth': 32, 'num_leaves': 31, 'min_child_samples': 2, 'subsample': 0.4300866021306842, 'colsample_bytree': 0.1290126930408131}. Best is trial 29 with value: -9.813017166878337.
# [I 2024-03-06 12:49:41,331] Trial 47 finished with value: -11.52000171143391 and parameters: {'learning_rate': 0.10403619894417483, 'n_estimators': 634, 'max_depth': 24, 'num_leaves': 11, 'min_child_samples': 12, 'subsample': 0.5235145263535068, 'colsample_bytree': 0.2974103238802048}. Best is trial 29 with value: -9.813017166878337.
# [I 2024-03-06 12:49:44,755] Trial 48 finished with value: -12.763282933235748 and parameters: {'learning_rate': 0.4324730915546574, 'n_estimators': 369, 'max_depth': 40, 'num_leaves': 28, 'min_child_samples': 11, 'subsample': 0.6549612462678289, 'colsample_bytree': 0.20240735876309346}. Best is trial 29 with value: -9.813017166878337.
# [I 2024-03-06 12:49:53,653] Trial 49 finished with value: -10.827385920618472 and parameters: {'learning_rate': 0.2908996398983437, 'n_estimators': 858, 'max_depth': 19, 'num_leaves': 34, 'min_child_samples': 3, 'subsample': 0.2815146890618368, 'colsample_bytree': 0.3677617253342413}. Best is trial 29 with value: -9.813017166878337.
# [I 2024-03-06 12:49:57,172] A new study created in memory with name: no-name-c4312bb8-47f4-4c61-90ee-a6c19458c8e8
# LGBM -9.813017166878337 10.610752934525996 342.9104220412855 202.0727365224596
# [I 2024-03-06 12:50:25,019] Trial 0 finished with value: -12.079886897800455 and parameters: {'max_features': 'sqrt', 'n_estimators': 165, 'max_depth': 144, 'min_samples_leaf': 8}. Best is trial 0 with value: -12.079886897800455.
# [I 2024-03-06 12:51:39,397] Trial 1 finished with value: -11.83206945962868 and parameters: {'max_features': 'log2', 'n_estimators': 424, 'max_depth': 48, 'min_samples_leaf': 3}. Best is trial 1 with value: -11.83206945962868.
# [I 2024-03-06 12:56:20,816] Trial 2 finished with value: -11.771961949477161 and parameters: {'max_features': 'log2', 'n_estimators': 1447, 'max_depth': 156, 'min_samples_leaf': 2}. Best is trial 2 with value: -11.771961949477161.
# [I 2024-03-06 12:56:26,956] Trial 3 finished with value: -15.509359185829355 and parameters: {'max_features': 'log2', 'n_estimators': 212, 'max_depth': 2, 'min_samples_leaf': 16}. Best is trial 2 with value: -11.771961949477161.
# [I 2024-03-06 12:56:56,745] Trial 4 finished with value: -12.013585549477433 and parameters: {'max_features': 'sqrt', 'n_estimators': 144, 'max_depth': 64, 'min_samples_leaf': 3}. Best is trial 2 with value: -11.771961949477161.
# [I 2024-03-06 13:03:23,189] Trial 5 finished with value: -11.957825659734855 and parameters: {'max_features': 'sqrt', 'n_estimators': 2086, 'max_depth': 168, 'min_samples_leaf': 6}. Best is trial 2 with value: -11.771961949477161.
# [I 2024-03-06 13:07:46,501] Trial 6 finished with value: -12.114606920266603 and parameters: {'max_features': 'log2', 'n_estimators': 1839, 'max_depth': 188, 'min_samples_leaf': 9}. Best is trial 2 with value: -11.771961949477161.
# [I 2024-03-06 13:07:58,304] Trial 7 finished with value: -12.027095945416562 and parameters: {'max_features': 'sqrt', 'n_estimators': 77, 'max_depth': 56, 'min_samples_leaf': 14}. Best is trial 2 with value: -11.771961949477161.
# [I 2024-03-06 13:09:15,980] Trial 8 finished with value: -11.957820976090147 and parameters: {'max_features': 'log2', 'n_estimators': 468, 'max_depth': 157, 'min_samples_leaf': 4}. Best is trial 2 with value: -11.771961949477161.
# [I 2024-03-06 13:09:36,637] Trial 9 finished with value: -12.134704229679457 and parameters: {'max_features': 'log2', 'n_estimators': 160, 'max_depth': 170, 'min_samples_leaf': 15}. Best is trial 2 with value: -11.771961949477161.
# [I 2024-03-06 13:11:07,660] Trial 10 finished with value: -12.526280632630336 and parameters: {'max_features': 'log2', 'n_estimators': 749, 'max_depth': 108, 'min_samples_leaf': 20}. Best is trial 2 with value: -11.771961949477161.
# [I 2024-03-06 13:14:41,319] Trial 11 finished with value: -11.70040402617239 and parameters: {'max_features': 'log2', 'n_estimators': 931, 'max_depth': 110, 'min_samples_leaf': 1}. Best is trial 11 with value: -11.70040402617239.
# [I 2024-03-06 13:18:40,578] Trial 12 finished with value: -11.685473930781528 and parameters: {'max_features': 'log2', 'n_estimators': 1046, 'max_depth': 118, 'min_samples_leaf': 1}. Best is trial 12 with value: -11.685473930781528.
# [I 2024-03-06 13:20:56,836] Trial 13 finished with value: -12.172389705964118 and parameters: {'max_features': 'log2', 'n_estimators': 909, 'max_depth': 113, 'min_samples_leaf': 7}. Best is trial 12 with value: -11.685473930781528.
# [I 2024-03-06 13:24:11,414] Trial 14 finished with value: -11.697446694793785 and parameters: {'max_features': 'log2', 'n_estimators': 910, 'max_depth': 87, 'min_samples_leaf': 1}. Best is trial 12 with value: -11.685473930781528.
# [I 2024-03-06 13:29:47,395] Trial 15 finished with value: -12.336189396004137 and parameters: {'max_features': 'log2', 'n_estimators': 2596, 'max_depth': 78, 'min_samples_leaf': 12}. Best is trial 12 with value: -11.685473930781528.
# [I 2024-03-06 13:31:24,126] Trial 16 finished with value: -11.986506838883278 and parameters: {'max_features': 'log2', 'n_estimators': 657, 'max_depth': 128, 'min_samples_leaf': 5}. Best is trial 12 with value: -11.685473930781528.
# [I 2024-03-06 13:35:39,718] Trial 17 finished with value: -11.701667153355752 and parameters: {'max_features': 'log2', 'n_estimators': 1247, 'max_depth': 24, 'min_samples_leaf': 1}. Best is trial 12 with value: -11.685473930781528.
# [I 2024-03-06 13:36:21,972] Trial 18 finished with value: -12.024183852236611 and parameters: {'max_features': 'sqrt', 'n_estimators': 281, 'max_depth': 84, 'min_samples_leaf': 11}. Best is trial 12 with value: -11.685473930781528.
# [I 2024-03-06 13:37:50,069] Trial 19 finished with value: -11.980245046691541 and parameters: {'max_features': 'log2', 'n_estimators': 578, 'max_depth': 86, 'min_samples_leaf': 5}. Best is trial 12 with value: -11.685473930781528.
# [I 2024-03-06 13:40:43,290] Trial 20 finished with value: -12.10455636675215 and parameters: {'max_features': 'log2', 'n_estimators': 1318, 'max_depth': 129, 'min_samples_leaf': 9}. Best is trial 12 with value: -11.685473930781528.
# [I 2024-03-06 13:44:01,214] Trial 21 finished with value: -11.703437395822366 and parameters: {'max_features': 'log2', 'n_estimators': 896, 'max_depth': 98, 'min_samples_leaf': 1}. Best is trial 12 with value: -11.685473930781528.
# [I 2024-03-06 13:48:03,611] Trial 22 finished with value: -11.691635446541328 and parameters: {'max_features': 'log2', 'n_estimators': 1057, 'max_depth': 121, 'min_samples_leaf': 1}. Best is trial 12 with value: -11.685473930781528.
# [I 2024-03-06 13:48:57,600] Trial 23 finished with value: -11.819932411146855 and parameters: {'max_features': 'log2', 'n_estimators': 307, 'max_depth': 127, 'min_samples_leaf': 3}. Best is trial 12 with value: -11.685473930781528.
# [I 2024-03-06 13:52:13,166] Trial 24 finished with value: -11.947908283371284 and parameters: {'max_features': 'log2', 'n_estimators': 1157, 'max_depth': 98, 'min_samples_leaf': 4}. Best is trial 12 with value: -11.685473930781528.
# [I 2024-03-06 13:58:17,124] Trial 25 finished with value: -11.73905655111283 and parameters: {'max_features': 'log2', 'n_estimators': 1875, 'max_depth': 70, 'min_samples_leaf': 2}. Best is trial 12 with value: -11.685473930781528.
# [I 2024-03-06 14:06:53,791] Trial 26 finished with value: -11.942892458988963 and parameters: {'max_features': 'sqrt', 'n_estimators': 2795, 'max_depth': 137, 'min_samples_leaf': 5}. Best is trial 12 with value: -11.685473930781528.
# [I 2024-03-06 14:08:57,667] Trial 27 finished with value: -11.735803379790159 and parameters: {'max_features': 'log2', 'n_estimators': 561, 'max_depth': 40, 'min_samples_leaf': 1}. Best is trial 12 with value: -11.685473930781528.
# [I 2024-03-06 14:11:54,141] Trial 28 finished with value: -12.432292598447754 and parameters: {'max_features': 'log2', 'n_estimators': 1499, 'max_depth': 117, 'min_samples_leaf': 20}. Best is trial 12 with value: -11.685473930781528.
# [I 2024-03-06 14:12:03,621] Trial 29 finished with value: -11.943148558343626 and parameters: {'max_features': 'sqrt', 'n_estimators': 55, 'max_depth': 144, 'min_samples_leaf': 7}. Best is trial 12 with value: -11.685473930781528.
# [I 2024-03-06 14:12:46,310] Trial 30 finished with value: -12.293570600834805 and parameters: {'max_features': 'log2', 'n_estimators': 353, 'max_depth': 91, 'min_samples_leaf': 18}. Best is trial 12 with value: -11.685473930781528.
# [I 2024-03-06 14:16:18,713] Trial 31 finished with value: -11.692209252132358 and parameters: {'max_features': 'log2', 'n_estimators': 971, 'max_depth': 111, 'min_samples_leaf': 1}. Best is trial 12 with value: -11.685473930781528.
# [I 2024-03-06 14:19:14,414] Trial 32 finished with value: -11.892309241729377 and parameters: {'max_features': 'log2', 'n_estimators': 1027, 'max_depth': 122, 'min_samples_leaf': 3}. Best is trial 12 with value: -11.685473930781528.
# [I 2024-03-06 14:21:35,310] Trial 33 finished with value: -11.780134725612115 and parameters: {'max_features': 'log2', 'n_estimators': 757, 'max_depth': 105, 'min_samples_leaf': 2}. Best is trial 12 with value: -11.685473930781528.
# [I 2024-03-06 14:26:02,176] Trial 34 finished with value: -11.882183014486007 and parameters: {'max_features': 'log2', 'n_estimators': 1556, 'max_depth': 140, 'min_samples_leaf': 3}. Best is trial 12 with value: -11.685473930781528.
# [I 2024-03-06 14:27:31,754] Trial 35 finished with value: -11.764497918036001 and parameters: {'max_features': 'log2', 'n_estimators': 486, 'max_depth': 74, 'min_samples_leaf': 2}. Best is trial 12 with value: -11.685473930781528.
# [I 2024-03-06 14:29:32,175] Trial 36 finished with value: -11.991082837926871 and parameters: {'max_features': 'log2', 'n_estimators': 751, 'max_depth': 153, 'min_samples_leaf': 4}. Best is trial 12 with value: -11.685473930781528.
# [I 2024-03-06 14:37:51,287] Trial 37 finished with value: -11.651151535249324 and parameters: {'max_features': 'sqrt', 'n_estimators': 2000, 'max_depth': 96, 'min_samples_leaf': 1}. Best is trial 37 with value: -11.651151535249324.
# [I 2024-03-06 14:48:52,203] Trial 38 finished with value: -11.962591133985752 and parameters: {'max_features': 'sqrt', 'n_estimators': 2247, 'max_depth': 96, 'min_samples_leaf': 6}. Best is trial 37 with value: -11.651151535249324.
# [I 2024-03-06 14:54:54,947] Trial 39 finished with value: -11.751217706314941 and parameters: {'max_features': 'sqrt', 'n_estimators': 1684, 'max_depth': 51, 'min_samples_leaf': 2}. Best is trial 37 with value: -11.651151535249324.
# [I 2024-03-06 15:02:10,992] Trial 40 finished with value: -11.850242210199237 and parameters: {'max_features': 'sqrt', 'n_estimators': 2343, 'max_depth': 168, 'min_samples_leaf': 4}. Best is trial 37 with value: -11.651151535249324.
# [I 2024-03-06 15:06:22,596] Trial 41 finished with value: -11.679596796784155 and parameters: {'max_features': 'sqrt', 'n_estimators': 1097, 'max_depth': 84, 'min_samples_leaf': 1}. Best is trial 37 with value: -11.651151535249324.
# [I 2024-03-06 15:11:03,045] Trial 42 finished with value: -11.684573156823525 and parameters: {'max_features': 'sqrt', 'n_estimators': 1232, 'max_depth': 61, 'min_samples_leaf': 1}. Best is trial 37 with value: -11.651151535249324.
# [I 2024-03-06 15:16:57,870] Trial 43 finished with value: -11.8280352737502 and parameters: {'max_features': 'sqrt', 'n_estimators': 1950, 'max_depth': 28, 'min_samples_leaf': 3}. Best is trial 37 with value: -11.651151535249324.
# [I 2024-03-06 15:21:02,076] Trial 44 finished with value: -11.798860972280353 and parameters: {'max_features': 'sqrt', 'n_estimators': 1233, 'max_depth': 61, 'min_samples_leaf': 2}. Best is trial 37 with value: -11.651151535249324.
# [I 2024-03-06 15:26:29,760] Trial 45 finished with value: -11.687204363382401 and parameters: {'max_features': 'sqrt', 'n_estimators': 1440, 'max_depth': 42, 'min_samples_leaf': 1}. Best is trial 37 with value: -11.651151535249324.
# [I 2024-03-06 15:26:50,102] Trial 46 finished with value: -11.83554173775347 and parameters: {'max_features': 'sqrt', 'n_estimators': 103, 'max_depth': 41, 'min_samples_leaf': 2}. Best is trial 37 with value: -11.651151535249324.
# [I 2024-03-06 15:28:41,096] Trial 47 finished with value: -13.077177409910721 and parameters: {'max_features': 'sqrt', 'n_estimators': 1438, 'max_depth': 7, 'min_samples_leaf': 4}. Best is trial 37 with value: -11.651151535249324.
# [I 2024-03-06 15:35:08,628] Trial 48 finished with value: -12.20962280665624 and parameters: {'max_features': 'sqrt', 'n_estimators': 2809, 'max_depth': 59, 'min_samples_leaf': 13}. Best is trial 37 with value: -11.651151535249324.
# [I 2024-03-06 15:39:42,790] Trial 49 finished with value: -11.963644257197307 and parameters: {'max_features': 'sqrt', 'n_estimators': 1721, 'max_depth': 40, 'min_samples_leaf': 6}. Best is trial 37 with value: -11.651151535249324.
# [I 2024-03-06 15:45:24,552] A new study created in memory with name: no-name-16f67d1c-add7-471e-9721-8a2388f57616
# RF -11.651151535249324 9.915961623636665 345.507688949671 209.9105
# [I 2024-03-06 15:47:12,026] Trial 0 finished with value: -24.339151652811022 and parameters: {'hidden_layer_sizes': (30, 30, 30), 'activation': 'relu', 'solver': 'adam', 'alpha': 5.1873746758734936e-05}. Best is trial 0 with value: -24.339151652811022.
# [W 2024-03-06 15:51:25,095] Trial 1 failed with parameters: {'hidden_layer_sizes': (100, 100), 'activation': 'relu', 'solver': 'sgd', 'alpha': 6.549279862090275} because of the following error: The value nan is not acceptable.
# [W 2024-03-06 15:51:25,096] Trial 1 failed with value nan.
# [W 2024-03-06 15:55:49,635] Trial 2 failed with parameters: {'hidden_layer_sizes': (100, 100), 'activation': 'relu', 'solver': 'sgd', 'alpha': 50.5445369700774} because of the following error: The value nan is not acceptable.
# [W 2024-03-06 15:55:49,637] Trial 2 failed with value nan.
# [I 2024-03-06 15:57:22,766] Trial 3 finished with value: -16.465562357260083 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'solver': 'adam', 'alpha': 103.57899857319786}. Best is trial 3 with value: -16.465562357260083.
# [I 2024-03-06 16:02:20,017] Trial 4 finished with value: -23.269499475614257 and parameters: {'hidden_layer_sizes': (100, 100), 'activation': 'logistic', 'solver': 'adam', 'alpha': 0.0001544301228211304}. Best is trial 3 with value: -16.465562357260083.
# [I 2024-03-06 16:04:25,433] Trial 5 finished with value: -14.669147750065159 and parameters: {'hidden_layer_sizes': (50, 50), 'activation': 'logistic', 'solver': 'adam', 'alpha': 289.4704092061168}. Best is trial 5 with value: -14.669147750065159.
# [W 2024-03-06 16:06:26,611] Trial 6 failed with parameters: {'hidden_layer_sizes': (30, 30, 30), 'activation': 'relu', 'solver': 'sgd', 'alpha': 0
. Best is trial 27 with value: -11.562705721389749.
# [I 2024-03-06 16:48:56,632] Trial 34 finished with value: -15.669992131539033 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'solver': 'adam', 'alpha': 114.22832799075934}. Best is trial 27 with value: -11.562705721389749.
# [I 2024-03-06 16:50:52,855] Trial 35 finished with value: -12.773632253940384 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'solver': 'adam', 'alpha': 556.5551822445497}. Best is trial 27 with value: -11.562705721389749.
# [I 2024-03-06 16:53:27,720] Trial 36 finished with value: -19.88276095625377 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'solver': 'adam', 'alpha': 8542.628941198647}. Best is trial 27 with value: -11.562705721389749.
# [I 2024-03-06 16:56:03,928] Trial 37 finished with value: -12.809911636117308 and parameters: {'hidden_layer_sizes': (100, 100), 'activation': 'logistic', 'solver': 'adam', 'alpha': 421.6259879357317}. Best is trial 27 with value: -11.562705721389749.
# [I 2024-03-06 16:58:40,079] Trial 38 finished with value: -12.821605028129818 and parameters: {'hidden_layer_sizes': (100, 100), 'activation': 'logistic', 'solver': 'adam', 'alpha': 447.82686326717163}. Best is trial 27 with value: -11.562705721389749.
# [I 2024-03-06 17:02:27,872] Trial 39 finished with value: -22.61803295815804 and parameters: {'hidden_layer_sizes': (100, 100), 'activation': 'logistic', 'solver': 'adam', 'alpha': 2.6548112042700978}. Best is trial 27 with value: -11.562705721389749.
# [I 2024-03-06 17:03:35,128] Trial 40 finished with value: -22.95322971358563 and parameters: {'hidden_layer_sizes': (100, 100), 'activation': 'logistic', 'solver': 'sgd', 'alpha': 591.6212588028487}. Best is trial 27 with value: -11.562705721389749.
# [I 2024-03-06 17:06:11,890] Trial 41 finished with value: -12.465330329653906 and parameters: {'hidden_layer_sizes': (100, 100), 'activation': 'logistic', 'solver': 'adam', 'alpha': 300.4736629289062}. Best is trial 27 with value: -11.562705721389749.
# [I 2024-03-06 17:08:48,659] Trial 42 finished with value: -20.026784015154433 and parameters: {'hidden_layer_sizes': (100, 100), 'activation': 'logistic', 'solver': 'adam', 'alpha': 50.372193671194644}. Best is trial 27 with value: -11.562705721389749.
# [I 2024-03-06 17:12:19,639] Trial 43 finished with value: -22.15888249455027 and parameters: {'hidden_layer_sizes': (100, 100), 'activation': 'tanh', 'solver': 'adam', 'alpha': 3.59255867698202}. Best is trial 27 with value: -11.562705721389749.
# [I 2024-03-06 17:15:04,877] Trial 44 finished with value: -13.60930222069072 and parameters: {'hidden_layer_sizes': (100, 100), 'activation': 'logistic', 'solver': 'adam', 'alpha': 266.5879979820588}. Best is trial 27 with value: -11.562705721389749.
# [I 2024-03-06 17:17:48,172] Trial 45 finished with value: -13.523959649888875 and parameters: {'hidden_layer_sizes': (100, 100), 'activation': 'logistic', 'solver': 'adam', 'alpha': 281.14443832920927}. Best is trial 27 with value: -11.562705721389749.
# [I 2024-03-06 17:22:42,577] Trial 46 finished with value: -22.466603556317985 and parameters: {'hidden_layer_sizes': (100, 100), 'activation': 'logistic', 'solver': 'adam', 'alpha': 8208.12911355462}. Best is trial 27 with value: -11.562705721389749.
# [I 2024-03-06 17:23:48,210] Trial 47 finished with value: -22.882147616442573 and parameters: {'hidden_layer_sizes': (100, 100), 'activation': 'logistic', 'solver': 'sgd', 'alpha': 361.0659069080805}. Best is trial 27 with value: -11.562705721389749.
# [I 2024-03-06 17:25:03,173] Trial 48 finished with value: -16.526542753288403 and parameters: {'hidden_layer_sizes': (30, 30, 30), 'activation': 'relu', 'solver': 'adam', 'alpha': 44.19752417615089}. Best is trial 27 with value: -11.562705721389749.
# [I 2024-03-06 17:27:28,942] Trial 49 finished with value: -22.2187744672292 and parameters: {'hidden_layer_sizes': (50, 50), 'activation': 'logistic', 'solver': 'adam', 'alpha': 18158.91113614015}. Best is trial 27 with value: -11.562705721389749.
# ANN -11.562705721389749 12.091260494115376 440.04431464163446 220.50840443176978

# %%
with open('best_model_onlyreg.pickle', 'wb') as f:
    pickle.dump(best_model_onlyreg, f, pickle.HIGHEST_PROTOCOL)

# %%
# X_t = X_t_old[selected_features] 
# X_t['cluster'] = train_data_tr['remainder__clusters']
# X_t['remainder__link_counts'] = train_data_tr['remainder__link_counts']
# X_v = validate_data_tr[selected_features]
# X_v['cluster'] = validate_data_tr['remainder__clusters']
# X_v['remainder__link_counts'] = validate_data_tr['remainder__link_counts']
# X_te = test_data_tr[selected_features]
# X_te['cluster'] = test_data_tr['remainder__clusters']
# X_te['remainder__link_counts'] = test_data_tr['remainder__link_counts']

# %%
selected_features

# %%
model = xgb.XGBRegressor(random_state=101)
opt = BayesSearchCV(
    model,
    param_space['XGB'],
    n_iter=50,  # Adjust the number of iterations based on your computational resources
    cv=ShuffleSplit(test_size=0.20, n_splits=3),  # Adjust the number of cross-validation folds
    scoring='neg_mean_absolute_error',  # Use a suitable regression metric
    n_jobs=-1,
)

opt.fit(X_t, y_t)
best_params = opt.best_params_ 

model = xgb.XGBRegressor(**best_params, random_state=101)
model.fit(X_t, y_t)
te_predictions = model.predict(X_te)
te_mae = mean_absolute_error(y_te, te_predictions)
print(te_mae)

onehot = OneHotEncoder()
X_t_leaves = onehot.fit_transform(model.apply(X_t))
rf_lr = LogisticRegressionCV(cv=ShuffleSplit(test_size=0.20, n_splits=3))
rf_lr.fit(X_t_leaves, y_t)
X_te_leaves = onehot.transform(model.apply(X_te))
y_te_pred_rf_lr = rf_lr.predict(X_te_leaves)
te_rflr_mae = mean_absolute_error(y_te, y_te_pred_rf_lr)
print(te_rflr_mae)

# %%
v_mae_list = []
te_mae_list = []
v_rf_mae_list = []
te_rf_mae_list = []
# X_te['cluster'] = 1
for cluster_label in list(set(X_t['cluster'])):
    X_v_cluster, X_te_cluster = None, None
    v_mae, te_mae, v_rflr_mae, te_rflr_mae = None, None, None, None
    # Subset the training data for the current cluster
    X_t_cluster = X_t[X_t['cluster'] == cluster_label]
    y_t_cluster = X_t_cluster['remainder__link_counts']
    X_t_cluster = X_t_cluster.drop(columns=['remainder__link_counts','cluster'])  
    
    if cluster_label in list(set(X_v['cluster'])):
        X_v_cluster = X_v[X_v['cluster'] == cluster_label]
        y_v_cluster = X_v_cluster['remainder__link_counts']
        X_v_cluster = X_v_cluster.drop(columns=['remainder__link_counts','cluster'])  
    if cluster_label in list(set(X_te['cluster'])):
        X_te_cluster = X_te[X_te['cluster'] == cluster_label]
        y_te_cluster = X_te_cluster['remainder__link_counts']
        X_te_cluster = X_te_cluster.drop(columns=['remainder__link_counts','cluster'])  
    

    # Train a regression model for the current cluster
    # model = RidgeCV(scoring='neg_mean_absolute_error')
    # model = RandomForestRegressor(criterion='friedman_mse', n_estimators=300,
    #                   random_state=101)

    if not ((X_v_cluster is None) and (X_te_cluster is None)):

        model = xgb.XGBRegressor(random_state=101)
        opt = BayesSearchCV(
            model,
            param_space['XGB'],
            n_iter=60,  # Adjust the number of iterations based on your computational resources
            cv=ShuffleSplit(test_size=0.20, n_splits=1),  # Adjust the number of cross-validation folds
            scoring='neg_mean_absolute_error',  # Use a suitable regression metric
            n_jobs=-1,
        )
        
        opt.fit(X_t_cluster, y_t_cluster)
        best_params = opt.best_params_ 
        onehot = OneHotEncoder()
        model = xgb.XGBRegressor(**best_params, random_state=101)
        model.fit(X_t_cluster, y_t_cluster)

        X_t_leaves = onehot.fit_transform(model.apply(X_t_cluster))
        rf_lr = LogisticRegression()
        rf_lr.fit(X_t_leaves, y_t_cluster)
        if (X_v_cluster is not None):
            v_predictions = model.predict(X_v_cluster)
            v_mae = mean_absolute_error(y_v_cluster, v_predictions)
            row_count = len(y_v_cluster)
            v_mae_list.append(v_mae*row_count)

            X_v_leaves = onehot.transform(model.apply(X_v_cluster))
            y_v_pred_rf_lr = rf_lr.predict(X_v_leaves)
            row_count = len(y_v_pred_rf_lr)
            v_rflr_mae = mean_absolute_error(y_v_cluster, y_v_pred_rf_lr)
            v_rf_mae_list.append(v_rflr_mae*row_count)
        if (X_te_cluster is not None):
            te_predictions = model.predict(X_te_cluster)
            te_mae = mean_absolute_error(y_te_cluster, te_predictions)
            row_count = len(y_te_cluster)
            te_mae_list.append(te_mae*row_count)
      
            X_te_leaves = onehot.transform(model.apply(X_te_cluster))
            y_te_pred_rf_lr = rf_lr.predict(X_te_leaves)
            row_count = len(y_te_pred_rf_lr)
            te_rflr_mae = mean_absolute_error(y_te_cluster, y_te_pred_rf_lr)
            te_rf_mae_list.append(te_rflr_mae*row_count)
    print(cluster_label, v_mae, te_mae, v_rflr_mae, te_rflr_mae)
v_mae_list = list(filter(lambda item: item is not None, v_mae_list))    
te_mae_list = list(filter(lambda item: item is not None, te_mae_list))    
v_mean_mae = sum(v_mae_list)/len(X_v)
te_mean_mae = sum(te_mae_list)/len(X_te)
print(v_mean_mae)
print(te_mean_mae)

# %%
best_params = None
best_mae = 0.0

# Generate all combinations of hyperparameters
param_combinations = product(*param_grid.values())
# Loop through hyperparameter combinations
for params in param_combinations:
    # Create and train the model with the current hyperparameters
    model = lgb.LGBMRegressor(**dict(zip(param_grid.keys(), params)), random_state=101)
    model.fit(X_t[X_v.columns], y_t)

    # Evaluate the model on the validation dataset
    y_val_pred = model.predict(X_v)
    mae = mean_absolute_error(y_v, y_val_pred)

    # Check if current hyperparameters are the best
    if mae > best_mae:
        best_mae = mae
        best_params = dict(zip(param_grid.keys(), params))
print(best_mae)
print(best_params)
# Train the final model using the entire training dataset with the best hyperparameters
final_model = lgb.LGBMRegressor(**best_params, random_state=101)
final_model.fit(X_t, y_t)

# Evaluate the final model on the test dataset
y_test_pred = final_model.predict(X_te)
test_mae = mean_absolute_error(y_te, y_test_pred)
print(test_mae)

# %%
# Define the LGBMRegressor model
lgbm_model = lgb.LGBMRegressor(random_state=101, force_col_wise=True)

# Create a Bayesian optimization object
opt = BayesSearchCV(
    lgbm_model,
    param_space,
    n_iter=100,  # Adjust the number of iterations based on your computational resources
    cv=3,  # Adjust the number of cross-validation folds
    scoring='neg_mean_absolute_error',  # Use a suitable regression metric
    n_jobs=-1,
)

# Perform Bayesian optimization
opt.fit(X_t[X_v.columns], y_t, eval_set = [(X_v, y_v)])

# Get the best hyperparameters
best_params = opt.best_params_
print(opt.best_estimator_)

# Train the final model with the best hyperparameters
final_model = lgb.LGBMRegressor(**best_params, random_state=101, force_col_wise=True)
final_model.fit(X_t, y_t, eval_set = [(X_te, y_te)])

print("With LGB Pred")
y_t_pred = final_model.predict(X_t)
print(mean_absolute_error(y_t, y_t_pred))

y_te_pred = final_model.predict(X_te)
print(mean_absolute_error(y_te, y_te_pred))

# %%
print("---------------")

onehot = OneHotEncoder()
X_t_leaves = onehot.fit_transform(final_model.predict(X_t, pred_leaf=True))
xgb_lr = LogisticRegression()
xgb_lr.fit(X_t_leaves, y_t)

print("With LGB + LR Pred")
X_t_leaves = onehot.transform(final_model.predict(X_t, pred_leaf=True))
y_t_pred_xgb_lr = xgb_lr.predict(X_t_leaves)
print(mean_absolute_error(y_t, y_t_pred_xgb_lr))

X_te_leaves = onehot.transform(final_model.predict(X_te, pred_leaf=True))
y_te_pred_xgb_lr = xgb_lr.predict(X_te_leaves)
print(mean_absolute_error(y_te, y_te_pred_xgb_lr))

# %%
param_space = {
    'learning_rate': np.arange(0.01, 1.0, 0.01),
    'n_estimators': np.arange(50, 2001, 50),
    'max_depth': np.arange(1, 20),
    'max_leaves': np.arange(2, 50),
    'max_bin': np.arange(2, 50),
    'gamma': np.arange(1, 20),
    # 'min_child_weight': np.arange(0, 20),
    # 'subsample': np.arange(0.1, 1.0, 0.1),
    # 'colsample_bytree': np.arange(0.1, 1.0, 0.1),
    # 'reg_alpha': np.arange(0, 100),
    # 'reg_lambda': np.arange(0, 10, 0.01),
}

# Define the LGBMRegressor model
xgb_model = xgb.XGBRegressor(random_state=101)

# Create a Bayesian optimization object
opt = BayesSearchCV(
    xgb_model,
    param_space,
    n_iter=100,  # Adjust the number of iterations based on your computational resources
    cv=3,  # Adjust the number of cross-validation folds
    scoring='neg_mean_absolute_error',  # Use a suitable regression metric
    n_jobs=-1,
)

# Perform Bayesian optimization
opt.fit(X_t[X_v.columns], y_t, eval_set = [(X_v, y_v)])
# 
# Get the best hyperparameters
best_params = opt.best_params_
print(opt.best_estimator_)

# Train the final model using the entire training dataset with the best hyperparameters
final_model = xgb.XGBRegressor(**best_params, random_state=101)
final_model.fit(X_t, y_t, eval_set = [(X_te, y_te)])

# Evaluate the final model on the test dataset
y_test_pred = final_model.predict(X_te)
test_mae = mean_absolute_error(y_te, y_test_pred)
print(test_mae)

# %%
# Train the final model with the best hyperparameters
final_model = xgb.XGBRegressor(**best_params, random_state=101)
final_model.fit(X_t, y_t)

print("With XGB Pred")
y_t_pred = final_model.predict(X_t)
print(mean_absolute_error(y_t, y_t_pred))

y_te_pred = final_model.predict(X_te)
print(mean_absolute_error(y_te, y_te_pred))

print("---------------")

onehot = OneHotEncoder()
X_t_leaves = onehot.fit_transform(final_model.apply(X_t))
xgb_lr = LogisticRegression()
xgb_lr.fit(X_t_leaves, y_t)

print("With XGB + LR Pred")
X_t_leaves = onehot.transform(final_model.apply(X_t))
y_t_pred_xgb_lr = xgb_lr.predict(X_t_leaves)
print(mean_absolute_error(y_t, y_t_pred_xgb_lr))

X_te_leaves = onehot.transform(final_model.apply(X_te))
y_te_pred_xgb_lr = xgb_lr.predict(X_te_leaves)
print(mean_absolute_error(y_te, y_te_pred_xgb_lr))


# # Make predictions on the validation set
# y_pred = final_model.predict(X_te)

# # Evaluate the model on the validation set
# mae = mean_absolute_error(y_te, y_pred)
# print(f'Mean Absolute Error on Validation Set: {mae}')

# %%
param_space =  {
    'max_features': Categorical(['sqrt', 'log2']),
    'n_estimators': np.arange(50, 2001, 50),
    'bootstrap': Categorical([True, False]),
    'max_depth': np.arange(1, 20),
    'min_samples_leaf': np.arange(1, 20),
    'criterion': Categorical(['squared_error', 'absolute_error', 'friedman_mse', 'poisson'])
}
# Define the LGBMRegressor model
rf_model = RandomForestRegressor(random_state=101)

# Create a Bayesian optimization object
opt = BayesSearchCV(
    rf_model,
    param_space,
    n_iter=100,  # Adjust the number of iterations based on your computational resources
    cv=3,  # Adjust the number of cross-validation folds
    scoring='neg_mean_absolute_error',  # Use a suitable regression metric
    n_jobs=-1,
)

# Perform Bayesian optimization
opt.fit(X_t, y_t)

# Get the best hyperparameters
best_params = opt.best_params_
print(opt.best_estimator_)

# %%
# Train the final model with the best hyperparameters
final_model = RandomForestRegressor(**best_params, random_state=101)
final_model.fit(X_t, y_t)

print("With RF Pred")
y_t_pred = final_model.predict(X_t)
print(mean_absolute_error(y_t, y_t_pred))

y_te_pred = final_model.predict(X_te)
print(mean_absolute_error(y_te, y_te_pred))

print("---------------")

onehot = OneHotEncoder()
X_t_leaves = onehot.fit_transform(final_model.apply(X_t))
xgb_lr = LogisticRegression()
xgb_lr.fit(X_t_leaves, y_t)

print("With XGB + LR Pred")
X_t_leaves = onehot.transform(final_model.apply(X_t))
y_t_pred_xgb_lr = xgb_lr.predict(X_t_leaves)
print(mean_absolute_error(y_t, y_t_pred_xgb_lr))

X_te_leaves = onehot.transform(final_model.apply(X_te))
y_te_pred_xgb_lr = xgb_lr.predict(X_te_leaves)
print(mean_absolute_error(y_te, y_te_pred_xgb_lr))

# %%
param_space = {
    'learning_rate': np.arange(0.01, 1.0, 0.01),
    'n_estimators': np.arange(50, 2001, 50),
    'max_depth': np.arange(1, 200),
    'min_samples_split': np.arange(2, 11, 1),
    'min_samples_leaf': np.arange(1, 10),
    'subsample': np.arange(0.1, 1.0, 0.1),
}
# Define the LGBMRegressor model
gb_model = GradientBoostingRegressor(random_state=101)

# Create a Bayesian optimization object
opt = BayesSearchCV(
    gb_model,
    param_space,
    n_iter=100,  # Adjust the number of iterations based on your computational resources
    cv=3,  # Adjust the number of cross-validation folds
    scoring='neg_mean_absolute_error',  # Use a suitable regression metric
    n_jobs=-1,
)

# Perform Bayesian optimization
opt.fit(X_t, y_t)

# Get the best hyperparameters
best_params = opt.best_params_
print(opt.best_estimator_)

# %%
final_model = GradientBoostingRegressor(**best_params, random_state=101)
final_model.fit(X_t, y_t)

print("With GB Pred")
y_t_pred = final_model.predict(X_t)
print(mean_absolute_error(y_t, y_t_pred))

y_te_pred = final_model.predict(X_te)
print(mean_absolute_error(y_te, y_te_pred))

print("---------------")

onehot = OneHotEncoder()
X_t_leaves = onehot.fit_transform(final_model.apply(X_t))
xgb_lr = LogisticRegression()
xgb_lr.fit(X_t_leaves, y_t)

print("With XGB + LR Pred")
X_t_leaves = onehot.transform(final_model.apply(X_t))
y_t_pred_xgb_lr = xgb_lr.predict(X_t_leaves)
print(mean_absolute_error(y_t, y_t_pred_xgb_lr))

X_te_leaves = onehot.transform(final_model.apply(X_te))
y_te_pred_xgb_lr = xgb_lr.predict(X_te_leaves)
print(mean_absolute_error(y_te, y_te_pred_xgb_lr))

# %%
def set_randomstate(model):
    current_params = model.get_params()

    # Update the random_state if it exists, otherwise add it to the parameters
    current_params['random_state'] = 101

    # Set the modified parameters back to the model
    model.set_params(**current_params)
    return model

kf = KFold(n_splits=5, shuffle=True, random_state=101)
models = {
    # 'Linear Regression': LinearRegression(),
    # 'Lasso': LassoCV(cv=kf, random_state=42, max_iter=200000),
    # 'Logistic': LogisticRegression(),
    # 'KNN': pd.read_pickle("result_KNN.pkl")['estimator'],
    'XGB': set_randomstate(pd.read_pickle("result_XGB.pkl")['estimator']),
    'LGBM': set_randomstate(pd.read_pickle("result_LGBM.pkl")['estimator']),
    # 'Ridge': RidgeCV(cv=kf),
    # 'SVR': pd.read_pickle("result_SVR.pkl")['estimator'],
    # 'Random Forest': RandomForestRegressor(bootstrap=False, max_depth=15, max_features=0.7,
    #                   min_samples_leaf=9, n_estimators=200, random_state=101),
    # 'Gradient Boosting': GradientBoostingRegressor(learning_rate=0.01, max_depth=14, min_samples_leaf=3,
    #                       min_samples_split=4, n_estimators=950, random_state=101, subsample=0.8),
    # 'Artificial Neural Network': MLPRegressor(activation='logistic', alpha=0.01, hidden_layer_sizes=(50, 50),
    #          max_iter=4000, random_state=101),
    # 'Gaussian Process Regression': GaussianProcessRegressor(0.1 ** 2 * RBF(length_scale=0.1) + WhiteKernel(noise_level=0.1 ** 2, noise_level_bounds=(1e-5, 1e5)))
}

# %%
# Function to train and evaluate models
def evaluate_models(models, X_train, y_train):
    results = {}
    for name, model in models.items():
        scoring=['neg_mean_absolute_error','neg_mean_squared_error']
        # Define the cross-validation strategy (e.g., 5-fold cross-validation)
        kf = KFold(n_splits=5, shuffle=True, random_state=101)

        # Perform k-fold cross-validation and calculate MSE and MAE
        scores = cross_validate(model, X_train, y_train, cv=kf, scoring=scoring, n_jobs=-1)

        mean_mae = -scores['test_neg_mean_absolute_error'].mean()
        mean_mse = -scores['test_neg_mean_squared_error'].mean()
        std_mse = scores['test_neg_mean_squared_error'].std()

        print(name + " done")
        print(mean_mae, mean_mse, std_mse)
        results[name] = {'MAE': mean_mae, 'MSE': mean_mse, 'MSE_std': std_mse}
    
    return results

# Train and evaluate
results = evaluate_models(models, X_t, y_t)

# %%
def model_lr_evaluation(models, X_train, y_train, X_test, y_test):
    results = {}
    scoring=['neg_mean_absolute_error','neg_mean_squared_error']

    for name, model in models.items():
        final_model = model
        
        scores = cross_validate(model, X_train, y_train, cv=3, scoring=scoring, n_jobs=-1)
        mean_mae = -scores['test_neg_mean_absolute_error'].mean()
        mean_mse = -scores['test_neg_mean_squared_error'].mean()
        std_mse = scores['test_neg_mean_squared_error'].std()
        print(name + " done")
        print(mean_mae, mean_mse, std_mse)
        
        final_model.fit(X_train, y_train)
        y_te_pred = final_model.predict(X_test)
        print(mean_absolute_error(y_test, y_te_pred), mean_squared_error(y_test, y_te_pred))
        
        print("---------------")
        
        onehot = OneHotEncoder()
        if name == 'LGBM':
            X_t_leaves = onehot.fit_transform(final_model.predict(X_train, pred_leaf=True))
        elif name == 'XGB':
            X_t_leaves = onehot.fit_transform(final_model.apply(X_train))
        xgb_lr = LogisticRegression()
        xgb_lr.fit(X_t_leaves, y_train)

        if name == 'LGBM':
            X_t_leaves = onehot.transform(final_model.predict(X_train, pred_leaf=True))
            X_te_leaves = onehot.transform(final_model.predict(X_test, pred_leaf=True))
        elif name == 'XGB':
            X_t_leaves = onehot.transform(final_model.apply(X_train))
            X_te_leaves = onehot.transform(final_model.apply(X_test))

        scores = cross_validate(model, X_t_leaves, y_train, cv=kf, scoring=scoring, n_jobs=-1)
        mean_mae = -scores['test_neg_mean_absolute_error'].mean()
        mean_mse = -scores['test_neg_mean_squared_error'].mean()
        std_mse = scores['test_neg_mean_squared_error'].std()
        print(mean_mae, mean_mse, std_mse) 
        
        y_te_pred_xgb_lr = xgb_lr.predict(X_te_leaves)
        print(mean_absolute_error(y_test, y_te_pred_xgb_lr), mean_squared_error(y_test, y_te_pred_xgb_lr))

model_lr_evaluation(models, X_t, y_t, X_te, y_te)

# %%
def evaluate_models_with_test(model, X_train, y_train, X_test, y_test):
    results = {}
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)      
    results = {'MAE': mae, 'MSE': mse}
    
    return results

# %%
import pickle

result_final_with_test = {}
for name, model in models.items():
    result_final_with_test[name] = evaluate_models_with_test(model, X_t, y_t, X_te, y_te)

result_final_with_test

# %%
train_data_0 = train_data[train_data['clusters']==0]
train_data_1 = train_data[train_data['clusters']==1]
validate_data_0 = validate_data[validate_data['clusters']==0]
validate_data_1 = validate_data[validate_data['clusters']==1]
test_data_0 = test_data[test_data['clusters']==0]
test_data_1 = test_data[test_data['clusters']==1]
test_data_2 = test_data[test_data['clusters']==2]
test_data_1 = pd.concat([test_data_1, test_data_2], ignore_index=True)

import matplotlib.pyplot as plt

# Assuming you have three DataFrames: df1, df2, and df3

# Plotting DataFrame 1 in red
plt.plot(train_data_0['start_node_x'], train_data_0['start_node_y'], 'ro-', label='DF1 Start')
plt.plot(train_data_0['end_node_x'], train_data_0['end_node_y'], 'ro-', label='DF1 End')

# Plotting DataFrame 2 in green
plt.plot(train_data_1['start_node_x'], train_data_1['start_node_y'], 'go-', label='DF2 Start')
plt.plot(train_data_1['end_node_x'], train_data_1['end_node_y'], 'go-', label='DF2 End')

# Plotting DataFrame 3 in blue
plt.plot(validate_data_0['start_node_x'], validate_data_0['start_node_y'], 'bo-', label='DF3 Start')
plt.plot(validate_data_0['end_node_x'], validate_data_0['end_node_y'], 'bo-', label='DF3 End')
plt.plot(validate_data_1['start_node_x'], validate_data_1['start_node_y'], 'yo-', label='DF4 Start')
plt.plot(validate_data_1['end_node_x'], validate_data_1['end_node_y'], 'yo-', label='DF4 End')

plt.plot(test_data_0['start_node_x'], test_data_0['start_node_y'], 'co-', label='DF5 Start')
plt.plot(test_data_0['end_node_x'], test_data_0['end_node_y'], 'co-', label='DF5 End')
plt.plot(test_data_1['start_node_x'], test_data_1['start_node_y'], 'mo-', label='DF6 Start')
plt.plot(test_data_1['end_node_x'], test_data_1['end_node_y'], 'mo-', label='DF6 End')
# plt.plot(test_data_2['start_node_x'], test_data_2['start_node_y'], 'ko-', label='DF7 Start')
# plt.plot(test_data_2['end_node_x'], test_data_2['end_node_y'], 'ko-', label='DF7 End')
# Add labels and legend
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()

# Show the plot
plt.show()
